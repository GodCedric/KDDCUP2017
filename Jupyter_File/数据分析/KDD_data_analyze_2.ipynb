# %% [markdown]
# # KDD_data_analyze_2

# %% [markdown]
# 2017-05-24

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
travel_time_raw_data = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/待加工数据集/数据提取与合并/travel_time_raw_data.csv')
volume_raw_data = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/待加工数据集/数据提取与合并/volume_raw_data.csv')
test_time_raw_data = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/待加工数据集/数据提取与合并/test_travel_time_feature_ffill.csv')
test_volume_raw_data = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/待加工数据集/数据提取与合并/test_volume_feature_ffill.csv')

# %% [markdown]
# ### last关系分析

# %%
# 平均流量与路线 直方图
fig = plt.figure()
fig.set_figheight(15)
fig.set_figwidth(20)
dic = {0:'last_20min', 1:'last_40min', 2:'last_60min', 3:'last_80min', 4:'last_100min', 5:'last_120min'}
for k in range(6):
    ax = fig.add_subplot(3,2,k+1)
    col = dic[k]
    delta = travel_time_raw_data['avg_travel_time'] - travel_time_raw_data[col]
    delta = np.abs(delta20.dropna())  
    ax.hist(delta, bins=100, alpha=0.6, color='k')
    #ax.set_xlim([0, 500])
    #ax.set_ylim([0, 1300])

# %%
delta20 = travel_time_raw_data['avg_travel_time'] - travel_time_raw_data['last_20min']
delta20 = np.abs(delta20.dropna())
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.hist(delta20, bins=100, alpha=0.6, color='k')
# Out:
# (array([  2.30500000e+03,   2.27700000e+03,   2.04100000e+03,
#           1.88300000e+03,   1.61600000e+03,   1.41900000e+03,
#           1.11500000e+03,   1.05200000e+03,   8.72000000e+02,
#           7.46000000e+02,   6.23000000e+02,   5.55000000e+02,
#           4.54000000e+02,   4.07000000e+02,   3.44000000e+02,
#           2.98000000e+02,   2.67000000e+02,   2.33000000e+02,
#           2.13000000e+02,   1.73000000e+02,   1.55000000e+02,
#           1.32000000e+02,   1.13000000e+02,   1.11000000e+02,
#           9.90000000e+01,   9.00000000e+01,   7.10000000e+01,
#           5.80000000e+01,   6.50000000e+01,   5.20000000e+01,
#           6.00000000e+01,   5.00000000e+01,   3.60000000e+01,
#           3.40000000e+01,   2.90000000e+01,   2.40000000e+01,
#           3.30000000e+01,   2.40000000e+01,   2.20000000e+01,
#           1.90000000e+01,   1.70000000e+01,   1.50000000e+01,
#           8.00000000e+00,   1.20000000e+01,   1.40000000e+01,
# ...

# %%
delta20.describe()
# Out:
# count    20369.000000
# mean        29.446379
# std         32.237252
# min          0.000000
# 25%          8.660000
# 50%         19.530000
# 75%         38.530000
# max        387.650000
# dtype: float64

# %%
delta40 = travel_time_raw_data['avg_travel_time'] - travel_time_raw_data['last_40min']
delta40 = np.abs(delta40.dropna())
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.hist(delta40, bins=100, alpha=0.6, color='k')
# Out:
# (array([  2.35800000e+03,   2.18400000e+03,   2.05200000e+03,
#           1.86100000e+03,   1.59500000e+03,   1.36800000e+03,
#           1.18200000e+03,   9.75000000e+02,   8.69000000e+02,
#           7.51000000e+02,   6.25000000e+02,   5.27000000e+02,
#           4.95000000e+02,   3.94000000e+02,   3.69000000e+02,
#           2.98000000e+02,   2.70000000e+02,   2.18000000e+02,
#           2.27000000e+02,   1.78000000e+02,   1.79000000e+02,
#           1.29000000e+02,   1.21000000e+02,   9.20000000e+01,
#           1.12000000e+02,   7.80000000e+01,   7.50000000e+01,
#           6.20000000e+01,   5.30000000e+01,   5.40000000e+01,
#           5.20000000e+01,   4.50000000e+01,   3.90000000e+01,
#           4.00000000e+01,   3.10000000e+01,   3.20000000e+01,
#           1.70000000e+01,   2.00000000e+01,   2.90000000e+01,
#           2.50000000e+01,   1.50000000e+01,   1.40000000e+01,
#           1.90000000e+01,   9.00000000e+00,   1.30000000e+01,
# ...
