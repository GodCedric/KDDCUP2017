# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### extract data

# %%
travel_time_raw_data = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/待加工数据集/数据提取与合并/travel_time_raw_data.csv')
volume_raw_data = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/待加工数据集/数据提取与合并/volume_raw_data.csv')
test_time_raw_data = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/待加工数据集/数据提取与合并/test_travel_time_feature_ffill.csv')
test_volume_raw_data = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/待加工数据集/数据提取与合并/test_volume_feature_ffill.csv')

# %%
volume_raw_data.describe()
# Out:
#         tollgate_id     direction        volume           etc      pressure  \
# count  10063.000000  10063.000000  10063.000000  10063.000000  10063.000000
# mean       2.000298      0.414290     54.029514     11.963232   1010.930071
# std        0.910363      0.492623     46.801792     11.346840      3.888292
# min        1.000000      0.000000      1.000000      0.000000   1003.000000
# 25%        1.000000      0.000000     14.000000      2.000000   1007.500000
# 50%        2.000000      0.000000     40.000000      9.000000   1011.100000
# 75%        3.000000      1.000000     88.000000     19.000000   1014.500000
# max        3.000000      1.000000    296.000000     74.000000   1018.400000
#
#        sea_pressure  wind_direction    wind_speed   temperature  rel_humidity  \
# count  10063.000000    10063.000000  10063.000000  10063.000000  10063.000000
# mean    1015.927219     8617.052768      2.485342     22.247153     78.953095
# ...

# %% [markdown]
# ### clean data

# %%
travel_time_clean_data = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/待加工数据集/清洗过的数据/travel_time_clean_data_ffill.csv')
volume_clean_data = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/待加工数据集/清洗过的数据/volume_clean_data_ffill.csv')

# %%
volume_clean_data.describe()
# Out:
#        tollgate_id    direction       volume          etc     pressure  \
# count   8124.00000  8124.000000  8124.000000  8124.000000  8124.000000
# mean       2.06967     0.389833    57.564746    13.391187  1011.411989
# std        0.91040     0.487742    42.834802    11.906520     3.960636
# min        1.00000     0.000000     1.000000     0.000000  1003.000000
# 25%        1.00000     0.000000    18.000000     3.000000  1007.800000
# 50%        2.00000     0.000000    50.000000    11.000000  1012.200000
# 75%        3.00000     1.000000    91.000000    21.000000  1014.500000
# max        3.00000     1.000000   296.000000    74.000000  1018.400000
#
#        sea_pressure  wind_direction   wind_speed  temperature  rel_humidity  \
# count   8124.000000     8124.000000  8124.000000  8124.000000   8124.000000
# mean    1016.414980      180.365707     2.567134    21.963097     78.269325
# std        4.017811      139.407491     1.319596     3.654239     13.661310
# ...

# %% [markdown]
# ### train data

# %%
travel_time_data = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/加工过的数据集/3.0/travel_time_train_data.csv')
volume_data = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/加工过的数据集/3.0/volume_train_data.csv')
test1 = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/加工过的数据集/3.0/test_travel_time_data.csv')
test2 = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/加工过的数据集/3.0/test_volume_data.csv')

# %%
volume_data.columns
# Out:
# Index(['volume', 'pair', 'tollgate_id', 'direction', 'time_window',
#        'start_time', 'date', 'time', 'hour', 'minute', 'weekday', 'timemap',
#        'pressure', 'wind_direction', 'wind_speed', 'temperature',
#        'rel_humidity', 'precipitation', 'last_20min', 'last_40min',
#        'last_60min', 'last_80min', 'last_100min', 'last_120min',
#        'wind_direction2', 'wind_speed2', 'precipitation2', 'SSD', 'SSD_level',
#        'is_workday', 'datemap', '1-0', '1-1', '2-0', '3-0', '3-1', 'hour__0',
#        'hour__1', 'hour__2', 'hour__3', 'hour__4', 'hour__5', 'hour__6',
#        'hour__7', 'hour__8', 'hour__9', 'hour__10', 'hour__11', 'hour__12',
#        'hour__13', 'hour__14', 'hour__15', 'hour__16', 'hour__17', 'hour__18',
#        'hour__19', 'hour__20', 'hour__21', 'hour__22', 'hour__23', 'minute__0',
#        'minute__20', 'minute__40', 'weekday__0', 'weekday__1', 'weekday__2',
#        'weekday__3', 'weekday__4', 'weekday__5', 'weekday__6', 'workday__1',
# ...

# %%
test2.columns.values
# Out:
# array(['pair', 'tollgate_id', 'direction', 'time_window', 'start_time',
#        'date', 'time', 'hour', 'minute', 'weekday', 'timemap', 'pressure',
#        'wind_direction', 'wind_speed', 'temperature', 'rel_humidity',
#        'precipitation', 'last_20min', 'last_40min', 'last_60min',
#        'last_80min', 'last_100min', 'last_120min', 'wind_direction2',
#        'wind_speed2', 'precipitation2', 'SSD', 'SSD_level', 'is_workday',
#        'datemap', '1-0', '1-1', '2-0', '3-0', '3-1', 'hour__0', 'hour__1',
#        'hour__2', 'hour__3', 'hour__4', 'hour__5', 'hour__6', 'hour__7',
#        'hour__8', 'hour__9', 'hour__10', 'hour__11', 'hour__12',
#        'hour__13', 'hour__14', 'hour__15', 'hour__16', 'hour__17',
#        'hour__18', 'hour__19', 'hour__20', 'hour__21', 'hour__22',
#        'hour__23', 'minute__0', 'minute__20', 'minute__40', 'weekday__0',
#        'weekday__1', 'weekday__2', 'weekday__3', 'weekday__4',
# ...
