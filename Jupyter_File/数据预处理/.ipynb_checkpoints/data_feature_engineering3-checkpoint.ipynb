# %% [markdown]
# # data_feature_engineering3

# %% [markdown]
# 2017-05-19

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from datetime import datetime,timedelta,date,time
from sklearn.cross_validation import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
import copy

# %% [markdown]
# ### 录入数据

# %%
travel_time_window = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/final_data/时间窗数据/train_20min_avg_travel_time.csv')
volume_window = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/final_data/时间窗数据/train_20min_avg_volume.csv')
weather_data = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/final_data/原始数据/weather_train.csv')

test_travel_time_window = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/final_data/时间窗数据/test_20min_avg_travel_time.csv')
test_volume_window = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/final_data/时间窗数据/test_20min_avg_volume.csv')
test_weather_data = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/final_data/原始数据/weather_test.csv')

# %% [markdown]
# ### 9.19后全时段数据

# %%
# 先形成全时段数据
time_full_time = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/pyscripts/analyze/full_time1.csv')
volume_full_time = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/pyscripts/analyze/full_time2.csv')

travel_time_window = pd.merge(time_full_time, travel_time_window, on=['intersection_id','tollgate_id','time_window'], how='outer')
volume_window = pd.merge(volume_full_time, volume_window, on=['tollgate_id','direction','time_window'], how='outer')

# %% [markdown]
# ### 补充特征

# %%
# 整合平均时间与天气数据
travel_time_window['start_time'] = travel_time_window['time_window'].map(lambda x: datetime.strptime(x.split(',')[0][1:], '%Y-%m-%d %H:%M:%S'))
weather_data['date'] = weather_data['date'].astype(str)
weather_data['hour'] = weather_data['hour'].map(lambda x: ' ' + time(x, 0, 0).strftime('%H:%M:%S'))
weather_data['start_time'] = weather_data['date'] + weather_data['hour']
weather_data['start_time'] = weather_data['start_time'].map(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M:%S'))
del weather_data['date']
del weather_data['hour']
num = len(weather_data)
for i in range(num):
    temp = weather_data.ix[i]
    temp1 = copy.deepcopy(temp)
    temp2 = copy.deepcopy(temp)
    temp3 = copy.deepcopy(temp)
    temp4 = copy.deepcopy(temp)
    temp5 = copy.deepcopy(temp)
    temp6 = copy.deepcopy(temp)
    temp7 = copy.deepcopy(temp)
    temp8 = copy.deepcopy(temp)
    stime = temp.start_time
    temp1.start_time = stime + timedelta(minutes=20)
    temp2.start_time = stime + timedelta(minutes=40)
    temp3.start_time = stime + timedelta(minutes=60)
    temp4.start_time = stime + timedelta(minutes=80)
    temp5.start_time = stime + timedelta(minutes=100)
    temp6.start_time = stime + timedelta(minutes=120)
    temp7.start_time = stime + timedelta(minutes=140)
    temp8.start_time = stime + timedelta(minutes=160)
    alltemp = [temp1, temp2, temp3, temp4, temp5, temp6, temp7, temp8]
    alltemp = pd.DataFrame(alltemp)
    weather_data = pd.concat([weather_data, alltemp])
# 合并
travel_time_window = pd.merge(travel_time_window, weather_data, on='start_time', how='left')
travel_time_window['time'] = travel_time_window['start_time'].map(lambda x: x.time())
travel_time_window['date'] = travel_time_window['start_time'].map(lambda x: x.date())

# 整合流量与天气数据
volume_window['start_time'] = volume_window['time_window'].map(lambda x: datetime.strptime(x.split(',')[0][1:],'%Y-%m-%d %H:%M:%S'))
volume_window['pair'] = volume_window['tollgate_id'].astype(str) + '-' + volume_window['direction'].astype(str)
volume_window = pd.merge(volume_window, weather_data, on='start_time', how='left')

# %%
# 增加路线和星期几，小时，分钟
travel_time_window['weekday'] = travel_time_window['start_time'].map(lambda x: x.weekday())
travel_time_window['hour'] = travel_time_window['start_time'].map(lambda x: x.hour)
travel_time_window['minute'] = travel_time_window['start_time'].map(lambda x: x.minute)
travel_time_window['route'] = travel_time_window['intersection_id'].astype(str) + '-' + travel_time_window['tollgate_id'].astype(str)

# 增加星期几和时间窗口两列
volume_window['date'] = volume_window['start_time'].map(lambda x: x.date())
volume_window['weekday'] = volume_window['start_time'].map(lambda x: x.weekday())
volume_window['time'] = volume_window['start_time'].map(lambda x: x.time())
volume_window['hour'] = volume_window['start_time'].map(lambda x: x.hour)
volume_window['minute'] = volume_window['start_time'].map(lambda x: x.minute)

# %%
# 增加月份和几号
travel_time_window['month'] = travel_time_window['date'].map(lambda x: x.month)
travel_time_window['day'] = travel_time_window['date'].map(lambda x: x.day)

volume_window['month'] = volume_window['date'].map(lambda x: x.month)
volume_window['day'] = volume_window['date'].map(lambda x: x.day)

# %%
# 把time映射成1～72
from collections import defaultdict
time_start = datetime(2016,10,17,0,0,0)
timedic = defaultdict(int)
for i in range(72):
    timedic[time_start.time()] = i+1
    time_start = time_start + timedelta(minutes=20)
travel_time_window['timemap'] = travel_time_window['time'].map(lambda x:timedic[x])

# 时间映射成1～72
volume_window['timemap'] = volume_window['time'].map(lambda x:timedic[x])

# %%
# 增加法定节假日特征
#holiday = ['2016-09-15','2016-09-16','2016-09-17','2016-10-01','2016-10-02','2016-10-03','2016-10-04','2016-10-05','2016-10-06','2016-10-07']
holiday = [date(2016,9,15),date(2016,9,16),date(2016,9,17),date(2016,10,1),date(2016,10,2),date(2016,10,3),date(2016,10,4),date(2016,10,5),date(2016,10,6),date(2016,10,7)]

def ff(x):
    if x in holiday:
        return 1
    else:
        return 0
travel_time_window['holiday'] = travel_time_window['date'].map(ff)

volume_window['holiday'] = volume_window['date'].map(ff)

# %% [markdown]
# ### 排序

# %%
time_columns = ['avg_travel_time', 
                'route', 'intersection_id', 'tollgate_id', 
                'time_window', 'start_time', 
                'date', 'month', 'day', 'weekday', 'holiday',
                'time', 'hour', 'minute', 'timemap',
                'pressure', 'sea_pressure', 'wind_direction', 'wind_speed', 'temperature', 'rel_humidity', 'precipitation', 
                 ]

volume_columns = ['volume',
                  'pair', 'tollgate_id', 'direction',
                  'time_window', 'start_time',
                  'date', 'month', 'day', 'weekday', 'holiday',
                  'time', 'hour', 'minute', 'timemap',
                  'pressure', 'sea_pressure', 'wind_direction', 'wind_speed', 'temperature', 'rel_humidity', 'precipitation', 
                  ]

travel_time_window = travel_time_window[time_columns]
volume_window = volume_window[volume_columns]

travel_time_window = travel_time_window.sort_values(by=['route', 'start_time'])
travel_time_window.index = np.arange(len(travel_time_window))

volume_window = volume_window.sort_values(by=['pair', 'start_time'])
volume_window.index = np.arange(len(volume_window))

# %% [markdown]
# ### 清洗数据

# %%
# 异常样本删除（最大的1%的平均时间的样本删除）
def ff(df):
    df = df.sort(['avg_travel_time'], ascending=False)
    num_sample = len(df)
    num_delete = round(0.01 * num_sample)
    temp_df = df.iloc[num_delete:]
    temp_df = temp_df.sort_values(by='start_time')
    return temp_df

def ff2(df):
    df = df.sort(['volume'], ascending=False)
    num_sample = len(df)
    num_delete = round(0.01 * num_sample)
    temp_df = df.iloc[num_delete:]
    temp_df = temp_df.sort_values(by='volume')
    return temp_df

travel_time_window = travel_time_window.groupby('route').apply(ff)

volume_window = volume_window.groupby('pair').apply(ff2)
# Out:
# /home/godcedric/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()
# /home/godcedric/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:11: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
# 风向异常值处理，以最近的风向值代替
wind_direction = travel_time_window['wind_direction']
wind_direction[wind_direction > 360] = np.nan
wind_direction.fillna(method='ffill', inplace=True)

wind_direction = volume_window['wind_direction']
wind_direction[wind_direction > 360] = np.nan
wind_direction.fillna(method='ffill', inplace=True)
# Out:
# /home/godcedric/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/godcedric/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# 流量节假日数据清除
#volume_window = volume_window[volume_window['holiday'] == 0]

# %% [markdown]
# ### xgboost补充9.19之后的缺失值

# %%
travel_time_window = travel_time_window.sort_values(by=['route','start_time'])
travel_time_window.index = np.arange(len(travel_time_window))
volume_window = volume_window.sort_values(by=['pair','start_time'])
volume_window.index = np.arange(len(volume_window))

# %%
# 分割训练集和测试集
time_train_data = travel_time_window.loc[travel_time_window['avg_travel_time'].notnull()]
time_test_data = travel_time_window.loc[travel_time_window['avg_travel_time'].isnull()]

volume_train_data = volume_window.loc[volume_window['volume'].notnull()]
volume_test_data = volume_window.loc[volume_window['volume'].isnull()]

# %%
temp_time_train = time_train_data[['avg_travel_time', 'route', 
                                   'month', 'day', 'weekday', 'holiday', 'timemap', 
                                   'pressure', 'wind_direction', 'wind_speed', 'temperature', 'rel_humidity', 'precipitation']]
temp_time_test = time_test_data[['route', 
                                 'month', 'day', 'weekday', 'holiday', 'timemap', 
                                 'pressure', 'wind_direction', 'wind_speed', 'temperature', 'rel_humidity', 'precipitation']]
temp_volume_train = volume_train_data[['volume', 'pair', 
                                       'month', 'day', 'weekday', 'holiday', 'timemap', 
                                       'pressure', 'wind_direction', 'wind_speed', 'temperature', 'rel_humidity', 'precipitation']]
temp_volume_test = volume_test_data[['pair', 
                                     'month', 'day', 'weekday', 'holiday', 'timemap', 
                                     'pressure', 'wind_direction', 'wind_speed', 'temperature', 'rel_humidity', 'precipitation']]

# %%
# 分割路径，对
A2_train = temp_time_train[temp_time_train['route'] == 'A-2']
A3_train = temp_time_train[temp_time_train['route'] == 'A-3']
B1_train = temp_time_train[temp_time_train['route'] == 'B-1']
B3_train = temp_time_train[temp_time_train['route'] == 'B-3']
C1_train = temp_time_train[temp_time_train['route'] == 'C-1']
C3_train = temp_time_train[temp_time_train['route'] == 'C-3']

A2_test = temp_time_test[temp_time_test['route'] == 'A-2']
A3_test = temp_time_test[temp_time_test['route'] == 'A-3']
B1_test = temp_time_test[temp_time_test['route'] == 'B-1']
B3_test = temp_time_test[temp_time_test['route'] == 'B-3']
C1_test = temp_time_test[temp_time_test['route'] == 'C-1']
C3_test = temp_time_test[temp_time_test['route'] == 'C-3']

V10_train =  temp_volume_train[temp_volume_train['pair'] == '1-0']
V11_train =  temp_volume_train[temp_volume_train['pair'] == '1-1']
V20_train =  temp_volume_train[temp_volume_train['pair'] == '2-0']
V30_train =  temp_volume_train[temp_volume_train['pair'] == '3-0']
V31_train =  temp_volume_train[temp_volume_train['pair'] == '3-1']

V10_test =  temp_volume_test[temp_volume_test['pair'] == '1-0']
V11_test =  temp_volume_test[temp_volume_test['pair'] == '1-1']
V20_test =  temp_volume_test[temp_volume_test['pair'] == '2-0']
V30_test =  temp_volume_test[temp_volume_test['pair'] == '3-0']
V31_test =  temp_volume_test[temp_volume_test['pair'] == '3-1']

# %%
del A2_train['route']
del A3_train['route']
del B1_train['route']
del B3_train['route']
del C1_train['route']
del C3_train['route']

del A2_test['route']
del A3_test['route']
del B1_test['route']
del B3_test['route']
del C1_test['route']
del C3_test['route']

del V10_train['pair']
del V11_train['pair']
del V20_train['pair']
del V30_train['pair']
del V31_train['pair']

del V10_test['pair']
del V11_test['pair']
del V20_test['pair']
del V30_test['pair']
del V31_test['pair']

# %%
# 自定义评价函数
def MAPE(preds, dtrain):
    labels = dtrain.get_label()
    return 'MAPE', float(sum(np.fabs((labels - preds) / labels))) / len(labels)

# %% [markdown]
# #### A2

# %%
## 训练预测
# 分割训练集和验证集
ll = round(len(A2_train)/5)
A2_train_val = A2_train.iloc[(len(A2_train)-ll):len(A2_train)]
A2_train_t = A2_train.iloc[:(len(A2_train)-ll)]

# 分离标签和特征
Y_time = A2_train_t['avg_travel_time']
X_time = A2_train_t.drop(['avg_travel_time'], axis=1)
val_Y_time = A2_train_val.avg_travel_time
val_X_time = A2_train_val.drop(['avg_travel_time'], axis=1)

# 转化格式
time_train = xgb.DMatrix(X_time, label=Y_time)
time_val = xgb.DMatrix(val_X_time, label=val_Y_time)
time_test = xgb.DMatrix(A2_test)

#参数设置
params = {
    'booster':'gbtree',      #gbtree和gblinear
    'objective':'reg:linear',
    'eta':0.04,             #为了防止过拟合，更新过程中用到的收缩步长。在每次提升计算之后，算法会直接获得新特征的权重。eta通过缩减特征的权重使提升计算过程更加保守。缺省值为0.3,通常最后设置eta为0.01~0.2
    #'gamma':0.3,            #模型在默认情况下，对于一个节点的划分只有在其loss function得到结果大于0的情况下才进行，而gamma 给定了所需的最低loss function的值gamma值使得算法更conservation，且其值依赖于loss function ，
    'max_depth':5,          #树的深度越大，则对数据的拟合程度越高（过拟合程度也越高）。即该参数也是控制过拟合,建议通过交叉验证（xgb.cv ) 进行调参,通常取值：3-10
    #'min_child_weight':2,   #孩子节点中最小的样本权重和。如果一个叶子节点的样本权重和小于min_child_weight则拆分过程结束。在现行回归模型中，这个参数是指建立每个模型所需要的最小样本数。该成熟越大算法越conservative。即调大这个参数能够控制过拟合。
    #'max_delta_step':2,     #如果取值为0，那么意味着无限制。如果取为正数，则其使得xgboost更新过程更加保守。
    'subsample':1,          #用于训练模型的子样本占整个样本集合的比例。如果设置为0.5则意味着XGBoost将随机的从整个样本集合中抽取出50%的子样本建立树模型，这能够防止过拟合。
    'colsample_bytree':1,   #在建立树时对特征随机采样的比例。缺省值为1 
    #'alpha':5,              #L1 正则的惩罚系数,当数据维度极高时可以使用，使得算法运行更快。
    #'lambda':40,           #L2 正则的惩罚系数,用于处理XGBoost的正则化部分。通常不使用，但可以用来降低过拟合
    'seed':2017,
}


plst = list(params.items())
num_rounds = 64
watchlist = [(time_train, 'train'), (time_val, 'val')]

A2time_model = xgb.train(plst, time_train, num_rounds, watchlist, feval=MAPE)
print("best best_ntree_limit", A2time_model.best_ntree_limit)

A2time_predict = A2time_model.predict(time_test)
# Out:
# [0]	train-rmse:63.1273	val-rmse:62.1259	train-MAPE:0.948307	val-MAPE:0.950797
# [1]	train-rmse:60.8265	val-rmse:59.9152	train-MAPE:0.907115	val-MAPE:0.912065
# [2]	train-rmse:58.6255	val-rmse:57.7882	train-MAPE:0.867572	val-MAPE:0.874549
# [3]	train-rmse:56.5211	val-rmse:55.7821	train-MAPE:0.829593	val-MAPE:0.839352
# [4]	train-rmse:54.5085	val-rmse:53.8477	train-MAPE:0.793194	val-MAPE:0.805253
# [5]	train-rmse:52.5839	val-rmse:51.9626	train-MAPE:0.758419	val-MAPE:0.771411
# [6]	train-rmse:50.7454	val-rmse:50.1594	train-MAPE:0.72508	val-MAPE:0.739024
# [7]	train-rmse:48.9886	val-rmse:48.4341	train-MAPE:0.69322	val-MAPE:0.708041
# [8]	train-rmse:47.3098	val-rmse:46.7325	train-MAPE:0.662899	val-MAPE:0.677586
# [9]	train-rmse:45.7061	val-rmse:45.2035	train-MAPE:0.634021	val-MAPE:0.649686
# [10]	train-rmse:44.175	val-rmse:43.754	train-MAPE:0.606514	val-MAPE:0.623284
# [11]	train-rmse:42.7144	val-rmse:42.2428	train-MAPE:0.580257	val-MAPE:0.595933
# [12]	train-rmse:41.3202	val-rmse:40.8641	train-MAPE:0.555267	val-MAPE:0.570635
# [13]	train-rmse:39.9929	val-rmse:39.6427	train-MAPE:0.531441	val-MAPE:0.548389
# [14]	train-rmse:38.7287	val-rmse:38.5564	train-MAPE:0.508651	val-MAPE:0.528078
# [15]	train-rmse:37.5237	val-rmse:37.3205	train-MAPE:0.486954	val-MAPE:0.505527
# [16]	train-rmse:36.3783	val-rmse:36.3363	train-MAPE:0.466201	val-MAPE:0.486858
# [17]	train-rmse:35.2875	val-rmse:35.2137	train-MAPE:0.44652	val-MAPE:0.466389
# [18]	train-rmse:34.2504	val-rmse:34.2264	train-MAPE:0.427731	val-MAPE:0.447189
# [19]	train-rmse:33.2629	val-rmse:33.1727	train-MAPE:0.409905	val-MAPE:0.427528
# [20]	train-rmse:32.3283	val-rmse:32.3912	train-MAPE:0.392962	val-MAPE:0.412524
# [21]	train-rmse:31.4381	val-rmse:31.5511	train-MAPE:0.376945	val-MAPE:0.396137
# [22]	train-rmse:30.5909	val-rmse:30.6228	train-MAPE:0.36184	val-MAPE:0.378999
# [23]	train-rmse:29.7935	val-rmse:29.9308	train-MAPE:0.347637	val-MAPE:0.365593
# [24]	train-rmse:29.0347	val-rmse:29.1383	train-MAPE:0.334307	val-MAPE:0.351004
# [25]	train-rmse:28.3159	val-rmse:28.4715	train-MAPE:0.321735	val-MAPE:0.338341
# [26]	train-rmse:27.6346	val-rmse:27.7959	train-MAPE:0.310118	val-MAPE:0.326157
# [27]	train-rmse:26.9921	val-rmse:27.0778	train-MAPE:0.29924	val-MAPE:0.313388
# [28]	train-rmse:26.384	val-rmse:26.5188	train-MAPE:0.289072	val-MAPE:0.303916
# [29]	train-rmse:25.8082	val-rmse:26.015	train-MAPE:0.279639	val-MAPE:0.294836
# [30]	train-rmse:25.2646	val-rmse:25.4306	train-MAPE:0.27097	val-MAPE:0.284928
# [31]	train-rmse:24.751	val-rmse:24.8128	train-MAPE:0.262786	val-MAPE:0.274472
# [32]	train-rmse:24.2701	val-rmse:24.3946	train-MAPE:0.255333	val-MAPE:0.266998
# [33]	train-rmse:23.81	val-rmse:23.9165	train-MAPE:0.248503	val-MAPE:0.259098
# [34]	train-rmse:23.3776	val-rmse:23.4432	train-MAPE:0.242332	val-MAPE:0.251404
# [35]	train-rmse:22.9783	val-rmse:23.0439	train-MAPE:0.236729	val-MAPE:0.245077
# [36]	train-rmse:22.5979	val-rmse:22.6357	train-MAPE:0.231728	val-MAPE:0.238817
# [37]	train-rmse:22.2374	val-rmse:22.2911	train-MAPE:0.227249	val-MAPE:0.23383
# [38]	train-rmse:21.899	val-rmse:21.9407	train-MAPE:0.22327	val-MAPE:0.228799
# [39]	train-rmse:21.5845	val-rmse:21.6206	train-MAPE:0.219647	val-MAPE:0.224329
# [40]	train-rmse:21.2867	val-rmse:21.3138	train-MAPE:0.216476	val-MAPE:0.220303
# [41]	train-rmse:21.0071	val-rmse:21.0209	train-MAPE:0.213684	val-MAPE:0.21653
# [42]	train-rmse:20.7418	val-rmse:20.7206	train-MAPE:0.211077	val-MAPE:0.212875
# [43]	train-rmse:20.4932	val-rmse:20.4412	train-MAPE:0.208793	val-MAPE:0.209618
# [44]	train-rmse:20.2635	val-rmse:20.2105	train-MAPE:0.206796	val-MAPE:0.206835
# [45]	train-rmse:20.0436	val-rmse:19.9617	train-MAPE:0.205071	val-MAPE:0.203983
# [46]	train-rmse:19.8395	val-rmse:19.7554	train-MAPE:0.203563	val-MAPE:0.201886
# [47]	train-rmse:19.6533	val-rmse:19.5411	train-MAPE:0.202303	val-MAPE:0.199778
# [48]	train-rmse:19.4716	val-rmse:19.3692	train-MAPE:0.201113	val-MAPE:0.198249
# [49]	train-rmse:19.3055	val-rmse:19.2129	train-MAPE:0.200176	val-MAPE:0.197063
# [50]	train-rmse:19.1449	val-rmse:19.037	train-MAPE:0.199357	val-MAPE:0.195536
# [51]	train-rmse:18.9968	val-rmse:18.9287	train-MAPE:0.198624	val-MAPE:0.194626
# [52]	train-rmse:18.8565	val-rmse:18.7732	train-MAPE:0.198096	val-MAPE:0.193503
# [53]	train-rmse:18.7247	val-rmse:18.6468	train-MAPE:0.197657	val-MAPE:0.192784
# [54]	train-rmse:18.6018	val-rmse:18.5008	train-MAPE:0.197291	val-MAPE:0.191936
# [55]	train-rmse:18.4825	val-rmse:18.4004	train-MAPE:0.197038	val-MAPE:0.191497
# [56]	train-rmse:18.3743	val-rmse:18.2995	train-MAPE:0.196882	val-MAPE:0.191174
# [57]	train-rmse:18.2694	val-rmse:18.1925	train-MAPE:0.196759	val-MAPE:0.190693
# [58]	train-rmse:18.1701	val-rmse:18.1392	train-MAPE:0.196643	val-MAPE:0.190488
# [59]	train-rmse:18.0838	val-rmse:18.0444	train-MAPE:0.19667	val-MAPE:0.189986
# [60]	train-rmse:18.0012	val-rmse:17.9635	train-MAPE:0.196785	val-MAPE:0.189931
# [61]	train-rmse:17.9202	val-rmse:17.9231	train-MAPE:0.196814	val-MAPE:0.189854
# [62]	train-rmse:17.846	val-rmse:17.8504	train-MAPE:0.196916	val-MAPE:0.189634
# [63]	train-rmse:17.7699	val-rmse:17.7497	train-MAPE:0.196981	val-MAPE:0.18946
# best best_ntree_limit 64

# %% [markdown]
# #### A3

# %%
## 训练预测
# 分割训练集和验证集
ll = round(len(A3_train)/5)
A3_train_val = A3_train.iloc[(len(A3_train)-ll):len(A3_train)]
A3_train_t = A3_train.iloc[:(len(A3_train)-ll)]

# 分离标签和特征
Y_time = A3_train_t['avg_travel_time']
X_time = A3_train_t.drop(['avg_travel_time'], axis=1)
val_Y_time = A3_train_val.avg_travel_time
val_X_time = A3_train_val.drop(['avg_travel_time'], axis=1)

# 转化格式
time_train = xgb.DMatrix(X_time, label=Y_time)
time_val = xgb.DMatrix(val_X_time, label=val_Y_time)
time_test = xgb.DMatrix(A3_test)

#参数设置
params = {
    'booster':'gbtree',      #gbtree和gblinear
    'objective':'reg:linear',
    'eta':0.04,             #为了防止过拟合，更新过程中用到的收缩步长。在每次提升计算之后，算法会直接获得新特征的权重。eta通过缩减特征的权重使提升计算过程更加保守。缺省值为0.3,通常最后设置eta为0.01~0.2
    #'gamma':0.3,            #模型在默认情况下，对于一个节点的划分只有在其loss function得到结果大于0的情况下才进行，而gamma 给定了所需的最低loss function的值gamma值使得算法更conservation，且其值依赖于loss function ，
    'max_depth':5,          #树的深度越大，则对数据的拟合程度越高（过拟合程度也越高）。即该参数也是控制过拟合,建议通过交叉验证（xgb.cv ) 进行调参,通常取值：3-10
    #'min_child_weight':2,   #孩子节点中最小的样本权重和。如果一个叶子节点的样本权重和小于min_child_weight则拆分过程结束。在现行回归模型中，这个参数是指建立每个模型所需要的最小样本数。该成熟越大算法越conservative。即调大这个参数能够控制过拟合。
    #'max_delta_step':2,     #如果取值为0，那么意味着无限制。如果取为正数，则其使得xgboost更新过程更加保守。
    'subsample':1,          #用于训练模型的子样本占整个样本集合的比例。如果设置为0.5则意味着XGBoost将随机的从整个样本集合中抽取出50%的子样本建立树模型，这能够防止过拟合。
    'colsample_bytree':1,   #在建立树时对特征随机采样的比例。缺省值为1 
    #'alpha':5,              #L1 正则的惩罚系数,当数据维度极高时可以使用，使得算法运行更快。
    #'lambda':40,           #L2 正则的惩罚系数,用于处理XGBoost的正则化部分。通常不使用，但可以用来降低过拟合
    'seed':2017,
}


plst = list(params.items())
num_rounds = 69
watchlist = [(time_train, 'train'), (time_val, 'val')]

A3time_model = xgb.train(plst, time_train, num_rounds, watchlist, feval=MAPE)
print("best best_ntree_limit", A3time_model.best_ntree_limit)

A3time_predict = A3time_model.predict(time_test)
# Out:
# [0]	train-rmse:114.236	val-rmse:115.648	train-MAPE:0.952613	val-MAPE:0.953842
# [1]	train-rmse:110.059	val-rmse:111.601	train-MAPE:0.911794	val-MAPE:0.914635
# [2]	train-rmse:106.06	val-rmse:107.779	train-MAPE:0.872657	val-MAPE:0.877854
# [3]	train-rmse:102.243	val-rmse:103.958	train-MAPE:0.835013	val-MAPE:0.841208
# [4]	train-rmse:98.5831	val-rmse:100.47	train-MAPE:0.798951	val-MAPE:0.807392
# [5]	train-rmse:95.084	val-rmse:97.0364	train-MAPE:0.764388	val-MAPE:0.774507
# [6]	train-rmse:91.7415	val-rmse:93.7812	train-MAPE:0.731367	val-MAPE:0.742776
# [7]	train-rmse:88.5458	val-rmse:90.7527	train-MAPE:0.699872	val-MAPE:0.713784
# [8]	train-rmse:85.489	val-rmse:87.7968	train-MAPE:0.669841	val-MAPE:0.685044
# [9]	train-rmse:82.5701	val-rmse:85.0226	train-MAPE:0.641126	val-MAPE:0.658235
# [10]	train-rmse:79.7759	val-rmse:82.3743	train-MAPE:0.613589	val-MAPE:0.632329
# [11]	train-rmse:77.1158	val-rmse:79.694	train-MAPE:0.587128	val-MAPE:0.606425
# [12]	train-rmse:74.5784	val-rmse:77.1447	train-MAPE:0.561761	val-MAPE:0.581501
# [13]	train-rmse:72.1508	val-rmse:74.8648	train-MAPE:0.537429	val-MAPE:0.55867
# [14]	train-rmse:69.8402	val-rmse:72.5637	train-MAPE:0.514106	val-MAPE:0.536304
# [15]	train-rmse:67.6363	val-rmse:70.3724	train-MAPE:0.491767	val-MAPE:0.515063
# [16]	train-rmse:65.5416	val-rmse:68.4254	train-MAPE:0.470388	val-MAPE:0.495322
# [17]	train-rmse:63.5487	val-rmse:66.4426	train-MAPE:0.449844	val-MAPE:0.475446
# [18]	train-rmse:61.6526	val-rmse:64.492	train-MAPE:0.430197	val-MAPE:0.455934
# [19]	train-rmse:59.8425	val-rmse:62.7802	train-MAPE:0.411403	val-MAPE:0.438416
# [20]	train-rmse:58.1266	val-rmse:61.0991	train-MAPE:0.393478	val-MAPE:0.421098
# [21]	train-rmse:56.4928	val-rmse:59.5098	train-MAPE:0.376434	val-MAPE:0.404834
# [22]	train-rmse:54.9454	val-rmse:58.0002	train-MAPE:0.360329	val-MAPE:0.38913
# [23]	train-rmse:53.4687	val-rmse:56.5208	train-MAPE:0.345071	val-MAPE:0.373278
# [24]	train-rmse:52.0631	val-rmse:55.1785	train-MAPE:0.330671	val-MAPE:0.358825
# [25]	train-rmse:50.7348	val-rmse:53.8383	train-MAPE:0.317008	val-MAPE:0.344587
# [26]	train-rmse:49.4678	val-rmse:52.5325	train-MAPE:0.304157	val-MAPE:0.331218
# [27]	train-rmse:48.2768	val-rmse:51.3349	train-MAPE:0.292098	val-MAPE:0.318472
# [28]	train-rmse:47.1399	val-rmse:50.2031	train-MAPE:0.280798	val-MAPE:0.306881
# [29]	train-rmse:46.08	val-rmse:49.2181	train-MAPE:0.2702	val-MAPE:0.296548
# [30]	train-rmse:45.0803	val-rmse:48.2865	train-MAPE:0.260407	val-MAPE:0.286857
# [31]	train-rmse:44.1206	val-rmse:47.3639	train-MAPE:0.251476	val-MAPE:0.277455
# [32]	train-rmse:43.2306	val-rmse:46.4673	train-MAPE:0.24322	val-MAPE:0.268385
# [33]	train-rmse:42.3678	val-rmse:45.6401	train-MAPE:0.235547	val-MAPE:0.259833
# [34]	train-rmse:41.5333	val-rmse:44.8296	train-MAPE:0.22839	val-MAPE:0.251771
# [35]	train-rmse:40.7553	val-rmse:44.0349	train-MAPE:0.221899	val-MAPE:0.243861
# [36]	train-rmse:40.0276	val-rmse:43.3948	train-MAPE:0.216039	val-MAPE:0.237616
# [37]	train-rmse:39.3462	val-rmse:42.7406	train-MAPE:0.210693	val-MAPE:0.231088
# [38]	train-rmse:38.6947	val-rmse:42.1606	train-MAPE:0.205812	val-MAPE:0.22556
# [39]	train-rmse:38.1022	val-rmse:41.5099	train-MAPE:0.201421	val-MAPE:0.21966
# [40]	train-rmse:37.5346	val-rmse:40.9089	train-MAPE:0.197421	val-MAPE:0.214061
# [41]	train-rmse:36.988	val-rmse:40.3698	train-MAPE:0.193839	val-MAPE:0.209209
# [42]	train-rmse:36.4709	val-rmse:39.8581	train-MAPE:0.190635	val-MAPE:0.204799
# [43]	train-rmse:36.008	val-rmse:39.3465	train-MAPE:0.187814	val-MAPE:0.200586
# [44]	train-rmse:35.5576	val-rmse:38.9143	train-MAPE:0.185178	val-MAPE:0.196882
# [45]	train-rmse:35.1346	val-rmse:38.4679	train-MAPE:0.182956	val-MAPE:0.193407
# [46]	train-rmse:34.7434	val-rmse:38.0679	train-MAPE:0.180945	val-MAPE:0.190335
# [47]	train-rmse:34.3765	val-rmse:37.6572	train-MAPE:0.179182	val-MAPE:0.187301
# [48]	train-rmse:34.0256	val-rmse:37.2997	train-MAPE:0.177561	val-MAPE:0.184794
# [49]	train-rmse:33.7082	val-rmse:36.9015	train-MAPE:0.176229	val-MAPE:0.182297
# [50]	train-rmse:33.3991	val-rmse:36.6097	train-MAPE:0.174998	val-MAPE:0.180487
# [51]	train-rmse:33.1215	val-rmse:36.2558	train-MAPE:0.174033	val-MAPE:0.178627
# [52]	train-rmse:32.8513	val-rmse:35.9765	train-MAPE:0.173152	val-MAPE:0.17718
# [53]	train-rmse:32.5796	val-rmse:35.6861	train-MAPE:0.172337	val-MAPE:0.175754
# [54]	train-rmse:32.3519	val-rmse:35.4454	train-MAPE:0.171734	val-MAPE:0.174685
# [55]	train-rmse:32.1281	val-rmse:35.2302	train-MAPE:0.171148	val-MAPE:0.173684
# [56]	train-rmse:31.9365	val-rmse:35.0124	train-MAPE:0.170817	val-MAPE:0.17286
# [57]	train-rmse:31.7341	val-rmse:34.8035	train-MAPE:0.170367	val-MAPE:0.172006
# [58]	train-rmse:31.5442	val-rmse:34.5869	train-MAPE:0.170102	val-MAPE:0.171253
# [59]	train-rmse:31.3695	val-rmse:34.4203	train-MAPE:0.169857	val-MAPE:0.17065
# [60]	train-rmse:31.2226	val-rmse:34.2908	train-MAPE:0.169799	val-MAPE:0.170469
# [61]	train-rmse:31.0674	val-rmse:34.1511	train-MAPE:0.169674	val-MAPE:0.170046
# [62]	train-rmse:30.9165	val-rmse:33.9147	train-MAPE:0.169632	val-MAPE:0.169533
# [63]	train-rmse:30.7784	val-rmse:33.7939	train-MAPE:0.169618	val-MAPE:0.169273
# [64]	train-rmse:30.6676	val-rmse:33.684	train-MAPE:0.169784	val-MAPE:0.169291
# [65]	train-rmse:30.5571	val-rmse:33.5106	train-MAPE:0.169897	val-MAPE:0.16908
# [66]	train-rmse:30.4567	val-rmse:33.3832	train-MAPE:0.170083	val-MAPE:0.168978
# [67]	train-rmse:30.3395	val-rmse:33.2586	train-MAPE:0.17016	val-MAPE:0.168984
# [68]	train-rmse:30.241	val-rmse:33.1403	train-MAPE:0.170338	val-MAPE:0.168878
# best best_ntree_limit 69

# %% [markdown]
# #### B1

# %%
## 训练预测
# 分割训练集和验证集
ll = round(len(B1_train)/5)
B1_train_val = B1_train.iloc[(len(B1_train)-ll):len(B1_train)]
B1_train_t = B1_train.iloc[:(len(B1_train)-ll)]

# 分离标签和特征
Y_time = B1_train_t['avg_travel_time']
X_time = B1_train_t.drop(['avg_travel_time'], axis=1)
val_Y_time = B1_train_val.avg_travel_time
val_X_time = B1_train_val.drop(['avg_travel_time'], axis=1)

# 转化格式
time_train = xgb.DMatrix(X_time, label=Y_time)
time_val = xgb.DMatrix(val_X_time, label=val_Y_time)
time_test = xgb.DMatrix(B1_test)

#参数设置
params = {
    'booster':'gbtree',      #gbtree和gblinear
    'objective':'reg:linear',
    'eta':0.04,             #为了防止过拟合，更新过程中用到的收缩步长。在每次提升计算之后，算法会直接获得新特征的权重。eta通过缩减特征的权重使提升计算过程更加保守。缺省值为0.3,通常最后设置eta为0.01~0.2
    #'gamma':0.3,            #模型在默认情况下，对于一个节点的划分只有在其loss function得到结果大于0的情况下才进行，而gamma 给定了所需的最低loss function的值gamma值使得算法更conservation，且其值依赖于loss function ，
    'max_depth':5,          #树的深度越大，则对数据的拟合程度越高（过拟合程度也越高）。即该参数也是控制过拟合,建议通过交叉验证（xgb.cv ) 进行调参,通常取值：3-10
    #'min_child_weight':2,   #孩子节点中最小的样本权重和。如果一个叶子节点的样本权重和小于min_child_weight则拆分过程结束。在现行回归模型中，这个参数是指建立每个模型所需要的最小样本数。该成熟越大算法越conservative。即调大这个参数能够控制过拟合。
    #'max_delta_step':2,     #如果取值为0，那么意味着无限制。如果取为正数，则其使得xgboost更新过程更加保守。
    'subsample':1,          #用于训练模型的子样本占整个样本集合的比例。如果设置为0.5则意味着XGBoost将随机的从整个样本集合中抽取出50%的子样本建立树模型，这能够防止过拟合。
    'colsample_bytree':1,   #在建立树时对特征随机采样的比例。缺省值为1 
    #'alpha':5,              #L1 正则的惩罚系数,当数据维度极高时可以使用，使得算法运行更快。
    #'lambda':40,           #L2 正则的惩罚系数,用于处理XGBoost的正则化部分。通常不使用，但可以用来降低过拟合
    'seed':2017,
}


plst = list(params.items())
num_rounds = 55
watchlist = [(time_train, 'train'), (time_val, 'val')]

B1time_model = xgb.train(plst, time_train, num_rounds, watchlist, feval=MAPE)
print("best best_ntree_limit", B1time_model.best_ntree_limit)

B1time_predict = B1time_model.predict(time_test)
# Out:
# [0]	train-rmse:119.946	val-rmse:119.533	train-MAPE:0.951897	val-MAPE:0.950611
# [1]	train-rmse:115.572	val-rmse:114.747	train-MAPE:0.910151	val-MAPE:0.907403
# [2]	train-rmse:111.381	val-rmse:110.177	train-MAPE:0.870163	val-MAPE:0.865985
# [3]	train-rmse:107.373	val-rmse:105.793	train-MAPE:0.831731	val-MAPE:0.826162
# [4]	train-rmse:103.545	val-rmse:101.599	train-MAPE:0.795032	val-MAPE:0.788423
# [5]	train-rmse:99.878	val-rmse:97.5933	train-MAPE:0.760538	val-MAPE:0.75226
# [6]	train-rmse:96.3734	val-rmse:93.8432	train-MAPE:0.727865	val-MAPE:0.718325
# [7]	train-rmse:93.0262	val-rmse:90.2587	train-MAPE:0.696813	val-MAPE:0.685924
# [8]	train-rmse:89.8211	val-rmse:86.7679	train-MAPE:0.667245	val-MAPE:0.654295
# [9]	train-rmse:86.7609	val-rmse:83.6511	train-MAPE:0.638936	val-MAPE:0.6256
# [10]	train-rmse:83.8372	val-rmse:80.475	train-MAPE:0.611909	val-MAPE:0.596474
# [11]	train-rmse:81.0484	val-rmse:77.4224	train-MAPE:0.586227	val-MAPE:0.568347
# [12]	train-rmse:78.3852	val-rmse:74.7317	train-MAPE:0.561584	val-MAPE:0.543083
# [13]	train-rmse:75.8467	val-rmse:71.9669	train-MAPE:0.538167	val-MAPE:0.517513
# [14]	train-rmse:73.4202	val-rmse:69.4835	train-MAPE:0.515784	val-MAPE:0.494254
# [15]	train-rmse:71.1157	val-rmse:67.162	train-MAPE:0.494459	val-MAPE:0.472082
# [16]	train-rmse:68.9256	val-rmse:64.8027	train-MAPE:0.474217	val-MAPE:0.45004
# [17]	train-rmse:66.8291	val-rmse:62.6706	train-MAPE:0.45501	val-MAPE:0.429971
# [18]	train-rmse:64.8258	val-rmse:60.6982	train-MAPE:0.436666	val-MAPE:0.411271
# [19]	train-rmse:62.9286	val-rmse:58.7714	train-MAPE:0.419307	val-MAPE:0.392939
# [20]	train-rmse:61.1264	val-rmse:56.9289	train-MAPE:0.402807	val-MAPE:0.375638
# [21]	train-rmse:59.4026	val-rmse:55.2483	train-MAPE:0.387222	val-MAPE:0.359671
# [22]	train-rmse:57.7658	val-rmse:53.6539	train-MAPE:0.372548	val-MAPE:0.344568
# [23]	train-rmse:56.2066	val-rmse:52.1648	train-MAPE:0.358919	val-MAPE:0.330661
# [24]	train-rmse:54.7436	val-rmse:50.6893	train-MAPE:0.345989	val-MAPE:0.31688
# [25]	train-rmse:53.3582	val-rmse:49.2924	train-MAPE:0.333756	val-MAPE:0.303904
# [26]	train-rmse:52.0361	val-rmse:47.9686	train-MAPE:0.322285	val-MAPE:0.291622
# [27]	train-rmse:50.7927	val-rmse:46.6901	train-MAPE:0.311662	val-MAPE:0.279672
# [28]	train-rmse:49.6206	val-rmse:45.5173	train-MAPE:0.301777	val-MAPE:0.269028
# [29]	train-rmse:48.4887	val-rmse:44.4172	train-MAPE:0.292544	val-MAPE:0.259317
# [30]	train-rmse:47.4174	val-rmse:43.4503	train-MAPE:0.283952	val-MAPE:0.251047
# [31]	train-rmse:46.4159	val-rmse:42.4496	train-MAPE:0.276014	val-MAPE:0.242865
# [32]	train-rmse:45.4642	val-rmse:41.5644	train-MAPE:0.268887	val-MAPE:0.235825
# [33]	train-rmse:44.5786	val-rmse:40.6965	train-MAPE:0.26228	val-MAPE:0.229072
# [34]	train-rmse:43.7337	val-rmse:39.945	train-MAPE:0.256278	val-MAPE:0.223273
# [35]	train-rmse:42.9366	val-rmse:39.2206	train-MAPE:0.250783	val-MAPE:0.217722
# [36]	train-rmse:42.1826	val-rmse:38.5294	train-MAPE:0.245661	val-MAPE:0.212412
# [37]	train-rmse:41.4636	val-rmse:37.8434	train-MAPE:0.240988	val-MAPE:0.207497
# [38]	train-rmse:40.8023	val-rmse:37.3106	train-MAPE:0.236878	val-MAPE:0.203667
# [39]	train-rmse:40.1752	val-rmse:36.6167	train-MAPE:0.233204	val-MAPE:0.198994
# [40]	train-rmse:39.5662	val-rmse:36.0671	train-MAPE:0.22967	val-MAPE:0.195494
# [41]	train-rmse:39.0148	val-rmse:35.5436	train-MAPE:0.226459	val-MAPE:0.192145
# [42]	train-rmse:38.5043	val-rmse:35.0926	train-MAPE:0.22371	val-MAPE:0.189318
# [43]	train-rmse:38.0121	val-rmse:34.7318	train-MAPE:0.221193	val-MAPE:0.187133
# [44]	train-rmse:37.5359	val-rmse:34.3233	train-MAPE:0.218797	val-MAPE:0.184764
# [45]	train-rmse:37.1029	val-rmse:34.0025	train-MAPE:0.216739	val-MAPE:0.183152
# [46]	train-rmse:36.6876	val-rmse:33.6796	train-MAPE:0.214907	val-MAPE:0.181393
# [47]	train-rmse:36.299	val-rmse:33.3347	train-MAPE:0.213146	val-MAPE:0.179788
# [48]	train-rmse:35.9507	val-rmse:33.0497	train-MAPE:0.211819	val-MAPE:0.178489
# [49]	train-rmse:35.6207	val-rmse:32.8262	train-MAPE:0.210719	val-MAPE:0.177885
# [50]	train-rmse:35.2987	val-rmse:32.5961	train-MAPE:0.209627	val-MAPE:0.177042
# [51]	train-rmse:34.9911	val-rmse:32.3021	train-MAPE:0.208582	val-MAPE:0.176315
# [52]	train-rmse:34.6845	val-rmse:32.0676	train-MAPE:0.207566	val-MAPE:0.175662
# [53]	train-rmse:34.4221	val-rmse:31.8706	train-MAPE:0.206814	val-MAPE:0.17514
# [54]	train-rmse:34.174	val-rmse:31.6987	train-MAPE:0.20614	val-MAPE:0.175118
# best best_ntree_limit 55

# %% [markdown]
# #### B3

# %%
## 训练预测
# 分割训练集和验证集
ll = round(len(B3_train)/5)
B3_train_val = B3_train.iloc[(len(B3_train)-ll):len(B3_train)]
B3_train_t = B3_train.iloc[:(len(B3_train)-ll)]

# 分离标签和特征
Y_time = B3_train_t['avg_travel_time']
X_time = B3_train_t.drop(['avg_travel_time'], axis=1)
val_Y_time = B3_train_val.avg_travel_time
val_X_time = B3_train_val.drop(['avg_travel_time'], axis=1)

# 转化格式
time_train = xgb.DMatrix(X_time, label=Y_time)
time_val = xgb.DMatrix(val_X_time, label=val_Y_time)
time_test = xgb.DMatrix(B3_test)

#参数设置
params = {
    'booster':'gbtree',      #gbtree和gblinear
    'objective':'reg:linear',
    'eta':0.04,             #为了防止过拟合，更新过程中用到的收缩步长。在每次提升计算之后，算法会直接获得新特征的权重。eta通过缩减特征的权重使提升计算过程更加保守。缺省值为0.3,通常最后设置eta为0.01~0.2
    #'gamma':0.3,            #模型在默认情况下，对于一个节点的划分只有在其loss function得到结果大于0的情况下才进行，而gamma 给定了所需的最低loss function的值gamma值使得算法更conservation，且其值依赖于loss function ，
    'max_depth':5,          #树的深度越大，则对数据的拟合程度越高（过拟合程度也越高）。即该参数也是控制过拟合,建议通过交叉验证（xgb.cv ) 进行调参,通常取值：3-10
    #'min_child_weight':2,   #孩子节点中最小的样本权重和。如果一个叶子节点的样本权重和小于min_child_weight则拆分过程结束。在现行回归模型中，这个参数是指建立每个模型所需要的最小样本数。该成熟越大算法越conservative。即调大这个参数能够控制过拟合。
    #'max_delta_step':2,     #如果取值为0，那么意味着无限制。如果取为正数，则其使得xgboost更新过程更加保守。
    'subsample':1,          #用于训练模型的子样本占整个样本集合的比例。如果设置为0.5则意味着XGBoost将随机的从整个样本集合中抽取出50%的子样本建立树模型，这能够防止过拟合。
    'colsample_bytree':1,   #在建立树时对特征随机采样的比例。缺省值为1 
    #'alpha':5,              #L1 正则的惩罚系数,当数据维度极高时可以使用，使得算法运行更快。
    #'lambda':40,           #L2 正则的惩罚系数,用于处理XGBoost的正则化部分。通常不使用，但可以用来降低过拟合
    'seed':2017,
}


plst = list(params.items())
num_rounds = 43
watchlist = [(time_train, 'train'), (time_val, 'val')]

B3time_model = xgb.train(plst, time_train, num_rounds, watchlist, feval=MAPE)
print("best best_ntree_limit", B3time_model.best_ntree_limit)

B3time_predict = B3time_model.predict(time_test)
# Out:
# [0]	train-rmse:108.811	val-rmse:94.9112	train-MAPE:0.951386	val-MAPE:0.946511
# [1]	train-rmse:104.81	val-rmse:90.9871	train-MAPE:0.909679	val-MAPE:0.90082
# [2]	train-rmse:100.98	val-rmse:87.191	train-MAPE:0.869713	val-MAPE:0.856539
# [3]	train-rmse:97.3151	val-rmse:83.5928	train-MAPE:0.831687	val-MAPE:0.814974
# [4]	train-rmse:93.809	val-rmse:80.1359	train-MAPE:0.795521	val-MAPE:0.775521
# [5]	train-rmse:90.4547	val-rmse:76.8744	train-MAPE:0.760862	val-MAPE:0.73846
# [6]	train-rmse:87.2467	val-rmse:73.7618	train-MAPE:0.727742	val-MAPE:0.70319
# [7]	train-rmse:84.182	val-rmse:70.7459	train-MAPE:0.696121	val-MAPE:0.669316
# [8]	train-rmse:81.2517	val-rmse:67.9343	train-MAPE:0.66625	val-MAPE:0.637538
# [9]	train-rmse:78.4517	val-rmse:65.2572	train-MAPE:0.63773	val-MAPE:0.607314
# [10]	train-rmse:75.7803	val-rmse:62.6214	train-MAPE:0.610429	val-MAPE:0.577725
# [11]	train-rmse:73.228	val-rmse:60.1535	train-MAPE:0.584349	val-MAPE:0.550215
# [12]	train-rmse:70.7911	val-rmse:57.7372	train-MAPE:0.559357	val-MAPE:0.523295
# [13]	train-rmse:68.4645	val-rmse:55.439	train-MAPE:0.535629	val-MAPE:0.49773
# [14]	train-rmse:66.2529	val-rmse:53.1831	train-MAPE:0.513004	val-MAPE:0.473047
# [15]	train-rmse:64.1352	val-rmse:51.0409	train-MAPE:0.491732	val-MAPE:0.449579
# [16]	train-rmse:62.1188	val-rmse:49.0955	train-MAPE:0.471503	val-MAPE:0.428382
# [17]	train-rmse:60.1984	val-rmse:47.1691	train-MAPE:0.452545	val-MAPE:0.40746
# [18]	train-rmse:58.3726	val-rmse:45.3767	train-MAPE:0.434684	val-MAPE:0.388085
# [19]	train-rmse:56.6338	val-rmse:43.741	train-MAPE:0.41801	val-MAPE:0.370668
# [20]	train-rmse:54.986	val-rmse:42.185	train-MAPE:0.402228	val-MAPE:0.354409
# [21]	train-rmse:53.4133	val-rmse:40.7133	train-MAPE:0.387705	val-MAPE:0.339172
# [22]	train-rmse:51.921	val-rmse:39.3509	train-MAPE:0.373963	val-MAPE:0.325512
# [23]	train-rmse:50.5038	val-rmse:38.0762	train-MAPE:0.361276	val-MAPE:0.313143
# [24]	train-rmse:49.1649	val-rmse:36.8671	train-MAPE:0.349319	val-MAPE:0.301531
# [25]	train-rmse:47.8906	val-rmse:35.7307	train-MAPE:0.338425	val-MAPE:0.291025
# [26]	train-rmse:46.6834	val-rmse:34.6606	train-MAPE:0.328279	val-MAPE:0.281291
# [27]	train-rmse:45.5312	val-rmse:33.6465	train-MAPE:0.319018	val-MAPE:0.27231
# [28]	train-rmse:44.4447	val-rmse:32.7318	train-MAPE:0.310534	val-MAPE:0.264737
# [29]	train-rmse:43.4208	val-rmse:31.8805	train-MAPE:0.302541	val-MAPE:0.257759
# [30]	train-rmse:42.4486	val-rmse:31.0578	train-MAPE:0.295251	val-MAPE:0.25138
# [31]	train-rmse:41.5367	val-rmse:30.3498	train-MAPE:0.288467	val-MAPE:0.246079
# [32]	train-rmse:40.6744	val-rmse:29.6421	train-MAPE:0.282131	val-MAPE:0.240999
# [33]	train-rmse:39.8568	val-rmse:29.0407	train-MAPE:0.276483	val-MAPE:0.237087
# [34]	train-rmse:39.0869	val-rmse:28.4712	train-MAPE:0.271236	val-MAPE:0.233748
# [35]	train-rmse:38.3632	val-rmse:27.9516	train-MAPE:0.266503	val-MAPE:0.230662
# [36]	train-rmse:37.6822	val-rmse:27.4923	train-MAPE:0.262174	val-MAPE:0.228482
# [37]	train-rmse:37.0414	val-rmse:27.069	train-MAPE:0.258094	val-MAPE:0.226604
# [38]	train-rmse:36.4386	val-rmse:26.6676	train-MAPE:0.25446	val-MAPE:0.225128
# [39]	train-rmse:35.8712	val-rmse:26.3242	train-MAPE:0.251079	val-MAPE:0.224022
# [40]	train-rmse:35.3409	val-rmse:26.0473	train-MAPE:0.248067	val-MAPE:0.223186
# [41]	train-rmse:34.8398	val-rmse:25.7544	train-MAPE:0.245267	val-MAPE:0.222487
# [42]	train-rmse:34.3704	val-rmse:25.5023	train-MAPE:0.242787	val-MAPE:0.221975
# best best_ntree_limit 43

# %% [markdown]
# #### C1

# %%
## 训练预测
# 分割训练集和验证集
ll = round(len(C1_train)/5)
C1_train_val = C1_train.iloc[(len(C1_train)-ll):len(C1_train)]
C1_train_t = C1_train.iloc[:(len(C1_train)-ll)]

# 分离标签和特征
Y_time = C1_train_t['avg_travel_time']
X_time = C1_train_t.drop(['avg_travel_time'], axis=1)
val_Y_time = C1_train_val.avg_travel_time
val_X_time = C1_train_val.drop(['avg_travel_time'], axis=1)

# 转化格式
time_train = xgb.DMatrix(X_time, label=Y_time)
time_val = xgb.DMatrix(val_X_time, label=val_Y_time)
time_test = xgb.DMatrix(C1_test)

#参数设置
params = {
    'booster':'gbtree',      #gbtree和gblinear
    'objective':'reg:linear',
    'eta':0.04,             #为了防止过拟合，更新过程中用到的收缩步长。在每次提升计算之后，算法会直接获得新特征的权重。eta通过缩减特征的权重使提升计算过程更加保守。缺省值为0.3,通常最后设置eta为0.01~0.2
    #'gamma':0.3,            #模型在默认情况下，对于一个节点的划分只有在其loss function得到结果大于0的情况下才进行，而gamma 给定了所需的最低loss function的值gamma值使得算法更conservation，且其值依赖于loss function ，
    'max_depth':5,          #树的深度越大，则对数据的拟合程度越高（过拟合程度也越高）。即该参数也是控制过拟合,建议通过交叉验证（xgb.cv ) 进行调参,通常取值：3-10
    #'min_child_weight':2,   #孩子节点中最小的样本权重和。如果一个叶子节点的样本权重和小于min_child_weight则拆分过程结束。在现行回归模型中，这个参数是指建立每个模型所需要的最小样本数。该成熟越大算法越conservative。即调大这个参数能够控制过拟合。
    #'max_delta_step':2,     #如果取值为0，那么意味着无限制。如果取为正数，则其使得xgboost更新过程更加保守。
    'subsample':1,          #用于训练模型的子样本占整个样本集合的比例。如果设置为0.5则意味着XGBoost将随机的从整个样本集合中抽取出50%的子样本建立树模型，这能够防止过拟合。
    'colsample_bytree':1,   #在建立树时对特征随机采样的比例。缺省值为1 
    #'alpha':5,              #L1 正则的惩罚系数,当数据维度极高时可以使用，使得算法运行更快。
    #'lambda':40,           #L2 正则的惩罚系数,用于处理XGBoost的正则化部分。通常不使用，但可以用来降低过拟合
    'seed':2017,
}


plst = list(params.items())
num_rounds = 68
watchlist = [(time_train, 'train'), (time_val, 'val')]

C1time_model = xgb.train(plst, time_train, num_rounds, watchlist, feval=MAPE)
print("best best_ntree_limit", C1time_model.best_ntree_limit)

C1time_predict = C1time_model.predict(time_test)
# Out:
# [0]	train-rmse:176.064	val-rmse:180.119	train-MAPE:0.955146	val-MAPE:0.955691
# [1]	train-rmse:169.455	val-rmse:173.109	train-MAPE:0.914982	val-MAPE:0.914799
# [2]	train-rmse:163.124	val-rmse:166.612	train-MAPE:0.876436	val-MAPE:0.876726
# [3]	train-rmse:157.062	val-rmse:160.398	train-MAPE:0.839437	val-MAPE:0.840094
# [4]	train-rmse:151.255	val-rmse:154.246	train-MAPE:0.803926	val-MAPE:0.803977
# [5]	train-rmse:145.696	val-rmse:148.511	train-MAPE:0.769773	val-MAPE:0.770112
# [6]	train-rmse:140.373	val-rmse:142.838	train-MAPE:0.737088	val-MAPE:0.736471
# [7]	train-rmse:135.277	val-rmse:137.628	train-MAPE:0.70582	val-MAPE:0.705399
# [8]	train-rmse:130.403	val-rmse:132.51	train-MAPE:0.675767	val-MAPE:0.674981
# [9]	train-rmse:125.74	val-rmse:127.653	train-MAPE:0.646922	val-MAPE:0.645933
# [10]	train-rmse:121.28	val-rmse:122.931	train-MAPE:0.61922	val-MAPE:0.617549
# [11]	train-rmse:117.016	val-rmse:118.522	train-MAPE:0.592651	val-MAPE:0.591041
# [12]	train-rmse:112.94	val-rmse:114.157	train-MAPE:0.567221	val-MAPE:0.564695
# [13]	train-rmse:109.043	val-rmse:110.289	train-MAPE:0.542835	val-MAPE:0.5408
# [14]	train-rmse:105.323	val-rmse:106.35	train-MAPE:0.519508	val-MAPE:0.516744
# [15]	train-rmse:101.761	val-rmse:102.69	train-MAPE:0.497182	val-MAPE:0.494065
# [16]	train-rmse:98.3626	val-rmse:99.2842	train-MAPE:0.475829	val-MAPE:0.473038
# [17]	train-rmse:95.116	val-rmse:96.0759	train-MAPE:0.455343	val-MAPE:0.4531
# [18]	train-rmse:92.0156	val-rmse:93.1138	train-MAPE:0.435738	val-MAPE:0.43448
# [19]	train-rmse:89.0634	val-rmse:90.0056	train-MAPE:0.416975	val-MAPE:0.41499
# [20]	train-rmse:86.2459	val-rmse:87.0974	train-MAPE:0.399039	val-MAPE:0.397039
# [21]	train-rmse:83.5642	val-rmse:84.4382	train-MAPE:0.381809	val-MAPE:0.380525
# [22]	train-rmse:81.0095	val-rmse:81.8805	train-MAPE:0.36545	val-MAPE:0.364416
# [23]	train-rmse:78.5687	val-rmse:79.2736	train-MAPE:0.349954	val-MAPE:0.347937
# [24]	train-rmse:76.2478	val-rmse:76.7923	train-MAPE:0.335183	val-MAPE:0.332818
# [25]	train-rmse:74.0491	val-rmse:74.6259	train-MAPE:0.321232	val-MAPE:0.319362
# [26]	train-rmse:71.9522	val-rmse:72.5204	train-MAPE:0.308134	val-MAPE:0.306937
# [27]	train-rmse:69.9593	val-rmse:70.5031	train-MAPE:0.295811	val-MAPE:0.29516
# [28]	train-rmse:68.0609	val-rmse:68.7592	train-MAPE:0.284314	val-MAPE:0.28459
# [29]	train-rmse:66.2659	val-rmse:66.9953	train-MAPE:0.273485	val-MAPE:0.274128
# [30]	train-rmse:64.5545	val-rmse:65.2639	train-MAPE:0.263432	val-MAPE:0.263984
# [31]	train-rmse:62.9436	val-rmse:63.6541	train-MAPE:0.254044	val-MAPE:0.254302
# [32]	train-rmse:61.4127	val-rmse:62.0817	train-MAPE:0.245399	val-MAPE:0.245239
# [33]	train-rmse:59.9646	val-rmse:60.7466	train-MAPE:0.237454	val-MAPE:0.237641
# [34]	train-rmse:58.5988	val-rmse:59.493	train-MAPE:0.230016	val-MAPE:0.230414
# [35]	train-rmse:57.3026	val-rmse:58.2739	train-MAPE:0.223263	val-MAPE:0.223788
# [36]	train-rmse:56.073	val-rmse:57.013	train-MAPE:0.216965	val-MAPE:0.217212
# [37]	train-rmse:54.9141	val-rmse:55.7695	train-MAPE:0.211136	val-MAPE:0.210677
# [38]	train-rmse:53.7964	val-rmse:54.6828	train-MAPE:0.205827	val-MAPE:0.205206
# [39]	train-rmse:52.7612	val-rmse:53.5802	train-MAPE:0.200949	val-MAPE:0.199883
# [40]	train-rmse:51.7655	val-rmse:52.6491	train-MAPE:0.196495	val-MAPE:0.19538
# [41]	train-rmse:50.8317	val-rmse:51.7847	train-MAPE:0.192446	val-MAPE:0.191349
# [42]	train-rmse:49.9711	val-rmse:50.8714	train-MAPE:0.188713	val-MAPE:0.18701
# [43]	train-rmse:49.1525	val-rmse:50.0598	train-MAPE:0.185401	val-MAPE:0.183631
# [44]	train-rmse:48.3843	val-rmse:49.2189	train-MAPE:0.182305	val-MAPE:0.180171
# [45]	train-rmse:47.6643	val-rmse:48.4369	train-MAPE:0.179451	val-MAPE:0.176956
# [46]	train-rmse:46.9825	val-rmse:47.7854	train-MAPE:0.176898	val-MAPE:0.174627
# [47]	train-rmse:46.3484	val-rmse:47.1601	train-MAPE:0.174672	val-MAPE:0.172298
# [48]	train-rmse:45.7378	val-rmse:46.5466	train-MAPE:0.172621	val-MAPE:0.170203
# [49]	train-rmse:45.1856	val-rmse:45.9657	train-MAPE:0.170828	val-MAPE:0.16826
# [50]	train-rmse:44.6559	val-rmse:45.5182	train-MAPE:0.169182	val-MAPE:0.16689
# [51]	train-rmse:44.1444	val-rmse:45.0957	train-MAPE:0.167652	val-MAPE:0.165797
# [52]	train-rmse:43.6735	val-rmse:44.6088	train-MAPE:0.166303	val-MAPE:0.164476
# [53]	train-rmse:43.1948	val-rmse:44.1481	train-MAPE:0.164981	val-MAPE:0.163225
# [54]	train-rmse:42.7732	val-rmse:43.7576	train-MAPE:0.163902	val-MAPE:0.162328
# [55]	train-rmse:42.3911	val-rmse:43.4026	train-MAPE:0.162942	val-MAPE:0.161672
# [56]	train-rmse:42.0365	val-rmse:43.0558	train-MAPE:0.162132	val-MAPE:0.160992
# [57]	train-rmse:41.6912	val-rmse:42.8108	train-MAPE:0.161369	val-MAPE:0.160645
# [58]	train-rmse:41.3741	val-rmse:42.549	train-MAPE:0.160715	val-MAPE:0.160184
# [59]	train-rmse:41.0733	val-rmse:42.2733	train-MAPE:0.160043	val-MAPE:0.159624
# [60]	train-rmse:40.7769	val-rmse:42.0131	train-MAPE:0.159491	val-MAPE:0.159144
# [61]	train-rmse:40.5011	val-rmse:41.7982	train-MAPE:0.159036	val-MAPE:0.158839
# [62]	train-rmse:40.2549	val-rmse:41.6095	train-MAPE:0.158628	val-MAPE:0.158704
# [63]	train-rmse:40.0208	val-rmse:41.3932	train-MAPE:0.158235	val-MAPE:0.158489
# [64]	train-rmse:39.784	val-rmse:41.271	train-MAPE:0.15787	val-MAPE:0.158463
# [65]	train-rmse:39.5771	val-rmse:41.1515	train-MAPE:0.157537	val-MAPE:0.158466
# [66]	train-rmse:39.3712	val-rmse:40.9792	train-MAPE:0.157303	val-MAPE:0.158336
# [67]	train-rmse:39.1886	val-rmse:40.8207	train-MAPE:0.157076	val-MAPE:0.158324
# best best_ntree_limit 68

# %%
## 训练预测
# 分割训练集和验证集
ll = round(len(C3_train)/5)
C3_train_val = C3_train.iloc[(len(C3_train)-ll):len(C3_train)]
C3_train_t = C3_train.iloc[:(len(C3_train)-ll)]

# 分离标签和特征
Y_time = C3_train_t['avg_travel_time']
X_time = C3_train_t.drop(['avg_travel_time'], axis=1)
val_Y_time = C3_train_val.avg_travel_time
val_X_time = C3_train_val.drop(['avg_travel_time'], axis=1)

# 转化格式
time_train = xgb.DMatrix(X_time, label=Y_time)
time_val = xgb.DMatrix(val_X_time, label=val_Y_time)
time_test = xgb.DMatrix(C3_test)

#参数设置
params = {
    'booster':'gbtree',      #gbtree和gblinear
    'objective':'reg:linear',
    'eta':0.04,             #为了防止过拟合，更新过程中用到的收缩步长。在每次提升计算之后，算法会直接获得新特征的权重。eta通过缩减特征的权重使提升计算过程更加保守。缺省值为0.3,通常最后设置eta为0.01~0.2
    #'gamma':0.3,            #模型在默认情况下，对于一个节点的划分只有在其loss function得到结果大于0的情况下才进行，而gamma 给定了所需的最低loss function的值gamma值使得算法更conservation，且其值依赖于loss function ，
    'max_depth':5,          #树的深度越大，则对数据的拟合程度越高（过拟合程度也越高）。即该参数也是控制过拟合,建议通过交叉验证（xgb.cv ) 进行调参,通常取值：3-10
    #'min_child_weight':2,   #孩子节点中最小的样本权重和。如果一个叶子节点的样本权重和小于min_child_weight则拆分过程结束。在现行回归模型中，这个参数是指建立每个模型所需要的最小样本数。该成熟越大算法越conservative。即调大这个参数能够控制过拟合。
    #'max_delta_step':2,     #如果取值为0，那么意味着无限制。如果取为正数，则其使得xgboost更新过程更加保守。
    'subsample':1,          #用于训练模型的子样本占整个样本集合的比例。如果设置为0.5则意味着XGBoost将随机的从整个样本集合中抽取出50%的子样本建立树模型，这能够防止过拟合。
    'colsample_bytree':1,   #在建立树时对特征随机采样的比例。缺省值为1 
    #'alpha':5,              #L1 正则的惩罚系数,当数据维度极高时可以使用，使得算法运行更快。
    #'lambda':40,           #L2 正则的惩罚系数,用于处理XGBoost的正则化部分。通常不使用，但可以用来降低过拟合
    'seed':2017,
}


plst = list(params.items())
num_rounds = 72
watchlist = [(time_train, 'train'), (time_val, 'val')]

C3time_model = xgb.train(plst, time_train, num_rounds, watchlist, feval=MAPE)
print("best best_ntree_limit", C3time_model.best_ntree_limit)

C3time_predict = C3time_model.predict(time_test)
# Out:
# [0]	train-rmse:181.498	val-rmse:168.034	train-MAPE:0.954205	val-MAPE:0.952475
# [1]	train-rmse:174.793	val-rmse:161.369	train-MAPE:0.913086	val-MAPE:0.909653
# [2]	train-rmse:168.376	val-rmse:155.169	train-MAPE:0.873669	val-MAPE:0.869601
# [3]	train-rmse:162.236	val-rmse:149.413	train-MAPE:0.835843	val-MAPE:0.832652
# [4]	train-rmse:156.361	val-rmse:143.734	train-MAPE:0.799503	val-MAPE:0.795724
# [5]	train-rmse:150.735	val-rmse:138.563	train-MAPE:0.764827	val-MAPE:0.76245
# [6]	train-rmse:145.355	val-rmse:133.595	train-MAPE:0.731812	val-MAPE:0.73037
# [7]	train-rmse:140.204	val-rmse:128.775	train-MAPE:0.700353	val-MAPE:0.698599
# [8]	train-rmse:135.28	val-rmse:124.256	train-MAPE:0.670231	val-MAPE:0.668704
# [9]	train-rmse:130.57	val-rmse:120.908	train-MAPE:0.641384	val-MAPE:0.646657
# [10]	train-rmse:126.066	val-rmse:116.706	train-MAPE:0.613763	val-MAPE:0.618602
# [11]	train-rmse:121.776	val-rmse:113.872	train-MAPE:0.587154	val-MAPE:0.599813
# [12]	train-rmse:117.681	val-rmse:110.122	train-MAPE:0.561722	val-MAPE:0.574793
# [13]	train-rmse:113.765	val-rmse:106.373	train-MAPE:0.537519	val-MAPE:0.549792
# [14]	train-rmse:110.03	val-rmse:103.011	train-MAPE:0.514328	val-MAPE:0.52712
# [15]	train-rmse:106.478	val-rmse:99.8036	train-MAPE:0.492056	val-MAPE:0.505337
# [16]	train-rmse:103.091	val-rmse:96.7031	train-MAPE:0.470726	val-MAPE:0.484196
# [17]	train-rmse:99.8538	val-rmse:93.6595	train-MAPE:0.450386	val-MAPE:0.463833
# [18]	train-rmse:96.7747	val-rmse:91.7827	train-MAPE:0.431065	val-MAPE:0.45119
# [19]	train-rmse:93.8567	val-rmse:89.9913	train-MAPE:0.412745	val-MAPE:0.43908
# [20]	train-rmse:91.0752	val-rmse:87.5246	train-MAPE:0.395511	val-MAPE:0.422289
# [21]	train-rmse:88.4075	val-rmse:85.0209	train-MAPE:0.37947	val-MAPE:0.405326
# [22]	train-rmse:85.8715	val-rmse:82.5257	train-MAPE:0.364364	val-MAPE:0.388537
# [23]	train-rmse:83.4898	val-rmse:81.1056	train-MAPE:0.350104	val-MAPE:0.379159
# [24]	train-rmse:81.2275	val-rmse:79.7537	train-MAPE:0.33678	val-MAPE:0.370327
# [25]	train-rmse:79.0839	val-rmse:78.4671	train-MAPE:0.324246	val-MAPE:0.362125
# [26]	train-rmse:77.0323	val-rmse:76.5515	train-MAPE:0.312672	val-MAPE:0.350209
# [27]	train-rmse:75.0964	val-rmse:74.7209	train-MAPE:0.30195	val-MAPE:0.338551
# [28]	train-rmse:73.2571	val-rmse:72.7911	train-MAPE:0.292049	val-MAPE:0.32636
# [29]	train-rmse:71.5164	val-rmse:71.0319	train-MAPE:0.283042	val-MAPE:0.315447
# [30]	train-rmse:69.8712	val-rmse:69.4346	train-MAPE:0.27473	val-MAPE:0.305979
# [31]	train-rmse:68.2964	val-rmse:67.8879	train-MAPE:0.267165	val-MAPE:0.296645
# [32]	train-rmse:66.8261	val-rmse:66.3688	train-MAPE:0.260245	val-MAPE:0.287745
# [33]	train-rmse:65.4417	val-rmse:65.0616	train-MAPE:0.253859	val-MAPE:0.280099
# [34]	train-rmse:64.1369	val-rmse:63.8201	train-MAPE:0.247992	val-MAPE:0.273044
# [35]	train-rmse:62.9008	val-rmse:62.5534	train-MAPE:0.242613	val-MAPE:0.266164
# [36]	train-rmse:61.7482	val-rmse:61.3411	train-MAPE:0.23783	val-MAPE:0.26008
# [37]	train-rmse:60.6556	val-rmse:60.3108	train-MAPE:0.233398	val-MAPE:0.254587
# [38]	train-rmse:59.6302	val-rmse:59.2867	train-MAPE:0.229294	val-MAPE:0.249389
# [39]	train-rmse:58.6702	val-rmse:58.3543	train-MAPE:0.22562	val-MAPE:0.244989
# [40]	train-rmse:57.7764	val-rmse:57.2798	train-MAPE:0.222252	val-MAPE:0.239831
# [41]	train-rmse:56.9267	val-rmse:56.3666	train-MAPE:0.219333	val-MAPE:0.235503
# [42]	train-rmse:56.1426	val-rmse:55.4451	train-MAPE:0.216687	val-MAPE:0.231198
# [43]	train-rmse:55.3996	val-rmse:54.5997	train-MAPE:0.21432	val-MAPE:0.227458
# [44]	train-rmse:54.7017	val-rmse:53.8071	train-MAPE:0.212223	val-MAPE:0.224123
# [45]	train-rmse:54.0555	val-rmse:53.007	train-MAPE:0.210341	val-MAPE:0.220807
# [46]	train-rmse:53.4457	val-rmse:52.3097	train-MAPE:0.208697	val-MAPE:0.218053
# [47]	train-rmse:52.8836	val-rmse:51.692	train-MAPE:0.207262	val-MAPE:0.215602
# [48]	train-rmse:52.3538	val-rmse:51.045	train-MAPE:0.205906	val-MAPE:0.213209
# [49]	train-rmse:51.8384	val-rmse:50.4274	train-MAPE:0.204706	val-MAPE:0.210863
# [50]	train-rmse:51.3604	val-rmse:49.9348	train-MAPE:0.2037	val-MAPE:0.209122
# [51]	train-rmse:50.9237	val-rmse:49.4983	train-MAPE:0.202805	val-MAPE:0.207763
# [52]	train-rmse:50.5273	val-rmse:49.0672	train-MAPE:0.202061	val-MAPE:0.206381
# [53]	train-rmse:50.1322	val-rmse:48.7005	train-MAPE:0.201353	val-MAPE:0.205232
# [54]	train-rmse:49.7563	val-rmse:48.415	train-MAPE:0.200591	val-MAPE:0.204438
# [55]	train-rmse:49.4271	val-rmse:48.0212	train-MAPE:0.200086	val-MAPE:0.203322
# [56]	train-rmse:49.0983	val-rmse:47.7791	train-MAPE:0.19949	val-MAPE:0.202746
# [57]	train-rmse:48.7876	val-rmse:47.4692	train-MAPE:0.199039	val-MAPE:0.201989
# [58]	train-rmse:48.5211	val-rmse:47.211	train-MAPE:0.1987	val-MAPE:0.201405
# [59]	train-rmse:48.2708	val-rmse:46.9037	train-MAPE:0.1985	val-MAPE:0.200862
# [60]	train-rmse:48.0221	val-rmse:46.696	train-MAPE:0.198229	val-MAPE:0.200429
# [61]	train-rmse:47.7557	val-rmse:46.4728	train-MAPE:0.197922	val-MAPE:0.200187
# [62]	train-rmse:47.5459	val-rmse:46.2402	train-MAPE:0.197824	val-MAPE:0.199876
# [63]	train-rmse:47.3376	val-rmse:46.0339	train-MAPE:0.197728	val-MAPE:0.199641
# [64]	train-rmse:47.1381	val-rmse:45.8809	train-MAPE:0.197592	val-MAPE:0.199502
# [65]	train-rmse:46.9701	val-rmse:45.6447	train-MAPE:0.197624	val-MAPE:0.199331
# [66]	train-rmse:46.8111	val-rmse:45.4393	train-MAPE:0.197653	val-MAPE:0.199318
# [67]	train-rmse:46.6442	val-rmse:45.3222	train-MAPE:0.19764	val-MAPE:0.199298
# [68]	train-rmse:46.5045	val-rmse:45.1445	train-MAPE:0.197719	val-MAPE:0.199185
# [69]	train-rmse:46.356	val-rmse:45.0703	train-MAPE:0.197813	val-MAPE:0.199184
# [70]	train-rmse:46.226	val-rmse:44.9204	train-MAPE:0.197891	val-MAPE:0.199186
# [71]	train-rmse:46.0931	val-rmse:44.7974	train-MAPE:0.197981	val-MAPE:0.199124
# best best_ntree_limit 72

# %% [markdown]
# #### V10

# %%
## 训练预测
# 分割训练集和验证集
ll = round(len(V10_train)/5)
V10_train_val = V10_train.iloc[:ll]
V10_train_t = V10_train.iloc[ll:len(V10_train)]

# 分离标签和特征
Y_time = V10_train_t['volume']
X_time = V10_train_t.drop(['volume'], axis=1)
val_Y_time = V10_train_val.volume
val_X_time = V10_train_val.drop(['volume'], axis=1)

# 转化格式
time_train = xgb.DMatrix(X_time, label=Y_time)
time_val = xgb.DMatrix(val_X_time, label=val_Y_time)
time_test = xgb.DMatrix(V10_test)

#参数设置
params = {
    'booster':'gbtree',      #gbtree和gblinear
    'objective':'reg:linear',
    'eta':0.04,             #为了防止过拟合，更新过程中用到的收缩步长。在每次提升计算之后，算法会直接获得新特征的权重。eta通过缩减特征的权重使提升计算过程更加保守。缺省值为0.3,通常最后设置eta为0.01~0.2
    #'gamma':0.3,            #模型在默认情况下，对于一个节点的划分只有在其loss function得到结果大于0的情况下才进行，而gamma 给定了所需的最低loss function的值gamma值使得算法更conservation，且其值依赖于loss function ，
    'max_depth':5,          #树的深度越大，则对数据的拟合程度越高（过拟合程度也越高）。即该参数也是控制过拟合,建议通过交叉验证（xgb.cv ) 进行调参,通常取值：3-10
    #'min_child_weight':2,   #孩子节点中最小的样本权重和。如果一个叶子节点的样本权重和小于min_child_weight则拆分过程结束。在现行回归模型中，这个参数是指建立每个模型所需要的最小样本数。该成熟越大算法越conservative。即调大这个参数能够控制过拟合。
    #'max_delta_step':2,     #如果取值为0，那么意味着无限制。如果取为正数，则其使得xgboost更新过程更加保守。
    'subsample':1,          #用于训练模型的子样本占整个样本集合的比例。如果设置为0.5则意味着XGBoost将随机的从整个样本集合中抽取出50%的子样本建立树模型，这能够防止过拟合。
    'colsample_bytree':1,   #在建立树时对特征随机采样的比例。缺省值为1 
    #'alpha':5,              #L1 正则的惩罚系数,当数据维度极高时可以使用，使得算法运行更快。
    #'lambda':40,           #L2 正则的惩罚系数,用于处理XGBoost的正则化部分。通常不使用，但可以用来降低过拟合
    'seed':2017,
}


plst = list(params.items())
num_rounds = 525
watchlist = [(time_train, 'train'), (time_val, 'val')]

V10time_model = xgb.train(plst, time_train, num_rounds, watchlist, feval=MAPE)
print("best best_ntree_limit", V10time_model.best_ntree_limit)

V10time_predict = V10time_model.predict(time_test)
# Out:
# [0]	train-rmse:65.4669	val-rmse:37.0729	train-MAPE:0.922879	val-MAPE:0.922521
# [1]	train-rmse:63.0184	val-rmse:35.9287	train-MAPE:0.880908	val-MAPE:0.88479
# [2]	train-rmse:60.6708	val-rmse:34.8341	train-MAPE:0.841189	val-MAPE:0.849382
# [3]	train-rmse:58.4236	val-rmse:33.7883	train-MAPE:0.803216	val-MAPE:0.815405
# [4]	train-rmse:56.2667	val-rmse:32.7868	train-MAPE:0.767122	val-MAPE:0.783027
# [5]	train-rmse:54.2008	val-rmse:31.8126	train-MAPE:0.732766	val-MAPE:0.752727
# [6]	train-rmse:52.2211	val-rmse:30.8932	train-MAPE:0.700183	val-MAPE:0.724677
# [7]	train-rmse:50.3244	val-rmse:30.0172	train-MAPE:0.669933	val-MAPE:0.698673
# [8]	train-rmse:48.5043	val-rmse:29.1911	train-MAPE:0.641477	val-MAPE:0.674612
# [9]	train-rmse:46.7558	val-rmse:28.402	train-MAPE:0.61429	val-MAPE:0.651508
# [10]	train-rmse:45.0815	val-rmse:27.647	train-MAPE:0.588842	val-MAPE:0.629029
# [11]	train-rmse:43.478	val-rmse:26.9488	train-MAPE:0.565081	val-MAPE:0.60855
# [12]	train-rmse:41.9381	val-rmse:26.259	train-MAPE:0.543297	val-MAPE:0.589742
# [13]	train-rmse:40.4691	val-rmse:25.6175	train-MAPE:0.521921	val-MAPE:0.57124
# [14]	train-rmse:39.0619	val-rmse:24.9761	train-MAPE:0.502172	val-MAPE:0.553687
# [15]	train-rmse:37.7093	val-rmse:24.3923	train-MAPE:0.483183	val-MAPE:0.536711
# [16]	train-rmse:36.4154	val-rmse:23.8178	train-MAPE:0.465494	val-MAPE:0.520686
# [17]	train-rmse:35.1743	val-rmse:23.2708	train-MAPE:0.449926	val-MAPE:0.506617
# [18]	train-rmse:33.9887	val-rmse:22.7519	train-MAPE:0.435367	val-MAPE:0.493182
# [19]	train-rmse:32.8597	val-rmse:22.2551	train-MAPE:0.421776	val-MAPE:0.480323
# [20]	train-rmse:31.7685	val-rmse:21.7779	train-MAPE:0.409167	val-MAPE:0.468335
# [21]	train-rmse:30.729	val-rmse:21.3235	train-MAPE:0.397641	val-MAPE:0.457506
# [22]	train-rmse:29.7381	val-rmse:20.9041	train-MAPE:0.38612	val-MAPE:0.446777
# [23]	train-rmse:28.7955	val-rmse:20.5103	train-MAPE:0.375162	val-MAPE:0.436375
# [24]	train-rmse:27.8818	val-rmse:20.118	train-MAPE:0.365995	val-MAPE:0.427691
# [25]	train-rmse:27.0131	val-rmse:19.7459	train-MAPE:0.357097	val-MAPE:0.419463
# [26]	train-rmse:26.183	val-rmse:19.3951	train-MAPE:0.348796	val-MAPE:0.412057
# [27]	train-rmse:25.3828	val-rmse:19.0581	train-MAPE:0.341086	val-MAPE:0.404928
# [28]	train-rmse:24.6222	val-rmse:18.7558	train-MAPE:0.333519	val-MAPE:0.397958
# [29]	train-rmse:23.8972	val-rmse:18.4508	train-MAPE:0.327137	val-MAPE:0.391803
# [30]	train-rmse:23.2194	val-rmse:18.1654	train-MAPE:0.321642	val-MAPE:0.387024
# [31]	train-rmse:22.5598	val-rmse:17.8911	train-MAPE:0.316397	val-MAPE:0.382352
# [32]	train-rmse:21.9407	val-rmse:17.616	train-MAPE:0.31096	val-MAPE:0.376918
# [33]	train-rmse:21.3374	val-rmse:17.2677	train-MAPE:0.306577	val-MAPE:0.371477
# [34]	train-rmse:20.7798	val-rmse:17.0491	train-MAPE:0.301838	val-MAPE:0.367197
# [35]	train-rmse:20.2317	val-rmse:16.8289	train-MAPE:0.298403	val-MAPE:0.364092
# [36]	train-rmse:19.725	val-rmse:16.6275	train-MAPE:0.295481	val-MAPE:0.362324
# [37]	train-rmse:19.2238	val-rmse:16.4124	train-MAPE:0.292009	val-MAPE:0.359828
# [38]	train-rmse:18.751	val-rmse:16.2247	train-MAPE:0.289104	val-MAPE:0.357138
# [39]	train-rmse:18.2998	val-rmse:16.0411	train-MAPE:0.28683	val-MAPE:0.355408
# [40]	train-rmse:17.8496	val-rmse:15.8785	train-MAPE:0.284749	val-MAPE:0.354678
# [41]	train-rmse:17.4337	val-rmse:15.7246	train-MAPE:0.282854	val-MAPE:0.354267
# [42]	train-rmse:17.0296	val-rmse:15.548	train-MAPE:0.280691	val-MAPE:0.352723
# [43]	train-rmse:16.66	val-rmse:15.4054	train-MAPE:0.279404	val-MAPE:0.351685
# [44]	train-rmse:16.2918	val-rmse:15.2824	train-MAPE:0.278164	val-MAPE:0.351469
# [45]	train-rmse:15.9617	val-rmse:15.1479	train-MAPE:0.277225	val-MAPE:0.350662
# [46]	train-rmse:15.6281	val-rmse:15.0292	train-MAPE:0.276296	val-MAPE:0.350924
# [47]	train-rmse:15.3139	val-rmse:14.918	train-MAPE:0.275677	val-MAPE:0.350997
# [48]	train-rmse:15.0211	val-rmse:14.7757	train-MAPE:0.274521	val-MAPE:0.34988
# [49]	train-rmse:14.7362	val-rmse:14.684	train-MAPE:0.274126	val-MAPE:0.350245
# [50]	train-rmse:14.4812	val-rmse:14.5762	train-MAPE:0.272627	val-MAPE:0.348981
# [51]	train-rmse:14.237	val-rmse:14.462	train-MAPE:0.272098	val-MAPE:0.348276
# [52]	train-rmse:13.9892	val-rmse:14.3533	train-MAPE:0.271605	val-MAPE:0.347616
# [53]	train-rmse:13.7539	val-rmse:14.2744	train-MAPE:0.271584	val-MAPE:0.348652
# [54]	train-rmse:13.5324	val-rmse:14.2048	train-MAPE:0.271469	val-MAPE:0.349687
# [55]	train-rmse:13.3364	val-rmse:14.1081	train-MAPE:0.270606	val-MAPE:0.348401
# [56]	train-rmse:13.1287	val-rmse:14.0361	train-MAPE:0.270455	val-MAPE:0.347672
# [57]	train-rmse:12.9335	val-rmse:13.9224	train-MAPE:0.269874	val-MAPE:0.346887
# [58]	train-rmse:12.7527	val-rmse:13.8494	train-MAPE:0.268933	val-MAPE:0.345998
# [59]	train-rmse:12.5483	val-rmse:13.773	train-MAPE:0.2682	val-MAPE:0.344823
# [60]	train-rmse:12.3931	val-rmse:13.7004	train-MAPE:0.267995	val-MAPE:0.344573
# [61]	train-rmse:12.2138	val-rmse:13.68	train-MAPE:0.267919	val-MAPE:0.344866
# [62]	train-rmse:12.0644	val-rmse:13.5908	train-MAPE:0.267267	val-MAPE:0.344112
# [63]	train-rmse:11.9228	val-rmse:13.5105	train-MAPE:0.267022	val-MAPE:0.34363
# [64]	train-rmse:11.7919	val-rmse:13.4195	train-MAPE:0.266161	val-MAPE:0.342313
# [65]	train-rmse:11.6694	val-rmse:13.3524	train-MAPE:0.265928	val-MAPE:0.34202
# [66]	train-rmse:11.5394	val-rmse:13.295	train-MAPE:0.265087	val-MAPE:0.341053
# [67]	train-rmse:11.4203	val-rmse:13.235	train-MAPE:0.26507	val-MAPE:0.340812
# [68]	train-rmse:11.2861	val-rmse:13.2036	train-MAPE:0.264997	val-MAPE:0.341308
# [69]	train-rmse:11.1781	val-rmse:13.1634	train-MAPE:0.264277	val-MAPE:0.341868
# [70]	train-rmse:11.0478	val-rmse:13.1357	train-MAPE:0.264187	val-MAPE:0.34243
# [71]	train-rmse:10.9594	val-rmse:13.0755	train-MAPE:0.263865	val-MAPE:0.342093
# [72]	train-rmse:10.8593	val-rmse:13.0412	train-MAPE:0.2634	val-MAPE:0.342583
# [73]	train-rmse:10.7632	val-rmse:12.9822	train-MAPE:0.262684	val-MAPE:0.341144
# [74]	train-rmse:10.6756	val-rmse:12.964	train-MAPE:0.26223	val-MAPE:0.341594
# [75]	train-rmse:10.5717	val-rmse:12.9083	train-MAPE:0.261827	val-MAPE:0.341209
# [76]	train-rmse:10.4745	val-rmse:12.8559	train-MAPE:0.26146	val-MAPE:0.340912
# [77]	train-rmse:10.3878	val-rmse:12.8074	train-MAPE:0.260738	val-MAPE:0.339913
# [78]	train-rmse:10.2977	val-rmse:12.7936	train-MAPE:0.260463	val-MAPE:0.340164
# [79]	train-rmse:10.2125	val-rmse:12.7121	train-MAPE:0.260175	val-MAPE:0.339484
# [80]	train-rmse:10.1353	val-rmse:12.6692	train-MAPE:0.259522	val-MAPE:0.338532
# [81]	train-rmse:10.0421	val-rmse:12.6381	train-MAPE:0.259059	val-MAPE:0.337918
# [82]	train-rmse:9.97384	val-rmse:12.5971	train-MAPE:0.258449	val-MAPE:0.337013
# [83]	train-rmse:9.88597	val-rmse:12.5718	train-MAPE:0.258069	val-MAPE:0.337682
# [84]	train-rmse:9.8185	val-rmse:12.5285	train-MAPE:0.257581	val-MAPE:0.336947
# [85]	train-rmse:9.74915	val-rmse:12.5096	train-MAPE:0.256685	val-MAPE:0.337013
# [86]	train-rmse:9.68113	val-rmse:12.4919	train-MAPE:0.255984	val-MAPE:0.337117
# [87]	train-rmse:9.60935	val-rmse:12.4841	train-MAPE:0.255829	val-MAPE:0.337656
# [88]	train-rmse:9.55113	val-rmse:12.4676	train-MAPE:0.255035	val-MAPE:0.337714
# [89]	train-rmse:9.4875	val-rmse:12.4432	train-MAPE:0.254582	val-MAPE:0.336821
# [90]	train-rmse:9.43933	val-rmse:12.4046	train-MAPE:0.254009	val-MAPE:0.336136
# [91]	train-rmse:9.38228	val-rmse:12.382	train-MAPE:0.253704	val-MAPE:0.335315
# [92]	train-rmse:9.33107	val-rmse:12.3589	train-MAPE:0.253125	val-MAPE:0.33531
# [93]	train-rmse:9.28629	val-rmse:12.3542	train-MAPE:0.252945	val-MAPE:0.334871
# [94]	train-rmse:9.23961	val-rmse:12.3257	train-MAPE:0.252608	val-MAPE:0.334753
# [95]	train-rmse:9.19383	val-rmse:12.3291	train-MAPE:0.252121	val-MAPE:0.334245
# [96]	train-rmse:9.15163	val-rmse:12.2944	train-MAPE:0.251433	val-MAPE:0.33389
# [97]	train-rmse:9.10842	val-rmse:12.2678	train-MAPE:0.2512	val-MAPE:0.333544
# [98]	train-rmse:9.07304	val-rmse:12.2336	train-MAPE:0.250733	val-MAPE:0.333191
# [99]	train-rmse:9.02395	val-rmse:12.2206	train-MAPE:0.250417	val-MAPE:0.333108
# [100]	train-rmse:8.99239	val-rmse:12.1897	train-MAPE:0.249971	val-MAPE:0.33273
# [101]	train-rmse:8.94623	val-rmse:12.1785	train-MAPE:0.249888	val-MAPE:0.332425
# [102]	train-rmse:8.9075	val-rmse:12.154	train-MAPE:0.249214	val-MAPE:0.331376
# [103]	train-rmse:8.87491	val-rmse:12.1249	train-MAPE:0.249152	val-MAPE:0.33146
# [104]	train-rmse:8.84606	val-rmse:12.1061	train-MAPE:0.248769	val-MAPE:0.330938
# [105]	train-rmse:8.81553	val-rmse:12.0856	train-MAPE:0.248558	val-MAPE:0.330842
# [106]	train-rmse:8.77434	val-rmse:12.0688	train-MAPE:0.248009	val-MAPE:0.330881
# [107]	train-rmse:8.75249	val-rmse:12.0567	train-MAPE:0.247243	val-MAPE:0.330386
# [108]	train-rmse:8.71626	val-rmse:12.0475	train-MAPE:0.247286	val-MAPE:0.330515
# [109]	train-rmse:8.69367	val-rmse:12.0294	train-MAPE:0.247153	val-MAPE:0.330449
# [110]	train-rmse:8.66335	val-rmse:12.0211	train-MAPE:0.247093	val-MAPE:0.330724
# [111]	train-rmse:8.63016	val-rmse:11.9864	train-MAPE:0.246505	val-MAPE:0.330248
# [112]	train-rmse:8.60805	val-rmse:11.9842	train-MAPE:0.245973	val-MAPE:0.330213
# [113]	train-rmse:8.5816	val-rmse:11.9748	train-MAPE:0.245956	val-MAPE:0.330735
# [114]	train-rmse:8.56101	val-rmse:11.9774	train-MAPE:0.245839	val-MAPE:0.330413
# [115]	train-rmse:8.53073	val-rmse:11.9605	train-MAPE:0.245103	val-MAPE:0.329732
# [116]	train-rmse:8.50209	val-rmse:11.9399	train-MAPE:0.24447	val-MAPE:0.32947
# [117]	train-rmse:8.48219	val-rmse:11.9412	train-MAPE:0.244694	val-MAPE:0.329691
# [118]	train-rmse:8.4561	val-rmse:11.9205	train-MAPE:0.244121	val-MAPE:0.329163
# [119]	train-rmse:8.43145	val-rmse:11.9056	train-MAPE:0.243513	val-MAPE:0.328907
# [120]	train-rmse:8.40555	val-rmse:11.8878	train-MAPE:0.243194	val-MAPE:0.328484
# [121]	train-rmse:8.38596	val-rmse:11.8847	train-MAPE:0.243023	val-MAPE:0.329864
# [122]	train-rmse:8.36394	val-rmse:11.8788	train-MAPE:0.242398	val-MAPE:0.329377
# [123]	train-rmse:8.34623	val-rmse:11.8689	train-MAPE:0.242066	val-MAPE:0.32939
# [124]	train-rmse:8.32274	val-rmse:11.858	train-MAPE:0.24194	val-MAPE:0.32963
# [125]	train-rmse:8.30976	val-rmse:11.8422	train-MAPE:0.241197	val-MAPE:0.32929
# [126]	train-rmse:8.28946	val-rmse:11.8462	train-MAPE:0.240808	val-MAPE:0.329391
# [127]	train-rmse:8.26945	val-rmse:11.8368	train-MAPE:0.240237	val-MAPE:0.329157
# [128]	train-rmse:8.25441	val-rmse:11.8326	train-MAPE:0.23994	val-MAPE:0.329164
# [129]	train-rmse:8.23602	val-rmse:11.8374	train-MAPE:0.239666	val-MAPE:0.32899
# [130]	train-rmse:8.21324	val-rmse:11.828	train-MAPE:0.239063	val-MAPE:0.328857
# [131]	train-rmse:8.19074	val-rmse:11.8152	train-MAPE:0.23866	val-MAPE:0.329739
# [132]	train-rmse:8.17649	val-rmse:11.8053	train-MAPE:0.238205	val-MAPE:0.329803
# [133]	train-rmse:8.16016	val-rmse:11.8091	train-MAPE:0.238009	val-MAPE:0.329423
# [134]	train-rmse:8.14025	val-rmse:11.8129	train-MAPE:0.237596	val-MAPE:0.329059
# [135]	train-rmse:8.12206	val-rmse:11.8073	train-MAPE:0.237111	val-MAPE:0.328978
# [136]	train-rmse:8.10032	val-rmse:11.795	train-MAPE:0.236691	val-MAPE:0.328979
# [137]	train-rmse:8.09104	val-rmse:11.7912	train-MAPE:0.236175	val-MAPE:0.329092
# [138]	train-rmse:8.07281	val-rmse:11.7795	train-MAPE:0.235804	val-MAPE:0.332264
# [139]	train-rmse:8.06101	val-rmse:11.776	train-MAPE:0.235543	val-MAPE:0.332327
# [140]	train-rmse:8.05197	val-rmse:11.7702	train-MAPE:0.234964	val-MAPE:0.332162
# [141]	train-rmse:8.03951	val-rmse:11.7688	train-MAPE:0.234898	val-MAPE:0.332151
# [142]	train-rmse:8.01983	val-rmse:11.7646	train-MAPE:0.234472	val-MAPE:0.333578
# [143]	train-rmse:8.00824	val-rmse:11.7635	train-MAPE:0.234407	val-MAPE:0.333546
# [144]	train-rmse:7.99288	val-rmse:11.7649	train-MAPE:0.234266	val-MAPE:0.333497
# [145]	train-rmse:7.96696	val-rmse:11.76	train-MAPE:0.233972	val-MAPE:0.333697
# [146]	train-rmse:7.96016	val-rmse:11.761	train-MAPE:0.233714	val-MAPE:0.333986
# [147]	train-rmse:7.94032	val-rmse:11.7597	train-MAPE:0.233445	val-MAPE:0.333358
# [148]	train-rmse:7.9157	val-rmse:11.7474	train-MAPE:0.233167	val-MAPE:0.333222
# [149]	train-rmse:7.90424	val-rmse:11.7454	train-MAPE:0.23313	val-MAPE:0.33332
# [150]	train-rmse:7.89811	val-rmse:11.7474	train-MAPE:0.232831	val-MAPE:0.333577
# [151]	train-rmse:7.88715	val-rmse:11.7438	train-MAPE:0.232436	val-MAPE:0.333778
# [152]	train-rmse:7.87633	val-rmse:11.7433	train-MAPE:0.2324	val-MAPE:0.333705
# [153]	train-rmse:7.85341	val-rmse:11.7415	train-MAPE:0.232076	val-MAPE:0.334154
# [154]	train-rmse:7.84776	val-rmse:11.7438	train-MAPE:0.231772	val-MAPE:0.334412
# [155]	train-rmse:7.82749	val-rmse:11.7398	train-MAPE:0.231323	val-MAPE:0.334407
# [156]	train-rmse:7.81745	val-rmse:11.7394	train-MAPE:0.231283	val-MAPE:0.334318
# [157]	train-rmse:7.80936	val-rmse:11.729	train-MAPE:0.23121	val-MAPE:0.334143
# [158]	train-rmse:7.80412	val-rmse:11.7315	train-MAPE:0.230903	val-MAPE:0.334401
# [159]	train-rmse:7.78794	val-rmse:11.7255	train-MAPE:0.230663	val-MAPE:0.333884
# [160]	train-rmse:7.78029	val-rmse:11.7169	train-MAPE:0.230615	val-MAPE:0.333556
# [161]	train-rmse:7.76256	val-rmse:11.7016	train-MAPE:0.230197	val-MAPE:0.333683
# [162]	train-rmse:7.7497	val-rmse:11.7002	train-MAPE:0.229815	val-MAPE:0.333458
# [163]	train-rmse:7.72841	val-rmse:11.6945	train-MAPE:0.229387	val-MAPE:0.333188
# [164]	train-rmse:7.72312	val-rmse:11.694	train-MAPE:0.22904	val-MAPE:0.333212
# [165]	train-rmse:7.71444	val-rmse:11.6925	train-MAPE:0.228911	val-MAPE:0.333372
# [166]	train-rmse:7.70904	val-rmse:11.6845	train-MAPE:0.228803	val-MAPE:0.33339
# [167]	train-rmse:7.69277	val-rmse:11.6715	train-MAPE:0.228511	val-MAPE:0.332616
# [168]	train-rmse:7.68775	val-rmse:11.6642	train-MAPE:0.228393	val-MAPE:0.332635
# [169]	train-rmse:7.6831	val-rmse:11.664	train-MAPE:0.228099	val-MAPE:0.332706
# [170]	train-rmse:7.67643	val-rmse:11.6579	train-MAPE:0.228042	val-MAPE:0.332436
# [171]	train-rmse:7.66559	val-rmse:11.6585	train-MAPE:0.227709	val-MAPE:0.332623
# [172]	train-rmse:7.64952	val-rmse:11.6502	train-MAPE:0.227374	val-MAPE:0.332404
# [173]	train-rmse:7.645	val-rmse:11.6441	train-MAPE:0.227256	val-MAPE:0.332414
# [174]	train-rmse:7.64116	val-rmse:11.6467	train-MAPE:0.227033	val-MAPE:0.332745
# [175]	train-rmse:7.62859	val-rmse:11.6391	train-MAPE:0.226893	val-MAPE:0.332425
# [176]	train-rmse:7.6244	val-rmse:11.6333	train-MAPE:0.226783	val-MAPE:0.332418
# [177]	train-rmse:7.61058	val-rmse:11.6325	train-MAPE:0.22652	val-MAPE:0.332523
# [178]	train-rmse:7.60371	val-rmse:11.6309	train-MAPE:0.225977	val-MAPE:0.332468
# [179]	train-rmse:7.59219	val-rmse:11.6243	train-MAPE:0.22584	val-MAPE:0.332162
# [180]	train-rmse:7.58312	val-rmse:11.6221	train-MAPE:0.225434	val-MAPE:0.332053
# [181]	train-rmse:7.57275	val-rmse:11.5964	train-MAPE:0.225165	val-MAPE:0.333011
# [182]	train-rmse:7.5678	val-rmse:11.5914	train-MAPE:0.224664	val-MAPE:0.332488
# [183]	train-rmse:7.55824	val-rmse:11.5905	train-MAPE:0.224137	val-MAPE:0.331776
# [184]	train-rmse:7.54625	val-rmse:11.591	train-MAPE:0.22387	val-MAPE:0.332345
# [185]	train-rmse:7.53963	val-rmse:11.5874	train-MAPE:0.223845	val-MAPE:0.332255
# [186]	train-rmse:7.53276	val-rmse:11.5867	train-MAPE:0.223663	val-MAPE:0.332359
# [187]	train-rmse:7.52752	val-rmse:11.5833	train-MAPE:0.223491	val-MAPE:0.33198
# [188]	train-rmse:7.52429	val-rmse:11.582	train-MAPE:0.222633	val-MAPE:0.331786
# [189]	train-rmse:7.51362	val-rmse:11.5809	train-MAPE:0.222276	val-MAPE:0.331816
# [190]	train-rmse:7.50858	val-rmse:11.581	train-MAPE:0.222197	val-MAPE:0.332165
# [191]	train-rmse:7.49963	val-rmse:11.5827	train-MAPE:0.22196	val-MAPE:0.332634
# [192]	train-rmse:7.49665	val-rmse:11.5813	train-MAPE:0.221124	val-MAPE:0.33212
# [193]	train-rmse:7.49209	val-rmse:11.5809	train-MAPE:0.220963	val-MAPE:0.331986
# [194]	train-rmse:7.48476	val-rmse:11.5804	train-MAPE:0.220861	val-MAPE:0.331999
# [195]	train-rmse:7.48193	val-rmse:11.5794	train-MAPE:0.220085	val-MAPE:0.331846
# [196]	train-rmse:7.47437	val-rmse:11.5796	train-MAPE:0.219848	val-MAPE:0.332241
# [197]	train-rmse:7.45808	val-rmse:11.5704	train-MAPE:0.219581	val-MAPE:0.332051
# [198]	train-rmse:7.45172	val-rmse:11.5701	train-MAPE:0.219479	val-MAPE:0.332089
# [199]	train-rmse:7.44851	val-rmse:11.5672	train-MAPE:0.219384	val-MAPE:0.331951
# [200]	train-rmse:7.44266	val-rmse:11.5623	train-MAPE:0.219174	val-MAPE:0.331366
# [201]	train-rmse:7.43698	val-rmse:11.5646	train-MAPE:0.219047	val-MAPE:0.331431
# [202]	train-rmse:7.43435	val-rmse:11.5632	train-MAPE:0.21823	val-MAPE:0.330936
# [203]	train-rmse:7.42816	val-rmse:11.566	train-MAPE:0.21811	val-MAPE:0.331047
# [204]	train-rmse:7.42257	val-rmse:11.561	train-MAPE:0.217973	val-MAPE:0.330888
# [205]	train-rmse:7.42007	val-rmse:11.56	train-MAPE:0.217272	val-MAPE:0.330733
# [206]	train-rmse:7.41255	val-rmse:11.5598	train-MAPE:0.217182	val-MAPE:0.330739
# [207]	train-rmse:7.40526	val-rmse:11.5534	train-MAPE:0.216894	val-MAPE:0.330857
# [208]	train-rmse:7.39574	val-rmse:11.5478	train-MAPE:0.216676	val-MAPE:0.330612
# [209]	train-rmse:7.38108	val-rmse:11.5566	train-MAPE:0.216356	val-MAPE:0.33016
# [210]	train-rmse:7.37871	val-rmse:11.5549	train-MAPE:0.215604	val-MAPE:0.329946
# [211]	train-rmse:7.37432	val-rmse:11.5551	train-MAPE:0.215626	val-MAPE:0.330183
# [212]	train-rmse:7.37228	val-rmse:11.5534	train-MAPE:0.215084	val-MAPE:0.330005
# [213]	train-rmse:7.36929	val-rmse:11.5538	train-MAPE:0.214942	val-MAPE:0.330005
# [214]	train-rmse:7.35906	val-rmse:11.5545	train-MAPE:0.214815	val-MAPE:0.330229
# [215]	train-rmse:7.35258	val-rmse:11.5502	train-MAPE:0.214549	val-MAPE:0.330407
# [216]	train-rmse:7.34437	val-rmse:11.548	train-MAPE:0.214375	val-MAPE:0.330568
# [217]	train-rmse:7.33591	val-rmse:11.5516	train-MAPE:0.214256	val-MAPE:0.330661
# [218]	train-rmse:7.31867	val-rmse:11.5492	train-MAPE:0.214001	val-MAPE:0.330456
# [219]	train-rmse:7.3083	val-rmse:11.5399	train-MAPE:0.213934	val-MAPE:0.330403
# [220]	train-rmse:7.30206	val-rmse:11.5391	train-MAPE:0.213757	val-MAPE:0.330335
# [221]	train-rmse:7.30003	val-rmse:11.5373	train-MAPE:0.21311	val-MAPE:0.330053
# [222]	train-rmse:7.29169	val-rmse:11.5332	train-MAPE:0.213029	val-MAPE:0.329938
# [223]	train-rmse:7.28969	val-rmse:11.5319	train-MAPE:0.212489	val-MAPE:0.329869
# [224]	train-rmse:7.28667	val-rmse:11.53	train-MAPE:0.212342	val-MAPE:0.329613
# [225]	train-rmse:7.27628	val-rmse:11.5316	train-MAPE:0.212202	val-MAPE:0.329912
# [226]	train-rmse:7.26895	val-rmse:11.5328	train-MAPE:0.212148	val-MAPE:0.329946
# [227]	train-rmse:7.26239	val-rmse:11.5321	train-MAPE:0.212044	val-MAPE:0.330114
# [228]	train-rmse:7.25825	val-rmse:11.5288	train-MAPE:0.211881	val-MAPE:0.32964
# [229]	train-rmse:7.25618	val-rmse:11.5269	train-MAPE:0.211304	val-MAPE:0.32955
# [230]	train-rmse:7.24701	val-rmse:11.5288	train-MAPE:0.211161	val-MAPE:0.329737
# [231]	train-rmse:7.23759	val-rmse:11.5308	train-MAPE:0.210924	val-MAPE:0.330074
# [232]	train-rmse:7.22857	val-rmse:11.5225	train-MAPE:0.210879	val-MAPE:0.330027
# [233]	train-rmse:7.21843	val-rmse:11.5223	train-MAPE:0.210856	val-MAPE:0.330091
# [234]	train-rmse:7.21023	val-rmse:11.5196	train-MAPE:0.210633	val-MAPE:0.330013
# [235]	train-rmse:7.20676	val-rmse:11.5191	train-MAPE:0.210553	val-MAPE:0.329973
# [236]	train-rmse:7.19184	val-rmse:11.5158	train-MAPE:0.210321	val-MAPE:0.329812
# [237]	train-rmse:7.19006	val-rmse:11.5151	train-MAPE:0.209831	val-MAPE:0.329496
# [238]	train-rmse:7.18338	val-rmse:11.5131	train-MAPE:0.20952	val-MAPE:0.329244
# [239]	train-rmse:7.17955	val-rmse:11.5036	train-MAPE:0.209204	val-MAPE:0.328995
# [240]	train-rmse:7.17701	val-rmse:11.5075	train-MAPE:0.209171	val-MAPE:0.329198
# [241]	train-rmse:7.16831	val-rmse:11.5019	train-MAPE:0.209068	val-MAPE:0.329153
# [242]	train-rmse:7.15876	val-rmse:11.5041	train-MAPE:0.208994	val-MAPE:0.329046
# [243]	train-rmse:7.15578	val-rmse:11.5059	train-MAPE:0.208939	val-MAPE:0.329053
# [244]	train-rmse:7.15404	val-rmse:11.5053	train-MAPE:0.208277	val-MAPE:0.328565
# [245]	train-rmse:7.15178	val-rmse:11.5103	train-MAPE:0.208215	val-MAPE:0.32868
# [246]	train-rmse:7.14836	val-rmse:11.5081	train-MAPE:0.208084	val-MAPE:0.328712
# [247]	train-rmse:7.13375	val-rmse:11.5072	train-MAPE:0.207924	val-MAPE:0.328722
# [248]	train-rmse:7.12505	val-rmse:11.51	train-MAPE:0.207715	val-MAPE:0.328576
# [249]	train-rmse:7.11642	val-rmse:11.5063	train-MAPE:0.207387	val-MAPE:0.328424
# [250]	train-rmse:7.11451	val-rmse:11.5052	train-MAPE:0.206858	val-MAPE:0.328039
# [251]	train-rmse:7.10496	val-rmse:11.5063	train-MAPE:0.206711	val-MAPE:0.327995
# [252]	train-rmse:7.10188	val-rmse:11.5063	train-MAPE:0.206668	val-MAPE:0.327645
# [253]	train-rmse:7.08936	val-rmse:11.5049	train-MAPE:0.206536	val-MAPE:0.327206
# [254]	train-rmse:7.08744	val-rmse:11.5077	train-MAPE:0.206463	val-MAPE:0.327393
# [255]	train-rmse:7.0742	val-rmse:11.5091	train-MAPE:0.206294	val-MAPE:0.3273
# [256]	train-rmse:7.07184	val-rmse:11.5118	train-MAPE:0.206255	val-MAPE:0.327336
# [257]	train-rmse:7.07026	val-rmse:11.5107	train-MAPE:0.205672	val-MAPE:0.326911
# [258]	train-rmse:7.06307	val-rmse:11.5085	train-MAPE:0.205476	val-MAPE:0.326846
# [259]	train-rmse:7.06079	val-rmse:11.5086	train-MAPE:0.205383	val-MAPE:0.326876
# [260]	train-rmse:7.0551	val-rmse:11.5067	train-MAPE:0.205081	val-MAPE:0.326766
# [261]	train-rmse:7.05335	val-rmse:11.5061	train-MAPE:0.204585	val-MAPE:0.326635
# [262]	train-rmse:7.04352	val-rmse:11.5097	train-MAPE:0.204521	val-MAPE:0.327293
# [263]	train-rmse:7.04145	val-rmse:11.5152	train-MAPE:0.204427	val-MAPE:0.327447
# [264]	train-rmse:7.03861	val-rmse:11.5145	train-MAPE:0.204303	val-MAPE:0.327373
# [265]	train-rmse:7.03186	val-rmse:11.5124	train-MAPE:0.204118	val-MAPE:0.327313
# [266]	train-rmse:7.03021	val-rmse:11.512	train-MAPE:0.203636	val-MAPE:0.327021
# [267]	train-rmse:7.02686	val-rmse:11.5072	train-MAPE:0.203463	val-MAPE:0.326796
# [268]	train-rmse:7.01824	val-rmse:11.5099	train-MAPE:0.203357	val-MAPE:0.32673
# [269]	train-rmse:7.01243	val-rmse:11.513	train-MAPE:0.203177	val-MAPE:0.327094
# [270]	train-rmse:7.00932	val-rmse:11.5155	train-MAPE:0.203058	val-MAPE:0.327094
# [271]	train-rmse:7.00766	val-rmse:11.5181	train-MAPE:0.203002	val-MAPE:0.327329
# [272]	train-rmse:7.00479	val-rmse:11.5162	train-MAPE:0.202883	val-MAPE:0.327264
# [273]	train-rmse:7.00168	val-rmse:11.5121	train-MAPE:0.202723	val-MAPE:0.327066
# [274]	train-rmse:7.00012	val-rmse:11.5114	train-MAPE:0.202219	val-MAPE:0.326747
# [275]	train-rmse:6.99379	val-rmse:11.5087	train-MAPE:0.202075	val-MAPE:0.326696
# [276]	train-rmse:6.99223	val-rmse:11.5119	train-MAPE:0.202024	val-MAPE:0.32691
# [277]	train-rmse:6.98355	val-rmse:11.5133	train-MAPE:0.201895	val-MAPE:0.326908
# [278]	train-rmse:6.97848	val-rmse:11.5123	train-MAPE:0.201659	val-MAPE:0.327186
# [279]	train-rmse:6.96936	val-rmse:11.51	train-MAPE:0.201599	val-MAPE:0.326998
# [280]	train-rmse:6.96658	val-rmse:11.5055	train-MAPE:0.2014	val-MAPE:0.326787
# [281]	train-rmse:6.96215	val-rmse:11.5062	train-MAPE:0.201277	val-MAPE:0.327128
# [282]	train-rmse:6.96033	val-rmse:11.5078	train-MAPE:0.201237	val-MAPE:0.327113
# [283]	train-rmse:6.95766	val-rmse:11.5126	train-MAPE:0.201182	val-MAPE:0.327192
# [284]	train-rmse:6.95624	val-rmse:11.512	train-MAPE:0.20068	val-MAPE:0.32717
# [285]	train-rmse:6.95527	val-rmse:11.5113	train-MAPE:0.200567	val-MAPE:0.327017
# [286]	train-rmse:6.95339	val-rmse:11.514	train-MAPE:0.200543	val-MAPE:0.32705
# [287]	train-rmse:6.9493	val-rmse:11.5131	train-MAPE:0.200366	val-MAPE:0.327251
# [288]	train-rmse:6.94639	val-rmse:11.5162	train-MAPE:0.200226	val-MAPE:0.327243
# [289]	train-rmse:6.94401	val-rmse:11.5162	train-MAPE:0.200146	val-MAPE:0.327239
# [290]	train-rmse:6.93978	val-rmse:11.5189	train-MAPE:0.20014	val-MAPE:0.327174
# [291]	train-rmse:6.93466	val-rmse:11.5178	train-MAPE:0.200094	val-MAPE:0.327039
# [292]	train-rmse:6.93223	val-rmse:11.5226	train-MAPE:0.200041	val-MAPE:0.327112
# [293]	train-rmse:6.93081	val-rmse:11.5229	train-MAPE:0.199633	val-MAPE:0.327149
# [294]	train-rmse:6.92685	val-rmse:11.5255	train-MAPE:0.199631	val-MAPE:0.327082
# [295]	train-rmse:6.92513	val-rmse:11.5279	train-MAPE:0.199606	val-MAPE:0.327117
# [296]	train-rmse:6.9225	val-rmse:11.5281	train-MAPE:0.199592	val-MAPE:0.326699
# [297]	train-rmse:6.91488	val-rmse:11.5247	train-MAPE:0.199469	val-MAPE:0.326686
# [298]	train-rmse:6.90558	val-rmse:11.5223	train-MAPE:0.19937	val-MAPE:0.326344
# [299]	train-rmse:6.89818	val-rmse:11.5224	train-MAPE:0.199212	val-MAPE:0.326366
# [300]	train-rmse:6.88993	val-rmse:11.5207	train-MAPE:0.199141	val-MAPE:0.326195
# [301]	train-rmse:6.88787	val-rmse:11.5231	train-MAPE:0.199104	val-MAPE:0.326071
# [302]	train-rmse:6.88095	val-rmse:11.5233	train-MAPE:0.198952	val-MAPE:0.326093
# [303]	train-rmse:6.87937	val-rmse:11.5229	train-MAPE:0.198498	val-MAPE:0.326056
# [304]	train-rmse:6.87722	val-rmse:11.5235	train-MAPE:0.198391	val-MAPE:0.326317
# [305]	train-rmse:6.86826	val-rmse:11.5214	train-MAPE:0.198292	val-MAPE:0.325999
# [306]	train-rmse:6.86632	val-rmse:11.5219	train-MAPE:0.198203	val-MAPE:0.326038
# [307]	train-rmse:6.85974	val-rmse:11.523	train-MAPE:0.198064	val-MAPE:0.326086
# [308]	train-rmse:6.85855	val-rmse:11.5228	train-MAPE:0.197638	val-MAPE:0.326136
# [309]	train-rmse:6.85475	val-rmse:11.5217	train-MAPE:0.197443	val-MAPE:0.326174
# [310]	train-rmse:6.85277	val-rmse:11.5238	train-MAPE:0.19743	val-MAPE:0.326311
# [311]	train-rmse:6.83399	val-rmse:11.5222	train-MAPE:0.197299	val-MAPE:0.326221
# [312]	train-rmse:6.83209	val-rmse:11.5201	train-MAPE:0.197164	val-MAPE:0.326028
# [313]	train-rmse:6.82473	val-rmse:11.5201	train-MAPE:0.197062	val-MAPE:0.325979
# [314]	train-rmse:6.81777	val-rmse:11.5232	train-MAPE:0.197045	val-MAPE:0.326039
# [315]	train-rmse:6.80169	val-rmse:11.5183	train-MAPE:0.196944	val-MAPE:0.326241
# [316]	train-rmse:6.79973	val-rmse:11.5174	train-MAPE:0.196896	val-MAPE:0.326154
# [317]	train-rmse:6.79104	val-rmse:11.5172	train-MAPE:0.196826	val-MAPE:0.325863
# [318]	train-rmse:6.78458	val-rmse:11.5203	train-MAPE:0.196815	val-MAPE:0.325918
# [319]	train-rmse:6.76753	val-rmse:11.5189	train-MAPE:0.196704	val-MAPE:0.325828
# [320]	train-rmse:6.75354	val-rmse:11.5137	train-MAPE:0.196577	val-MAPE:0.32579
# [321]	train-rmse:6.75226	val-rmse:11.5136	train-MAPE:0.196291	val-MAPE:0.325669
# [322]	train-rmse:6.74868	val-rmse:11.519	train-MAPE:0.19624	val-MAPE:0.325819
# [323]	train-rmse:6.74358	val-rmse:11.5196	train-MAPE:0.196187	val-MAPE:0.325735
# [324]	train-rmse:6.73949	val-rmse:11.5196	train-MAPE:0.19597	val-MAPE:0.326143
# [325]	train-rmse:6.73114	val-rmse:11.5188	train-MAPE:0.195873	val-MAPE:0.326286
# [326]	train-rmse:6.72622	val-rmse:11.5208	train-MAPE:0.19578	val-MAPE:0.32641
# [327]	train-rmse:6.71617	val-rmse:11.5241	train-MAPE:0.195685	val-MAPE:0.326424
# [328]	train-rmse:6.70249	val-rmse:11.5203	train-MAPE:0.195575	val-MAPE:0.326147
# [329]	train-rmse:6.69763	val-rmse:11.5199	train-MAPE:0.195484	val-MAPE:0.326097
# [330]	train-rmse:6.68676	val-rmse:11.5209	train-MAPE:0.195316	val-MAPE:0.326066
# [331]	train-rmse:6.68544	val-rmse:11.521	train-MAPE:0.194942	val-MAPE:0.326007
# [332]	train-rmse:6.67824	val-rmse:11.52	train-MAPE:0.194833	val-MAPE:0.325948
# [333]	train-rmse:6.66431	val-rmse:11.5174	train-MAPE:0.194714	val-MAPE:0.325927
# [334]	train-rmse:6.65975	val-rmse:11.5171	train-MAPE:0.194629	val-MAPE:0.325882
# [335]	train-rmse:6.65498	val-rmse:11.5175	train-MAPE:0.194548	val-MAPE:0.32547
# [336]	train-rmse:6.65038	val-rmse:11.5213	train-MAPE:0.194427	val-MAPE:0.325588
# [337]	train-rmse:6.64049	val-rmse:11.518	train-MAPE:0.194288	val-MAPE:0.325636
# [338]	train-rmse:6.63278	val-rmse:11.5196	train-MAPE:0.194252	val-MAPE:0.325594
# [339]	train-rmse:6.63016	val-rmse:11.5203	train-MAPE:0.194191	val-MAPE:0.325578
# [340]	train-rmse:6.62295	val-rmse:11.519	train-MAPE:0.194072	val-MAPE:0.325487
# [341]	train-rmse:6.61835	val-rmse:11.5238	train-MAPE:0.193958	val-MAPE:0.325436
# [342]	train-rmse:6.61401	val-rmse:11.5235	train-MAPE:0.193901	val-MAPE:0.325396
# [343]	train-rmse:6.61193	val-rmse:11.5235	train-MAPE:0.193761	val-MAPE:0.325202
# [344]	train-rmse:6.60604	val-rmse:11.5208	train-MAPE:0.193671	val-MAPE:0.325232
# [345]	train-rmse:6.60197	val-rmse:11.5229	train-MAPE:0.193637	val-MAPE:0.325187
# [346]	train-rmse:6.59788	val-rmse:11.5226	train-MAPE:0.193581	val-MAPE:0.325147
# [347]	train-rmse:6.59544	val-rmse:11.5272	train-MAPE:0.193562	val-MAPE:0.325159
# [348]	train-rmse:6.5911	val-rmse:11.5281	train-MAPE:0.193481	val-MAPE:0.325498
# [349]	train-rmse:6.5845	val-rmse:11.5282	train-MAPE:0.193411	val-MAPE:0.325427
# [350]	train-rmse:6.57802	val-rmse:11.5283	train-MAPE:0.193169	val-MAPE:0.325236
# [351]	train-rmse:6.57425	val-rmse:11.5281	train-MAPE:0.193122	val-MAPE:0.325253
# [352]	train-rmse:6.56869	val-rmse:11.5279	train-MAPE:0.193061	val-MAPE:0.325223
# [353]	train-rmse:6.56363	val-rmse:11.5254	train-MAPE:0.192981	val-MAPE:0.325256
# [354]	train-rmse:6.562	val-rmse:11.5277	train-MAPE:0.192888	val-MAPE:0.325038
# [355]	train-rmse:6.55577	val-rmse:11.5273	train-MAPE:0.192716	val-MAPE:0.324967
# [356]	train-rmse:6.55101	val-rmse:11.5284	train-MAPE:0.192629	val-MAPE:0.324704
# [357]	train-rmse:6.55001	val-rmse:11.5285	train-MAPE:0.19227	val-MAPE:0.324621
# [358]	train-rmse:6.54793	val-rmse:11.5287	train-MAPE:0.192194	val-MAPE:0.324581
# [359]	train-rmse:6.54636	val-rmse:11.5282	train-MAPE:0.192168	val-MAPE:0.324613
# [360]	train-rmse:6.54388	val-rmse:11.5255	train-MAPE:0.192114	val-MAPE:0.324815
# [361]	train-rmse:6.53967	val-rmse:11.5265	train-MAPE:0.192022	val-MAPE:0.32463
# [362]	train-rmse:6.536	val-rmse:11.5263	train-MAPE:0.191969	val-MAPE:0.324591
# [363]	train-rmse:6.53485	val-rmse:11.5264	train-MAPE:0.191673	val-MAPE:0.32479
# [364]	train-rmse:6.53059	val-rmse:11.5261	train-MAPE:0.19156	val-MAPE:0.324757
# [365]	train-rmse:6.5293	val-rmse:11.5248	train-MAPE:0.191566	val-MAPE:0.324892
# [366]	train-rmse:6.52698	val-rmse:11.5231	train-MAPE:0.191532	val-MAPE:0.324864
# [367]	train-rmse:6.52384	val-rmse:11.5246	train-MAPE:0.191332	val-MAPE:0.324886
# [368]	train-rmse:6.52218	val-rmse:11.5222	train-MAPE:0.191274	val-MAPE:0.32508
# [369]	train-rmse:6.51983	val-rmse:11.5233	train-MAPE:0.191266	val-MAPE:0.325289
# [370]	train-rmse:6.51863	val-rmse:11.5269	train-MAPE:0.19124	val-MAPE:0.325359
# [371]	train-rmse:6.51568	val-rmse:11.5272	train-MAPE:0.19106	val-MAPE:0.325482
# [372]	train-rmse:6.51026	val-rmse:11.5269	train-MAPE:0.191044	val-MAPE:0.325517
# [373]	train-rmse:6.50854	val-rmse:11.5248	train-MAPE:0.190985	val-MAPE:0.32544
# [374]	train-rmse:6.50382	val-rmse:11.5247	train-MAPE:0.190972	val-MAPE:0.325414
# [375]	train-rmse:6.50273	val-rmse:11.5256	train-MAPE:0.19087	val-MAPE:0.325326
# [376]	train-rmse:6.50151	val-rmse:11.5303	train-MAPE:0.190858	val-MAPE:0.325214
# [377]	train-rmse:6.49572	val-rmse:11.5307	train-MAPE:0.190659	val-MAPE:0.325161
# [378]	train-rmse:6.49085	val-rmse:11.5295	train-MAPE:0.190625	val-MAPE:0.325111
# [379]	train-rmse:6.48799	val-rmse:11.5299	train-MAPE:0.190601	val-MAPE:0.325114
# [380]	train-rmse:6.48647	val-rmse:11.5354	train-MAPE:0.190578	val-MAPE:0.32516
# [381]	train-rmse:6.48423	val-rmse:11.5367	train-MAPE:0.190479	val-MAPE:0.325121
# [382]	train-rmse:6.47706	val-rmse:11.5398	train-MAPE:0.190404	val-MAPE:0.324797
# [383]	train-rmse:6.46612	val-rmse:11.5391	train-MAPE:0.190252	val-MAPE:0.324729
# [384]	train-rmse:6.45899	val-rmse:11.5329	train-MAPE:0.190172	val-MAPE:0.324613
# [385]	train-rmse:6.4533	val-rmse:11.5335	train-MAPE:0.19005	val-MAPE:0.324543
# [386]	train-rmse:6.43847	val-rmse:11.5328	train-MAPE:0.189914	val-MAPE:0.324427
# [387]	train-rmse:6.43203	val-rmse:11.5271	train-MAPE:0.189836	val-MAPE:0.324314
# [388]	train-rmse:6.42499	val-rmse:11.5282	train-MAPE:0.189684	val-MAPE:0.32431
# [389]	train-rmse:6.41903	val-rmse:11.5304	train-MAPE:0.189563	val-MAPE:0.325493
# [390]	train-rmse:6.41476	val-rmse:11.5302	train-MAPE:0.189483	val-MAPE:0.325507
# [391]	train-rmse:6.40945	val-rmse:11.5343	train-MAPE:0.189367	val-MAPE:0.325449
# [392]	train-rmse:6.40361	val-rmse:11.5362	train-MAPE:0.189298	val-MAPE:0.325439
# [393]	train-rmse:6.40274	val-rmse:11.5361	train-MAPE:0.189214	val-MAPE:0.325563
# [394]	train-rmse:6.39508	val-rmse:11.5372	train-MAPE:0.189164	val-MAPE:0.325567
# [395]	train-rmse:6.39163	val-rmse:11.5394	train-MAPE:0.189073	val-MAPE:0.325639
# [396]	train-rmse:6.38364	val-rmse:11.5419	train-MAPE:0.188869	val-MAPE:0.326713
# [397]	train-rmse:6.37824	val-rmse:11.542	train-MAPE:0.188775	val-MAPE:0.32667
# [398]	train-rmse:6.37728	val-rmse:11.5416	train-MAPE:0.188425	val-MAPE:0.326485
# [399]	train-rmse:6.37615	val-rmse:11.5417	train-MAPE:0.188324	val-MAPE:0.326532
# [400]	train-rmse:6.3751	val-rmse:11.541	train-MAPE:0.187985	val-MAPE:0.326356
# [401]	train-rmse:6.36649	val-rmse:11.5419	train-MAPE:0.187842	val-MAPE:0.326359
# [402]	train-rmse:6.36542	val-rmse:11.5421	train-MAPE:0.187745	val-MAPE:0.326424
# [403]	train-rmse:6.3625	val-rmse:11.5447	train-MAPE:0.187703	val-MAPE:0.326457
# [404]	train-rmse:6.36031	val-rmse:11.5436	train-MAPE:0.187544	val-MAPE:0.326419
# [405]	train-rmse:6.3583	val-rmse:11.5455	train-MAPE:0.18746	val-MAPE:0.326328
# [406]	train-rmse:6.35563	val-rmse:11.5476	train-MAPE:0.187454	val-MAPE:0.326395
# [407]	train-rmse:6.35486	val-rmse:11.5468	train-MAPE:0.18745	val-MAPE:0.326419
# [408]	train-rmse:6.35241	val-rmse:11.5472	train-MAPE:0.187419	val-MAPE:0.326387
# [409]	train-rmse:6.34784	val-rmse:11.5454	train-MAPE:0.187352	val-MAPE:0.32642
# [410]	train-rmse:6.34021	val-rmse:11.5481	train-MAPE:0.187199	val-MAPE:0.326503
# [411]	train-rmse:6.33091	val-rmse:11.5457	train-MAPE:0.186949	val-MAPE:0.326034
# [412]	train-rmse:6.32661	val-rmse:11.544	train-MAPE:0.186889	val-MAPE:0.326066
# [413]	train-rmse:6.32547	val-rmse:11.544	train-MAPE:0.186601	val-MAPE:0.325945
# [414]	train-rmse:6.31642	val-rmse:11.5425	train-MAPE:0.186326	val-MAPE:0.325602
# [415]	train-rmse:6.31355	val-rmse:11.5474	train-MAPE:0.186164	val-MAPE:0.325277
# [416]	train-rmse:6.30089	val-rmse:11.5472	train-MAPE:0.186084	val-MAPE:0.325256
# [417]	train-rmse:6.29931	val-rmse:11.5473	train-MAPE:0.18596	val-MAPE:0.325348
# [418]	train-rmse:6.29609	val-rmse:11.5471	train-MAPE:0.185946	val-MAPE:0.325328
# [419]	train-rmse:6.29223	val-rmse:11.5454	train-MAPE:0.185887	val-MAPE:0.325361
# [420]	train-rmse:6.28492	val-rmse:11.5465	train-MAPE:0.185779	val-MAPE:0.325701
# [421]	train-rmse:6.28256	val-rmse:11.5474	train-MAPE:0.185677	val-MAPE:0.325719
# [422]	train-rmse:6.28147	val-rmse:11.5475	train-MAPE:0.185399	val-MAPE:0.325634
# [423]	train-rmse:6.27896	val-rmse:11.5498	train-MAPE:0.185231	val-MAPE:0.32542
# [424]	train-rmse:6.27768	val-rmse:11.5505	train-MAPE:0.18515	val-MAPE:0.325426
# [425]	train-rmse:6.26273	val-rmse:11.55	train-MAPE:0.184942	val-MAPE:0.325539
# [426]	train-rmse:6.25657	val-rmse:11.5466	train-MAPE:0.184799	val-MAPE:0.325373
# [427]	train-rmse:6.24511	val-rmse:11.5478	train-MAPE:0.184714	val-MAPE:0.325461
# [428]	train-rmse:6.23471	val-rmse:11.5502	train-MAPE:0.18466	val-MAPE:0.325512
# [429]	train-rmse:6.23241	val-rmse:11.5503	train-MAPE:0.184601	val-MAPE:0.325519
# [430]	train-rmse:6.2226	val-rmse:11.553	train-MAPE:0.18455	val-MAPE:0.325577
# [431]	train-rmse:6.21367	val-rmse:11.5493	train-MAPE:0.184425	val-MAPE:0.325376
# [432]	train-rmse:6.20312	val-rmse:11.5436	train-MAPE:0.184352	val-MAPE:0.325287
# [433]	train-rmse:6.20233	val-rmse:11.5428	train-MAPE:0.184305	val-MAPE:0.325424
# [434]	train-rmse:6.1981	val-rmse:11.5449	train-MAPE:0.184146	val-MAPE:0.325231
# [435]	train-rmse:6.18824	val-rmse:11.5467	train-MAPE:0.184053	val-MAPE:0.325303
# [436]	train-rmse:6.18146	val-rmse:11.5493	train-MAPE:0.183951	val-MAPE:0.325688
# [437]	train-rmse:6.18023	val-rmse:11.5492	train-MAPE:0.183755	val-MAPE:0.32567
# [438]	train-rmse:6.17569	val-rmse:11.5494	train-MAPE:0.183742	val-MAPE:0.325718
# [439]	train-rmse:6.16966	val-rmse:11.5493	train-MAPE:0.183653	val-MAPE:0.325643
# [440]	train-rmse:6.1685	val-rmse:11.5492	train-MAPE:0.183456	val-MAPE:0.325618
# [441]	train-rmse:6.16725	val-rmse:11.548	train-MAPE:0.183405	val-MAPE:0.325626
# [442]	train-rmse:6.1648	val-rmse:11.5466	train-MAPE:0.183296	val-MAPE:0.325529
# [443]	train-rmse:6.16272	val-rmse:11.546	train-MAPE:0.183204	val-MAPE:0.32561
# [444]	train-rmse:6.15926	val-rmse:11.5463	train-MAPE:0.183133	val-MAPE:0.325621
# [445]	train-rmse:6.1577	val-rmse:11.5465	train-MAPE:0.18305	val-MAPE:0.325672
# [446]	train-rmse:6.15607	val-rmse:11.5475	train-MAPE:0.182854	val-MAPE:0.325753
# [447]	train-rmse:6.15263	val-rmse:11.5595	train-MAPE:0.182784	val-MAPE:0.325477
# [448]	train-rmse:6.15193	val-rmse:11.5647	train-MAPE:0.182721	val-MAPE:0.325623
# [449]	train-rmse:6.14904	val-rmse:11.5657	train-MAPE:0.182588	val-MAPE:0.325587
# [450]	train-rmse:6.14732	val-rmse:11.5667	train-MAPE:0.1824	val-MAPE:0.325611
# [451]	train-rmse:6.14449	val-rmse:11.5697	train-MAPE:0.182333	val-MAPE:0.325598
# [452]	train-rmse:6.14249	val-rmse:11.5698	train-MAPE:0.182099	val-MAPE:0.325472
# [453]	train-rmse:6.13777	val-rmse:11.5614	train-MAPE:0.182067	val-MAPE:0.325559
# [454]	train-rmse:6.1277	val-rmse:11.5619	train-MAPE:0.182003	val-MAPE:0.325601
# [455]	train-rmse:6.12683	val-rmse:11.562	train-MAPE:0.181772	val-MAPE:0.325639
# [456]	train-rmse:6.12438	val-rmse:11.5616	train-MAPE:0.181678	val-MAPE:0.32554
# [457]	train-rmse:6.11643	val-rmse:11.5586	train-MAPE:0.181581	val-MAPE:0.325289
# [458]	train-rmse:6.11554	val-rmse:11.559	train-MAPE:0.181572	val-MAPE:0.325282
# [459]	train-rmse:6.11399	val-rmse:11.5606	train-MAPE:0.181556	val-MAPE:0.3253
# [460]	train-rmse:6.10274	val-rmse:11.5613	train-MAPE:0.181464	val-MAPE:0.325283
# [461]	train-rmse:6.10069	val-rmse:11.5617	train-MAPE:0.181392	val-MAPE:0.325343
# [462]	train-rmse:6.092	val-rmse:11.5615	train-MAPE:0.181342	val-MAPE:0.325343
# [463]	train-rmse:6.0909	val-rmse:11.5691	train-MAPE:0.18131	val-MAPE:0.325211
# [464]	train-rmse:6.09003	val-rmse:11.5695	train-MAPE:0.181196	val-MAPE:0.325275
# [465]	train-rmse:6.08899	val-rmse:11.5768	train-MAPE:0.181164	val-MAPE:0.325161
# [466]	train-rmse:6.0839	val-rmse:11.5737	train-MAPE:0.181035	val-MAPE:0.32496
# [467]	train-rmse:6.08308	val-rmse:11.5741	train-MAPE:0.180926	val-MAPE:0.325039
# [468]	train-rmse:6.08197	val-rmse:11.5741	train-MAPE:0.18054	val-MAPE:0.32495
# [469]	train-rmse:6.07637	val-rmse:11.5742	train-MAPE:0.180456	val-MAPE:0.324916
# [470]	train-rmse:6.06647	val-rmse:11.5697	train-MAPE:0.18032	val-MAPE:0.324804
# [471]	train-rmse:6.05523	val-rmse:11.571	train-MAPE:0.180181	val-MAPE:0.32483
# [472]	train-rmse:6.05177	val-rmse:11.5712	train-MAPE:0.180085	val-MAPE:0.324889
# [473]	train-rmse:6.04871	val-rmse:11.5702	train-MAPE:0.180052	val-MAPE:0.324927
# [474]	train-rmse:6.04788	val-rmse:11.5704	train-MAPE:0.17983	val-MAPE:0.32492
# [475]	train-rmse:6.03734	val-rmse:11.5716	train-MAPE:0.179702	val-MAPE:0.324948
# [476]	train-rmse:6.03464	val-rmse:11.5702	train-MAPE:0.179689	val-MAPE:0.324987
# [477]	train-rmse:6.02906	val-rmse:11.5711	train-MAPE:0.179673	val-MAPE:0.324904
# [478]	train-rmse:6.02175	val-rmse:11.5681	train-MAPE:0.179633	val-MAPE:0.324913
# [479]	train-rmse:6.01724	val-rmse:11.5694	train-MAPE:0.179588	val-MAPE:0.324941
# [480]	train-rmse:6.01329	val-rmse:11.5671	train-MAPE:0.179515	val-MAPE:0.324814
# [481]	train-rmse:6.00904	val-rmse:11.5713	train-MAPE:0.179494	val-MAPE:0.324965
# [482]	train-rmse:6.00425	val-rmse:11.5688	train-MAPE:0.179476	val-MAPE:0.324976
# [483]	train-rmse:5.99575	val-rmse:11.5682	train-MAPE:0.179357	val-MAPE:0.324863
# [484]	train-rmse:5.98356	val-rmse:11.5683	train-MAPE:0.179173	val-MAPE:0.324972
# [485]	train-rmse:5.9825	val-rmse:11.569	train-MAPE:0.179172	val-MAPE:0.325126
# [486]	train-rmse:5.9771	val-rmse:11.567	train-MAPE:0.179053	val-MAPE:0.325004
# [487]	train-rmse:5.97618	val-rmse:11.5687	train-MAPE:0.179039	val-MAPE:0.324998
# [488]	train-rmse:5.96472	val-rmse:11.5686	train-MAPE:0.178878	val-MAPE:0.325106
# [489]	train-rmse:5.96283	val-rmse:11.5669	train-MAPE:0.17893	val-MAPE:0.324823
# [490]	train-rmse:5.96214	val-rmse:11.5684	train-MAPE:0.178842	val-MAPE:0.324825
# [491]	train-rmse:5.95833	val-rmse:11.5807	train-MAPE:0.17878	val-MAPE:0.325028
# [492]	train-rmse:5.95072	val-rmse:11.5803	train-MAPE:0.178736	val-MAPE:0.325023
# [493]	train-rmse:5.9485	val-rmse:11.5817	train-MAPE:0.178694	val-MAPE:0.32501
# [494]	train-rmse:5.94639	val-rmse:11.583	train-MAPE:0.178685	val-MAPE:0.325036
# [495]	train-rmse:5.94303	val-rmse:11.5838	train-MAPE:0.17866	val-MAPE:0.325044
# [496]	train-rmse:5.94102	val-rmse:11.5851	train-MAPE:0.178626	val-MAPE:0.325032
# [497]	train-rmse:5.93783	val-rmse:11.5895	train-MAPE:0.178591	val-MAPE:0.325055
# [498]	train-rmse:5.93528	val-rmse:11.5908	train-MAPE:0.178591	val-MAPE:0.325055
# [499]	train-rmse:5.92815	val-rmse:11.5928	train-MAPE:0.17852	val-MAPE:0.325125
# [500]	train-rmse:5.92122	val-rmse:11.5926	train-MAPE:0.178483	val-MAPE:0.325033
# [501]	train-rmse:5.91734	val-rmse:11.5929	train-MAPE:0.17839	val-MAPE:0.324958
# [502]	train-rmse:5.91544	val-rmse:11.5941	train-MAPE:0.178394	val-MAPE:0.324982
# [503]	train-rmse:5.91453	val-rmse:11.5933	train-MAPE:0.178447	val-MAPE:0.324822
# [504]	train-rmse:5.91266	val-rmse:11.5899	train-MAPE:0.17834	val-MAPE:0.324812
# [505]	train-rmse:5.91169	val-rmse:11.59	train-MAPE:0.178129	val-MAPE:0.324893
# [506]	train-rmse:5.90902	val-rmse:11.5909	train-MAPE:0.178102	val-MAPE:0.324925
# [507]	train-rmse:5.90723	val-rmse:11.5882	train-MAPE:0.177954	val-MAPE:0.324852
# [508]	train-rmse:5.90596	val-rmse:11.5884	train-MAPE:0.177944	val-MAPE:0.324867
# [509]	train-rmse:5.90305	val-rmse:11.5882	train-MAPE:0.177882	val-MAPE:0.324879
# [510]	train-rmse:5.90001	val-rmse:11.588	train-MAPE:0.177804	val-MAPE:0.325084
# [511]	train-rmse:5.8941	val-rmse:11.5921	train-MAPE:0.177814	val-MAPE:0.325077
# [512]	train-rmse:5.89027	val-rmse:11.588	train-MAPE:0.177739	val-MAPE:0.325038
# [513]	train-rmse:5.88644	val-rmse:11.5871	train-MAPE:0.177487	val-MAPE:0.324912
# [514]	train-rmse:5.87876	val-rmse:11.583	train-MAPE:0.177393	val-MAPE:0.324877
# [515]	train-rmse:5.87333	val-rmse:11.5832	train-MAPE:0.177286	val-MAPE:0.324901
# [516]	train-rmse:5.86906	val-rmse:11.5825	train-MAPE:0.177219	val-MAPE:0.324945
# [517]	train-rmse:5.86286	val-rmse:11.5812	train-MAPE:0.177122	val-MAPE:0.324949
# [518]	train-rmse:5.86037	val-rmse:11.5808	train-MAPE:0.177028	val-MAPE:0.32489
# [519]	train-rmse:5.85528	val-rmse:11.5809	train-MAPE:0.176917	val-MAPE:0.324935
# [520]	train-rmse:5.85013	val-rmse:11.5815	train-MAPE:0.17689	val-MAPE:0.325
# [521]	train-rmse:5.84468	val-rmse:11.5815	train-MAPE:0.176824	val-MAPE:0.3249
# [522]	train-rmse:5.84181	val-rmse:11.582	train-MAPE:0.176696	val-MAPE:0.324941
# [523]	train-rmse:5.83754	val-rmse:11.5822	train-MAPE:0.176577	val-MAPE:0.324918
# [524]	train-rmse:5.83135	val-rmse:11.583	train-MAPE:0.176495	val-MAPE:0.324833
# best best_ntree_limit 525

# %% [markdown]
# #### V11

# %%
## 训练预测
# 分割训练集和验证集
ll = round(len(V11_train)/5)
V11_train_val = V11_train.iloc[:ll]
V11_train_t = V11_train.iloc[ll:len(V11_train)]

# 分离标签和特征
Y_time = V11_train_t['volume']
X_time = V11_train_t.drop(['volume'], axis=1)
val_Y_time = V11_train_val.volume
val_X_time = V11_train_val.drop(['volume'], axis=1)

# 转化格式
time_train = xgb.DMatrix(X_time, label=Y_time)
time_val = xgb.DMatrix(val_X_time, label=val_Y_time)
time_test = xgb.DMatrix(V11_test)

#参数设置
params = {
    'booster':'gbtree',      #gbtree和gblinear
    'objective':'reg:linear',
    'eta':0.04,             #为了防止过拟合，更新过程中用到的收缩步长。在每次提升计算之后，算法会直接获得新特征的权重。eta通过缩减特征的权重使提升计算过程更加保守。缺省值为0.3,通常最后设置eta为0.01~0.2
    #'gamma':0.3,            #模型在默认情况下，对于一个节点的划分只有在其loss function得到结果大于0的情况下才进行，而gamma 给定了所需的最低loss function的值gamma值使得算法更conservation，且其值依赖于loss function ，
    'max_depth':5,          #树的深度越大，则对数据的拟合程度越高（过拟合程度也越高）。即该参数也是控制过拟合,建议通过交叉验证（xgb.cv ) 进行调参,通常取值：3-10
    #'min_child_weight':2,   #孩子节点中最小的样本权重和。如果一个叶子节点的样本权重和小于min_child_weight则拆分过程结束。在现行回归模型中，这个参数是指建立每个模型所需要的最小样本数。该成熟越大算法越conservative。即调大这个参数能够控制过拟合。
    #'max_delta_step':2,     #如果取值为0，那么意味着无限制。如果取为正数，则其使得xgboost更新过程更加保守。
    'subsample':1,          #用于训练模型的子样本占整个样本集合的比例。如果设置为0.5则意味着XGBoost将随机的从整个样本集合中抽取出50%的子样本建立树模型，这能够防止过拟合。
    'colsample_bytree':1,   #在建立树时对特征随机采样的比例。缺省值为1 
    #'alpha':5,              #L1 正则的惩罚系数,当数据维度极高时可以使用，使得算法运行更快。
    #'lambda':40,           #L2 正则的惩罚系数,用于处理XGBoost的正则化部分。通常不使用，但可以用来降低过拟合
    'seed':2017,
}


plst = list(params.items())
num_rounds = 357
watchlist = [(time_train, 'train'), (time_val, 'val')]

V11time_model = xgb.train(plst, time_train, num_rounds, watchlist, feval=MAPE)
print("best best_ntree_limit", V11time_model.best_ntree_limit)

V11time_predict = V11time_model.predict(time_test)
# Out:
# [0]	train-rmse:60.8137	val-rmse:69.478	train-MAPE:0.925532	val-MAPE:0.941498
# [1]	train-rmse:58.483	val-rmse:66.8528	train-MAPE:0.884547	val-MAPE:0.902612
# [2]	train-rmse:56.2485	val-rmse:64.3354	train-MAPE:0.845539	val-MAPE:0.865293
# [3]	train-rmse:54.1065	val-rmse:61.9209	train-MAPE:0.808414	val-MAPE:0.829725
# [4]	train-rmse:52.0535	val-rmse:59.6063	train-MAPE:0.773739	val-MAPE:0.796039
# [5]	train-rmse:50.0852	val-rmse:57.3849	train-MAPE:0.741004	val-MAPE:0.763986
# [6]	train-rmse:48.1992	val-rmse:55.2562	train-MAPE:0.710196	val-MAPE:0.733384
# [7]	train-rmse:46.3922	val-rmse:53.2152	train-MAPE:0.680958	val-MAPE:0.704226
# [8]	train-rmse:44.6618	val-rmse:51.2601	train-MAPE:0.652931	val-MAPE:0.675974
# [9]	train-rmse:43.0039	val-rmse:49.3864	train-MAPE:0.626187	val-MAPE:0.649257
# [10]	train-rmse:41.4156	val-rmse:47.5911	train-MAPE:0.601617	val-MAPE:0.624629
# [11]	train-rmse:39.8956	val-rmse:45.8817	train-MAPE:0.57829	val-MAPE:0.601073
# [12]	train-rmse:38.4396	val-rmse:44.2334	train-MAPE:0.556202	val-MAPE:0.578412
# [13]	train-rmse:37.046	val-rmse:42.6551	train-MAPE:0.5351	val-MAPE:0.556589
# [14]	train-rmse:35.714	val-rmse:41.1438	train-MAPE:0.515393	val-MAPE:0.535755
# [15]	train-rmse:34.437	val-rmse:39.6946	train-MAPE:0.496718	val-MAPE:0.515892
# [16]	train-rmse:33.2164	val-rmse:38.3076	train-MAPE:0.479009	val-MAPE:0.496948
# [17]	train-rmse:32.0488	val-rmse:36.9817	train-MAPE:0.462607	val-MAPE:0.478798
# [18]	train-rmse:30.9292	val-rmse:35.7074	train-MAPE:0.447093	val-MAPE:0.461393
# [19]	train-rmse:29.8587	val-rmse:34.4926	train-MAPE:0.432457	val-MAPE:0.44484
# [20]	train-rmse:28.8389	val-rmse:33.3348	train-MAPE:0.418189	val-MAPE:0.429038
# [21]	train-rmse:27.866	val-rmse:32.2274	train-MAPE:0.404858	val-MAPE:0.414333
# [22]	train-rmse:26.9368	val-rmse:31.1577	train-MAPE:0.392654	val-MAPE:0.400273
# [23]	train-rmse:26.0447	val-rmse:30.14	train-MAPE:0.381053	val-MAPE:0.386898
# [24]	train-rmse:25.1996	val-rmse:29.1686	train-MAPE:0.369673	val-MAPE:0.374029
# [25]	train-rmse:24.3932	val-rmse:28.2456	train-MAPE:0.359249	val-MAPE:0.361765
# [26]	train-rmse:23.6246	val-rmse:27.3576	train-MAPE:0.349271	val-MAPE:0.349864
# [27]	train-rmse:22.8864	val-rmse:26.5184	train-MAPE:0.340009	val-MAPE:0.338939
# [28]	train-rmse:22.1835	val-rmse:25.7149	train-MAPE:0.331419	val-MAPE:0.328439
# [29]	train-rmse:21.5088	val-rmse:24.9395	train-MAPE:0.323331	val-MAPE:0.318434
# [30]	train-rmse:20.8605	val-rmse:24.2011	train-MAPE:0.315928	val-MAPE:0.309071
# [31]	train-rmse:20.2543	val-rmse:23.4917	train-MAPE:0.30892	val-MAPE:0.299857
# [32]	train-rmse:19.6731	val-rmse:22.8018	train-MAPE:0.302809	val-MAPE:0.29118
# [33]	train-rmse:19.1255	val-rmse:22.1672	train-MAPE:0.296523	val-MAPE:0.283158
# [34]	train-rmse:18.6002	val-rmse:21.5591	train-MAPE:0.291516	val-MAPE:0.275572
# [35]	train-rmse:18.1058	val-rmse:20.9787	train-MAPE:0.286171	val-MAPE:0.268247
# [36]	train-rmse:17.631	val-rmse:20.4128	train-MAPE:0.281561	val-MAPE:0.261355
# [37]	train-rmse:17.1735	val-rmse:19.8816	train-MAPE:0.276353	val-MAPE:0.254327
# [38]	train-rmse:16.7459	val-rmse:19.3781	train-MAPE:0.27202	val-MAPE:0.248212
# [39]	train-rmse:16.3342	val-rmse:18.884	train-MAPE:0.268033	val-MAPE:0.242239
# [40]	train-rmse:15.948	val-rmse:18.408	train-MAPE:0.264283	val-MAPE:0.236434
# [41]	train-rmse:15.5788	val-rmse:17.9654	train-MAPE:0.260793	val-MAPE:0.231117
# [42]	train-rmse:15.2337	val-rmse:17.5459	train-MAPE:0.257611	val-MAPE:0.226155
# [43]	train-rmse:14.8933	val-rmse:17.1324	train-MAPE:0.254485	val-MAPE:0.221355
# [44]	train-rmse:14.585	val-rmse:16.7526	train-MAPE:0.251532	val-MAPE:0.216932
# [45]	train-rmse:14.2901	val-rmse:16.3966	train-MAPE:0.249585	val-MAPE:0.212964
# [46]	train-rmse:14.0071	val-rmse:16.0594	train-MAPE:0.246671	val-MAPE:0.209092
# [47]	train-rmse:13.7476	val-rmse:15.7499	train-MAPE:0.244519	val-MAPE:0.205544
# [48]	train-rmse:13.4878	val-rmse:15.4334	train-MAPE:0.242317	val-MAPE:0.202142
# [49]	train-rmse:13.2529	val-rmse:15.1497	train-MAPE:0.240554	val-MAPE:0.198834
# [50]	train-rmse:13.0349	val-rmse:14.885	train-MAPE:0.238688	val-MAPE:0.196091
# [51]	train-rmse:12.8162	val-rmse:14.6147	train-MAPE:0.236794	val-MAPE:0.193321
# [52]	train-rmse:12.5956	val-rmse:14.3379	train-MAPE:0.235366	val-MAPE:0.190757
# [53]	train-rmse:12.4026	val-rmse:14.124	train-MAPE:0.233774	val-MAPE:0.188661
# [54]	train-rmse:12.2057	val-rmse:13.8752	train-MAPE:0.232663	val-MAPE:0.186552
# [55]	train-rmse:12.0204	val-rmse:13.6424	train-MAPE:0.231566	val-MAPE:0.184751
# [56]	train-rmse:11.8582	val-rmse:13.4652	train-MAPE:0.230377	val-MAPE:0.183041
# [57]	train-rmse:11.6936	val-rmse:13.2506	train-MAPE:0.229594	val-MAPE:0.1815
# [58]	train-rmse:11.5481	val-rmse:13.1239	train-MAPE:0.228405	val-MAPE:0.180142
# [59]	train-rmse:11.4007	val-rmse:12.9278	train-MAPE:0.227816	val-MAPE:0.178763
# [60]	train-rmse:11.2626	val-rmse:12.7517	train-MAPE:0.227261	val-MAPE:0.177457
# [61]	train-rmse:11.1394	val-rmse:12.6437	train-MAPE:0.226264	val-MAPE:0.176345
# [62]	train-rmse:11.0159	val-rmse:12.4944	train-MAPE:0.225872	val-MAPE:0.175756
# [63]	train-rmse:10.9128	val-rmse:12.3867	train-MAPE:0.225129	val-MAPE:0.174483
# [64]	train-rmse:10.7918	val-rmse:12.2469	train-MAPE:0.224722	val-MAPE:0.173588
# [65]	train-rmse:10.6829	val-rmse:12.0912	train-MAPE:0.224524	val-MAPE:0.173002
# [66]	train-rmse:10.5742	val-rmse:11.9641	train-MAPE:0.224327	val-MAPE:0.172453
# [67]	train-rmse:10.4922	val-rmse:11.8924	train-MAPE:0.223492	val-MAPE:0.171551
# [68]	train-rmse:10.3883	val-rmse:11.7848	train-MAPE:0.223195	val-MAPE:0.171084
# [69]	train-rmse:10.2974	val-rmse:11.6674	train-MAPE:0.223141	val-MAPE:0.1713
# [70]	train-rmse:10.2031	val-rmse:11.5677	train-MAPE:0.222837	val-MAPE:0.170897
# [71]	train-rmse:10.131	val-rmse:11.5127	train-MAPE:0.221923	val-MAPE:0.170218
# [72]	train-rmse:10.0706	val-rmse:11.4359	train-MAPE:0.221679	val-MAPE:0.169813
# [73]	train-rmse:9.98989	val-rmse:11.3321	train-MAPE:0.221386	val-MAPE:0.169454
# [74]	train-rmse:9.91883	val-rmse:11.2491	train-MAPE:0.22115	val-MAPE:0.16942
# [75]	train-rmse:9.84515	val-rmse:11.169	train-MAPE:0.221043	val-MAPE:0.169344
# [76]	train-rmse:9.78636	val-rmse:11.0948	train-MAPE:0.220319	val-MAPE:0.169616
# [77]	train-rmse:9.73572	val-rmse:11.0305	train-MAPE:0.219882	val-MAPE:0.169345
# [78]	train-rmse:9.67773	val-rmse:10.9825	train-MAPE:0.21949	val-MAPE:0.169309
# [79]	train-rmse:9.63256	val-rmse:10.9208	train-MAPE:0.219396	val-MAPE:0.169049
# [80]	train-rmse:9.56558	val-rmse:10.8605	train-MAPE:0.219276	val-MAPE:0.168918
# [81]	train-rmse:9.51235	val-rmse:10.8109	train-MAPE:0.219329	val-MAPE:0.168989
# [82]	train-rmse:9.46543	val-rmse:10.7837	train-MAPE:0.218634	val-MAPE:0.169053
# [83]	train-rmse:9.4148	val-rmse:10.7342	train-MAPE:0.218604	val-MAPE:0.168977
# [84]	train-rmse:9.37256	val-rmse:10.7118	train-MAPE:0.218042	val-MAPE:0.169063
# [85]	train-rmse:9.33311	val-rmse:10.6683	train-MAPE:0.218163	val-MAPE:0.169087
# [86]	train-rmse:9.29642	val-rmse:10.6334	train-MAPE:0.218444	val-MAPE:0.169359
# [87]	train-rmse:9.252	val-rmse:10.6059	train-MAPE:0.21848	val-MAPE:0.169666
# [88]	train-rmse:9.20053	val-rmse:10.5742	train-MAPE:0.217838	val-MAPE:0.169434
# [89]	train-rmse:9.16789	val-rmse:10.5441	train-MAPE:0.218237	val-MAPE:0.170005
# [90]	train-rmse:9.11845	val-rmse:10.5268	train-MAPE:0.217918	val-MAPE:0.17013
# [91]	train-rmse:9.07077	val-rmse:10.4765	train-MAPE:0.217246	val-MAPE:0.170006
# [92]	train-rmse:9.02739	val-rmse:10.4562	train-MAPE:0.216774	val-MAPE:0.17003
# [93]	train-rmse:8.99399	val-rmse:10.4416	train-MAPE:0.216931	val-MAPE:0.170521
# [94]	train-rmse:8.95409	val-rmse:10.4321	train-MAPE:0.217118	val-MAPE:0.17087
# [95]	train-rmse:8.91282	val-rmse:10.3894	train-MAPE:0.216444	val-MAPE:0.170887
# [96]	train-rmse:8.87747	val-rmse:10.3825	train-MAPE:0.216642	val-MAPE:0.171241
# [97]	train-rmse:8.8402	val-rmse:10.3445	train-MAPE:0.216066	val-MAPE:0.17113
# [98]	train-rmse:8.81278	val-rmse:10.3252	train-MAPE:0.215945	val-MAPE:0.171134
# [99]	train-rmse:8.78377	val-rmse:10.3109	train-MAPE:0.216033	val-MAPE:0.171878
# [100]	train-rmse:8.75612	val-rmse:10.3073	train-MAPE:0.21616	val-MAPE:0.17218
# [101]	train-rmse:8.73091	val-rmse:10.2887	train-MAPE:0.216122	val-MAPE:0.17219
# [102]	train-rmse:8.70522	val-rmse:10.2743	train-MAPE:0.216017	val-MAPE:0.172268
# [103]	train-rmse:8.68023	val-rmse:10.2715	train-MAPE:0.21612	val-MAPE:0.173015
# [104]	train-rmse:8.65629	val-rmse:10.2635	train-MAPE:0.216084	val-MAPE:0.173056
# [105]	train-rmse:8.63373	val-rmse:10.2612	train-MAPE:0.216165	val-MAPE:0.173297
# [106]	train-rmse:8.61458	val-rmse:10.2433	train-MAPE:0.216166	val-MAPE:0.173481
# [107]	train-rmse:8.59157	val-rmse:10.2245	train-MAPE:0.214989	val-MAPE:0.172837
# [108]	train-rmse:8.5718	val-rmse:10.2271	train-MAPE:0.21478	val-MAPE:0.173789
# [109]	train-rmse:8.55107	val-rmse:10.2197	train-MAPE:0.214627	val-MAPE:0.173784
# [110]	train-rmse:8.52089	val-rmse:10.1979	train-MAPE:0.21381	val-MAPE:0.174054
# [111]	train-rmse:8.50106	val-rmse:10.1846	train-MAPE:0.213376	val-MAPE:0.173779
# [112]	train-rmse:8.48254	val-rmse:10.1723	train-MAPE:0.212933	val-MAPE:0.173512
# [113]	train-rmse:8.46478	val-rmse:10.1712	train-MAPE:0.212736	val-MAPE:0.173734
# [114]	train-rmse:8.44849	val-rmse:10.1615	train-MAPE:0.21232	val-MAPE:0.173493
# [115]	train-rmse:8.4287	val-rmse:10.158	train-MAPE:0.212044	val-MAPE:0.173765
# [116]	train-rmse:8.41007	val-rmse:10.1471	train-MAPE:0.211878	val-MAPE:0.174225
# [117]	train-rmse:8.39784	val-rmse:10.1426	train-MAPE:0.211664	val-MAPE:0.174645
# [118]	train-rmse:8.3845	val-rmse:10.126	train-MAPE:0.211044	val-MAPE:0.174244
# [119]	train-rmse:8.37271	val-rmse:10.1226	train-MAPE:0.210899	val-MAPE:0.174456
# [120]	train-rmse:8.35465	val-rmse:10.1131	train-MAPE:0.210766	val-MAPE:0.174427
# [121]	train-rmse:8.33866	val-rmse:10.1102	train-MAPE:0.210563	val-MAPE:0.17508
# [122]	train-rmse:8.32292	val-rmse:10.1009	train-MAPE:0.210598	val-MAPE:0.175261
# [123]	train-rmse:8.30616	val-rmse:10.0994	train-MAPE:0.210156	val-MAPE:0.175372
# [124]	train-rmse:8.29656	val-rmse:10.0922	train-MAPE:0.210266	val-MAPE:0.175596
# [125]	train-rmse:8.28078	val-rmse:10.0846	train-MAPE:0.210288	val-MAPE:0.175692
# [126]	train-rmse:8.26488	val-rmse:10.0871	train-MAPE:0.210044	val-MAPE:0.176149
# [127]	train-rmse:8.24893	val-rmse:10.0912	train-MAPE:0.209958	val-MAPE:0.17657
# [128]	train-rmse:8.23781	val-rmse:10.0823	train-MAPE:0.209252	val-MAPE:0.176327
# [129]	train-rmse:8.22346	val-rmse:10.0858	train-MAPE:0.209058	val-MAPE:0.176787
# [130]	train-rmse:8.1977	val-rmse:10.0813	train-MAPE:0.208276	val-MAPE:0.176179
# [131]	train-rmse:8.18758	val-rmse:10.0731	train-MAPE:0.20745	val-MAPE:0.175721
# [132]	train-rmse:8.16253	val-rmse:10.0735	train-MAPE:0.206877	val-MAPE:0.175195
# [133]	train-rmse:8.14874	val-rmse:10.0772	train-MAPE:0.206872	val-MAPE:0.175576
# [134]	train-rmse:8.12613	val-rmse:10.0686	train-MAPE:0.206346	val-MAPE:0.175376
# [135]	train-rmse:8.11777	val-rmse:10.0626	train-MAPE:0.206428	val-MAPE:0.174916
# [136]	train-rmse:8.09408	val-rmse:10.0432	train-MAPE:0.206112	val-MAPE:0.174805
# [137]	train-rmse:8.08186	val-rmse:10.0497	train-MAPE:0.205948	val-MAPE:0.175125
# [138]	train-rmse:8.07138	val-rmse:10.0421	train-MAPE:0.205729	val-MAPE:0.175087
# [139]	train-rmse:8.0575	val-rmse:10.0425	train-MAPE:0.205686	val-MAPE:0.17529
# [140]	train-rmse:8.04534	val-rmse:10.0471	train-MAPE:0.205463	val-MAPE:0.175671
# [141]	train-rmse:8.02554	val-rmse:10.0571	train-MAPE:0.204788	val-MAPE:0.174864
# [142]	train-rmse:8.00879	val-rmse:10.0568	train-MAPE:0.204487	val-MAPE:0.17556
# [143]	train-rmse:7.98448	val-rmse:10.0451	train-MAPE:0.203956	val-MAPE:0.175243
# [144]	train-rmse:7.97683	val-rmse:10.0371	train-MAPE:0.203762	val-MAPE:0.175253
# [145]	train-rmse:7.96439	val-rmse:10.0254	train-MAPE:0.203391	val-MAPE:0.174974
# [146]	train-rmse:7.95227	val-rmse:10.0417	train-MAPE:0.203244	val-MAPE:0.175374
# [147]	train-rmse:7.93831	val-rmse:10.0504	train-MAPE:0.202976	val-MAPE:0.175779
# [148]	train-rmse:7.927	val-rmse:10.042	train-MAPE:0.202611	val-MAPE:0.175585
# [149]	train-rmse:7.91787	val-rmse:10.0485	train-MAPE:0.202524	val-MAPE:0.175823
# [150]	train-rmse:7.90706	val-rmse:10.0387	train-MAPE:0.202211	val-MAPE:0.17555
# [151]	train-rmse:7.8987	val-rmse:10.0357	train-MAPE:0.202217	val-MAPE:0.175679
# [152]	train-rmse:7.88862	val-rmse:10.0269	train-MAPE:0.201999	val-MAPE:0.175426
# [153]	train-rmse:7.87728	val-rmse:10.0266	train-MAPE:0.201768	val-MAPE:0.175371
# [154]	train-rmse:7.86232	val-rmse:10.0386	train-MAPE:0.201319	val-MAPE:0.174617
# [155]	train-rmse:7.85264	val-rmse:10.0564	train-MAPE:0.20121	val-MAPE:0.174938
# [156]	train-rmse:7.84579	val-rmse:10.0552	train-MAPE:0.200687	val-MAPE:0.174647
# [157]	train-rmse:7.83786	val-rmse:10.0622	train-MAPE:0.200585	val-MAPE:0.174861
# [158]	train-rmse:7.82883	val-rmse:10.0558	train-MAPE:0.200578	val-MAPE:0.174988
# [159]	train-rmse:7.81529	val-rmse:10.0573	train-MAPE:0.199979	val-MAPE:0.175169
# [160]	train-rmse:7.80068	val-rmse:10.0707	train-MAPE:0.199772	val-MAPE:0.174635
# [161]	train-rmse:7.79324	val-rmse:10.0695	train-MAPE:0.1994	val-MAPE:0.174694
# [162]	train-rmse:7.78393	val-rmse:10.076	train-MAPE:0.199213	val-MAPE:0.17464
# [163]	train-rmse:7.77175	val-rmse:10.0873	train-MAPE:0.198802	val-MAPE:0.174171
# [164]	train-rmse:7.75896	val-rmse:10.1046	train-MAPE:0.198592	val-MAPE:0.173737
# [165]	train-rmse:7.75467	val-rmse:10.1038	train-MAPE:0.19846	val-MAPE:0.173732
# [166]	train-rmse:7.74524	val-rmse:10.1014	train-MAPE:0.197997	val-MAPE:0.173659
# [167]	train-rmse:7.7326	val-rmse:10.1067	train-MAPE:0.197867	val-MAPE:0.1737
# [168]	train-rmse:7.72618	val-rmse:10.1111	train-MAPE:0.197717	val-MAPE:0.17382
# [169]	train-rmse:7.72068	val-rmse:10.1036	train-MAPE:0.197442	val-MAPE:0.173947
# [170]	train-rmse:7.712	val-rmse:10.1017	train-MAPE:0.196994	val-MAPE:0.173875
# [171]	train-rmse:7.70875	val-rmse:10.0998	train-MAPE:0.196832	val-MAPE:0.174069
# [172]	train-rmse:7.70157	val-rmse:10.0972	train-MAPE:0.196425	val-MAPE:0.173789
# [173]	train-rmse:7.6943	val-rmse:10.1167	train-MAPE:0.196337	val-MAPE:0.17393
# [174]	train-rmse:7.69044	val-rmse:10.1155	train-MAPE:0.195947	val-MAPE:0.173495
# [175]	train-rmse:7.68375	val-rmse:10.1219	train-MAPE:0.19595	val-MAPE:0.17354
# [176]	train-rmse:7.67872	val-rmse:10.1149	train-MAPE:0.195684	val-MAPE:0.17345
# [177]	train-rmse:7.6724	val-rmse:10.1174	train-MAPE:0.19563	val-MAPE:0.173444
# [178]	train-rmse:7.66591	val-rmse:10.1153	train-MAPE:0.195247	val-MAPE:0.173194
# [179]	train-rmse:7.66096	val-rmse:10.1095	train-MAPE:0.194938	val-MAPE:0.173107
# [180]	train-rmse:7.65489	val-rmse:10.117	train-MAPE:0.194815	val-MAPE:0.17314
# [181]	train-rmse:7.64925	val-rmse:10.1098	train-MAPE:0.194556	val-MAPE:0.173161
# [182]	train-rmse:7.64235	val-rmse:10.1176	train-MAPE:0.194495	val-MAPE:0.173248
# [183]	train-rmse:7.6336	val-rmse:10.1212	train-MAPE:0.194329	val-MAPE:0.173398
# [184]	train-rmse:7.62308	val-rmse:10.1236	train-MAPE:0.193994	val-MAPE:0.173559
# [185]	train-rmse:7.61787	val-rmse:10.1246	train-MAPE:0.193766	val-MAPE:0.17371
# [186]	train-rmse:7.61307	val-rmse:10.1223	train-MAPE:0.193548	val-MAPE:0.17363
# [187]	train-rmse:7.60805	val-rmse:10.1206	train-MAPE:0.193577	val-MAPE:0.173542
# [188]	train-rmse:7.60394	val-rmse:10.1161	train-MAPE:0.193204	val-MAPE:0.173806
# [189]	train-rmse:7.59087	val-rmse:10.1052	train-MAPE:0.193041	val-MAPE:0.173714
# [190]	train-rmse:7.5856	val-rmse:10.1001	train-MAPE:0.192862	val-MAPE:0.174048
# [191]	train-rmse:7.57743	val-rmse:10.1004	train-MAPE:0.19275	val-MAPE:0.174173
# [192]	train-rmse:7.57101	val-rmse:10.1069	train-MAPE:0.19264	val-MAPE:0.174297
# [193]	train-rmse:7.56462	val-rmse:10.0998	train-MAPE:0.19224	val-MAPE:0.174247
# [194]	train-rmse:7.55799	val-rmse:10.0961	train-MAPE:0.191864	val-MAPE:0.173985
# [195]	train-rmse:7.55166	val-rmse:10.0936	train-MAPE:0.19171	val-MAPE:0.173895
# [196]	train-rmse:7.54755	val-rmse:10.0925	train-MAPE:0.191517	val-MAPE:0.173564
# [197]	train-rmse:7.54214	val-rmse:10.0914	train-MAPE:0.191332	val-MAPE:0.173531
# [198]	train-rmse:7.5293	val-rmse:10.0903	train-MAPE:0.191135	val-MAPE:0.173374
# [199]	train-rmse:7.52492	val-rmse:10.0897	train-MAPE:0.190893	val-MAPE:0.173117
# [200]	train-rmse:7.52125	val-rmse:10.0857	train-MAPE:0.190699	val-MAPE:0.173145
# [201]	train-rmse:7.51272	val-rmse:10.089	train-MAPE:0.190663	val-MAPE:0.173197
# [202]	train-rmse:7.50062	val-rmse:10.0852	train-MAPE:0.190486	val-MAPE:0.173081
# [203]	train-rmse:7.49295	val-rmse:10.0989	train-MAPE:0.190136	val-MAPE:0.173584
# [204]	train-rmse:7.48845	val-rmse:10.0981	train-MAPE:0.190153	val-MAPE:0.17351
# [205]	train-rmse:7.48272	val-rmse:10.0955	train-MAPE:0.189758	val-MAPE:0.173398
# [206]	train-rmse:7.47541	val-rmse:10.1078	train-MAPE:0.189462	val-MAPE:0.173611
# [207]	train-rmse:7.47022	val-rmse:10.1129	train-MAPE:0.189455	val-MAPE:0.173644
# [208]	train-rmse:7.4597	val-rmse:10.1079	train-MAPE:0.189327	val-MAPE:0.173618
# [209]	train-rmse:7.45587	val-rmse:10.1109	train-MAPE:0.189093	val-MAPE:0.173565
# [210]	train-rmse:7.45348	val-rmse:10.108	train-MAPE:0.188923	val-MAPE:0.17349
# [211]	train-rmse:7.44581	val-rmse:10.1027	train-MAPE:0.188563	val-MAPE:0.173283
# [212]	train-rmse:7.44127	val-rmse:10.1016	train-MAPE:0.188291	val-MAPE:0.173072
# [213]	train-rmse:7.43008	val-rmse:10.1023	train-MAPE:0.188113	val-MAPE:0.172987
# [214]	train-rmse:7.42085	val-rmse:10.1006	train-MAPE:0.187922	val-MAPE:0.173008
# [215]	train-rmse:7.4159	val-rmse:10.0955	train-MAPE:0.187905	val-MAPE:0.172929
# [216]	train-rmse:7.40781	val-rmse:10.0919	train-MAPE:0.18786	val-MAPE:0.172968
# [217]	train-rmse:7.39794	val-rmse:10.093	train-MAPE:0.187682	val-MAPE:0.172967
# [218]	train-rmse:7.39266	val-rmse:10.0909	train-MAPE:0.187542	val-MAPE:0.172941
# [219]	train-rmse:7.38868	val-rmse:10.0908	train-MAPE:0.187556	val-MAPE:0.172875
# [220]	train-rmse:7.37859	val-rmse:10.0861	train-MAPE:0.187394	val-MAPE:0.172856
# [221]	train-rmse:7.37487	val-rmse:10.0833	train-MAPE:0.187129	val-MAPE:0.172765
# [222]	train-rmse:7.36902	val-rmse:10.0844	train-MAPE:0.18689	val-MAPE:0.172701
# [223]	train-rmse:7.36529	val-rmse:10.0854	train-MAPE:0.186904	val-MAPE:0.172651
# [224]	train-rmse:7.35507	val-rmse:10.0844	train-MAPE:0.186799	val-MAPE:0.172495
# [225]	train-rmse:7.35104	val-rmse:10.0886	train-MAPE:0.186675	val-MAPE:0.172515
# [226]	train-rmse:7.34309	val-rmse:10.089	train-MAPE:0.186488	val-MAPE:0.1722
# [227]	train-rmse:7.34133	val-rmse:10.0871	train-MAPE:0.186281	val-MAPE:0.172041
# [228]	train-rmse:7.33733	val-rmse:10.0852	train-MAPE:0.186157	val-MAPE:0.172405
# [229]	train-rmse:7.33146	val-rmse:10.0896	train-MAPE:0.185993	val-MAPE:0.172955
# [230]	train-rmse:7.32771	val-rmse:10.0877	train-MAPE:0.185795	val-MAPE:0.172917
# [231]	train-rmse:7.32574	val-rmse:10.0862	train-MAPE:0.185601	val-MAPE:0.172824
# [232]	train-rmse:7.32178	val-rmse:10.0819	train-MAPE:0.185577	val-MAPE:0.172754
# [233]	train-rmse:7.32016	val-rmse:10.0802	train-MAPE:0.185374	val-MAPE:0.172599
# [234]	train-rmse:7.31809	val-rmse:10.0796	train-MAPE:0.185352	val-MAPE:0.172591
# [235]	train-rmse:7.31472	val-rmse:10.0793	train-MAPE:0.185336	val-MAPE:0.172555
# [236]	train-rmse:7.31131	val-rmse:10.0776	train-MAPE:0.185155	val-MAPE:0.172523
# [237]	train-rmse:7.30001	val-rmse:10.0822	train-MAPE:0.184887	val-MAPE:0.172933
# [238]	train-rmse:7.28399	val-rmse:10.0829	train-MAPE:0.184598	val-MAPE:0.172993
# [239]	train-rmse:7.27788	val-rmse:10.0799	train-MAPE:0.184573	val-MAPE:0.173079
# [240]	train-rmse:7.27194	val-rmse:10.0806	train-MAPE:0.184438	val-MAPE:0.173174
# [241]	train-rmse:7.2665	val-rmse:10.0781	train-MAPE:0.184066	val-MAPE:0.173049
# [242]	train-rmse:7.26437	val-rmse:10.0783	train-MAPE:0.184022	val-MAPE:0.173115
# [243]	train-rmse:7.25365	val-rmse:10.0798	train-MAPE:0.18384	val-MAPE:0.172852
# [244]	train-rmse:7.24457	val-rmse:10.0833	train-MAPE:0.183645	val-MAPE:0.172865
# [245]	train-rmse:7.24058	val-rmse:10.083	train-MAPE:0.183355	val-MAPE:0.172864
# [246]	train-rmse:7.23669	val-rmse:10.0817	train-MAPE:0.183102	val-MAPE:0.172671
# [247]	train-rmse:7.22227	val-rmse:10.0812	train-MAPE:0.182786	val-MAPE:0.172647
# [248]	train-rmse:7.2174	val-rmse:10.0793	train-MAPE:0.182472	val-MAPE:0.172512
# [249]	train-rmse:7.20603	val-rmse:10.0766	train-MAPE:0.182294	val-MAPE:0.172229
# [250]	train-rmse:7.20377	val-rmse:10.0755	train-MAPE:0.18227	val-MAPE:0.172193
# [251]	train-rmse:7.19818	val-rmse:10.0756	train-MAPE:0.182156	val-MAPE:0.172425
# [252]	train-rmse:7.19199	val-rmse:10.0753	train-MAPE:0.182183	val-MAPE:0.172473
# [253]	train-rmse:7.18826	val-rmse:10.0759	train-MAPE:0.181849	val-MAPE:0.172549
# [254]	train-rmse:7.17771	val-rmse:10.0735	train-MAPE:0.18172	val-MAPE:0.172268
# [255]	train-rmse:7.17587	val-rmse:10.0726	train-MAPE:0.181577	val-MAPE:0.172235
# [256]	train-rmse:7.1684	val-rmse:10.0722	train-MAPE:0.181386	val-MAPE:0.17223
# [257]	train-rmse:7.16397	val-rmse:10.0724	train-MAPE:0.181442	val-MAPE:0.172278
# [258]	train-rmse:7.15703	val-rmse:10.0721	train-MAPE:0.181231	val-MAPE:0.172272
# [259]	train-rmse:7.15149	val-rmse:10.0682	train-MAPE:0.181015	val-MAPE:0.17237
# [260]	train-rmse:7.14883	val-rmse:10.0675	train-MAPE:0.180988	val-MAPE:0.172362
# [261]	train-rmse:7.14377	val-rmse:10.0634	train-MAPE:0.180759	val-MAPE:0.172449
# [262]	train-rmse:7.13511	val-rmse:10.0606	train-MAPE:0.180527	val-MAPE:0.172424
# [263]	train-rmse:7.13261	val-rmse:10.0599	train-MAPE:0.180499	val-MAPE:0.172417
# [264]	train-rmse:7.12343	val-rmse:10.0585	train-MAPE:0.180331	val-MAPE:0.172375
# [265]	train-rmse:7.11591	val-rmse:10.0562	train-MAPE:0.18019	val-MAPE:0.172318
# [266]	train-rmse:7.1121	val-rmse:10.0575	train-MAPE:0.180082	val-MAPE:0.172328
# [267]	train-rmse:7.11015	val-rmse:10.057	train-MAPE:0.180122	val-MAPE:0.172398
# [268]	train-rmse:7.10565	val-rmse:10.0569	train-MAPE:0.180002	val-MAPE:0.172354
# [269]	train-rmse:7.10122	val-rmse:10.0581	train-MAPE:0.179803	val-MAPE:0.172265
# [270]	train-rmse:7.09694	val-rmse:10.0573	train-MAPE:0.179676	val-MAPE:0.172243
# [271]	train-rmse:7.09089	val-rmse:10.0535	train-MAPE:0.179361	val-MAPE:0.172047
# [272]	train-rmse:7.08553	val-rmse:10.0528	train-MAPE:0.179355	val-MAPE:0.172016
# [273]	train-rmse:7.0826	val-rmse:10.0509	train-MAPE:0.17931	val-MAPE:0.172006
# [274]	train-rmse:7.07825	val-rmse:10.0503	train-MAPE:0.179181	val-MAPE:0.171982
# [275]	train-rmse:7.07314	val-rmse:10.051	train-MAPE:0.179175	val-MAPE:0.172015
# [276]	train-rmse:7.06818	val-rmse:10.0503	train-MAPE:0.179168	val-MAPE:0.171985
# [277]	train-rmse:7.0547	val-rmse:10.0517	train-MAPE:0.178916	val-MAPE:0.172025
# [278]	train-rmse:7.04566	val-rmse:10.0479	train-MAPE:0.17874	val-MAPE:0.171979
# [279]	train-rmse:7.04195	val-rmse:10.048	train-MAPE:0.178538	val-MAPE:0.171932
# [280]	train-rmse:7.03096	val-rmse:10.0486	train-MAPE:0.178435	val-MAPE:0.172115
# [281]	train-rmse:7.02763	val-rmse:10.0461	train-MAPE:0.17812	val-MAPE:0.172068
# [282]	train-rmse:7.02614	val-rmse:10.0443	train-MAPE:0.17817	val-MAPE:0.172115
# [283]	train-rmse:7.02152	val-rmse:10.0437	train-MAPE:0.178164	val-MAPE:0.172087
# [284]	train-rmse:7.00943	val-rmse:10.0447	train-MAPE:0.177949	val-MAPE:0.172054
# [285]	train-rmse:7.00074	val-rmse:10.0421	train-MAPE:0.177801	val-MAPE:0.172003
# [286]	train-rmse:6.99345	val-rmse:10.0355	train-MAPE:0.177756	val-MAPE:0.171455
# [287]	train-rmse:6.99246	val-rmse:10.035	train-MAPE:0.177732	val-MAPE:0.171535
# [288]	train-rmse:6.99144	val-rmse:10.034	train-MAPE:0.177753	val-MAPE:0.171537
# [289]	train-rmse:6.98681	val-rmse:10.0318	train-MAPE:0.177812	val-MAPE:0.171545
# [290]	train-rmse:6.98339	val-rmse:10.031	train-MAPE:0.177589	val-MAPE:0.171378
# [291]	train-rmse:6.97915	val-rmse:10.0304	train-MAPE:0.177583	val-MAPE:0.171352
# [292]	train-rmse:6.96747	val-rmse:10.0286	train-MAPE:0.177362	val-MAPE:0.171396
# [293]	train-rmse:6.9609	val-rmse:10.0302	train-MAPE:0.177239	val-MAPE:0.171398
# [294]	train-rmse:6.9568	val-rmse:10.0299	train-MAPE:0.177089	val-MAPE:0.171357
# [295]	train-rmse:6.95166	val-rmse:10.0301	train-MAPE:0.177044	val-MAPE:0.171326
# [296]	train-rmse:6.94177	val-rmse:10.0286	train-MAPE:0.176943	val-MAPE:0.171503
# [297]	train-rmse:6.93861	val-rmse:10.0278	train-MAPE:0.176704	val-MAPE:0.171346
# [298]	train-rmse:6.93153	val-rmse:10.0239	train-MAPE:0.176597	val-MAPE:0.170817
# [299]	train-rmse:6.92664	val-rmse:10.0241	train-MAPE:0.176548	val-MAPE:0.17079
# [300]	train-rmse:6.91611	val-rmse:10.0242	train-MAPE:0.176478	val-MAPE:0.170937
# [301]	train-rmse:6.90635	val-rmse:10.0246	train-MAPE:0.176229	val-MAPE:0.170801
# [302]	train-rmse:6.90172	val-rmse:10.0267	train-MAPE:0.176187	val-MAPE:0.170803
# [303]	train-rmse:6.89844	val-rmse:10.0277	train-MAPE:0.175921	val-MAPE:0.17085
# [304]	train-rmse:6.88786	val-rmse:10.0266	train-MAPE:0.175739	val-MAPE:0.170844
# [305]	train-rmse:6.88638	val-rmse:10.0262	train-MAPE:0.175761	val-MAPE:0.170906
# [306]	train-rmse:6.87892	val-rmse:10.0231	train-MAPE:0.175666	val-MAPE:0.170897
# [307]	train-rmse:6.87521	val-rmse:10.0214	train-MAPE:0.175341	val-MAPE:0.170813
# [308]	train-rmse:6.8649	val-rmse:10.0226	train-MAPE:0.175162	val-MAPE:0.170793
# [309]	train-rmse:6.86102	val-rmse:10.0217	train-MAPE:0.175096	val-MAPE:0.170775
# [310]	train-rmse:6.84833	val-rmse:10.0084	train-MAPE:0.174891	val-MAPE:0.170247
# [311]	train-rmse:6.84743	val-rmse:10.0074	train-MAPE:0.174789	val-MAPE:0.170202
# [312]	train-rmse:6.84615	val-rmse:10.0065	train-MAPE:0.174774	val-MAPE:0.170207
# [313]	train-rmse:6.84475	val-rmse:10.0063	train-MAPE:0.174654	val-MAPE:0.170189
# [314]	train-rmse:6.83359	val-rmse:9.99918	train-MAPE:0.174487	val-MAPE:0.169757
# [315]	train-rmse:6.82778	val-rmse:9.99485	train-MAPE:0.174407	val-MAPE:0.169244
# [316]	train-rmse:6.82021	val-rmse:9.99513	train-MAPE:0.174308	val-MAPE:0.169171
# [317]	train-rmse:6.8131	val-rmse:9.99583	train-MAPE:0.174216	val-MAPE:0.168926
# [318]	train-rmse:6.80966	val-rmse:9.99607	train-MAPE:0.174156	val-MAPE:0.168963
# [319]	train-rmse:6.80326	val-rmse:9.99641	train-MAPE:0.17411	val-MAPE:0.168858
# [320]	train-rmse:6.79734	val-rmse:9.99236	train-MAPE:0.174043	val-MAPE:0.168618
# [321]	train-rmse:6.79433	val-rmse:9.99233	train-MAPE:0.173964	val-MAPE:0.168624
# [322]	train-rmse:6.78828	val-rmse:9.99379	train-MAPE:0.173883	val-MAPE:0.168588
# [323]	train-rmse:6.78493	val-rmse:9.99629	train-MAPE:0.173837	val-MAPE:0.168704
# [324]	train-rmse:6.78078	val-rmse:9.99895	train-MAPE:0.173751	val-MAPE:0.168826
# [325]	train-rmse:6.77755	val-rmse:9.99993	train-MAPE:0.173687	val-MAPE:0.168877
# [326]	train-rmse:6.77177	val-rmse:9.99906	train-MAPE:0.173507	val-MAPE:0.168999
# [327]	train-rmse:6.76762	val-rmse:9.99873	train-MAPE:0.173434	val-MAPE:0.168994
# [328]	train-rmse:6.76387	val-rmse:9.99887	train-MAPE:0.173379	val-MAPE:0.169034
# [329]	train-rmse:6.75705	val-rmse:10.0008	train-MAPE:0.173155	val-MAPE:0.168946
# [330]	train-rmse:6.75382	val-rmse:10.0017	train-MAPE:0.173116	val-MAPE:0.168963
# [331]	train-rmse:6.75042	val-rmse:10.0002	train-MAPE:0.173158	val-MAPE:0.168991
# [332]	train-rmse:6.744	val-rmse:10.0021	train-MAPE:0.172942	val-MAPE:0.168904
# [333]	train-rmse:6.74219	val-rmse:10.0013	train-MAPE:0.172693	val-MAPE:0.168858
# [334]	train-rmse:6.7354	val-rmse:10.0013	train-MAPE:0.172554	val-MAPE:0.168942
# [335]	train-rmse:6.73125	val-rmse:9.99976	train-MAPE:0.172381	val-MAPE:0.168972
# [336]	train-rmse:6.72478	val-rmse:9.99817	train-MAPE:0.172259	val-MAPE:0.169021
# [337]	train-rmse:6.71855	val-rmse:9.99481	train-MAPE:0.172173	val-MAPE:0.169003
# [338]	train-rmse:6.71451	val-rmse:9.99547	train-MAPE:0.172105	val-MAPE:0.169018
# [339]	train-rmse:6.71063	val-rmse:9.99698	train-MAPE:0.172073	val-MAPE:0.169121
# [340]	train-rmse:6.70468	val-rmse:9.99652	train-MAPE:0.171957	val-MAPE:0.169092
# [341]	train-rmse:6.69882	val-rmse:9.99385	train-MAPE:0.171877	val-MAPE:0.169078
# [342]	train-rmse:6.69368	val-rmse:9.99401	train-MAPE:0.171828	val-MAPE:0.16907
# [343]	train-rmse:6.69045	val-rmse:9.99395	train-MAPE:0.171744	val-MAPE:0.169056
# [344]	train-rmse:6.6868	val-rmse:9.99433	train-MAPE:0.17163	val-MAPE:0.169202
# [345]	train-rmse:6.68243	val-rmse:9.99301	train-MAPE:0.171568	val-MAPE:0.169192
# [346]	train-rmse:6.67715	val-rmse:9.99181	train-MAPE:0.171511	val-MAPE:0.169184
# [347]	train-rmse:6.67295	val-rmse:9.98985	train-MAPE:0.171424	val-MAPE:0.169114
# [348]	train-rmse:6.66798	val-rmse:9.99155	train-MAPE:0.17133	val-MAPE:0.169077
# [349]	train-rmse:6.66585	val-rmse:9.99112	train-MAPE:0.171105	val-MAPE:0.168933
# [350]	train-rmse:6.66315	val-rmse:9.99158	train-MAPE:0.170954	val-MAPE:0.16893
# [351]	train-rmse:6.65902	val-rmse:9.99132	train-MAPE:0.170813	val-MAPE:0.16895
# [352]	train-rmse:6.6554	val-rmse:9.99046	train-MAPE:0.170762	val-MAPE:0.168979
# [353]	train-rmse:6.6494	val-rmse:9.98991	train-MAPE:0.170664	val-MAPE:0.168948
# [354]	train-rmse:6.64556	val-rmse:9.99054	train-MAPE:0.170654	val-MAPE:0.16883
# [355]	train-rmse:6.63635	val-rmse:9.9888	train-MAPE:0.170526	val-MAPE:0.168774
# [356]	train-rmse:6.63069	val-rmse:9.98865	train-MAPE:0.170408	val-MAPE:0.168741
# best best_ntree_limit 357

# %% [markdown]
# #### V20

# %%
## 训练预测
# 分割训练集和验证集
ll = round(len(V20_train)/5)
V20_train_val = V20_train.iloc[:ll]
V20_train_t = V20_train.iloc[ll:len(V11_train)]

# 分离标签和特征
Y_time = V20_train_t['volume']
X_time = V20_train_t.drop(['volume'], axis=1)
val_Y_time = V20_train_val.volume
val_X_time = V20_train_val.drop(['volume'], axis=1)

# 转化格式
time_train = xgb.DMatrix(X_time, label=Y_time)
time_val = xgb.DMatrix(val_X_time, label=val_Y_time)
time_test = xgb.DMatrix(V20_test)

#参数设置
params = {
    'booster':'gbtree',      #gbtree和gblinear
    'objective':'reg:linear',
    'eta':0.04,             #为了防止过拟合，更新过程中用到的收缩步长。在每次提升计算之后，算法会直接获得新特征的权重。eta通过缩减特征的权重使提升计算过程更加保守。缺省值为0.3,通常最后设置eta为0.01~0.2
    #'gamma':0.3,            #模型在默认情况下，对于一个节点的划分只有在其loss function得到结果大于0的情况下才进行，而gamma 给定了所需的最低loss function的值gamma值使得算法更conservation，且其值依赖于loss function ，
    'max_depth':5,          #树的深度越大，则对数据的拟合程度越高（过拟合程度也越高）。即该参数也是控制过拟合,建议通过交叉验证（xgb.cv ) 进行调参,通常取值：3-10
    #'min_child_weight':2,   #孩子节点中最小的样本权重和。如果一个叶子节点的样本权重和小于min_child_weight则拆分过程结束。在现行回归模型中，这个参数是指建立每个模型所需要的最小样本数。该成熟越大算法越conservative。即调大这个参数能够控制过拟合。
    #'max_delta_step':2,     #如果取值为0，那么意味着无限制。如果取为正数，则其使得xgboost更新过程更加保守。
    'subsample':1,          #用于训练模型的子样本占整个样本集合的比例。如果设置为0.5则意味着XGBoost将随机的从整个样本集合中抽取出50%的子样本建立树模型，这能够防止过拟合。
    'colsample_bytree':1,   #在建立树时对特征随机采样的比例。缺省值为1 
    #'alpha':5,              #L1 正则的惩罚系数,当数据维度极高时可以使用，使得算法运行更快。
    #'lambda':40,           #L2 正则的惩罚系数,用于处理XGBoost的正则化部分。通常不使用，但可以用来降低过拟合
    'seed':2017,
}


plst = list(params.items())
num_rounds = 50
watchlist = [(time_train, 'train'), (time_val, 'val')]

V20time_model = xgb.train(plst, time_train, num_rounds, watchlist, feval=MAPE)
print("best best_ntree_limit", V20time_model.best_ntree_limit)

V20time_predict = V20time_model.predict(time_test)
# Out:
# [0]	train-rmse:50.2793	val-rmse:59.252	train-MAPE:0.888621	val-MAPE:0.914175
# [1]	train-rmse:48.4166	val-rmse:57.0907	train-MAPE:0.847472	val-MAPE:0.880798
# [2]	train-rmse:46.6321	val-rmse:55.018	train-MAPE:0.80807	val-MAPE:0.849375
# [3]	train-rmse:44.9242	val-rmse:53.0314	train-MAPE:0.770528	val-MAPE:0.819017
# [4]	train-rmse:43.2911	val-rmse:51.1331	train-MAPE:0.735293	val-MAPE:0.792565
# [5]	train-rmse:41.7258	val-rmse:49.3103	train-MAPE:0.702568	val-MAPE:0.765227
# [6]	train-rmse:40.2259	val-rmse:47.5642	train-MAPE:0.672344	val-MAPE:0.740944
# [7]	train-rmse:38.7918	val-rmse:45.889	train-MAPE:0.644752	val-MAPE:0.717589
# [8]	train-rmse:37.4214	val-rmse:44.2934	train-MAPE:0.61786	val-MAPE:0.698235
# [9]	train-rmse:36.0862	val-rmse:42.7458	train-MAPE:0.592416	val-MAPE:0.679078
# [10]	train-rmse:34.8099	val-rmse:41.2689	train-MAPE:0.56842	val-MAPE:0.660758
# [11]	train-rmse:33.5899	val-rmse:39.8539	train-MAPE:0.546217	val-MAPE:0.642866
# [12]	train-rmse:32.4263	val-rmse:38.5103	train-MAPE:0.525213	val-MAPE:0.626913
# [13]	train-rmse:31.3042	val-rmse:37.1887	train-MAPE:0.506526	val-MAPE:0.612016
# [14]	train-rmse:30.2324	val-rmse:35.935	train-MAPE:0.489489	val-MAPE:0.598639
# [15]	train-rmse:29.2091	val-rmse:34.7328	train-MAPE:0.474053	val-MAPE:0.585868
# [16]	train-rmse:28.2353	val-rmse:33.6161	train-MAPE:0.459128	val-MAPE:0.576363
# [17]	train-rmse:27.3023	val-rmse:32.5226	train-MAPE:0.445647	val-MAPE:0.565522
# [18]	train-rmse:26.4158	val-rmse:31.5088	train-MAPE:0.432839	val-MAPE:0.557255
# [19]	train-rmse:25.5662	val-rmse:30.5094	train-MAPE:0.420981	val-MAPE:0.54745
# [20]	train-rmse:24.7565	val-rmse:29.6433	train-MAPE:0.410665	val-MAPE:0.539807
# [21]	train-rmse:23.9892	val-rmse:28.7492	train-MAPE:0.399103	val-MAPE:0.532735
# [22]	train-rmse:23.2595	val-rmse:27.899	train-MAPE:0.388219	val-MAPE:0.526075
# [23]	train-rmse:22.5548	val-rmse:27.0717	train-MAPE:0.378402	val-MAPE:0.518139
# [24]	train-rmse:21.8804	val-rmse:26.3865	train-MAPE:0.37058	val-MAPE:0.51242
# [25]	train-rmse:21.2389	val-rmse:25.6667	train-MAPE:0.363331	val-MAPE:0.507129
# [26]	train-rmse:20.644	val-rmse:25.0197	train-MAPE:0.355543	val-MAPE:0.502986
# [27]	train-rmse:20.0614	val-rmse:24.3585	train-MAPE:0.349227	val-MAPE:0.497409
# [28]	train-rmse:19.5072	val-rmse:23.7982	train-MAPE:0.34329	val-MAPE:0.493589
# [29]	train-rmse:18.9652	val-rmse:23.1997	train-MAPE:0.33704	val-MAPE:0.488975
# [30]	train-rmse:18.464	val-rmse:22.6389	train-MAPE:0.332083	val-MAPE:0.48612
# [31]	train-rmse:17.9756	val-rmse:22.1046	train-MAPE:0.32622	val-MAPE:0.481903
# [32]	train-rmse:17.5118	val-rmse:21.6054	train-MAPE:0.321189	val-MAPE:0.478577
# [33]	train-rmse:17.084	val-rmse:21.1266	train-MAPE:0.317416	val-MAPE:0.47509
# [34]	train-rmse:16.6791	val-rmse:20.7334	train-MAPE:0.313799	val-MAPE:0.473327
# [35]	train-rmse:16.2792	val-rmse:20.3066	train-MAPE:0.30968	val-MAPE:0.470888
# [36]	train-rmse:15.9222	val-rmse:20.0454	train-MAPE:0.305786	val-MAPE:0.470982
# [37]	train-rmse:15.559	val-rmse:19.6546	train-MAPE:0.302988	val-MAPE:0.46884
# [38]	train-rmse:15.1991	val-rmse:19.269	train-MAPE:0.299487	val-MAPE:0.466413
# [39]	train-rmse:14.858	val-rmse:18.9058	train-MAPE:0.296688	val-MAPE:0.463966
# [40]	train-rmse:14.5452	val-rmse:18.5641	train-MAPE:0.293887	val-MAPE:0.461517
# [41]	train-rmse:14.2427	val-rmse:18.2906	train-MAPE:0.292571	val-MAPE:0.460196
# [42]	train-rmse:13.9583	val-rmse:18.0418	train-MAPE:0.291231	val-MAPE:0.45885
# [43]	train-rmse:13.7012	val-rmse:17.7558	train-MAPE:0.289853	val-MAPE:0.457481
# [44]	train-rmse:13.4503	val-rmse:17.4988	train-MAPE:0.288516	val-MAPE:0.456373
# [45]	train-rmse:13.2066	val-rmse:17.2561	train-MAPE:0.287041	val-MAPE:0.454595
# [46]	train-rmse:12.9779	val-rmse:17.1159	train-MAPE:0.285814	val-MAPE:0.453705
# [47]	train-rmse:12.7635	val-rmse:16.922	train-MAPE:0.285269	val-MAPE:0.453441
# [48]	train-rmse:12.5699	val-rmse:16.788	train-MAPE:0.284004	val-MAPE:0.453126
# [49]	train-rmse:12.3533	val-rmse:16.6449	train-MAPE:0.283697	val-MAPE:0.453788
# best best_ntree_limit 50

# %%
## 训练预测
# 分割训练集和验证集
ll = round(len(V30_train)/5)
V30_train_val = V30_train.iloc[:ll]
V30_train_t = V30_train.iloc[ll:len(V30_train)]

# 分离标签和特征
Y_time = V30_train_t['volume']
X_time = V30_train_t.drop(['volume'], axis=1)
val_Y_time = V30_train_val.volume
val_X_time = V30_train_val.drop(['volume'], axis=1)

# 转化格式
time_train = xgb.DMatrix(X_time, label=Y_time)
time_val = xgb.DMatrix(val_X_time, label=val_Y_time)
time_test = xgb.DMatrix(V30_test)

#参数设置
params = {
    'booster':'gbtree',      #gbtree和gblinear
    'objective':'reg:linear',
    'eta':0.04,             #为了防止过拟合，更新过程中用到的收缩步长。在每次提升计算之后，算法会直接获得新特征的权重。eta通过缩减特征的权重使提升计算过程更加保守。缺省值为0.3,通常最后设置eta为0.01~0.2
    #'gamma':0.3,            #模型在默认情况下，对于一个节点的划分只有在其loss function得到结果大于0的情况下才进行，而gamma 给定了所需的最低loss function的值gamma值使得算法更conservation，且其值依赖于loss function ，
    'max_depth':5,          #树的深度越大，则对数据的拟合程度越高（过拟合程度也越高）。即该参数也是控制过拟合,建议通过交叉验证（xgb.cv ) 进行调参,通常取值：3-10
    #'min_child_weight':2,   #孩子节点中最小的样本权重和。如果一个叶子节点的样本权重和小于min_child_weight则拆分过程结束。在现行回归模型中，这个参数是指建立每个模型所需要的最小样本数。该成熟越大算法越conservative。即调大这个参数能够控制过拟合。
    #'max_delta_step':2,     #如果取值为0，那么意味着无限制。如果取为正数，则其使得xgboost更新过程更加保守。
    'subsample':1,          #用于训练模型的子样本占整个样本集合的比例。如果设置为0.5则意味着XGBoost将随机的从整个样本集合中抽取出50%的子样本建立树模型，这能够防止过拟合。
    'colsample_bytree':1,   #在建立树时对特征随机采样的比例。缺省值为1 
    #'alpha':5,              #L1 正则的惩罚系数,当数据维度极高时可以使用，使得算法运行更快。
    #'lambda':40,           #L2 正则的惩罚系数,用于处理XGBoost的正则化部分。通常不使用，但可以用来降低过拟合
    'seed':2017,
}


plst = list(params.items())
num_rounds = 369
watchlist = [(time_train, 'train'), (time_val, 'val')]

V30time_model = xgb.train(plst, time_train, num_rounds, watchlist, feval=MAPE)
print("best best_ntree_limit", V30time_model.best_ntree_limit)

V30time_predict = V30time_model.predict(time_test)
# Out:
# [0]	train-rmse:81.7515	val-rmse:82.8132	train-MAPE:0.942034	val-MAPE:0.943768
# [1]	train-rmse:78.6259	val-rmse:79.8317	train-MAPE:0.901716	val-MAPE:0.905309
# [2]	train-rmse:75.6324	val-rmse:76.8803	train-MAPE:0.863421	val-MAPE:0.868241
# [3]	train-rmse:72.7594	val-rmse:74.1479	train-MAPE:0.826929	val-MAPE:0.832814
# [4]	train-rmse:70.0068	val-rmse:71.4413	train-MAPE:0.791937	val-MAPE:0.798478
# [5]	train-rmse:67.3704	val-rmse:68.8516	train-MAPE:0.758691	val-MAPE:0.7658
# [6]	train-rmse:64.8398	val-rmse:66.3444	train-MAPE:0.727039	val-MAPE:0.734126
# [7]	train-rmse:62.4192	val-rmse:63.9581	train-MAPE:0.696677	val-MAPE:0.703924
# [8]	train-rmse:60.0955	val-rmse:61.6629	train-MAPE:0.667655	val-MAPE:0.674463
# [9]	train-rmse:57.8696	val-rmse:59.4672	train-MAPE:0.639955	val-MAPE:0.646444
# [10]	train-rmse:55.744	val-rmse:57.384	train-MAPE:0.613507	val-MAPE:0.620175
# [11]	train-rmse:53.698	val-rmse:55.3605	train-MAPE:0.588197	val-MAPE:0.594934
# [12]	train-rmse:51.7442	val-rmse:53.4446	train-MAPE:0.564032	val-MAPE:0.571065
# [13]	train-rmse:49.878	val-rmse:51.6	train-MAPE:0.540816	val-MAPE:0.547944
# [14]	train-rmse:48.0887	val-rmse:49.8301	train-MAPE:0.518739	val-MAPE:0.52576
# [15]	train-rmse:46.3561	val-rmse:48.1951	train-MAPE:0.49781	val-MAPE:0.504823
# [16]	train-rmse:44.721	val-rmse:46.575	train-MAPE:0.477321	val-MAPE:0.484621
# [17]	train-rmse:43.1539	val-rmse:45.0233	train-MAPE:0.458335	val-MAPE:0.46536
# [18]	train-rmse:41.6562	val-rmse:43.496	train-MAPE:0.440326	val-MAPE:0.446939
# [19]	train-rmse:40.2246	val-rmse:42.0734	train-MAPE:0.423183	val-MAPE:0.42937
# [20]	train-rmse:38.854	val-rmse:40.6688	train-MAPE:0.406906	val-MAPE:0.412267
# [21]	train-rmse:37.5279	val-rmse:39.3245	train-MAPE:0.391519	val-MAPE:0.396065
# [22]	train-rmse:36.2757	val-rmse:38.0769	train-MAPE:0.376854	val-MAPE:0.381229
# [23]	train-rmse:35.0823	val-rmse:36.9056	train-MAPE:0.362966	val-MAPE:0.367377
# [24]	train-rmse:33.9444	val-rmse:35.7297	train-MAPE:0.349582	val-MAPE:0.353992
# [25]	train-rmse:32.8468	val-rmse:34.7151	train-MAPE:0.337048	val-MAPE:0.341181
# [26]	train-rmse:31.7809	val-rmse:33.6968	train-MAPE:0.325489	val-MAPE:0.329521
# [27]	train-rmse:30.7742	val-rmse:32.7708	train-MAPE:0.314487	val-MAPE:0.318287
# [28]	train-rmse:29.8292	val-rmse:31.8041	train-MAPE:0.304232	val-MAPE:0.307365
# [29]	train-rmse:28.9341	val-rmse:30.9542	train-MAPE:0.294199	val-MAPE:0.297811
# [30]	train-rmse:28.0561	val-rmse:30.1077	train-MAPE:0.284918	val-MAPE:0.288896
# [31]	train-rmse:27.2269	val-rmse:29.3466	train-MAPE:0.276144	val-MAPE:0.280578
# [32]	train-rmse:26.4258	val-rmse:28.5746	train-MAPE:0.267729	val-MAPE:0.272237
# [33]	train-rmse:25.6649	val-rmse:27.796	train-MAPE:0.260068	val-MAPE:0.264754
# [34]	train-rmse:24.9428	val-rmse:27.1484	train-MAPE:0.253033	val-MAPE:0.258269
# [35]	train-rmse:24.2575	val-rmse:26.5345	train-MAPE:0.246646	val-MAPE:0.25229
# [36]	train-rmse:23.6007	val-rmse:25.855	train-MAPE:0.239968	val-MAPE:0.245726
# [37]	train-rmse:22.9872	val-rmse:25.2115	train-MAPE:0.234232	val-MAPE:0.239807
# [38]	train-rmse:22.393	val-rmse:24.5856	train-MAPE:0.228782	val-MAPE:0.23404
# [39]	train-rmse:21.8327	val-rmse:24.0876	train-MAPE:0.22355	val-MAPE:0.229207
# [40]	train-rmse:21.3126	val-rmse:23.6198	train-MAPE:0.218617	val-MAPE:0.224653
# [41]	train-rmse:20.7908	val-rmse:23.1991	train-MAPE:0.213944	val-MAPE:0.220609
# [42]	train-rmse:20.3034	val-rmse:22.6807	train-MAPE:0.21036	val-MAPE:0.216598
# [43]	train-rmse:19.8243	val-rmse:22.3057	train-MAPE:0.206614	val-MAPE:0.213206
# [44]	train-rmse:19.3711	val-rmse:21.8577	train-MAPE:0.203432	val-MAPE:0.20978
# [45]	train-rmse:18.9562	val-rmse:21.414	train-MAPE:0.200261	val-MAPE:0.206123
# [46]	train-rmse:18.5637	val-rmse:21.0526	train-MAPE:0.197456	val-MAPE:0.203237
# [47]	train-rmse:18.1956	val-rmse:20.6703	train-MAPE:0.195036	val-MAPE:0.200468
# [48]	train-rmse:17.8236	val-rmse:20.3898	train-MAPE:0.192365	val-MAPE:0.198199
# [49]	train-rmse:17.457	val-rmse:20.0315	train-MAPE:0.189664	val-MAPE:0.195405
# [50]	train-rmse:17.1439	val-rmse:19.7475	train-MAPE:0.18737	val-MAPE:0.193173
# [51]	train-rmse:16.8498	val-rmse:19.4978	train-MAPE:0.185405	val-MAPE:0.191287
# [52]	train-rmse:16.5497	val-rmse:19.201	train-MAPE:0.183621	val-MAPE:0.189626
# [53]	train-rmse:16.2834	val-rmse:18.9555	train-MAPE:0.181954	val-MAPE:0.188107
# [54]	train-rmse:16.0078	val-rmse:18.7816	train-MAPE:0.180404	val-MAPE:0.186936
# [55]	train-rmse:15.7382	val-rmse:18.5109	train-MAPE:0.178704	val-MAPE:0.185283
# [56]	train-rmse:15.4755	val-rmse:18.2674	train-MAPE:0.177448	val-MAPE:0.184078
# [57]	train-rmse:15.2573	val-rmse:18.0349	train-MAPE:0.17616	val-MAPE:0.182711
# [58]	train-rmse:15.0612	val-rmse:17.8139	train-MAPE:0.175029	val-MAPE:0.181489
# [59]	train-rmse:14.846	val-rmse:17.6498	train-MAPE:0.173952	val-MAPE:0.180484
# [60]	train-rmse:14.637	val-rmse:17.4333	train-MAPE:0.173019	val-MAPE:0.17946
# [61]	train-rmse:14.4352	val-rmse:17.2073	train-MAPE:0.17192	val-MAPE:0.178504
# [62]	train-rmse:14.2384	val-rmse:17.029	train-MAPE:0.171096	val-MAPE:0.177618
# [63]	train-rmse:14.0538	val-rmse:16.8931	train-MAPE:0.170258	val-MAPE:0.176955
# [64]	train-rmse:13.9032	val-rmse:16.7269	train-MAPE:0.169697	val-MAPE:0.176188
# [65]	train-rmse:13.7405	val-rmse:16.6107	train-MAPE:0.168959	val-MAPE:0.175516
# [66]	train-rmse:13.6045	val-rmse:16.4751	train-MAPE:0.168432	val-MAPE:0.174906
# [67]	train-rmse:13.4747	val-rmse:16.3275	train-MAPE:0.167802	val-MAPE:0.174264
# [68]	train-rmse:13.3332	val-rmse:16.2344	train-MAPE:0.16724	val-MAPE:0.1737
# [69]	train-rmse:13.2014	val-rmse:16.1397	train-MAPE:0.166663	val-MAPE:0.173267
# [70]	train-rmse:13.0848	val-rmse:16.0078	train-MAPE:0.1662	val-MAPE:0.172351
# [71]	train-rmse:12.9918	val-rmse:15.9052	train-MAPE:0.16554	val-MAPE:0.17175
# [72]	train-rmse:12.8593	val-rmse:15.8035	train-MAPE:0.165244	val-MAPE:0.171355
# [73]	train-rmse:12.7402	val-rmse:15.697	train-MAPE:0.16488	val-MAPE:0.171053
# [74]	train-rmse:12.6203	val-rmse:15.5805	train-MAPE:0.164622	val-MAPE:0.170681
# [75]	train-rmse:12.5384	val-rmse:15.5022	train-MAPE:0.164414	val-MAPE:0.170448
# [76]	train-rmse:12.4445	val-rmse:15.431	train-MAPE:0.164304	val-MAPE:0.170136
# [77]	train-rmse:12.3694	val-rmse:15.3992	train-MAPE:0.164006	val-MAPE:0.170074
# [78]	train-rmse:12.2805	val-rmse:15.3335	train-MAPE:0.163851	val-MAPE:0.169743
# [79]	train-rmse:12.1794	val-rmse:15.2448	train-MAPE:0.163564	val-MAPE:0.169499
# [80]	train-rmse:12.1003	val-rmse:15.1814	train-MAPE:0.163498	val-MAPE:0.16932
# [81]	train-rmse:12.0093	val-rmse:15.1007	train-MAPE:0.163313	val-MAPE:0.169208
# [82]	train-rmse:11.9251	val-rmse:15.0182	train-MAPE:0.163072	val-MAPE:0.168953
# [83]	train-rmse:11.8479	val-rmse:14.939	train-MAPE:0.16299	val-MAPE:0.168744
# [84]	train-rmse:11.774	val-rmse:14.8703	train-MAPE:0.162871	val-MAPE:0.168642
# [85]	train-rmse:11.7101	val-rmse:14.8247	train-MAPE:0.162899	val-MAPE:0.168717
# [86]	train-rmse:11.6568	val-rmse:14.7705	train-MAPE:0.162715	val-MAPE:0.168636
# [87]	train-rmse:11.5926	val-rmse:14.7054	train-MAPE:0.162597	val-MAPE:0.168451
# [88]	train-rmse:11.5442	val-rmse:14.6591	train-MAPE:0.162414	val-MAPE:0.16829
# [89]	train-rmse:11.4844	val-rmse:14.6097	train-MAPE:0.162225	val-MAPE:0.168087
# [90]	train-rmse:11.434	val-rmse:14.5575	train-MAPE:0.162275	val-MAPE:0.168174
# [91]	train-rmse:11.388	val-rmse:14.5019	train-MAPE:0.162025	val-MAPE:0.167945
# [92]	train-rmse:11.3494	val-rmse:14.4592	train-MAPE:0.161929	val-MAPE:0.167854
# [93]	train-rmse:11.3089	val-rmse:14.4086	train-MAPE:0.161698	val-MAPE:0.167656
# [94]	train-rmse:11.275	val-rmse:14.3751	train-MAPE:0.161608	val-MAPE:0.167606
# [95]	train-rmse:11.2401	val-rmse:14.329	train-MAPE:0.161633	val-MAPE:0.167643
# [96]	train-rmse:11.205	val-rmse:14.2719	train-MAPE:0.161544	val-MAPE:0.167942
# [97]	train-rmse:11.1753	val-rmse:14.2463	train-MAPE:0.161535	val-MAPE:0.167914
# [98]	train-rmse:11.1441	val-rmse:14.1936	train-MAPE:0.16147	val-MAPE:0.168206
# [99]	train-rmse:11.1176	val-rmse:14.1758	train-MAPE:0.161652	val-MAPE:0.168313
# [100]	train-rmse:11.0683	val-rmse:14.1436	train-MAPE:0.16147	val-MAPE:0.168318
# [101]	train-rmse:11.0436	val-rmse:14.1266	train-MAPE:0.161595	val-MAPE:0.16846
# [102]	train-rmse:10.9945	val-rmse:14.1118	train-MAPE:0.161544	val-MAPE:0.168754
# [103]	train-rmse:10.9718	val-rmse:14.0979	train-MAPE:0.161682	val-MAPE:0.168914
# [104]	train-rmse:10.9504	val-rmse:14.077	train-MAPE:0.161759	val-MAPE:0.169499
# [105]	train-rmse:10.9135	val-rmse:14.0667	train-MAPE:0.161738	val-MAPE:0.169534
# [106]	train-rmse:10.8896	val-rmse:14.0377	train-MAPE:0.161742	val-MAPE:0.169604
# [107]	train-rmse:10.8701	val-rmse:14.0214	train-MAPE:0.161866	val-MAPE:0.169837
# [108]	train-rmse:10.841	val-rmse:13.9846	train-MAPE:0.161791	val-MAPE:0.169591
# [109]	train-rmse:10.8228	val-rmse:13.9744	train-MAPE:0.161895	val-MAPE:0.169776
# [110]	train-rmse:10.8023	val-rmse:13.944	train-MAPE:0.161783	val-MAPE:0.169586
# [111]	train-rmse:10.7868	val-rmse:13.9383	train-MAPE:0.161854	val-MAPE:0.169801
# [112]	train-rmse:10.7498	val-rmse:13.9158	train-MAPE:0.161647	val-MAPE:0.169762
# [113]	train-rmse:10.7356	val-rmse:13.9028	train-MAPE:0.161721	val-MAPE:0.169935
# [114]	train-rmse:10.6995	val-rmse:13.879	train-MAPE:0.161502	val-MAPE:0.169936
# [115]	train-rmse:10.6506	val-rmse:13.8628	train-MAPE:0.161386	val-MAPE:0.16924
# [116]	train-rmse:10.6268	val-rmse:13.8606	train-MAPE:0.161031	val-MAPE:0.169246
# [117]	train-rmse:10.6127	val-rmse:13.8495	train-MAPE:0.160732	val-MAPE:0.169123
# [118]	train-rmse:10.5927	val-rmse:13.8554	train-MAPE:0.160763	val-MAPE:0.169508
# [119]	train-rmse:10.5757	val-rmse:13.8646	train-MAPE:0.16079	val-MAPE:0.169447
# [120]	train-rmse:10.535	val-rmse:13.8431	train-MAPE:0.160351	val-MAPE:0.169188
# [121]	train-rmse:10.4958	val-rmse:13.8187	train-MAPE:0.15991	val-MAPE:0.169108
# [122]	train-rmse:10.4841	val-rmse:13.8128	train-MAPE:0.159969	val-MAPE:0.169216
# [123]	train-rmse:10.4727	val-rmse:13.7885	train-MAPE:0.160005	val-MAPE:0.169323
# [124]	train-rmse:10.4617	val-rmse:13.7779	train-MAPE:0.159967	val-MAPE:0.169462
# [125]	train-rmse:10.4077	val-rmse:13.8001	train-MAPE:0.159835	val-MAPE:0.169348
# [126]	train-rmse:10.3962	val-rmse:13.7772	train-MAPE:0.159774	val-MAPE:0.169417
# [127]	train-rmse:10.3653	val-rmse:13.7791	train-MAPE:0.159562	val-MAPE:0.169443
# [128]	train-rmse:10.3343	val-rmse:13.7723	train-MAPE:0.159059	val-MAPE:0.169205
# [129]	train-rmse:10.2847	val-rmse:13.7834	train-MAPE:0.158824	val-MAPE:0.169455
# [130]	train-rmse:10.2732	val-rmse:13.7815	train-MAPE:0.158812	val-MAPE:0.169628
# [131]	train-rmse:10.2447	val-rmse:13.7673	train-MAPE:0.158277	val-MAPE:0.169631
# [132]	train-rmse:10.2166	val-rmse:13.7474	train-MAPE:0.158177	val-MAPE:0.169539
# [133]	train-rmse:10.2071	val-rmse:13.7486	train-MAPE:0.158092	val-MAPE:0.169686
# [134]	train-rmse:10.1918	val-rmse:13.732	train-MAPE:0.158043	val-MAPE:0.169594
# [135]	train-rmse:10.1658	val-rmse:13.7509	train-MAPE:0.15756	val-MAPE:0.169529
# [136]	train-rmse:10.1587	val-rmse:13.7363	train-MAPE:0.157547	val-MAPE:0.169587
# [137]	train-rmse:10.1439	val-rmse:13.7165	train-MAPE:0.157292	val-MAPE:0.169657
# [138]	train-rmse:10.1357	val-rmse:13.708	train-MAPE:0.157272	val-MAPE:0.169622
# [139]	train-rmse:10.1213	val-rmse:13.7097	train-MAPE:0.157166	val-MAPE:0.169739
# [140]	train-rmse:10.0933	val-rmse:13.6787	train-MAPE:0.156797	val-MAPE:0.169568
# [141]	train-rmse:10.084	val-rmse:13.6608	train-MAPE:0.15667	val-MAPE:0.16959
# [142]	train-rmse:10.0765	val-rmse:13.6532	train-MAPE:0.156516	val-MAPE:0.169495
# [143]	train-rmse:10.0643	val-rmse:13.6451	train-MAPE:0.156476	val-MAPE:0.169411
# [144]	train-rmse:10.043	val-rmse:13.6531	train-MAPE:0.15618	val-MAPE:0.169606
# [145]	train-rmse:10.0363	val-rmse:13.6479	train-MAPE:0.155906	val-MAPE:0.169379
# [146]	train-rmse:10.0286	val-rmse:13.6461	train-MAPE:0.155821	val-MAPE:0.169474
# [147]	train-rmse:10.0086	val-rmse:13.6513	train-MAPE:0.155659	val-MAPE:0.169622
# [148]	train-rmse:10.0007	val-rmse:13.6345	train-MAPE:0.155536	val-MAPE:0.169387
# [149]	train-rmse:9.99423	val-rmse:13.6281	train-MAPE:0.155385	val-MAPE:0.169285
# [150]	train-rmse:9.98794	val-rmse:13.6144	train-MAPE:0.155361	val-MAPE:0.16929
# [151]	train-rmse:9.96943	val-rmse:13.6218	train-MAPE:0.155193	val-MAPE:0.169446
# [152]	train-rmse:9.96242	val-rmse:13.6156	train-MAPE:0.15512	val-MAPE:0.16943
# [153]	train-rmse:9.92102	val-rmse:13.6297	train-MAPE:0.154897	val-MAPE:0.169637
# [154]	train-rmse:9.9137	val-rmse:13.6287	train-MAPE:0.154779	val-MAPE:0.169451
# [155]	train-rmse:9.88858	val-rmse:13.6193	train-MAPE:0.154324	val-MAPE:0.169413
# [156]	train-rmse:9.87855	val-rmse:13.6088	train-MAPE:0.154254	val-MAPE:0.169134
# [157]	train-rmse:9.87167	val-rmse:13.6013	train-MAPE:0.154126	val-MAPE:0.169887
# [158]	train-rmse:9.86657	val-rmse:13.5909	train-MAPE:0.154137	val-MAPE:0.169926
# [159]	train-rmse:9.84323	val-rmse:13.5789	train-MAPE:0.153714	val-MAPE:0.169989
# [160]	train-rmse:9.8363	val-rmse:13.5782	train-MAPE:0.153588	val-MAPE:0.17008
# [161]	train-rmse:9.81415	val-rmse:13.5586	train-MAPE:0.153245	val-MAPE:0.169969
# [162]	train-rmse:9.80412	val-rmse:13.5616	train-MAPE:0.153153	val-MAPE:0.170024
# [163]	train-rmse:9.79767	val-rmse:13.5354	train-MAPE:0.153132	val-MAPE:0.16974
# [164]	train-rmse:9.79136	val-rmse:13.5292	train-MAPE:0.153005	val-MAPE:0.169714
# [165]	train-rmse:9.78138	val-rmse:13.525	train-MAPE:0.152966	val-MAPE:0.169525
# [166]	train-rmse:9.74468	val-rmse:13.5397	train-MAPE:0.152737	val-MAPE:0.169712
# [167]	train-rmse:9.72565	val-rmse:13.5215	train-MAPE:0.152543	val-MAPE:0.169602
# [168]	train-rmse:9.71963	val-rmse:13.5212	train-MAPE:0.152422	val-MAPE:0.16968
# [169]	train-rmse:9.70171	val-rmse:13.5046	train-MAPE:0.152223	val-MAPE:0.169207
# [170]	train-rmse:9.69473	val-rmse:13.4925	train-MAPE:0.152149	val-MAPE:0.169166
# [171]	train-rmse:9.68855	val-rmse:13.4777	train-MAPE:0.152078	val-MAPE:0.169068
# [172]	train-rmse:9.65528	val-rmse:13.4887	train-MAPE:0.151747	val-MAPE:0.169317
# [173]	train-rmse:9.63892	val-rmse:13.4775	train-MAPE:0.151593	val-MAPE:0.169011
# [174]	train-rmse:9.62709	val-rmse:13.4726	train-MAPE:0.151491	val-MAPE:0.168973
# [175]	train-rmse:9.59158	val-rmse:13.467	train-MAPE:0.151066	val-MAPE:0.16883
# [176]	train-rmse:9.58474	val-rmse:13.466	train-MAPE:0.15093	val-MAPE:0.168879
# [177]	train-rmse:9.56978	val-rmse:13.4538	train-MAPE:0.150805	val-MAPE:0.168554
# [178]	train-rmse:9.53697	val-rmse:13.4489	train-MAPE:0.150424	val-MAPE:0.168422
# [179]	train-rmse:9.5272	val-rmse:13.4441	train-MAPE:0.150321	val-MAPE:0.168422
# [180]	train-rmse:9.51942	val-rmse:13.4345	train-MAPE:0.150179	val-MAPE:0.168332
# [181]	train-rmse:9.50657	val-rmse:13.4418	train-MAPE:0.150122	val-MAPE:0.16832
# [182]	train-rmse:9.48848	val-rmse:13.4292	train-MAPE:0.149748	val-MAPE:0.168225
# [183]	train-rmse:9.47935	val-rmse:13.4247	train-MAPE:0.149648	val-MAPE:0.168222
# [184]	train-rmse:9.4621	val-rmse:13.4368	train-MAPE:0.149488	val-MAPE:0.167987
# [185]	train-rmse:9.45262	val-rmse:13.4425	train-MAPE:0.149413	val-MAPE:0.168052
# [186]	train-rmse:9.4438	val-rmse:13.4417	train-MAPE:0.149325	val-MAPE:0.168109
# [187]	train-rmse:9.43922	val-rmse:13.444	train-MAPE:0.14929	val-MAPE:0.168142
# [188]	train-rmse:9.42602	val-rmse:13.4524	train-MAPE:0.149167	val-MAPE:0.168139
# [189]	train-rmse:9.41069	val-rmse:13.4234	train-MAPE:0.148992	val-MAPE:0.167748
# [190]	train-rmse:9.4071	val-rmse:13.4213	train-MAPE:0.148841	val-MAPE:0.16785
# [191]	train-rmse:9.39323	val-rmse:13.4271	train-MAPE:0.148758	val-MAPE:0.167858
# [192]	train-rmse:9.3895	val-rmse:13.4274	train-MAPE:0.148735	val-MAPE:0.167963
# [193]	train-rmse:9.37682	val-rmse:13.4212	train-MAPE:0.148591	val-MAPE:0.167714
# [194]	train-rmse:9.36399	val-rmse:13.4272	train-MAPE:0.148519	val-MAPE:0.167727
# [195]	train-rmse:9.35537	val-rmse:13.4326	train-MAPE:0.148451	val-MAPE:0.167618
# [196]	train-rmse:9.35231	val-rmse:13.4325	train-MAPE:0.148413	val-MAPE:0.167636
# [197]	train-rmse:9.34035	val-rmse:13.4387	train-MAPE:0.148347	val-MAPE:0.167645
# [198]	train-rmse:9.33133	val-rmse:13.4208	train-MAPE:0.148139	val-MAPE:0.167649
# [199]	train-rmse:9.31776	val-rmse:13.4195	train-MAPE:0.148017	val-MAPE:0.167753
# [200]	train-rmse:9.30653	val-rmse:13.4264	train-MAPE:0.147916	val-MAPE:0.167628
# [201]	train-rmse:9.29888	val-rmse:13.4222	train-MAPE:0.147849	val-MAPE:0.167469
# [202]	train-rmse:9.29484	val-rmse:13.4203	train-MAPE:0.147799	val-MAPE:0.167526
# [203]	train-rmse:9.2871	val-rmse:13.4207	train-MAPE:0.147714	val-MAPE:0.167578
# [204]	train-rmse:9.2833	val-rmse:13.4185	train-MAPE:0.147669	val-MAPE:0.167664
# [205]	train-rmse:9.27226	val-rmse:13.4236	train-MAPE:0.147599	val-MAPE:0.16764
# [206]	train-rmse:9.25723	val-rmse:13.423	train-MAPE:0.147135	val-MAPE:0.16764
# [207]	train-rmse:9.25022	val-rmse:13.4178	train-MAPE:0.14709	val-MAPE:0.167591
# [208]	train-rmse:9.24665	val-rmse:13.4157	train-MAPE:0.147051	val-MAPE:0.167673
# [209]	train-rmse:9.24113	val-rmse:13.4112	train-MAPE:0.146866	val-MAPE:0.167645
# [210]	train-rmse:9.22944	val-rmse:13.4148	train-MAPE:0.146734	val-MAPE:0.167567
# [211]	train-rmse:9.22423	val-rmse:13.4118	train-MAPE:0.146668	val-MAPE:0.167545
# [212]	train-rmse:9.21179	val-rmse:13.4107	train-MAPE:0.146569	val-MAPE:0.167705
# [213]	train-rmse:9.20688	val-rmse:13.4105	train-MAPE:0.146517	val-MAPE:0.167737
# [214]	train-rmse:9.20053	val-rmse:13.4092	train-MAPE:0.146502	val-MAPE:0.167786
# [215]	train-rmse:9.19385	val-rmse:13.4099	train-MAPE:0.146427	val-MAPE:0.16786
# [216]	train-rmse:9.18845	val-rmse:13.4022	train-MAPE:0.146252	val-MAPE:0.167806
# [217]	train-rmse:9.17831	val-rmse:13.4115	train-MAPE:0.146234	val-MAPE:0.167964
# [218]	train-rmse:9.17308	val-rmse:13.4088	train-MAPE:0.146245	val-MAPE:0.167965
# [219]	train-rmse:9.1664	val-rmse:13.4095	train-MAPE:0.146167	val-MAPE:0.168037
# [220]	train-rmse:9.14073	val-rmse:13.3784	train-MAPE:0.145934	val-MAPE:0.167756
# [221]	train-rmse:9.13553	val-rmse:13.3692	train-MAPE:0.145849	val-MAPE:0.167732
# [222]	train-rmse:9.12977	val-rmse:13.3663	train-MAPE:0.145806	val-MAPE:0.167684
# [223]	train-rmse:9.10597	val-rmse:13.339	train-MAPE:0.145593	val-MAPE:0.167433
# [224]	train-rmse:9.09921	val-rmse:13.3382	train-MAPE:0.145501	val-MAPE:0.167409
# [225]	train-rmse:9.09474	val-rmse:13.3349	train-MAPE:0.145341	val-MAPE:0.167389
# [226]	train-rmse:9.08943	val-rmse:13.334	train-MAPE:0.145266	val-MAPE:0.167356
# [227]	train-rmse:9.08682	val-rmse:13.3323	train-MAPE:0.145151	val-MAPE:0.167319
# [228]	train-rmse:9.07337	val-rmse:13.3393	train-MAPE:0.144938	val-MAPE:0.167834
# [229]	train-rmse:9.06629	val-rmse:13.3381	train-MAPE:0.1449	val-MAPE:0.167749
# [230]	train-rmse:9.0573	val-rmse:13.35	train-MAPE:0.144808	val-MAPE:0.168529
# [231]	train-rmse:9.04466	val-rmse:13.3504	train-MAPE:0.144698	val-MAPE:0.168615
# [232]	train-rmse:9.04166	val-rmse:13.3487	train-MAPE:0.14466	val-MAPE:0.168692
# [233]	train-rmse:9.03884	val-rmse:13.347	train-MAPE:0.14462	val-MAPE:0.168767
# [234]	train-rmse:9.02743	val-rmse:13.3339	train-MAPE:0.144565	val-MAPE:0.168863
# [235]	train-rmse:9.00231	val-rmse:13.3072	train-MAPE:0.14435	val-MAPE:0.168627
# [236]	train-rmse:8.99644	val-rmse:13.3074	train-MAPE:0.144274	val-MAPE:0.16861
# [237]	train-rmse:8.99233	val-rmse:13.3131	train-MAPE:0.144251	val-MAPE:0.168656
# [238]	train-rmse:8.98824	val-rmse:13.3115	train-MAPE:0.144223	val-MAPE:0.168665
# [239]	train-rmse:8.96525	val-rmse:13.307	train-MAPE:0.144004	val-MAPE:0.168513
# [240]	train-rmse:8.95982	val-rmse:13.3073	train-MAPE:0.143922	val-MAPE:0.168497
# [241]	train-rmse:8.9553	val-rmse:13.3092	train-MAPE:0.143866	val-MAPE:0.168407
# [242]	train-rmse:8.95116	val-rmse:13.3034	train-MAPE:0.143697	val-MAPE:0.16836
# [243]	train-rmse:8.94106	val-rmse:13.3034	train-MAPE:0.143465	val-MAPE:0.169211
# [244]	train-rmse:8.93059	val-rmse:13.3033	train-MAPE:0.143343	val-MAPE:0.169493
# [245]	train-rmse:8.92635	val-rmse:13.3052	train-MAPE:0.143288	val-MAPE:0.169405
# [246]	train-rmse:8.91895	val-rmse:13.3072	train-MAPE:0.143215	val-MAPE:0.169906
# [247]	train-rmse:8.90878	val-rmse:13.3173	train-MAPE:0.143177	val-MAPE:0.169697
# [248]	train-rmse:8.88959	val-rmse:13.3248	train-MAPE:0.14298	val-MAPE:0.169521
# [249]	train-rmse:8.86677	val-rmse:13.3264	train-MAPE:0.14276	val-MAPE:0.169406
# [250]	train-rmse:8.84293	val-rmse:13.3218	train-MAPE:0.142591	val-MAPE:0.16929
# [251]	train-rmse:8.82089	val-rmse:13.3128	train-MAPE:0.14231	val-MAPE:0.168941
# [252]	train-rmse:8.79994	val-rmse:13.3127	train-MAPE:0.142088	val-MAPE:0.168855
# [253]	train-rmse:8.78836	val-rmse:13.3116	train-MAPE:0.142082	val-MAPE:0.168933
# [254]	train-rmse:8.76652	val-rmse:13.3111	train-MAPE:0.141855	val-MAPE:0.168862
# [255]	train-rmse:8.76061	val-rmse:13.3141	train-MAPE:0.141625	val-MAPE:0.168833
# [256]	train-rmse:8.74923	val-rmse:13.3212	train-MAPE:0.141521	val-MAPE:0.168889
# [257]	train-rmse:8.73856	val-rmse:13.3283	train-MAPE:0.141421	val-MAPE:0.168942
# [258]	train-rmse:8.73483	val-rmse:13.3301	train-MAPE:0.141373	val-MAPE:0.168853
# [259]	train-rmse:8.72674	val-rmse:13.3303	train-MAPE:0.141287	val-MAPE:0.169097
# [260]	train-rmse:8.72367	val-rmse:13.3354	train-MAPE:0.141267	val-MAPE:0.169132
# [261]	train-rmse:8.714	val-rmse:13.3424	train-MAPE:0.141157	val-MAPE:0.169141
# [262]	train-rmse:8.7047	val-rmse:13.3539	train-MAPE:0.141107	val-MAPE:0.16905
# [263]	train-rmse:8.69933	val-rmse:13.3551	train-MAPE:0.141069	val-MAPE:0.168995
# [264]	train-rmse:8.69601	val-rmse:13.351	train-MAPE:0.140896	val-MAPE:0.169027
# [265]	train-rmse:8.69186	val-rmse:13.351	train-MAPE:0.14085	val-MAPE:0.169035
# [266]	train-rmse:8.68462	val-rmse:13.356	train-MAPE:0.140817	val-MAPE:0.1691
# [267]	train-rmse:8.6768	val-rmse:13.3559	train-MAPE:0.14067	val-MAPE:0.169151
# [268]	train-rmse:8.67233	val-rmse:13.3558	train-MAPE:0.140622	val-MAPE:0.169136
# [269]	train-rmse:8.66394	val-rmse:13.3575	train-MAPE:0.140243	val-MAPE:0.169055
# [270]	train-rmse:8.65825	val-rmse:13.3605	train-MAPE:0.140227	val-MAPE:0.169144
# [271]	train-rmse:8.63883	val-rmse:13.3508	train-MAPE:0.140016	val-MAPE:0.169041
# [272]	train-rmse:8.63539	val-rmse:13.3515	train-MAPE:0.140009	val-MAPE:0.168967
# [273]	train-rmse:8.6274	val-rmse:13.3407	train-MAPE:0.139692	val-MAPE:0.169167
# [274]	train-rmse:8.62406	val-rmse:13.3395	train-MAPE:0.139508	val-MAPE:0.169047
# [275]	train-rmse:8.61284	val-rmse:13.345	train-MAPE:0.139409	val-MAPE:0.168942
# [276]	train-rmse:8.60937	val-rmse:13.3441	train-MAPE:0.13937	val-MAPE:0.168933
# [277]	train-rmse:8.60031	val-rmse:13.3578	train-MAPE:0.139311	val-MAPE:0.169041
# [278]	train-rmse:8.59774	val-rmse:13.3627	train-MAPE:0.139299	val-MAPE:0.169072
# [279]	train-rmse:8.58921	val-rmse:13.3698	train-MAPE:0.139196	val-MAPE:0.169099
# [280]	train-rmse:8.58192	val-rmse:13.3723	train-MAPE:0.138866	val-MAPE:0.16904
# [281]	train-rmse:8.57526	val-rmse:13.3656	train-MAPE:0.138814	val-MAPE:0.169736
# [282]	train-rmse:8.57293	val-rmse:13.3653	train-MAPE:0.138787	val-MAPE:0.169747
# [283]	train-rmse:8.56716	val-rmse:13.3632	train-MAPE:0.138719	val-MAPE:0.169633
# [284]	train-rmse:8.55721	val-rmse:13.362	train-MAPE:0.138606	val-MAPE:0.169315
# [285]	train-rmse:8.54794	val-rmse:13.3615	train-MAPE:0.138484	val-MAPE:0.168997
# [286]	train-rmse:8.54574	val-rmse:13.3612	train-MAPE:0.13846	val-MAPE:0.169008
# [287]	train-rmse:8.53786	val-rmse:13.3654	train-MAPE:0.13836	val-MAPE:0.169211
# [288]	train-rmse:8.53225	val-rmse:13.3648	train-MAPE:0.138266	val-MAPE:0.169105
# [289]	train-rmse:8.52453	val-rmse:13.3719	train-MAPE:0.13817	val-MAPE:0.169089
# [290]	train-rmse:8.51292	val-rmse:13.3764	train-MAPE:0.138009	val-MAPE:0.169207
# [291]	train-rmse:8.50604	val-rmse:13.3806	train-MAPE:0.13797	val-MAPE:0.170111
# [292]	train-rmse:8.50394	val-rmse:13.3803	train-MAPE:0.137936	val-MAPE:0.170132
# [293]	train-rmse:8.49526	val-rmse:13.3798	train-MAPE:0.137741	val-MAPE:0.169864
# [294]	train-rmse:8.4862	val-rmse:13.3852	train-MAPE:0.137635	val-MAPE:0.169663
# [295]	train-rmse:8.47514	val-rmse:13.3912	train-MAPE:0.137571	val-MAPE:0.17011
# [296]	train-rmse:8.46947	val-rmse:13.3951	train-MAPE:0.137509	val-MAPE:0.171045
# [297]	train-rmse:8.46285	val-rmse:13.3938	train-MAPE:0.137363	val-MAPE:0.171021
# [298]	train-rmse:8.45414	val-rmse:13.4032	train-MAPE:0.137266	val-MAPE:0.170931
# [299]	train-rmse:8.44825	val-rmse:13.4106	train-MAPE:0.137201	val-MAPE:0.171322
# [300]	train-rmse:8.44026	val-rmse:13.4204	train-MAPE:0.137127	val-MAPE:0.171241
# [301]	train-rmse:8.42954	val-rmse:13.4031	train-MAPE:0.13698	val-MAPE:0.171196
# [302]	train-rmse:8.42452	val-rmse:13.4034	train-MAPE:0.136705	val-MAPE:0.171108
# [303]	train-rmse:8.40762	val-rmse:13.4064	train-MAPE:0.136658	val-MAPE:0.171117
# [304]	train-rmse:8.40039	val-rmse:13.4061	train-MAPE:0.13659	val-MAPE:0.171117
# [305]	train-rmse:8.38957	val-rmse:13.4149	train-MAPE:0.136469	val-MAPE:0.171291
# [306]	train-rmse:8.38582	val-rmse:13.413	train-MAPE:0.1363	val-MAPE:0.171319
# [307]	train-rmse:8.37977	val-rmse:13.4165	train-MAPE:0.13624	val-MAPE:0.17119
# [308]	train-rmse:8.37651	val-rmse:13.4148	train-MAPE:0.136082	val-MAPE:0.171224
# [309]	train-rmse:8.37166	val-rmse:13.4153	train-MAPE:0.135758	val-MAPE:0.171217
# [310]	train-rmse:8.36699	val-rmse:13.4133	train-MAPE:0.135698	val-MAPE:0.171068
# [311]	train-rmse:8.36478	val-rmse:13.4168	train-MAPE:0.135686	val-MAPE:0.171141
# [312]	train-rmse:8.35646	val-rmse:13.4208	train-MAPE:0.135606	val-MAPE:0.170995
# [313]	train-rmse:8.35219	val-rmse:13.4213	train-MAPE:0.135356	val-MAPE:0.170962
# [314]	train-rmse:8.34626	val-rmse:13.4261	train-MAPE:0.135305	val-MAPE:0.170815
# [315]	train-rmse:8.34206	val-rmse:13.4267	train-MAPE:0.135007	val-MAPE:0.170879
# [316]	train-rmse:8.33546	val-rmse:13.4326	train-MAPE:0.134931	val-MAPE:0.170923
# [317]	train-rmse:8.32459	val-rmse:13.4167	train-MAPE:0.134825	val-MAPE:0.170952
# [318]	train-rmse:8.31818	val-rmse:13.4135	train-MAPE:0.134758	val-MAPE:0.170948
# [319]	train-rmse:8.31449	val-rmse:13.4151	train-MAPE:0.134524	val-MAPE:0.170913
# [320]	train-rmse:8.3053	val-rmse:13.4145	train-MAPE:0.134429	val-MAPE:0.170935
# [321]	train-rmse:8.29922	val-rmse:13.4147	train-MAPE:0.134353	val-MAPE:0.170858
# [322]	train-rmse:8.29561	val-rmse:13.4142	train-MAPE:0.134209	val-MAPE:0.170873
# [323]	train-rmse:8.29014	val-rmse:13.4172	train-MAPE:0.134157	val-MAPE:0.170692
# [324]	train-rmse:8.28668	val-rmse:13.4216	train-MAPE:0.134131	val-MAPE:0.17071
# [325]	train-rmse:8.27976	val-rmse:13.4275	train-MAPE:0.134012	val-MAPE:0.17063
# [326]	train-rmse:8.27547	val-rmse:13.4292	train-MAPE:0.133727	val-MAPE:0.170645
# [327]	train-rmse:8.2661	val-rmse:13.4131	train-MAPE:0.133628	val-MAPE:0.170558
# [328]	train-rmse:8.26211	val-rmse:13.4149	train-MAPE:0.133346	val-MAPE:0.170595
# [329]	train-rmse:8.25045	val-rmse:13.4153	train-MAPE:0.133287	val-MAPE:0.171117
# [330]	train-rmse:8.24106	val-rmse:13.398	train-MAPE:0.133211	val-MAPE:0.17101
# [331]	train-rmse:8.23597	val-rmse:13.4031	train-MAPE:0.133167	val-MAPE:0.171094
# [332]	train-rmse:8.22717	val-rmse:13.3867	train-MAPE:0.133096	val-MAPE:0.170997
# [333]	train-rmse:8.22298	val-rmse:13.3967	train-MAPE:0.13304	val-MAPE:0.170804
# [334]	train-rmse:8.21899	val-rmse:13.3966	train-MAPE:0.132819	val-MAPE:0.170744
# [335]	train-rmse:8.20111	val-rmse:13.4003	train-MAPE:0.132695	val-MAPE:0.170882
# [336]	train-rmse:8.19495	val-rmse:13.3983	train-MAPE:0.132607	val-MAPE:0.170929
# [337]	train-rmse:8.19035	val-rmse:13.4039	train-MAPE:0.132571	val-MAPE:0.170772
# [338]	train-rmse:8.18681	val-rmse:13.4052	train-MAPE:0.132325	val-MAPE:0.170802
# [339]	train-rmse:8.1743	val-rmse:13.3784	train-MAPE:0.132167	val-MAPE:0.170316
# [340]	train-rmse:8.15758	val-rmse:13.3832	train-MAPE:0.132085	val-MAPE:0.170437
# [341]	train-rmse:8.15335	val-rmse:13.388	train-MAPE:0.132045	val-MAPE:0.170507
# [342]	train-rmse:8.13777	val-rmse:13.3919	train-MAPE:0.13193	val-MAPE:0.170635
# [343]	train-rmse:8.13138	val-rmse:13.3894	train-MAPE:0.131868	val-MAPE:0.170192
# [344]	train-rmse:8.12748	val-rmse:13.3948	train-MAPE:0.131846	val-MAPE:0.170054
# [345]	train-rmse:8.12359	val-rmse:13.3994	train-MAPE:0.131852	val-MAPE:0.170065
# [346]	train-rmse:8.1215	val-rmse:13.402	train-MAPE:0.131713	val-MAPE:0.170194
# [347]	train-rmse:8.10976	val-rmse:13.3946	train-MAPE:0.131645	val-MAPE:0.170268
# [348]	train-rmse:8.10303	val-rmse:13.3922	train-MAPE:0.131567	val-MAPE:0.16988
# [349]	train-rmse:8.09507	val-rmse:13.3919	train-MAPE:0.131494	val-MAPE:0.1699
# [350]	train-rmse:8.09107	val-rmse:13.3961	train-MAPE:0.131474	val-MAPE:0.170023
# [351]	train-rmse:8.08695	val-rmse:13.4022	train-MAPE:0.131427	val-MAPE:0.169952
# [352]	train-rmse:8.07598	val-rmse:13.3939	train-MAPE:0.131362	val-MAPE:0.170008
# [353]	train-rmse:8.06933	val-rmse:13.3917	train-MAPE:0.13127	val-MAPE:0.169578
# [354]	train-rmse:8.06098	val-rmse:13.3785	train-MAPE:0.131218	val-MAPE:0.16952
# [355]	train-rmse:8.05747	val-rmse:13.3841	train-MAPE:0.131194	val-MAPE:0.169622
# [356]	train-rmse:8.04098	val-rmse:13.3793	train-MAPE:0.131138	val-MAPE:0.169519
# [357]	train-rmse:8.02936	val-rmse:13.3729	train-MAPE:0.13097	val-MAPE:0.169169
# [358]	train-rmse:8.01917	val-rmse:13.3679	train-MAPE:0.130905	val-MAPE:0.169215
# [359]	train-rmse:8.01312	val-rmse:13.3657	train-MAPE:0.130862	val-MAPE:0.16884
# [360]	train-rmse:8.00352	val-rmse:13.3587	train-MAPE:0.130802	val-MAPE:0.168901
# [361]	train-rmse:7.99707	val-rmse:13.366	train-MAPE:0.130725	val-MAPE:0.168935
# [362]	train-rmse:7.99161	val-rmse:13.3642	train-MAPE:0.130656	val-MAPE:0.168548
# [363]	train-rmse:7.9889	val-rmse:13.3678	train-MAPE:0.130608	val-MAPE:0.168568
# [364]	train-rmse:7.98324	val-rmse:13.3807	train-MAPE:0.130558	val-MAPE:0.168628
# [365]	train-rmse:7.97684	val-rmse:13.3756	train-MAPE:0.13052	val-MAPE:0.168277
# [366]	train-rmse:7.97252	val-rmse:13.3741	train-MAPE:0.130498	val-MAPE:0.167921
# [367]	train-rmse:7.96258	val-rmse:13.3758	train-MAPE:0.130427	val-MAPE:0.167764
# [368]	train-rmse:7.96044	val-rmse:13.3749	train-MAPE:0.130296	val-MAPE:0.167728
# best best_ntree_limit 369

# %%
## 训练预测
# 分割训练集和验证集
ll = round(len(V31_train)/5)
V31_train_val = V31_train.iloc[:ll]
V31_train_t = V31_train.iloc[ll:len(V11_train)]

# 分离标签和特征
Y_time = V31_train_t['volume']
X_time = V31_train_t.drop(['volume'], axis=1)
val_Y_time = V31_train_val.volume
val_X_time = V31_train_val.drop(['volume'], axis=1)

# 转化格式
time_train = xgb.DMatrix(X_time, label=Y_time)
time_val = xgb.DMatrix(val_X_time, label=val_Y_time)
time_test = xgb.DMatrix(V31_test)

#参数设置
params = {
    'booster':'gbtree',      #gbtree和gblinear
    'objective':'reg:linear',
    'eta':0.04,             #为了防止过拟合，更新过程中用到的收缩步长。在每次提升计算之后，算法会直接获得新特征的权重。eta通过缩减特征的权重使提升计算过程更加保守。缺省值为0.3,通常最后设置eta为0.01~0.2
    #'gamma':0.3,            #模型在默认情况下，对于一个节点的划分只有在其loss function得到结果大于0的情况下才进行，而gamma 给定了所需的最低loss function的值gamma值使得算法更conservation，且其值依赖于loss function ，
    'max_depth':5,          #树的深度越大，则对数据的拟合程度越高（过拟合程度也越高）。即该参数也是控制过拟合,建议通过交叉验证（xgb.cv ) 进行调参,通常取值：3-10
    #'min_child_weight':2,   #孩子节点中最小的样本权重和。如果一个叶子节点的样本权重和小于min_child_weight则拆分过程结束。在现行回归模型中，这个参数是指建立每个模型所需要的最小样本数。该成熟越大算法越conservative。即调大这个参数能够控制过拟合。
    #'max_delta_step':2,     #如果取值为0，那么意味着无限制。如果取为正数，则其使得xgboost更新过程更加保守。
    'subsample':1,          #用于训练模型的子样本占整个样本集合的比例。如果设置为0.5则意味着XGBoost将随机的从整个样本集合中抽取出50%的子样本建立树模型，这能够防止过拟合。
    'colsample_bytree':1,   #在建立树时对特征随机采样的比例。缺省值为1 
    #'alpha':5,              #L1 正则的惩罚系数,当数据维度极高时可以使用，使得算法运行更快。
    #'lambda':40,           #L2 正则的惩罚系数,用于处理XGBoost的正则化部分。通常不使用，但可以用来降低过拟合
    'seed':2017,
}


plst = list(params.items())
num_rounds = 62
watchlist = [(time_train, 'train'), (time_val, 'val')]

V31time_model = xgb.train(plst, time_train, num_rounds, watchlist, feval=MAPE)
print("best best_ntree_limit", V31time_model.best_ntree_limit)

V31time_predict = V31time_model.predict(time_test)
# Out:
# [0]	train-rmse:60.3008	val-rmse:70.566	train-MAPE:0.91624	val-MAPE:0.930302
# [1]	train-rmse:58.0114	val-rmse:68.0235	train-MAPE:0.874537	val-MAPE:0.891407
# [2]	train-rmse:55.8171	val-rmse:65.5842	train-MAPE:0.83598	val-MAPE:0.854795
# [3]	train-rmse:53.7139	val-rmse:63.2407	train-MAPE:0.799227	val-MAPE:0.819733
# [4]	train-rmse:51.6981	val-rmse:60.9968	train-MAPE:0.764127	val-MAPE:0.786026
# [5]	train-rmse:49.7653	val-rmse:58.8393	train-MAPE:0.731736	val-MAPE:0.753636
# [6]	train-rmse:47.9137	val-rmse:56.7676	train-MAPE:0.700657	val-MAPE:0.722721
# [7]	train-rmse:46.1405	val-rmse:54.7856	train-MAPE:0.672115	val-MAPE:0.693481
# [8]	train-rmse:44.4426	val-rmse:52.8795	train-MAPE:0.645168	val-MAPE:0.665482
# [9]	train-rmse:42.817	val-rmse:51.0588	train-MAPE:0.619289	val-MAPE:0.638691
# [10]	train-rmse:41.2612	val-rmse:49.3171	train-MAPE:0.5947	val-MAPE:0.612947
# [11]	train-rmse:39.772	val-rmse:47.6416	train-MAPE:0.571251	val-MAPE:0.588499
# [12]	train-rmse:38.3475	val-rmse:46.042	train-MAPE:0.548809	val-MAPE:0.564872
# [13]	train-rmse:36.9789	val-rmse:44.5126	train-MAPE:0.527832	val-MAPE:0.542646
# [14]	train-rmse:35.6737	val-rmse:43.0439	train-MAPE:0.508847	val-MAPE:0.523012
# [15]	train-rmse:34.4261	val-rmse:41.6377	train-MAPE:0.490557	val-MAPE:0.504149
# [16]	train-rmse:33.2149	val-rmse:40.2802	train-MAPE:0.4732	val-MAPE:0.486187
# [17]	train-rmse:32.0571	val-rmse:38.9762	train-MAPE:0.457008	val-MAPE:0.468975
# [18]	train-rmse:30.964	val-rmse:37.7385	train-MAPE:0.441567	val-MAPE:0.452413
# [19]	train-rmse:29.9177	val-rmse:36.5516	train-MAPE:0.427045	val-MAPE:0.436505
# [20]	train-rmse:28.9188	val-rmse:35.2929	train-MAPE:0.413682	val-MAPE:0.420181
# [21]	train-rmse:27.9677	val-rmse:34.2063	train-MAPE:0.401102	val-MAPE:0.405914
# [22]	train-rmse:27.0534	val-rmse:33.1664	train-MAPE:0.389362	val-MAPE:0.392156
# [23]	train-rmse:26.1839	val-rmse:32.1578	train-MAPE:0.378409	val-MAPE:0.379213
# [24]	train-rmse:25.3437	val-rmse:31.2051	train-MAPE:0.368601	val-MAPE:0.368435
# [25]	train-rmse:24.5427	val-rmse:30.2939	train-MAPE:0.35936	val-MAPE:0.358366
# [26]	train-rmse:23.7804	val-rmse:29.4268	train-MAPE:0.350454	val-MAPE:0.348756
# [27]	train-rmse:23.0392	val-rmse:28.5897	train-MAPE:0.342238	val-MAPE:0.339659
# [28]	train-rmse:22.3462	val-rmse:27.8158	train-MAPE:0.334709	val-MAPE:0.331231
# [29]	train-rmse:21.6887	val-rmse:27.0712	train-MAPE:0.327468	val-MAPE:0.323971
# [30]	train-rmse:21.0606	val-rmse:26.3714	train-MAPE:0.320876	val-MAPE:0.316544
# [31]	train-rmse:20.4634	val-rmse:25.7116	train-MAPE:0.314843	val-MAPE:0.309655
# [32]	train-rmse:19.8947	val-rmse:25.0563	train-MAPE:0.308976	val-MAPE:0.30292
# [33]	train-rmse:19.3551	val-rmse:24.4589	train-MAPE:0.303658	val-MAPE:0.296533
# [34]	train-rmse:18.8457	val-rmse:23.8879	train-MAPE:0.2988	val-MAPE:0.290557
# [35]	train-rmse:18.3591	val-rmse:23.3269	train-MAPE:0.29441	val-MAPE:0.284801
# [36]	train-rmse:17.8985	val-rmse:22.8062	train-MAPE:0.290304	val-MAPE:0.27935
# [37]	train-rmse:17.4616	val-rmse:22.3044	train-MAPE:0.286797	val-MAPE:0.27443
# [38]	train-rmse:17.0446	val-rmse:21.8627	train-MAPE:0.283143	val-MAPE:0.269079
# [39]	train-rmse:16.6517	val-rmse:21.3975	train-MAPE:0.279989	val-MAPE:0.265229
# [40]	train-rmse:16.2555	val-rmse:20.9294	train-MAPE:0.27718	val-MAPE:0.261555
# [41]	train-rmse:15.8999	val-rmse:20.4849	train-MAPE:0.274589	val-MAPE:0.258256
# [42]	train-rmse:15.5449	val-rmse:20.0485	train-MAPE:0.272299	val-MAPE:0.254795
# [43]	train-rmse:15.2018	val-rmse:19.6503	train-MAPE:0.270278	val-MAPE:0.251907
# [44]	train-rmse:14.8696	val-rmse:19.2484	train-MAPE:0.268253	val-MAPE:0.248988
# [45]	train-rmse:14.5499	val-rmse:18.8947	train-MAPE:0.266552	val-MAPE:0.246825
# [46]	train-rmse:14.2475	val-rmse:18.5465	train-MAPE:0.265031	val-MAPE:0.244638
# [47]	train-rmse:13.9602	val-rmse:18.2293	train-MAPE:0.263669	val-MAPE:0.243
# [48]	train-rmse:13.6925	val-rmse:17.9112	train-MAPE:0.261989	val-MAPE:0.240615
# [49]	train-rmse:13.4593	val-rmse:17.6913	train-MAPE:0.260429	val-MAPE:0.23868
# [50]	train-rmse:13.216	val-rmse:17.4113	train-MAPE:0.25924	val-MAPE:0.23693
# [51]	train-rmse:12.9856	val-rmse:17.1426	train-MAPE:0.258453	val-MAPE:0.235842
# [52]	train-rmse:12.7686	val-rmse:16.8888	train-MAPE:0.257673	val-MAPE:0.234688
# [53]	train-rmse:12.5634	val-rmse:16.6231	train-MAPE:0.257107	val-MAPE:0.23323
# [54]	train-rmse:12.3751	val-rmse:16.3696	train-MAPE:0.256512	val-MAPE:0.231664
# [55]	train-rmse:12.1944	val-rmse:16.1332	train-MAPE:0.255572	val-MAPE:0.22978
# [56]	train-rmse:12.0365	val-rmse:15.9634	train-MAPE:0.25513	val-MAPE:0.228504
# [57]	train-rmse:11.8679	val-rmse:15.7197	train-MAPE:0.254866	val-MAPE:0.227321
# [58]	train-rmse:11.7335	val-rmse:15.5068	train-MAPE:0.254237	val-MAPE:0.225344
# [59]	train-rmse:11.5808	val-rmse:15.3002	train-MAPE:0.253954	val-MAPE:0.224179
# [60]	train-rmse:11.4554	val-rmse:15.1436	train-MAPE:0.253544	val-MAPE:0.223159
# [61]	train-rmse:11.2987	val-rmse:14.9447	train-MAPE:0.253913	val-MAPE:0.224553
# best best_ntree_limit 62

# %% [markdown]
# #### 预测结果填充

# %%
time_predict_result = np.concatenate([A2time_predict, A3time_predict, B1time_predict, B3time_predict, C1time_predict, C3time_predict], axis=0)
time_test_data['avg_travel_time'] = time_predict_result

volume_predict_result = np.concatenate([V10time_predict, V11time_predict, V20time_predict, V30time_predict, V31time_predict])
volume_test_data['volume'] = volume_predict_result

travel_time_window = pd.concat([time_train_data, time_test_data], axis=0)
volume_window = pd.concat([volume_train_data, volume_test_data], axis=0)
# Out:
# /home/godcedric/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /home/godcedric/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# #### 排序

# %%
travel_time_window = travel_time_window.sort_values(by=['route', 'start_time'])
travel_time_window.index = np.arange(len(travel_time_window))

volume_window = volume_window.sort_values(by=['pair', 'start_time'])
volume_window.index = np.arange(len(volume_window))

# %%
grouped_by_route = travel_time_window.groupby(['route'])
fig = plt.figure()
fig.set_figheight(30)
fig.set_figwidth(40)
k = 1
for k1, group in grouped_by_route:  
    ax = fig.add_subplot(6,1,k)
    k += 1
    ax.plot(group['start_time'], group['avg_travel_time'],'ko--', label=k1)
    ax.legend()

# %%
grouped_by_pair = volume_window.groupby(['pair'])
fig = plt.figure()
fig.set_figheight(30)
fig.set_figwidth(40)
k = 1
for k1, group in grouped_by_pair:  
    ax = fig.add_subplot(5,1,k)
    k += 1
    ax.plot(group['start_time'], group['volume'],'ko--', label=k1)
    ax.plot(group['start_time'], 100*np.ones(len(group)))
    ax.plot(group['start_time'], 75*np.ones(len(group)))
    ax.plot(group['start_time'], 50*np.ones(len(group)))
    ax.legend()

# %% [markdown]
# ### 分割，只留9.19之后的数据

# %%
# 只取9.19之后的数据
start_date = date(2016,9,19)
travel_time_window = travel_time_window[travel_time_window['date'] >= start_date]

# %% [markdown]
# ### 测试集先导信息缺失值补充（以均值补充）

# %%
# 先填充6,7,15,16点的

# 获取测试集时间段均值
time_for_mean = travel_time_window.copy()

# 留下目标时间段数据
time_for_mean = time_for_mean[['avg_travel_time', 'route', 'weekday', 'time', 'hour']]

time_for_mean = time_for_mean[(time_for_mean['hour']==6) | (time_for_mean['hour']==7) | 
                              (time_for_mean['hour']==15) | (time_for_mean['hour']==16)]

del time_for_mean['hour']
# 排好序
time_for_mean = time_for_mean.sort_values(by=['route', 'weekday', 'time'])

# 求好均值
time_group = time_for_mean.groupby(['route', 'weekday', 'time'])
mean_values = time_group.mean().values

# 补充
test_travel_time_window['weekday'] = test_travel_time_window['start_time'].map(lambda x: x.weekday())

test_travel_time_window = test_travel_time_window.sort_values(by=['intersection_id','tollgate_id','weekday','start_time'])
test_travel_time_window.index = np.arange(len(test_travel_time_window))

for k in range(len(test_travel_time_window)):
    if not (test_travel_time_window.ix[k,'avg_travel_time'] > 0):
        test_travel_time_window.ix[k,'avg_travel_time'] = mean_values[k]

del test_travel_time_window['weekday']
test_travel_time_window = test_travel_time_window.sort_values(by=['intersection_id', 'tollgate_id', 'start_time'])
test_travel_time_window.index = np.arange(len(test_travel_time_window))

# %%
# 测试集均值补充
submission_travel_time = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/final_submission/day1/travel_time_submission.csv')
submission_volume = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/final_submission/day1/volume_submission.csv')

# %%
# 留下目标时间段数据
time_for_mean = travel_time_window.copy()
volume_for_mean = volume_window.copy()

time_for_mean = time_for_mean[['avg_travel_time', 'route', 'weekday', 'time', 'hour']]
volume_for_mean = volume_for_mean[['volume', 'pair', 'weekday', 'time', 'hour']]

time_for_mean = time_for_mean[(time_for_mean['hour']==8) | (time_for_mean['hour']==9) | 
                              (time_for_mean['hour']==17) | (time_for_mean['hour']==18)]

volume_for_mean = volume_for_mean[(volume_for_mean['hour']==8) | (volume_for_mean['hour']==9) | 
                                  (volume_for_mean['hour']==17) | (volume_for_mean['hour']==18)]

del time_for_mean['hour']
del volume_for_mean['hour']
# 排好序
time_for_mean = time_for_mean.sort_values(by=['route', 'weekday', 'time'])
volume_for_mean = volume_for_mean.sort_values(by=['pair', 'weekday', 'time'])

# 求好均值
time_group = time_for_mean.groupby(['route', 'weekday', 'time'])
mean_values = time_group.mean().values

# 补充

submission_travel_time['start_time'] = submission_travel_time['time_window'].map(lambda x: datetime.strptime(x.split(',')[0][1:], '%Y-%m-%d %H:%M:%S'))
submission_travel_time['weekday'] = submission_travel_time['start_time'].map(lambda x: x.weekday())
submission_travel_time = submission_travel_time.sort_values(by=['intersection_id','tollgate_id','weekday','start_time'])
submission_travel_time.index = np.arange(len(submission_travel_time))
submission_travel_time['avg_travel_time'] = mean_values

# 排序
submission_travel_time = submission_travel_time.sort_values(by=['intersection_id','tollgate_id','start_time'])
submission_travel_time.index = np.arange(len(submission_travel_time))

# 求好均值
volume_group = volume_for_mean.groupby(['pair', 'weekday', 'time'])
mean_values = volume_group.mean().values

# 补充
submission_volume['start_time'] = submission_volume['time_window'].map(lambda x: datetime.strptime(x.split(',')[0][1:], '%Y-%m-%d %H:%M:%S'))
submission_volume['weekday'] = submission_volume['start_time'].map(lambda x: x.weekday())
submission_volume = submission_volume.sort_values(by=['tollgate_id','direction','weekday','start_time'])
submission_volume.index = np.arange(len(submission_volume))
submission_volume['volume'] = mean_values

# 排序
submission_volume = submission_volume.sort_values(by=['tollgate_id','direction','start_time'])
submission_volume.index = np.arange(len(submission_volume))

# %% [markdown]
# ### 补充测试集特征

# %%
travel_time_window.columns
# Out:
# Index(['avg_travel_time', 'route', 'intersection_id', 'tollgate_id',
#        'time_window', 'start_time', 'date', 'month', 'day', 'weekday',
#        'holiday', 'time', 'hour', 'minute', 'timemap', 'pressure',
#        'sea_pressure', 'wind_direction', 'wind_speed', 'temperature',
#        'rel_humidity', 'precipitation'],
#       dtype='object')

# %%
volume_window.columns
# Out:
# Index(['volume', 'pair', 'tollgate_id', 'direction', 'time_window',
#        'start_time', 'date', 'month', 'day', 'weekday', 'holiday', 'time',
#        'hour', 'minute', 'timemap', 'pressure', 'sea_pressure',
#        'wind_direction', 'wind_speed', 'temperature', 'rel_humidity',
#        'precipitation'],
#       dtype='object')

# %%
submission_travel_time.columns
# Out:
# Index(['intersection_id', 'tollgate_id', 'time_window', 'avg_travel_time',
#        'start_time', 'weekday'],
#       dtype='object')

# %%
submission_volume.columns
# Out:
# Index(['tollgate_id', 'time_window', 'direction', 'volume', 'start_time',
#        'weekday'],
#       dtype='object')

# %%
# 天气特征
test_weather_data['hour'] = test_weather_data['hour'].map(lambda x: ' ' + time(x, 0, 0).strftime('%H:%M:%S'))
test_weather_data['start_time'] = test_weather_data['date'] + test_weather_data['hour']
test_weather_data['start_time'] = test_weather_data['start_time'].map(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M:%S'))
del test_weather_data['date']
del test_weather_data['hour']
num = len(test_weather_data)
for i in range(num):
    temp = test_weather_data.ix[i]
    temp1 = copy.deepcopy(temp)
    temp2 = copy.deepcopy(temp)
    temp3 = copy.deepcopy(temp)
    temp4 = copy.deepcopy(temp)
    temp5 = copy.deepcopy(temp)
    temp6 = copy.deepcopy(temp)
    temp7 = copy.deepcopy(temp)
    temp8 = copy.deepcopy(temp)
    stime = temp.start_time
    temp1.start_time = stime + timedelta(minutes=20)
    temp2.start_time = stime + timedelta(minutes=40)
    temp3.start_time = stime + timedelta(minutes=60)
    temp4.start_time = stime + timedelta(minutes=80)
    temp5.start_time = stime + timedelta(minutes=100)
    temp6.start_time = stime + timedelta(minutes=120)
    temp7.start_time = stime + timedelta(minutes=140)
    temp8.start_time = stime + timedelta(minutes=160)
    alltemp = [temp1, temp2, temp3, temp4, temp5, temp6, temp7, temp8]
    alltemp = pd.DataFrame(alltemp)
    test_weather_data = pd.concat([test_weather_data, alltemp])

# %%
submission_travel_time = submission_travel_time.sort_values(by = ['intersection_id', 'tollgate_id', 'start_time'])
submission_travel_time.index = np.arange(len(submission_travel_time))

submission_travel_time = pd.merge(submission_travel_time, test_weather_data, on='start_time', how='left')
submission_travel_time['date'] = submission_travel_time['start_time'].map(lambda x: x.date())
submission_travel_time['time'] = submission_travel_time['start_time'].map(lambda x: x.time())
submission_travel_time['hour'] = submission_travel_time['start_time'].map(lambda x: x.hour)
submission_travel_time['minute'] = submission_travel_time['start_time'].map(lambda x: x.minute)

# %%
# weekday特征
submission_travel_time['weekday'] = submission_travel_time['start_time'].map(lambda x: x.weekday())
# route特征
submission_travel_time['route'] = submission_travel_time['intersection_id'].astype(str) + '-' + submission_travel_time['tollgate_id'].astype(str)

# %%
submission_travel_time['last_20min'] = 0
# last_20min
for i in range(len(submission_travel_time)):
    if (i % 6) == 0:
        submission_travel_time.ix[i,'last_20min'] = test_travel_time_window.ix[i+5,'avg_travel_time']
    else:
        submission_travel_time.ix[i,'last_20min'] = submission_travel_time.ix[i-1,'avg_travel_time']

# %%
# 把time映射成1～72
from collections import defaultdict
time_start = datetime(2016,10,17,0,0,0)
timedic = defaultdict(int)
for i in range(72):
    timedic[time_start.time()] = i+1
    time_start = time_start + timedelta(minutes=20)
submission_travel_time['timemap'] = submission_travel_time['time'].map(lambda x:timedic[x])

# %%
submission_volume = submission_volume.sort(['tollgate_id', 'direction', 'start_time'])
# pair特征
submission_volume['pair'] = submission_volume['tollgate_id'].astype(str) + '-' + submission_volume['direction'].astype(str)

# 天气特征
submission_volume = pd.merge(submission_volume, test_weather_data, on='start_time', how='left')

# 星期几
submission_volume['weekday'] = submission_volume['start_time'].map(lambda x: x.weekday())

# 时间窗口
submission_volume['time'] = submission_volume['start_time'].map(lambda x: x.time())
submission_volume['date'] = submission_volume['start_time'].map(lambda x: x.date())

submission_volume['hour'] = submission_volume['start_time'].map(lambda x: x.hour)
submission_volume['minute'] = submission_volume['start_time'].map(lambda x: x.minute)
# Out:
# /home/godcedric/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':

# %%
# last_20min
submission_volume['last_20min'] = 0
# last_20min
for i in range(len(submission_volume)):
    if (i % 6) == 0:
        submission_volume.ix[i,'last_20min'] = test_volume_window.ix[i+5,'volume']
    else:
        submission_volume.ix[i,'last_20min'] = submission_volume.ix[i-1,'volume']

# %%
from collections import defaultdict
time_start = datetime(2016,10,17,0,0,0)
timedic = defaultdict(int)
for i in range(72):
    timedic[time_start.time()] = i+1
    time_start = time_start + timedelta(minutes=20)
submission_volume['timemap'] = submission_volume['time'].map(lambda x:timedic[x])

# %% [markdown]
# ### 补充下训练集的last_20min

# %%
travel_time_window = travel_time_window.sort_values(by = ['intersection_id', 'tollgate_id', 'start_time'])
travel_time_window.index = np.arange(len(travel_time_window))

volume_window = volume_window.sort_values(by = ['tollgate_id', 'direction', 'start_time'])
volume_window.index = np.arange(len(volume_window))

# %%
travel_time_window['last_20min'] = np.nan
volume_window['last_20min'] = np.nan

start_time = datetime(2016,9,19,0,0,0)

for i in range(0,len(travel_time_window)):
    if travel_time_window.ix[i,'start_time'] != start_time:
        travel_time_window.ix[i,'last_20min'] = travel_time_window.ix[i-1,'avg_travel_time']

for i in range(0,len(volume_window)):
    if volume_window.ix[i,'start_time'] != start_time:
        volume_window.ix[i,'last_20min'] = volume_window.ix[i-1,'volume']

# %%
travel_time_window = travel_time_window.fillna(method='bfill')
volume_window = volume_window.fillna(method='bfill')

# %% [markdown]
# ### 选择特征输出

# %%
submission_travel_time['month'] = submission_travel_time['date'].map(lambda x: x.month)
submission_travel_time['day'] = submission_travel_time['date'].map(lambda x: x.day)
submission_travel_time['holiday'] = 0

submission_volume['month'] = submission_volume['date'].map(lambda x: x.month)
submission_volume['day'] = submission_volume['date'].map(lambda x: x.day)
submission_volume['holiday'] = 0

# %%
time_columns = ['route', 'intersection_id', 'tollgate_id',
                'time_window', 'start_time', 'date', 'month', 'day', 'weekday',
                'holiday', 'time', 'hour', 'minute', 'timemap', 'pressure',
                'sea_pressure', 'wind_direction', 'wind_speed', 'temperature',
                'rel_humidity', 'precipitation', 'last_20min']
volume_columns = ['pair', 'tollgate_id', 'direction', 'time_window',
                  'start_time', 'date', 'month', 'day', 'weekday', 'holiday', 'time',
                  'hour', 'minute', 'timemap', 'pressure', 'sea_pressure',
                  'wind_direction', 'wind_speed', 'temperature', 'rel_humidity',
                  'precipitation', 'last_20min']

# %%
submission_travel_time = submission_travel_time[time_columns]
submission_volume = submission_volume[volume_columns]

# %%
# 输出
travel_time_window.to_csv('/home/godcedric/GitLocal/KDDCUP2017/final_data/加工好的数据/7.0/travel_time_train_data.csv', index=False)
volume_window.to_csv('/home/godcedric/GitLocal/KDDCUP2017/final_data/加工好的数据/7.0/volume_train_data.csv', index=False)

submission_travel_time.to_csv('/home/godcedric/GitLocal/KDDCUP2017/final_data/加工好的数据/7.0/test_travel_time_data', index=False)
submission_volume.to_csv('/home/godcedric/GitLocal/KDDCUP2017/final_data/加工好的数据/7.0/test_volume_data', index=False)
