# %% [markdown]
# # split_xgboost_with_feature2

# %% [markdown]
# 2017-05-31

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from datetime import datetime,timedelta,date,time
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics.scorer import make_scorer
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
# %matplotlib inline
import copy

# %% [markdown]
# ### 录入数据

# %%
travel_time_train = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/final_data/加工好的数据/7.75/travel_time_train_data.csv')
volume_train = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/final_data/加工好的数据/7.75/volume_train_data.csv')

test_travel_time = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/final_data/加工好的数据/7.75/test_travel_time_data.csv')
test_volume = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/final_data/加工好的数据/7.75/test_volume_data.csv')

# %% [markdown]
# ### 分割路径，对

# %%
A2_train = travel_time_train[travel_time_train['route'] == 'A-2']
A3_train = travel_time_train[travel_time_train['route'] == 'A-3']
B1_train = travel_time_train[travel_time_train['route'] == 'B-1']
B3_train = travel_time_train[travel_time_train['route'] == 'B-3']
C1_train = travel_time_train[travel_time_train['route'] == 'C-1']
C3_train = travel_time_train[travel_time_train['route'] == 'C-3']

A2_test = test_travel_time[test_travel_time['route'] == 'A-2']
A3_test = test_travel_time[test_travel_time['route'] == 'A-3']
B1_test = test_travel_time[test_travel_time['route'] == 'B-1']
B3_test = test_travel_time[test_travel_time['route'] == 'B-3']
C1_test = test_travel_time[test_travel_time['route'] == 'C-1']
C3_test = test_travel_time[test_travel_time['route'] == 'C-3']

V10_train =  volume_train[volume_train['pair'] == '1-0']
V11_train =  volume_train[volume_train['pair'] == '1-1']
V20_train =  volume_train[volume_train['pair'] == '2-0']
V30_train =  volume_train[volume_train['pair'] == '3-0']
V31_train =  volume_train[volume_train['pair'] == '3-1']

V10_test =  test_volume[test_volume['pair'] == '1-0']
V11_test =  test_volume[test_volume['pair'] == '1-1']
V20_test =  test_volume[test_volume['pair'] == '2-0']
V30_test =  test_volume[test_volume['pair'] == '3-0']
V31_test =  test_volume[test_volume['pair'] == '3-1']

# %% [markdown]
# ### 选择特征

# %%
time_columns = ['avg_travel_time', 'is_true',
                'month', 'day', 'weekday','holiday','timemap', 
                'pressure', 'sea_pressure', 
                'wind_direction', 'wind_speed', 'temperature',
                'rel_humidity', 
                'precipitation', 
                #'last_20min_A2', 'last_20min_A3', 'last_20min_B1', 'last_20min_B3', 'last_20min_C1',
                #'last_20min_C3', 'last_20min_V10', 'last_20min_V11', 'last_20min_V20',
                #'last_20min_V30', 'last_20min_V31'
               ]

time_columns2 = ['month', 'day', 'weekday','holiday','timemap', 
                'pressure', 'sea_pressure', 
                'wind_direction', 'wind_speed', 'temperature',
                'rel_humidity', 
                'precipitation', 
                #'last_20min_A2', 'last_20min_A3', 'last_20min_B1', 'last_20min_B3', 'last_20min_C1',
                #'last_20min_C3', 'last_20min_V10', 'last_20min_V11', 'last_20min_V20',
                #'last_20min_V30', 'last_20min_V31'
                ]

volume_columns = ['volume', 'is_true',
                  'month', 'day', 'weekday', 'holiday', 'timemap', 
                  'pressure', 'sea_pressure',
                  'wind_direction', 'wind_speed', 'temperature', 
                  'rel_humidity', 
                  'precipitation', 
                  #'last_20min_A2', 'last_20min_A3', 'last_20min_B1', 'last_20min_B3', 'last_20min_C1', 'last_20min_C3',
                  #'last_20min_V10', 'last_20min_V11', 'last_20min_V20', 'last_20min_V30',
                  #'last_20min_V31'
                 ]

volume_columns2 = ['month', 'day', 'weekday', 'holiday', 'timemap', 
                  'pressure', 'sea_pressure',
                  'wind_direction', 'wind_speed', 'temperature', 
                  'rel_humidity', 
                  'precipitation', 
                  #'last_20min_A2', 'last_20min_A3', 'last_20min_B1', 'last_20min_B3', 'last_20min_C1', 'last_20min_C3',
                  #'last_20min_V10', 'last_20min_V11', 'last_20min_V20', 'last_20min_V30',
                  #'last_20min_V31'
                  ]

A2_train = A2_train[time_columns]
A3_train = A3_train[time_columns]
B1_train = B1_train[time_columns]
B3_train = B3_train[time_columns]
C1_train = C1_train[time_columns]
C3_train = C3_train[time_columns]

A2_test = A2_test[time_columns2]
A3_test = A3_test[time_columns2]
B1_test = B1_test[time_columns2]
B3_test = B3_test[time_columns2]
C1_test = C1_test[time_columns2]
C3_test = C3_test[time_columns2]

V10_train =  V10_train[volume_columns]
V11_train =  V11_train[volume_columns]
V20_train =  V20_train[volume_columns]
V30_train =  V30_train[volume_columns]
V31_train =  V31_train[volume_columns]

V10_test =  V10_test[volume_columns2]
V11_test =  V11_test[volume_columns2]
V20_test =  V20_test[volume_columns2]
V30_test =  V30_test[volume_columns2]
V31_test =  V31_test[volume_columns2]

# %% [markdown]
# ### 定义评价函数

# %%
# 自定义评价函数
def MAPE(preds, dtrain):
    labels = dtrain.get_label()
    return 'MAPE', float(sum(np.fabs((labels - preds) / labels))) / len(labels)

# %%
# 自定义评分函数
def MAPE2(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true))
score = make_scorer(MAPE2, greater_is_better=False)

# %% [markdown]
# ### 训练预测

# %% [markdown]
# #### A2

# %%
print(len(A2_train))
print(len(A2_train_true))
print(len(A2_train_false))
# Out:
# 2592
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-327005bc47a5> in <module>()
#       1 print(len(A2_train))
# ----> 2 print(len(A2_train_true))
#       3 print(len(A2_train_false))
#
# NameError: name 'A2_train_true' is not defined

# %%
# 分割训练集验证集
A2_train_true = A2_train[A2_train['is_true'] == True]
A2_train_false = A2_train[A2_train['is_true'] == False]

X_train, X_val, y_train, y_val = train_test_split(A2_train_true.iloc[:,1:], A2_train_true.iloc[:,0], test_size=0.2, random_state=63)

X_train = pd.concat([X_train, A2_train_false.iloc[:,1:]], axis=0)
y_train = pd.concat([y_train, A2_train_false.iloc[:,0]])

del X_train['is_true']
del X_val['is_true']

# 转化格式
time_train = xgb.DMatrix(X_train, label=y_train)
time_val = xgb.DMatrix(X_val, label=y_val)
time_test = xgb.DMatrix(A2_test)

#参数设置
params = {
    'booster':'gbtree',      #gbtree和gblinear
    'objective':'reg:linear',
    'eta':0.04,             #为了防止过拟合，更新过程中用到的收缩步长。在每次提升计算之后，算法会直接获得新特征的权重。eta通过缩减特征的权重使提升计算过程更加保守。缺省值为0.3,通常最后设置eta为0.01~0.2
    #'gamma':0.3,            #模型在默认情况下，对于一个节点的划分只有在其loss function得到结果大于0的情况下才进行，而gamma 给定了所需的最低loss function的值gamma值使得算法更conservation，且其值依赖于loss function ，
    'max_depth':5,          #树的深度越大，则对数据的拟合程度越高（过拟合程度也越高）。即该参数也是控制过拟合,建议通过交叉验证（xgb.cv ) 进行调参,通常取值：3-10
    #'min_child_weight':2,   #孩子节点中最小的样本权重和。如果一个叶子节点的样本权重和小于min_child_weight则拆分过程结束。在现行回归模型中，这个参数是指建立每个模型所需要的最小样本数。该成熟越大算法越conservative。即调大这个参数能够控制过拟合。
    #'max_delta_step':2,     #如果取值为0，那么意味着无限制。如果取为正数，则其使得xgboost更新过程更加保守。
    'subsample':1,          #用于训练模型的子样本占整个样本集合的比例。如果设置为0.5则意味着XGBoost将随机的从整个样本集合中抽取出50%的子样本建立树模型，这能够防止过拟合。
    'colsample_bytree':1,   #在建立树时对特征随机采样的比例。缺省值为1 
    #'alpha':5,              #L1 正则的惩罚系数,当数据维度极高时可以使用，使得算法运行更快。
    #'lambda':40,           #L2 正则的惩罚系数,用于处理XGBoost的正则化部分。通常不使用，但可以用来降低过拟合
    'seed':2017,
}

plst = list(params.items())
num_rounds = 64
watchlist = [(time_train, 'train'), (time_val, 'val')]

A2time_model = xgb.train(plst, time_train, num_rounds, watchlist, feval=MAPE)
print("best best_ntree_limit", A2time_model.best_ntree_limit)

A2time_predict = A2time_model.predict(time_test)
# Out:
# [0]	train-rmse:60.9708	val-rmse:62.2665	train-MAPE:0.949391	val-MAPE:0.949527
# [1]	train-rmse:58.7017	val-rmse:59.9464	train-MAPE:0.909308	val-MAPE:0.909312
# [2]	train-rmse:56.529	val-rmse:57.7252	train-MAPE:0.87082	val-MAPE:0.870698
# [3]	train-rmse:54.4489	val-rmse:55.5993	train-MAPE:0.833863	val-MAPE:0.833623
# [4]	train-rmse:52.4581	val-rmse:53.5682	train-MAPE:0.798345	val-MAPE:0.79804
# [5]	train-rmse:50.5527	val-rmse:51.6235	train-MAPE:0.764619	val-MAPE:0.763962
# [6]	train-rmse:48.7269	val-rmse:49.7565	train-MAPE:0.732321	val-MAPE:0.731138
# [7]	train-rmse:46.9803	val-rmse:47.9711	train-MAPE:0.701333	val-MAPE:0.699618
# [8]	train-rmse:45.3101	val-rmse:46.2661	train-MAPE:0.671738	val-MAPE:0.669418
# [9]	train-rmse:43.7155	val-rmse:44.6425	train-MAPE:0.643232	val-MAPE:0.640447
# [10]	train-rmse:42.1887	val-rmse:43.0813	train-MAPE:0.616202	val-MAPE:0.612497
# [11]	train-rmse:40.7301	val-rmse:41.5982	train-MAPE:0.590314	val-MAPE:0.585856
# [12]	train-rmse:39.3392	val-rmse:40.1861	train-MAPE:0.565487	val-MAPE:0.560121
# [13]	train-rmse:38.0078	val-rmse:38.8293	train-MAPE:0.54175	val-MAPE:0.535345
# [14]	train-rmse:36.7359	val-rmse:37.5426	train-MAPE:0.519079	val-MAPE:0.511845
# [15]	train-rmse:35.5247	val-rmse:36.3216	train-MAPE:0.497276	val-MAPE:0.489352
# [16]	train-rmse:34.3663	val-rmse:35.1482	train-MAPE:0.476387	val-MAPE:0.46793
# [17]	train-rmse:33.2613	val-rmse:34.0271	train-MAPE:0.45635	val-MAPE:0.447556
# [18]	train-rmse:32.2092	val-rmse:32.9587	train-MAPE:0.437089	val-MAPE:0.427819
# [19]	train-rmse:31.2061	val-rmse:31.9433	train-MAPE:0.418564	val-MAPE:0.40896
# [20]	train-rmse:30.2494	val-rmse:30.982	train-MAPE:0.400948	val-MAPE:0.39092
# [21]	train-rmse:29.3391	val-rmse:30.0699	train-MAPE:0.384085	val-MAPE:0.373664
# [22]	train-rmse:28.4741	val-rmse:29.2072	train-MAPE:0.367991	val-MAPE:0.357358
# [23]	train-rmse:27.6446	val-rmse:28.3817	train-MAPE:0.352702	val-MAPE:0.342065
# [24]	train-rmse:26.8631	val-rmse:27.6107	train-MAPE:0.338188	val-MAPE:0.327679
# [25]	train-rmse:26.1152	val-rmse:26.867	train-MAPE:0.324328	val-MAPE:0.314166
# [26]	train-rmse:25.4101	val-rmse:26.1723	train-MAPE:0.311313	val-MAPE:0.301641
# [27]	train-rmse:24.7348	val-rmse:25.4967	train-MAPE:0.298971	val-MAPE:0.289861
# [28]	train-rmse:24.0955	val-rmse:24.8619	train-MAPE:0.287283	val-MAPE:0.278736
# [29]	train-rmse:23.4915	val-rmse:24.2584	train-MAPE:0.27612	val-MAPE:0.268195
# [30]	train-rmse:22.9185	val-rmse:23.693	train-MAPE:0.265613	val-MAPE:0.258355
# [31]	train-rmse:22.3681	val-rmse:23.1471	train-MAPE:0.255734	val-MAPE:0.249348
# [32]	train-rmse:21.8547	val-rmse:22.6581	train-MAPE:0.246387	val-MAPE:0.240967
# [33]	train-rmse:21.3688	val-rmse:22.1881	train-MAPE:0.237626	val-MAPE:0.233255
# [34]	train-rmse:20.9101	val-rmse:21.7474	train-MAPE:0.229545	val-MAPE:0.226014
# [35]	train-rmse:20.4737	val-rmse:21.3428	train-MAPE:0.221944	val-MAPE:0.219455
# [36]	train-rmse:20.0635	val-rmse:20.9556	train-MAPE:0.214967	val-MAPE:0.213493
# [37]	train-rmse:19.6747	val-rmse:20.5773	train-MAPE:0.208493	val-MAPE:0.207702
# [38]	train-rmse:19.3103	val-rmse:20.2362	train-MAPE:0.202578	val-MAPE:0.202684
# [39]	train-rmse:18.9568	val-rmse:19.8931	train-MAPE:0.197131	val-MAPE:0.197993
# [40]	train-rmse:18.6311	val-rmse:19.5818	train-MAPE:0.192199	val-MAPE:0.193851
# [41]	train-rmse:18.3265	val-rmse:19.2981	train-MAPE:0.187622	val-MAPE:0.190019
# [42]	train-rmse:18.0382	val-rmse:19.0365	train-MAPE:0.183418	val-MAPE:0.186584
# [43]	train-rmse:17.7694	val-rmse:18.7933	train-MAPE:0.179564	val-MAPE:0.183753
# [44]	train-rmse:17.5084	val-rmse:18.5636	train-MAPE:0.17593	val-MAPE:0.181112
# [45]	train-rmse:17.2667	val-rmse:18.3481	train-MAPE:0.172701	val-MAPE:0.178842
# [46]	train-rmse:17.0315	val-rmse:18.1277	train-MAPE:0.169798	val-MAPE:0.176669
# [47]	train-rmse:16.8202	val-rmse:17.9429	train-MAPE:0.167134	val-MAPE:0.17489
# [48]	train-rmse:16.6192	val-rmse:17.7682	train-MAPE:0.164612	val-MAPE:0.173212
# [49]	train-rmse:16.4304	val-rmse:17.6065	train-MAPE:0.162402	val-MAPE:0.17178
# [50]	train-rmse:16.2534	val-rmse:17.4575	train-MAPE:0.16043	val-MAPE:0.170599
# [51]	train-rmse:16.0779	val-rmse:17.2993	train-MAPE:0.158662	val-MAPE:0.169411
# [52]	train-rmse:15.9223	val-rmse:17.1714	train-MAPE:0.157058	val-MAPE:0.168437
# [53]	train-rmse:15.7638	val-rmse:17.0397	train-MAPE:0.155614	val-MAPE:0.167449
# [54]	train-rmse:15.6142	val-rmse:16.9177	train-MAPE:0.154324	val-MAPE:0.166779
# [55]	train-rmse:15.4732	val-rmse:16.7961	train-MAPE:0.153168	val-MAPE:0.166061
# [56]	train-rmse:15.3477	val-rmse:16.6797	train-MAPE:0.152188	val-MAPE:0.165469
# [57]	train-rmse:15.2178	val-rmse:16.5965	train-MAPE:0.151322	val-MAPE:0.165286
# [58]	train-rmse:15.0972	val-rmse:16.5169	train-MAPE:0.150575	val-MAPE:0.165196
# [59]	train-rmse:14.9941	val-rmse:16.4247	train-MAPE:0.149969	val-MAPE:0.16485
# [60]	train-rmse:14.8897	val-rmse:16.35	train-MAPE:0.149532	val-MAPE:0.164816
# [61]	train-rmse:14.7987	val-rmse:16.2822	train-MAPE:0.149129	val-MAPE:0.164824
# [62]	train-rmse:14.7067	val-rmse:16.2091	train-MAPE:0.14878	val-MAPE:0.164803
# [63]	train-rmse:14.6285	val-rmse:16.1535	train-MAPE:0.148495	val-MAPE:0.164848
# best best_ntree_limit 64

# %%
A2time_model.get_fscore()
# Out:
# {'day': 234,
#  'month': 5,
#  'precipitation': 7,
#  'pressure': 105,
#  'rel_humidity': 77,
#  'sea_pressure': 7,
#  'temperature': 109,
#  'timemap': 611,
#  'weekday': 48,
#  'wind_direction': 146,
#  'wind_speed': 140}

# %% [markdown]
# #### A3

# %%
# 分割训练集验证集
A3_train_true = A3_train[A3_train['is_true'] == True]
A3_train_false = A3_train[A3_train['is_true'] == False]

X_train, X_val, y_train, y_val = train_test_split(A3_train_true.iloc[:,1:], A3_train_true.iloc[:,0], test_size=0.2, random_state=8)

X_train = pd.concat([X_train, A3_train_false.iloc[:,1:]], axis=0)
y_train = pd.concat([y_train, A3_train_false.iloc[:,0]])

del X_train['is_true']
del X_val['is_true']

# 转化格式
time_train = xgb.DMatrix(X_train, label=y_train)
time_val = xgb.DMatrix(X_val, label=y_val)
time_test = xgb.DMatrix(A3_test)

#参数设置
params = {
    'booster':'gbtree',      #gbtree和gblinear
    'objective':'reg:linear',
    'eta':0.04,             #为了防止过拟合，更新过程中用到的收缩步长。在每次提升计算之后，算法会直接获得新特征的权重。eta通过缩减特征的权重使提升计算过程更加保守。缺省值为0.3,通常最后设置eta为0.01~0.2
    #'gamma':0.3,            #模型在默认情况下，对于一个节点的划分只有在其loss function得到结果大于0的情况下才进行，而gamma 给定了所需的最低loss function的值gamma值使得算法更conservation，且其值依赖于loss function ，
    'max_depth':5,          #树的深度越大，则对数据的拟合程度越高（过拟合程度也越高）。即该参数也是控制过拟合,建议通过交叉验证（xgb.cv ) 进行调参,通常取值：3-10
    #'min_child_weight':2,   #孩子节点中最小的样本权重和。如果一个叶子节点的样本权重和小于min_child_weight则拆分过程结束。在现行回归模型中，这个参数是指建立每个模型所需要的最小样本数。该成熟越大算法越conservative。即调大这个参数能够控制过拟合。
    #'max_delta_step':2,     #如果取值为0，那么意味着无限制。如果取为正数，则其使得xgboost更新过程更加保守。
    'subsample':1,          #用于训练模型的子样本占整个样本集合的比例。如果设置为0.5则意味着XGBoost将随机的从整个样本集合中抽取出50%的子样本建立树模型，这能够防止过拟合。
    'colsample_bytree':1,   #在建立树时对特征随机采样的比例。缺省值为1 
    #'alpha':5,              #L1 正则的惩罚系数,当数据维度极高时可以使用，使得算法运行更快。
    #'lambda':40,           #L2 正则的惩罚系数,用于处理XGBoost的正则化部分。通常不使用，但可以用来降低过拟合
    'seed':2017,
}

plst = list(params.items())
num_rounds = 68
watchlist = [(time_train, 'train'), (time_val, 'val')]

A3time_model = xgb.train(plst, time_train, num_rounds, watchlist, feval=MAPE)
print("best best_ntree_limit", A2time_model.best_ntree_limit)

A3time_predict = A3time_model.predict(time_test)
# Out:
# [0]	train-rmse:111.208	val-rmse:115.302	train-MAPE:0.953619	val-MAPE:0.953578
# [1]	train-rmse:107.06	val-rmse:111.041	train-MAPE:0.913716	val-MAPE:0.913223
# [2]	train-rmse:103.089	val-rmse:107.006	train-MAPE:0.875634	val-MAPE:0.874822
# [3]	train-rmse:99.2787	val-rmse:103.089	train-MAPE:0.839026	val-MAPE:0.837774
# [4]	train-rmse:95.6224	val-rmse:99.3297	train-MAPE:0.803956	val-MAPE:0.80213
# [5]	train-rmse:92.1325	val-rmse:95.8029	train-MAPE:0.770224	val-MAPE:0.768277
# [6]	train-rmse:88.7779	val-rmse:92.3636	train-MAPE:0.738033	val-MAPE:0.735613
# [7]	train-rmse:85.5794	val-rmse:89.123	train-MAPE:0.707148	val-MAPE:0.704595
# [8]	train-rmse:82.519	val-rmse:86.0284	train-MAPE:0.677798	val-MAPE:0.675659
# [9]	train-rmse:79.5798	val-rmse:83.0149	train-MAPE:0.649735	val-MAPE:0.647588
# [10]	train-rmse:76.7635	val-rmse:80.1349	train-MAPE:0.622819	val-MAPE:0.620738
# [11]	train-rmse:74.0704	val-rmse:77.3785	train-MAPE:0.596944	val-MAPE:0.594871
# [12]	train-rmse:71.5061	val-rmse:74.8005	train-MAPE:0.572096	val-MAPE:0.570244
# [13]	train-rmse:69.0467	val-rmse:72.3173	train-MAPE:0.548307	val-MAPE:0.546603
# [14]	train-rmse:66.7066	val-rmse:69.9543	train-MAPE:0.525414	val-MAPE:0.523891
# [15]	train-rmse:64.4526	val-rmse:67.6627	train-MAPE:0.503471	val-MAPE:0.502053
# [16]	train-rmse:62.3085	val-rmse:65.4928	train-MAPE:0.482407	val-MAPE:0.480917
# [17]	train-rmse:60.2559	val-rmse:63.3945	train-MAPE:0.462346	val-MAPE:0.46065
# [18]	train-rmse:58.2951	val-rmse:61.4	train-MAPE:0.443024	val-MAPE:0.441109
# [19]	train-rmse:56.4234	val-rmse:59.4961	train-MAPE:0.424564	val-MAPE:0.422551
# [20]	train-rmse:54.6496	val-rmse:57.7298	train-MAPE:0.406755	val-MAPE:0.40492
# [21]	train-rmse:52.959	val-rmse:56.0554	train-MAPE:0.389673	val-MAPE:0.388338
# [22]	train-rmse:51.3402	val-rmse:54.4456	train-MAPE:0.37334	val-MAPE:0.372499
# [23]	train-rmse:49.8058	val-rmse:52.9173	train-MAPE:0.357703	val-MAPE:0.357194
# [24]	train-rmse:48.3342	val-rmse:51.4681	train-MAPE:0.342852	val-MAPE:0.342939
# [25]	train-rmse:46.9444	val-rmse:50.0764	train-MAPE:0.328657	val-MAPE:0.32915
# [26]	train-rmse:45.6085	val-rmse:48.7129	train-MAPE:0.315209	val-MAPE:0.316084
# [27]	train-rmse:44.3312	val-rmse:47.4009	train-MAPE:0.302302	val-MAPE:0.303773
# [28]	train-rmse:43.1192	val-rmse:46.2026	train-MAPE:0.290114	val-MAPE:0.292258
# [29]	train-rmse:41.9605	val-rmse:45.0194	train-MAPE:0.278488	val-MAPE:0.281317
# [30]	train-rmse:40.8579	val-rmse:43.8859	train-MAPE:0.267555	val-MAPE:0.270763
# [31]	train-rmse:39.8135	val-rmse:42.8507	train-MAPE:0.257218	val-MAPE:0.261
# [32]	train-rmse:38.825	val-rmse:41.8527	train-MAPE:0.247504	val-MAPE:0.252076
# [33]	train-rmse:37.9007	val-rmse:40.9266	train-MAPE:0.238292	val-MAPE:0.243922
# [34]	train-rmse:37.0109	val-rmse:40.0322	train-MAPE:0.229648	val-MAPE:0.236262
# [35]	train-rmse:36.1756	val-rmse:39.1878	train-MAPE:0.221605	val-MAPE:0.228996
# [36]	train-rmse:35.3881	val-rmse:38.3964	train-MAPE:0.213994	val-MAPE:0.222394
# [37]	train-rmse:34.645	val-rmse:37.6951	train-MAPE:0.20681	val-MAPE:0.216161
# [38]	train-rmse:33.9313	val-rmse:36.9705	train-MAPE:0.200201	val-MAPE:0.210459
# [39]	train-rmse:33.2654	val-rmse:36.3151	train-MAPE:0.194002	val-MAPE:0.205246
# [40]	train-rmse:32.6409	val-rmse:35.6944	train-MAPE:0.188243	val-MAPE:0.200691
# [41]	train-rmse:32.0439	val-rmse:35.1175	train-MAPE:0.182937	val-MAPE:0.196571
# [42]	train-rmse:31.4666	val-rmse:34.5615	train-MAPE:0.177961	val-MAPE:0.1927
# [43]	train-rmse:30.9442	val-rmse:34.0628	train-MAPE:0.173315	val-MAPE:0.188967
# [44]	train-rmse:30.4216	val-rmse:33.574	train-MAPE:0.169022	val-MAPE:0.185775
# [45]	train-rmse:29.9562	val-rmse:33.1501	train-MAPE:0.165023	val-MAPE:0.183055
# [46]	train-rmse:29.4849	val-rmse:32.6901	train-MAPE:0.161349	val-MAPE:0.180361
# [47]	train-rmse:29.0754	val-rmse:32.3029	train-MAPE:0.157944	val-MAPE:0.177796
# [48]	train-rmse:28.6828	val-rmse:31.9557	train-MAPE:0.154902	val-MAPE:0.175691
# [49]	train-rmse:28.3147	val-rmse:31.6088	train-MAPE:0.152056	val-MAPE:0.173664
# [50]	train-rmse:27.9775	val-rmse:31.2761	train-MAPE:0.149459	val-MAPE:0.171808
# [51]	train-rmse:27.652	val-rmse:30.9935	train-MAPE:0.147096	val-MAPE:0.17033
# [52]	train-rmse:27.3457	val-rmse:30.7085	train-MAPE:0.144953	val-MAPE:0.168951
# [53]	train-rmse:27.0707	val-rmse:30.4641	train-MAPE:0.142871	val-MAPE:0.167676
# [54]	train-rmse:26.7978	val-rmse:30.2059	train-MAPE:0.141024	val-MAPE:0.166364
# [55]	train-rmse:26.5598	val-rmse:29.9945	train-MAPE:0.139288	val-MAPE:0.165356
# [56]	train-rmse:26.3176	val-rmse:29.7715	train-MAPE:0.137758	val-MAPE:0.164371
# [57]	train-rmse:26.0898	val-rmse:29.578	train-MAPE:0.136329	val-MAPE:0.163577
# [58]	train-rmse:25.8825	val-rmse:29.3951	train-MAPE:0.135076	val-MAPE:0.162812
# [59]	train-rmse:25.697	val-rmse:29.2177	train-MAPE:0.133856	val-MAPE:0.162117
# [60]	train-rmse:25.5179	val-rmse:29.0635	train-MAPE:0.132778	val-MAPE:0.16159
# [61]	train-rmse:25.3533	val-rmse:28.9231	train-MAPE:0.131793	val-MAPE:0.161198
# [62]	train-rmse:25.1975	val-rmse:28.7939	train-MAPE:0.130878	val-MAPE:0.160807
# [63]	train-rmse:25.06	val-rmse:28.674	train-MAPE:0.130132	val-MAPE:0.160484
# [64]	train-rmse:24.8912	val-rmse:28.5101	train-MAPE:0.129466	val-MAPE:0.159997
# [65]	train-rmse:24.7315	val-rmse:28.3954	train-MAPE:0.128717	val-MAPE:0.159627
# [66]	train-rmse:24.6157	val-rmse:28.2856	train-MAPE:0.12816	val-MAPE:0.15944
# [67]	train-rmse:24.5084	val-rmse:28.194	train-MAPE:0.127732	val-MAPE:0.159297
# best best_ntree_limit 64

# %% [markdown]
# #### B1

# %%
# 分割训练集验证集
B1_train_true = B1_train[B1_train['is_true'] == True]
B1_train_false = B1_train[B1_train['is_true'] == False]

X_train, X_val, y_train, y_val = train_test_split(B1_train_true.iloc[:,1:], B1_train_true.iloc[:,0], test_size=0.2, random_state=23)

X_train = pd.concat([X_train, B1_train_false.iloc[:,1:]], axis=0)
y_train = pd.concat([y_train, B1_train_false.iloc[:,0]])

del X_train['is_true']
del X_val['is_true']
# 转化格式
time_train = xgb.DMatrix(X_train, label=y_train)
time_val = xgb.DMatrix(X_val, label=y_val)
time_test = xgb.DMatrix(B1_test)

#参数设置
params = {
    'booster':'gbtree',      #gbtree和gblinear
    'objective':'reg:linear',
    'eta':0.04,             #为了防止过拟合，更新过程中用到的收缩步长。在每次提升计算之后，算法会直接获得新特征的权重。eta通过缩减特征的权重使提升计算过程更加保守。缺省值为0.3,通常最后设置eta为0.01~0.2
    #'gamma':0.3,            #模型在默认情况下，对于一个节点的划分只有在其loss function得到结果大于0的情况下才进行，而gamma 给定了所需的最低loss function的值gamma值使得算法更conservation，且其值依赖于loss function ，
    'max_depth':5,          #树的深度越大，则对数据的拟合程度越高（过拟合程度也越高）。即该参数也是控制过拟合,建议通过交叉验证（xgb.cv ) 进行调参,通常取值：3-10
    #'min_child_weight':2,   #孩子节点中最小的样本权重和。如果一个叶子节点的样本权重和小于min_child_weight则拆分过程结束。在现行回归模型中，这个参数是指建立每个模型所需要的最小样本数。该成熟越大算法越conservative。即调大这个参数能够控制过拟合。
    #'max_delta_step':2,     #如果取值为0，那么意味着无限制。如果取为正数，则其使得xgboost更新过程更加保守。
    'subsample':1,          #用于训练模型的子样本占整个样本集合的比例。如果设置为0.5则意味着XGBoost将随机的从整个样本集合中抽取出50%的子样本建立树模型，这能够防止过拟合。
    'colsample_bytree':1,   #在建立树时对特征随机采样的比例。缺省值为1 
    #'alpha':5,              #L1 正则的惩罚系数,当数据维度极高时可以使用，使得算法运行更快。
    #'lambda':40,           #L2 正则的惩罚系数,用于处理XGBoost的正则化部分。通常不使用，但可以用来降低过拟合
    'seed':2017,
}

plst = list(params.items())
num_rounds = 66
watchlist = [(time_train, 'train'), (time_val, 'val')]

B1time_model = xgb.train(plst, time_train, num_rounds, watchlist, feval=MAPE)
print("best best_ntree_limit", B1time_model.best_ntree_limit)

B1time_predict = B1time_model.predict(time_test)
# Out:
# [0]	train-rmse:110.974	val-rmse:116.366	train-MAPE:0.954152	val-MAPE:0.954333
# [1]	train-rmse:106.77	val-rmse:111.977	train-MAPE:0.914602	val-MAPE:0.914766
# [2]	train-rmse:102.741	val-rmse:107.775	train-MAPE:0.876689	val-MAPE:0.876758
# [3]	train-rmse:98.8777	val-rmse:103.743	train-MAPE:0.840279	val-MAPE:0.840207
# [4]	train-rmse:95.1773	val-rmse:99.8813	train-MAPE:0.805422	val-MAPE:0.80518
# [5]	train-rmse:91.6326	val-rmse:96.1765	train-MAPE:0.772093	val-MAPE:0.771456
# [6]	train-rmse:88.2385	val-rmse:92.6482	train-MAPE:0.740073	val-MAPE:0.739304
# [7]	train-rmse:84.9869	val-rmse:89.2822	train-MAPE:0.709377	val-MAPE:0.708428
# [8]	train-rmse:81.874	val-rmse:86.0351	train-MAPE:0.679906	val-MAPE:0.678592
# [9]	train-rmse:78.8915	val-rmse:82.9521	train-MAPE:0.651573	val-MAPE:0.650155
# [10]	train-rmse:76.04	val-rmse:79.9855	train-MAPE:0.624369	val-MAPE:0.622705
# [11]	train-rmse:73.3124	val-rmse:77.1576	train-MAPE:0.598338	val-MAPE:0.596486
# [12]	train-rmse:70.7001	val-rmse:74.4617	train-MAPE:0.57337	val-MAPE:0.571356
# [13]	train-rmse:68.2044	val-rmse:71.8619	train-MAPE:0.54946	val-MAPE:0.547302
# [14]	train-rmse:65.816	val-rmse:69.4002	train-MAPE:0.526595	val-MAPE:0.524438
# [15]	train-rmse:63.5362	val-rmse:67.0384	train-MAPE:0.504634	val-MAPE:0.50261
# [16]	train-rmse:61.3558	val-rmse:64.7973	train-MAPE:0.483627	val-MAPE:0.481753
# [17]	train-rmse:59.2679	val-rmse:62.654	train-MAPE:0.463546	val-MAPE:0.461863
# [18]	train-rmse:57.2827	val-rmse:60.5937	train-MAPE:0.444292	val-MAPE:0.442538
# [19]	train-rmse:55.3871	val-rmse:58.6357	train-MAPE:0.425866	val-MAPE:0.423901
# [20]	train-rmse:53.5685	val-rmse:56.7879	train-MAPE:0.408285	val-MAPE:0.406335
# [21]	train-rmse:51.8388	val-rmse:55.021	train-MAPE:0.391414	val-MAPE:0.389306
# [22]	train-rmse:50.1861	val-rmse:53.3416	train-MAPE:0.37523	val-MAPE:0.373174
# [23]	train-rmse:48.6178	val-rmse:51.736	train-MAPE:0.359725	val-MAPE:0.358046
# [24]	train-rmse:47.1096	val-rmse:50.2053	train-MAPE:0.344955	val-MAPE:0.343719
# [25]	train-rmse:45.6739	val-rmse:48.7699	train-MAPE:0.330822	val-MAPE:0.330269
# [26]	train-rmse:44.3125	val-rmse:47.3893	train-MAPE:0.31734	val-MAPE:0.317394
# [27]	train-rmse:43.0118	val-rmse:46.077	train-MAPE:0.304578	val-MAPE:0.30511
# [28]	train-rmse:41.7745	val-rmse:44.8469	train-MAPE:0.29234	val-MAPE:0.293655
# [29]	train-rmse:40.6105	val-rmse:43.6619	train-MAPE:0.280672	val-MAPE:0.282348
# [30]	train-rmse:39.4933	val-rmse:42.5217	train-MAPE:0.269607	val-MAPE:0.27157
# [31]	train-rmse:38.4438	val-rmse:41.4622	train-MAPE:0.259093	val-MAPE:0.261304
# [32]	train-rmse:37.4365	val-rmse:40.4647	train-MAPE:0.249165	val-MAPE:0.251619
# [33]	train-rmse:36.4925	val-rmse:39.5106	train-MAPE:0.239742	val-MAPE:0.242528
# [34]	train-rmse:35.5855	val-rmse:38.6121	train-MAPE:0.230815	val-MAPE:0.234427
# [35]	train-rmse:34.7338	val-rmse:37.7668	train-MAPE:0.222397	val-MAPE:0.226807
# [36]	train-rmse:33.9254	val-rmse:36.9588	train-MAPE:0.214403	val-MAPE:0.219761
# [37]	train-rmse:33.1617	val-rmse:36.1972	train-MAPE:0.206855	val-MAPE:0.213275
# [38]	train-rmse:32.4308	val-rmse:35.5034	train-MAPE:0.199818	val-MAPE:0.207631
# [39]	train-rmse:31.7498	val-rmse:34.8245	train-MAPE:0.193092	val-MAPE:0.202164
# [40]	train-rmse:31.1086	val-rmse:34.1997	train-MAPE:0.186804	val-MAPE:0.197212
# [41]	train-rmse:30.4942	val-rmse:33.6156	train-MAPE:0.180811	val-MAPE:0.192704
# [42]	train-rmse:29.9115	val-rmse:33.0745	train-MAPE:0.175226	val-MAPE:0.188483
# [43]	train-rmse:29.3699	val-rmse:32.5414	train-MAPE:0.169875	val-MAPE:0.18438
# [44]	train-rmse:28.8588	val-rmse:32.0489	train-MAPE:0.164868	val-MAPE:0.180751
# [45]	train-rmse:28.3689	val-rmse:31.6014	train-MAPE:0.160188	val-MAPE:0.177734
# [46]	train-rmse:27.9199	val-rmse:31.1815	train-MAPE:0.155802	val-MAPE:0.174903
# [47]	train-rmse:27.4906	val-rmse:30.79	train-MAPE:0.151568	val-MAPE:0.172105
# [48]	train-rmse:27.0897	val-rmse:30.4134	train-MAPE:0.147656	val-MAPE:0.169659
# [49]	train-rmse:26.7033	val-rmse:30.0777	train-MAPE:0.144033	val-MAPE:0.167677
# [50]	train-rmse:26.3359	val-rmse:29.7762	train-MAPE:0.140662	val-MAPE:0.165915
# [51]	train-rmse:25.996	val-rmse:29.4721	train-MAPE:0.137446	val-MAPE:0.164233
# [52]	train-rmse:25.6711	val-rmse:29.2145	train-MAPE:0.13449	val-MAPE:0.16283
# [53]	train-rmse:25.3662	val-rmse:28.9455	train-MAPE:0.131683	val-MAPE:0.161267
# [54]	train-rmse:25.0797	val-rmse:28.7214	train-MAPE:0.129147	val-MAPE:0.160155
# [55]	train-rmse:24.8112	val-rmse:28.4914	train-MAPE:0.126845	val-MAPE:0.159125
# [56]	train-rmse:24.5596	val-rmse:28.3025	train-MAPE:0.124686	val-MAPE:0.158318
# [57]	train-rmse:24.3237	val-rmse:28.1153	train-MAPE:0.122683	val-MAPE:0.15751
# [58]	train-rmse:24.1026	val-rmse:27.95	train-MAPE:0.120927	val-MAPE:0.156907
# [59]	train-rmse:23.896	val-rmse:27.7891	train-MAPE:0.119262	val-MAPE:0.156287
# [60]	train-rmse:23.7053	val-rmse:27.6237	train-MAPE:0.117807	val-MAPE:0.155814
# [61]	train-rmse:23.5182	val-rmse:27.4773	train-MAPE:0.116499	val-MAPE:0.155392
# [62]	train-rmse:23.3327	val-rmse:27.3344	train-MAPE:0.115234	val-MAPE:0.154963
# [63]	train-rmse:23.1712	val-rmse:27.2189	train-MAPE:0.1141	val-MAPE:0.154623
# [64]	train-rmse:22.9909	val-rmse:27.0912	train-MAPE:0.113028	val-MAPE:0.154309
# [65]	train-rmse:22.8472	val-rmse:26.9839	train-MAPE:0.112071	val-MAPE:0.153924
# best best_ntree_limit 66

# %% [markdown]
# #### B3

# %%
# 分割训练集验证集
B3_train_true = B3_train[B3_train['is_true'] == True]
B3_train_false = B3_train[B3_train['is_true'] == False]

X_train, X_val, y_train, y_val = train_test_split(B3_train_true.iloc[:,1:], B3_train_true.iloc[:,0], test_size=0.2, random_state=29)

X_train = pd.concat([X_train, B3_train_false.iloc[:,1:]], axis=0)
y_train = pd.concat([y_train, B3_train_false.iloc[:,0]])

del X_train['is_true']
del X_val['is_true']
# 转化格式
time_train = xgb.DMatrix(X_train, label=y_train)
time_val = xgb.DMatrix(X_val, label=y_val)
time_test = xgb.DMatrix(B3_test)

#参数设置
params = {
    'booster':'gbtree',      #gbtree和gblinear
    'objective':'reg:linear',
    'eta':0.04,             #为了防止过拟合，更新过程中用到的收缩步长。在每次提升计算之后，算法会直接获得新特征的权重。eta通过缩减特征的权重使提升计算过程更加保守。缺省值为0.3,通常最后设置eta为0.01~0.2
    #'gamma':0.3,            #模型在默认情况下，对于一个节点的划分只有在其loss function得到结果大于0的情况下才进行，而gamma 给定了所需的最低loss function的值gamma值使得算法更conservation，且其值依赖于loss function ，
    'max_depth':5,          #树的深度越大，则对数据的拟合程度越高（过拟合程度也越高）。即该参数也是控制过拟合,建议通过交叉验证（xgb.cv ) 进行调参,通常取值：3-10
    #'min_child_weight':2,   #孩子节点中最小的样本权重和。如果一个叶子节点的样本权重和小于min_child_weight则拆分过程结束。在现行回归模型中，这个参数是指建立每个模型所需要的最小样本数。该成熟越大算法越conservative。即调大这个参数能够控制过拟合。
    #'max_delta_step':2,     #如果取值为0，那么意味着无限制。如果取为正数，则其使得xgboost更新过程更加保守。
    'subsample':1,          #用于训练模型的子样本占整个样本集合的比例。如果设置为0.5则意味着XGBoost将随机的从整个样本集合中抽取出50%的子样本建立树模型，这能够防止过拟合。
    'colsample_bytree':1,   #在建立树时对特征随机采样的比例。缺省值为1 
    #'alpha':5,              #L1 正则的惩罚系数,当数据维度极高时可以使用，使得算法运行更快。
    #'lambda':40,           #L2 正则的惩罚系数,用于处理XGBoost的正则化部分。通常不使用，但可以用来降低过拟合
    'seed':2017,
}

plst = list(params.items())
num_rounds = 88
watchlist = [(time_train, 'train'), (time_val, 'val')]

B3time_model = xgb.train(plst, time_train, num_rounds, watchlist, feval=MAPE)
print("best best_ntree_limit", B3time_model.best_ntree_limit)

B3time_predict = B3time_model.predict(time_test)
# Out:
# [0]	train-rmse:89.8968	val-rmse:98.4763	train-MAPE:0.952013	val-MAPE:0.953199
# [1]	train-rmse:86.523	val-rmse:94.9577	train-MAPE:0.911709	val-MAPE:0.913617
# [2]	train-rmse:83.2915	val-rmse:91.5849	train-MAPE:0.873065	val-MAPE:0.875569
# [3]	train-rmse:80.197	val-rmse:88.3575	train-MAPE:0.836082	val-MAPE:0.839038
# [4]	train-rmse:77.2338	val-rmse:85.2674	train-MAPE:0.800731	val-MAPE:0.803856
# [5]	train-rmse:74.3972	val-rmse:82.3141	train-MAPE:0.766973	val-MAPE:0.77097
# [6]	train-rmse:71.6822	val-rmse:79.4962	train-MAPE:0.734718	val-MAPE:0.739786
# [7]	train-rmse:69.0846	val-rmse:76.7937	train-MAPE:0.703858	val-MAPE:0.710064
# [8]	train-rmse:66.599	val-rmse:74.2125	train-MAPE:0.674245	val-MAPE:0.681961
# [9]	train-rmse:64.2215	val-rmse:71.7344	train-MAPE:0.645834	val-MAPE:0.655092
# [10]	train-rmse:61.9475	val-rmse:69.3668	train-MAPE:0.618727	val-MAPE:0.629235
# [11]	train-rmse:59.7739	val-rmse:67.1145	train-MAPE:0.592753	val-MAPE:0.604603
# [12]	train-rmse:57.6974	val-rmse:64.97	train-MAPE:0.567926	val-MAPE:0.581172
# [13]	train-rmse:55.7128	val-rmse:62.9202	train-MAPE:0.544298	val-MAPE:0.558986
# [14]	train-rmse:53.8174	val-rmse:60.9445	train-MAPE:0.521623	val-MAPE:0.53768
# [15]	train-rmse:52.0031	val-rmse:59.0599	train-MAPE:0.500122	val-MAPE:0.517485
# [16]	train-rmse:50.2743	val-rmse:57.2768	train-MAPE:0.479524	val-MAPE:0.498501
# [17]	train-rmse:48.6273	val-rmse:55.5512	train-MAPE:0.459897	val-MAPE:0.480051
# [18]	train-rmse:47.0543	val-rmse:53.9167	train-MAPE:0.441213	val-MAPE:0.462622
# [19]	train-rmse:45.5568	val-rmse:52.3552	train-MAPE:0.423364	val-MAPE:0.446084
# [20]	train-rmse:44.1282	val-rmse:50.8703	train-MAPE:0.406292	val-MAPE:0.43054
# [21]	train-rmse:42.7668	val-rmse:49.4595	train-MAPE:0.389981	val-MAPE:0.415871
# [22]	train-rmse:41.4682	val-rmse:48.1218	train-MAPE:0.374483	val-MAPE:0.401885
# [23]	train-rmse:40.2356	val-rmse:46.8673	train-MAPE:0.359744	val-MAPE:0.388975
# [24]	train-rmse:39.0608	val-rmse:45.6637	train-MAPE:0.345677	val-MAPE:0.376779
# [25]	train-rmse:37.9443	val-rmse:44.5024	train-MAPE:0.332421	val-MAPE:0.364934
# [26]	train-rmse:36.8786	val-rmse:43.4309	train-MAPE:0.319945	val-MAPE:0.354045
# [27]	train-rmse:35.8723	val-rmse:42.3926	train-MAPE:0.308138	val-MAPE:0.343668
# [28]	train-rmse:34.9171	val-rmse:41.3994	train-MAPE:0.296982	val-MAPE:0.333884
# [29]	train-rmse:34.0056	val-rmse:40.4494	train-MAPE:0.28634	val-MAPE:0.324857
# [30]	train-rmse:33.142	val-rmse:39.579	train-MAPE:0.276359	val-MAPE:0.3165
# [31]	train-rmse:32.3206	val-rmse:38.7215	train-MAPE:0.266899	val-MAPE:0.308434
# [32]	train-rmse:31.5456	val-rmse:37.9059	train-MAPE:0.257987	val-MAPE:0.300772
# [33]	train-rmse:30.8108	val-rmse:37.1448	train-MAPE:0.249644	val-MAPE:0.293741
# [34]	train-rmse:30.1156	val-rmse:36.4416	train-MAPE:0.241816	val-MAPE:0.287264
# [35]	train-rmse:29.4594	val-rmse:35.7648	train-MAPE:0.234376	val-MAPE:0.281331
# [36]	train-rmse:28.8412	val-rmse:35.126	train-MAPE:0.2275	val-MAPE:0.275679
# [37]	train-rmse:28.2517	val-rmse:34.5301	train-MAPE:0.221098	val-MAPE:0.270578
# [38]	train-rmse:27.6988	val-rmse:33.9535	train-MAPE:0.215178	val-MAPE:0.265794
# [39]	train-rmse:27.1822	val-rmse:33.4147	train-MAPE:0.209652	val-MAPE:0.261381
# [40]	train-rmse:26.6904	val-rmse:32.9137	train-MAPE:0.204469	val-MAPE:0.257496
# [41]	train-rmse:26.2346	val-rmse:32.4282	train-MAPE:0.199541	val-MAPE:0.253892
# [42]	train-rmse:25.8004	val-rmse:31.9733	train-MAPE:0.195034	val-MAPE:0.250481
# [43]	train-rmse:25.3808	val-rmse:31.5525	train-MAPE:0.190792	val-MAPE:0.247463
# [44]	train-rmse:24.9952	val-rmse:31.1518	train-MAPE:0.18692	val-MAPE:0.244595
# [45]	train-rmse:24.6312	val-rmse:30.7783	train-MAPE:0.183264	val-MAPE:0.241891
# [46]	train-rmse:24.2845	val-rmse:30.4286	train-MAPE:0.17998	val-MAPE:0.239402
# [47]	train-rmse:23.9692	val-rmse:30.0908	train-MAPE:0.176914	val-MAPE:0.236934
# [48]	train-rmse:23.6669	val-rmse:29.7815	train-MAPE:0.174143	val-MAPE:0.234761
# [49]	train-rmse:23.386	val-rmse:29.4955	train-MAPE:0.171532	val-MAPE:0.232817
# [50]	train-rmse:23.1114	val-rmse:29.2198	train-MAPE:0.169217	val-MAPE:0.230888
# [51]	train-rmse:22.8624	val-rmse:28.9722	train-MAPE:0.167109	val-MAPE:0.229335
# [52]	train-rmse:22.6275	val-rmse:28.7297	train-MAPE:0.165131	val-MAPE:0.227755
# [53]	train-rmse:22.4142	val-rmse:28.5086	train-MAPE:0.163508	val-MAPE:0.226376
# [54]	train-rmse:22.2011	val-rmse:28.2773	train-MAPE:0.161783	val-MAPE:0.22507
# [55]	train-rmse:22.0118	val-rmse:28.0709	train-MAPE:0.160386	val-MAPE:0.223821
# [56]	train-rmse:21.8259	val-rmse:27.8842	train-MAPE:0.158992	val-MAPE:0.222708
# [57]	train-rmse:21.6545	val-rmse:27.7039	train-MAPE:0.157824	val-MAPE:0.221713
# [58]	train-rmse:21.4934	val-rmse:27.527	train-MAPE:0.156843	val-MAPE:0.220688
# [59]	train-rmse:21.3411	val-rmse:27.3578	train-MAPE:0.155855	val-MAPE:0.219671
# [60]	train-rmse:21.2087	val-rmse:27.2082	train-MAPE:0.155084	val-MAPE:0.218796
# [61]	train-rmse:21.0788	val-rmse:27.0557	train-MAPE:0.154465	val-MAPE:0.218004
# [62]	train-rmse:20.9587	val-rmse:26.9256	train-MAPE:0.153974	val-MAPE:0.217289
# [63]	train-rmse:20.84	val-rmse:26.7895	train-MAPE:0.153387	val-MAPE:0.216534
# [64]	train-rmse:20.7199	val-rmse:26.6791	train-MAPE:0.152941	val-MAPE:0.21588
# [65]	train-rmse:20.6195	val-rmse:26.578	train-MAPE:0.152717	val-MAPE:0.2154
# [66]	train-rmse:20.5159	val-rmse:26.4684	train-MAPE:0.152315	val-MAPE:0.214917
# [67]	train-rmse:20.4153	val-rmse:26.3784	train-MAPE:0.152074	val-MAPE:0.214441
# [68]	train-rmse:20.3303	val-rmse:26.2857	train-MAPE:0.151994	val-MAPE:0.213977
# [69]	train-rmse:20.2454	val-rmse:26.196	train-MAPE:0.151777	val-MAPE:0.213633
# [70]	train-rmse:20.1673	val-rmse:26.1145	train-MAPE:0.151705	val-MAPE:0.213225
# [71]	train-rmse:20.0945	val-rmse:26.0382	train-MAPE:0.151714	val-MAPE:0.212869
# [72]	train-rmse:20.027	val-rmse:25.9732	train-MAPE:0.151742	val-MAPE:0.21257
# [73]	train-rmse:19.9633	val-rmse:25.8984	train-MAPE:0.151784	val-MAPE:0.212272
# [74]	train-rmse:19.8974	val-rmse:25.8502	train-MAPE:0.15171	val-MAPE:0.212224
# [75]	train-rmse:19.8411	val-rmse:25.7811	train-MAPE:0.151791	val-MAPE:0.212005
# [76]	train-rmse:19.7843	val-rmse:25.7294	train-MAPE:0.151792	val-MAPE:0.21196
# [77]	train-rmse:19.7372	val-rmse:25.6826	train-MAPE:0.151944	val-MAPE:0.211848
# [78]	train-rmse:19.6918	val-rmse:25.6423	train-MAPE:0.152087	val-MAPE:0.211765
# [79]	train-rmse:19.6471	val-rmse:25.5909	train-MAPE:0.152212	val-MAPE:0.211697
# [80]	train-rmse:19.6081	val-rmse:25.5475	train-MAPE:0.152424	val-MAPE:0.2116
# [81]	train-rmse:19.5639	val-rmse:25.513	train-MAPE:0.152486	val-MAPE:0.211596
# [82]	train-rmse:19.5279	val-rmse:25.4829	train-MAPE:0.152677	val-MAPE:0.211549
# [83]	train-rmse:19.4909	val-rmse:25.4382	train-MAPE:0.152845	val-MAPE:0.211456
# [84]	train-rmse:19.4599	val-rmse:25.411	train-MAPE:0.153053	val-MAPE:0.211468
# [85]	train-rmse:19.431	val-rmse:25.3743	train-MAPE:0.15325	val-MAPE:0.211423
# [86]	train-rmse:19.3956	val-rmse:25.3464	train-MAPE:0.153356	val-MAPE:0.21146
# [87]	train-rmse:19.3631	val-rmse:25.3136	train-MAPE:0.153506	val-MAPE:0.211457
# best best_ntree_limit 88

# %% [markdown]
# #### C1

# %%
# 分割训练集验证集
C1_train_true = C1_train[C1_train['is_true'] == True]
C1_train_false = C1_train[C1_train['is_true'] == False]

X_train, X_val, y_train, y_val = train_test_split(C1_train_true.iloc[:,1:], C1_train_true.iloc[:,0], test_size=0.2, random_state=77)

X_train = pd.concat([X_train, C1_train_false.iloc[:,1:]], axis=0)
y_train = pd.concat([y_train, C1_train_false.iloc[:,0]])

del X_train['is_true']
del X_val['is_true']
# 转化格式
time_train = xgb.DMatrix(X_train, label=y_train)
time_val = xgb.DMatrix(X_val, label=y_val)
time_test = xgb.DMatrix(C1_test)

#参数设置
params = {
    'booster':'gbtree',      #gbtree和gblinear
    'objective':'reg:linear',
    'eta':0.04,             #为了防止过拟合，更新过程中用到的收缩步长。在每次提升计算之后，算法会直接获得新特征的权重。eta通过缩减特征的权重使提升计算过程更加保守。缺省值为0.3,通常最后设置eta为0.01~0.2
    #'gamma':0.3,            #模型在默认情况下，对于一个节点的划分只有在其loss function得到结果大于0的情况下才进行，而gamma 给定了所需的最低loss function的值gamma值使得算法更conservation，且其值依赖于loss function ，
    'max_depth':5,          #树的深度越大，则对数据的拟合程度越高（过拟合程度也越高）。即该参数也是控制过拟合,建议通过交叉验证（xgb.cv ) 进行调参,通常取值：3-10
    #'min_child_weight':2,   #孩子节点中最小的样本权重和。如果一个叶子节点的样本权重和小于min_child_weight则拆分过程结束。在现行回归模型中，这个参数是指建立每个模型所需要的最小样本数。该成熟越大算法越conservative。即调大这个参数能够控制过拟合。
    #'max_delta_step':2,     #如果取值为0，那么意味着无限制。如果取为正数，则其使得xgboost更新过程更加保守。
    'subsample':1,          #用于训练模型的子样本占整个样本集合的比例。如果设置为0.5则意味着XGBoost将随机的从整个样本集合中抽取出50%的子样本建立树模型，这能够防止过拟合。
    'colsample_bytree':1,   #在建立树时对特征随机采样的比例。缺省值为1 
    #'alpha':5,              #L1 正则的惩罚系数,当数据维度极高时可以使用，使得算法运行更快。
    #'lambda':40,           #L2 正则的惩罚系数,用于处理XGBoost的正则化部分。通常不使用，但可以用来降低过拟合
    'seed':2017,
}

plst = list(params.items())
num_rounds = 80
watchlist = [(time_train, 'train'), (time_val, 'val')]

C1time_model = xgb.train(plst, time_train, num_rounds, watchlist, feval=MAPE)
print("best best_ntree_limit", C1time_model.best_ntree_limit)

C1time_predict = C1time_model.predict(time_test)
# Out:
# [0]	train-rmse:169.809	val-rmse:177.68	train-MAPE:0.955999	val-MAPE:0.956035
# [1]	train-rmse:163.296	val-rmse:171.068	train-MAPE:0.916749	val-MAPE:0.916906
# [2]	train-rmse:157.056	val-rmse:164.764	train-MAPE:0.879013	val-MAPE:0.879313
# [3]	train-rmse:151.071	val-rmse:158.706	train-MAPE:0.84285	val-MAPE:0.84328
# [4]	train-rmse:145.335	val-rmse:152.915	train-MAPE:0.8081	val-MAPE:0.808595
# [5]	train-rmse:139.839	val-rmse:147.372	train-MAPE:0.774766	val-MAPE:0.77532
# [6]	train-rmse:134.57	val-rmse:142.008	train-MAPE:0.74282	val-MAPE:0.74329
# [7]	train-rmse:129.519	val-rmse:136.917	train-MAPE:0.712135	val-MAPE:0.712588
# [8]	train-rmse:124.677	val-rmse:132.041	train-MAPE:0.682685	val-MAPE:0.683197
# [9]	train-rmse:120.041	val-rmse:127.358	train-MAPE:0.654452	val-MAPE:0.654848
# [10]	train-rmse:115.605	val-rmse:122.877	train-MAPE:0.627301	val-MAPE:0.627602
# [11]	train-rmse:111.355	val-rmse:118.591	train-MAPE:0.601207	val-MAPE:0.601346
# [12]	train-rmse:107.283	val-rmse:114.474	train-MAPE:0.576237	val-MAPE:0.576188
# [13]	train-rmse:103.371	val-rmse:110.571	train-MAPE:0.552316	val-MAPE:0.552359
# [14]	train-rmse:99.6345	val-rmse:106.828	train-MAPE:0.529347	val-MAPE:0.529428
# [15]	train-rmse:96.0602	val-rmse:103.216	train-MAPE:0.507295	val-MAPE:0.50727
# [16]	train-rmse:92.6378	val-rmse:99.7667	train-MAPE:0.486145	val-MAPE:0.485875
# [17]	train-rmse:89.3644	val-rmse:96.4657	train-MAPE:0.465855	val-MAPE:0.465356
# [18]	train-rmse:86.2243	val-rmse:93.3259	train-MAPE:0.446411	val-MAPE:0.445821
# [19]	train-rmse:83.2309	val-rmse:90.3152	train-MAPE:0.427683	val-MAPE:0.426781
# [20]	train-rmse:80.3596	val-rmse:87.4297	train-MAPE:0.409801	val-MAPE:0.408743
# [21]	train-rmse:77.6165	val-rmse:84.6852	train-MAPE:0.392626	val-MAPE:0.391463
# [22]	train-rmse:74.9982	val-rmse:82.0595	train-MAPE:0.376211	val-MAPE:0.374765
# [23]	train-rmse:72.4965	val-rmse:79.5827	train-MAPE:0.360552	val-MAPE:0.359222
# [24]	train-rmse:70.108	val-rmse:77.2267	train-MAPE:0.345589	val-MAPE:0.344372
# [25]	train-rmse:67.831	val-rmse:74.9775	train-MAPE:0.33124	val-MAPE:0.330226
# [26]	train-rmse:65.6578	val-rmse:72.8088	train-MAPE:0.317595	val-MAPE:0.316416
# [27]	train-rmse:63.5838	val-rmse:70.7443	train-MAPE:0.304615	val-MAPE:0.303724
# [28]	train-rmse:61.607	val-rmse:68.8137	train-MAPE:0.292252	val-MAPE:0.292017
# [29]	train-rmse:59.7202	val-rmse:66.9669	train-MAPE:0.280495	val-MAPE:0.280658
# [30]	train-rmse:57.9287	val-rmse:65.2233	train-MAPE:0.269305	val-MAPE:0.269943
# [31]	train-rmse:56.2213	val-rmse:63.5589	train-MAPE:0.258633	val-MAPE:0.259751
# [32]	train-rmse:54.5953	val-rmse:61.9844	train-MAPE:0.248526	val-MAPE:0.250262
# [33]	train-rmse:53.048	val-rmse:60.4686	train-MAPE:0.238939	val-MAPE:0.241639
# [34]	train-rmse:51.5746	val-rmse:59.0774	train-MAPE:0.229746	val-MAPE:0.233726
# [35]	train-rmse:50.1787	val-rmse:57.7473	train-MAPE:0.221059	val-MAPE:0.226228
# [36]	train-rmse:48.8548	val-rmse:56.4736	train-MAPE:0.212892	val-MAPE:0.219056
# [37]	train-rmse:47.5975	val-rmse:55.2747	train-MAPE:0.205172	val-MAPE:0.212332
# [38]	train-rmse:46.39	val-rmse:54.1766	train-MAPE:0.197853	val-MAPE:0.20633
# [39]	train-rmse:45.2652	val-rmse:53.1018	train-MAPE:0.190938	val-MAPE:0.200536
# [40]	train-rmse:44.1815	val-rmse:52.115	train-MAPE:0.184397	val-MAPE:0.195441
# [41]	train-rmse:43.1471	val-rmse:51.0931	train-MAPE:0.17821	val-MAPE:0.190531
# [42]	train-rmse:42.1869	val-rmse:50.1989	train-MAPE:0.172372	val-MAPE:0.185842
# [43]	train-rmse:41.272	val-rmse:49.3638	train-MAPE:0.166882	val-MAPE:0.181713
# [44]	train-rmse:40.4145	val-rmse:48.5667	train-MAPE:0.161701	val-MAPE:0.177842
# [45]	train-rmse:39.6039	val-rmse:47.8105	train-MAPE:0.156904	val-MAPE:0.174334
# [46]	train-rmse:38.8224	val-rmse:47.1175	train-MAPE:0.15236	val-MAPE:0.171411
# [47]	train-rmse:38.1028	val-rmse:46.4526	train-MAPE:0.148127	val-MAPE:0.168426
# [48]	train-rmse:37.4211	val-rmse:45.8155	train-MAPE:0.144123	val-MAPE:0.165877
# [49]	train-rmse:36.7828	val-rmse:45.2206	train-MAPE:0.140451	val-MAPE:0.163373
# [50]	train-rmse:36.1871	val-rmse:44.6678	train-MAPE:0.136973	val-MAPE:0.161162
# [51]	train-rmse:35.5916	val-rmse:44.1562	train-MAPE:0.133665	val-MAPE:0.159278
# [52]	train-rmse:35.0334	val-rmse:43.6196	train-MAPE:0.130576	val-MAPE:0.15756
# [53]	train-rmse:34.5027	val-rmse:43.1683	train-MAPE:0.127698	val-MAPE:0.156003
# [54]	train-rmse:34.0064	val-rmse:42.7493	train-MAPE:0.125002	val-MAPE:0.154684
# [55]	train-rmse:33.5559	val-rmse:42.3231	train-MAPE:0.122507	val-MAPE:0.153416
# [56]	train-rmse:33.1117	val-rmse:41.9586	train-MAPE:0.120128	val-MAPE:0.152429
# [57]	train-rmse:32.6968	val-rmse:41.6099	train-MAPE:0.11791	val-MAPE:0.151519
# [58]	train-rmse:32.3263	val-rmse:41.2718	train-MAPE:0.115911	val-MAPE:0.15083
# [59]	train-rmse:31.9605	val-rmse:40.9703	train-MAPE:0.113979	val-MAPE:0.150161
# [60]	train-rmse:31.6332	val-rmse:40.669	train-MAPE:0.112223	val-MAPE:0.149625
# [61]	train-rmse:31.3051	val-rmse:40.3903	train-MAPE:0.110506	val-MAPE:0.149064
# [62]	train-rmse:30.9984	val-rmse:40.1433	train-MAPE:0.108967	val-MAPE:0.148743
# [63]	train-rmse:30.7287	val-rmse:39.9001	train-MAPE:0.107569	val-MAPE:0.148448
# [64]	train-rmse:30.4564	val-rmse:39.668	train-MAPE:0.106162	val-MAPE:0.147991
# [65]	train-rmse:30.2024	val-rmse:39.485	train-MAPE:0.104924	val-MAPE:0.147815
# [66]	train-rmse:29.9707	val-rmse:39.277	train-MAPE:0.103825	val-MAPE:0.147555
# [67]	train-rmse:29.7447	val-rmse:39.1068	train-MAPE:0.102773	val-MAPE:0.147366
# [68]	train-rmse:29.5403	val-rmse:38.9234	train-MAPE:0.101775	val-MAPE:0.147091
# [69]	train-rmse:29.3521	val-rmse:38.761	train-MAPE:0.100912	val-MAPE:0.146977
# [70]	train-rmse:29.1532	val-rmse:38.6124	train-MAPE:0.100071	val-MAPE:0.146834
# [71]	train-rmse:28.9721	val-rmse:38.4761	train-MAPE:0.09936	val-MAPE:0.146756
# [72]	train-rmse:28.8233	val-rmse:38.3373	train-MAPE:0.098754	val-MAPE:0.146692
# [73]	train-rmse:28.6618	val-rmse:38.2102	train-MAPE:0.098123	val-MAPE:0.146648
# [74]	train-rmse:28.5197	val-rmse:38.1041	train-MAPE:0.097519	val-MAPE:0.146598
# [75]	train-rmse:28.3638	val-rmse:37.9965	train-MAPE:0.096921	val-MAPE:0.146745
# [76]	train-rmse:28.24	val-rmse:37.8882	train-MAPE:0.096546	val-MAPE:0.14676
# [77]	train-rmse:28.1121	val-rmse:37.7948	train-MAPE:0.096064	val-MAPE:0.146726
# [78]	train-rmse:28.0085	val-rmse:37.7042	train-MAPE:0.095753	val-MAPE:0.146686
# [79]	train-rmse:27.8968	val-rmse:37.6253	train-MAPE:0.095409	val-MAPE:0.1466
# best best_ntree_limit 80

# %% [markdown]
# #### C3

# %%
# 分割训练集验证集
C3_train_true = C3_train[C3_train['is_true'] == True]
C3_train_false = C3_train[C3_train['is_true'] == False]

X_train, X_val, y_train, y_val = train_test_split(C3_train_true.iloc[:,1:], C3_train_true.iloc[:,0], test_size=0.2, random_state=177)

X_train = pd.concat([X_train, C3_train_false.iloc[:,1:]], axis=0)
y_train = pd.concat([y_train, C3_train_false.iloc[:,0]])

del X_train['is_true']
del X_val['is_true']
# 转化格式
time_train = xgb.DMatrix(X_train, label=y_train)
time_val = xgb.DMatrix(X_val, label=y_val)
time_test = xgb.DMatrix(C3_test)

#参数设置
params = {
    'booster':'gbtree',      #gbtree和gblinear
    'objective':'reg:linear',
    'eta':0.04,             #为了防止过拟合，更新过程中用到的收缩步长。在每次提升计算之后，算法会直接获得新特征的权重。eta通过缩减特征的权重使提升计算过程更加保守。缺省值为0.3,通常最后设置eta为0.01~0.2
    #'gamma':0.3,            #模型在默认情况下，对于一个节点的划分只有在其loss function得到结果大于0的情况下才进行，而gamma 给定了所需的最低loss function的值gamma值使得算法更conservation，且其值依赖于loss function ，
    'max_depth':5,          #树的深度越大，则对数据的拟合程度越高（过拟合程度也越高）。即该参数也是控制过拟合,建议通过交叉验证（xgb.cv ) 进行调参,通常取值：3-10
    #'min_child_weight':2,   #孩子节点中最小的样本权重和。如果一个叶子节点的样本权重和小于min_child_weight则拆分过程结束。在现行回归模型中，这个参数是指建立每个模型所需要的最小样本数。该成熟越大算法越conservative。即调大这个参数能够控制过拟合。
    #'max_delta_step':2,     #如果取值为0，那么意味着无限制。如果取为正数，则其使得xgboost更新过程更加保守。
    'subsample':1,          #用于训练模型的子样本占整个样本集合的比例。如果设置为0.5则意味着XGBoost将随机的从整个样本集合中抽取出50%的子样本建立树模型，这能够防止过拟合。
    'colsample_bytree':1,   #在建立树时对特征随机采样的比例。缺省值为1 
    #'alpha':5,              #L1 正则的惩罚系数,当数据维度极高时可以使用，使得算法运行更快。
    #'lambda':40,           #L2 正则的惩罚系数,用于处理XGBoost的正则化部分。通常不使用，但可以用来降低过拟合
    'seed':2017,
}

plst = list(params.items())
num_rounds = 70
watchlist = [(time_train, 'train'), (time_val, 'val')]

C3time_model = xgb.train(plst, time_train, num_rounds, watchlist, feval=MAPE)
print("best best_ntree_limit", C3time_model.best_ntree_limit)

C3time_predict = C3time_model.predict(time_test)
# Out:
# [0]	train-rmse:163.636	val-rmse:171.111	train-MAPE:0.95586	val-MAPE:0.954464
# [1]	train-rmse:157.35	val-rmse:164.857	train-MAPE:0.916501	val-MAPE:0.91388
# [2]	train-rmse:151.324	val-rmse:158.872	train-MAPE:0.878713	val-MAPE:0.874914
# [3]	train-rmse:145.55	val-rmse:153.121	train-MAPE:0.842436	val-MAPE:0.837423
# [4]	train-rmse:140.014	val-rmse:147.637	train-MAPE:0.807661	val-MAPE:0.801539
# [5]	train-rmse:134.71	val-rmse:142.378	train-MAPE:0.774239	val-MAPE:0.766984
# [6]	train-rmse:129.627	val-rmse:137.362	train-MAPE:0.742183	val-MAPE:0.733893
# [7]	train-rmse:124.758	val-rmse:132.635	train-MAPE:0.711414	val-MAPE:0.702477
# [8]	train-rmse:120.093	val-rmse:128.033	train-MAPE:0.681861	val-MAPE:0.671873
# [9]	train-rmse:115.625	val-rmse:123.719	train-MAPE:0.653581	val-MAPE:0.643029
# [10]	train-rmse:111.346	val-rmse:119.517	train-MAPE:0.626399	val-MAPE:0.614765
# [11]	train-rmse:107.248	val-rmse:115.525	train-MAPE:0.600282	val-MAPE:0.587706
# [12]	train-rmse:103.324	val-rmse:111.757	train-MAPE:0.575308	val-MAPE:0.562021
# [13]	train-rmse:99.5703	val-rmse:108.108	train-MAPE:0.551315	val-MAPE:0.537444
# [14]	train-rmse:95.9796	val-rmse:104.635	train-MAPE:0.528279	val-MAPE:0.514063
# [15]	train-rmse:92.5417	val-rmse:101.323	train-MAPE:0.506187	val-MAPE:0.491753
# [16]	train-rmse:89.2544	val-rmse:98.2151	train-MAPE:0.48505	val-MAPE:0.470593
# [17]	train-rmse:86.1135	val-rmse:95.2603	train-MAPE:0.464809	val-MAPE:0.450241
# [18]	train-rmse:83.1114	val-rmse:92.3811	train-MAPE:0.44542	val-MAPE:0.430489
# [19]	train-rmse:80.2374	val-rmse:89.6874	train-MAPE:0.426941	val-MAPE:0.412189
# [20]	train-rmse:77.4961	val-rmse:87.154	train-MAPE:0.409223	val-MAPE:0.395103
# [21]	train-rmse:74.8741	val-rmse:84.7114	train-MAPE:0.392427	val-MAPE:0.379286
# [22]	train-rmse:72.3749	val-rmse:82.423	train-MAPE:0.376357	val-MAPE:0.364222
# [23]	train-rmse:69.9852	val-rmse:80.2418	train-MAPE:0.36107	val-MAPE:0.350323
# [24]	train-rmse:67.7071	val-rmse:78.1465	train-MAPE:0.346522	val-MAPE:0.337246
# [25]	train-rmse:65.5348	val-rmse:76.1898	train-MAPE:0.332642	val-MAPE:0.325322
# [26]	train-rmse:63.4637	val-rmse:74.3139	train-MAPE:0.319388	val-MAPE:0.314014
# [27]	train-rmse:61.4947	val-rmse:72.524	train-MAPE:0.306826	val-MAPE:0.30348
# [28]	train-rmse:59.6184	val-rmse:70.8726	train-MAPE:0.294967	val-MAPE:0.294022
# [29]	train-rmse:57.8286	val-rmse:69.2787	train-MAPE:0.283773	val-MAPE:0.285255
# [30]	train-rmse:56.1292	val-rmse:67.7714	train-MAPE:0.273195	val-MAPE:0.27694
# [31]	train-rmse:54.5132	val-rmse:66.3629	train-MAPE:0.263149	val-MAPE:0.269
# [32]	train-rmse:52.9789	val-rmse:65.0205	train-MAPE:0.253628	val-MAPE:0.261728
# [33]	train-rmse:51.5175	val-rmse:63.7734	train-MAPE:0.244554	val-MAPE:0.255137
# [34]	train-rmse:50.1324	val-rmse:62.6315	train-MAPE:0.235897	val-MAPE:0.249236
# [35]	train-rmse:48.818	val-rmse:61.5428	train-MAPE:0.227673	val-MAPE:0.243764
# [36]	train-rmse:47.5751	val-rmse:60.532	train-MAPE:0.219842	val-MAPE:0.238664
# [37]	train-rmse:46.398	val-rmse:59.5805	train-MAPE:0.212443	val-MAPE:0.233854
# [38]	train-rmse:45.2807	val-rmse:58.6779	train-MAPE:0.205373	val-MAPE:0.229384
# [39]	train-rmse:44.2245	val-rmse:57.8332	train-MAPE:0.198732	val-MAPE:0.225249
# [40]	train-rmse:43.2248	val-rmse:57.0559	train-MAPE:0.192448	val-MAPE:0.221684
# [41]	train-rmse:42.283	val-rmse:56.312	train-MAPE:0.186538	val-MAPE:0.218395
# [42]	train-rmse:41.3903	val-rmse:55.624	train-MAPE:0.18093	val-MAPE:0.215591
# [43]	train-rmse:40.5454	val-rmse:54.9843	train-MAPE:0.175617	val-MAPE:0.213147
# [44]	train-rmse:39.7535	val-rmse:54.3892	train-MAPE:0.170643	val-MAPE:0.211079
# [45]	train-rmse:39.0022	val-rmse:53.8265	train-MAPE:0.165902	val-MAPE:0.209169
# [46]	train-rmse:38.299	val-rmse:53.2967	train-MAPE:0.161389	val-MAPE:0.207524
# [47]	train-rmse:37.6274	val-rmse:52.8202	train-MAPE:0.157073	val-MAPE:0.206521
# [48]	train-rmse:37.0023	val-rmse:52.3551	train-MAPE:0.15302	val-MAPE:0.205707
# [49]	train-rmse:36.4144	val-rmse:51.9225	train-MAPE:0.149202	val-MAPE:0.205216
# [50]	train-rmse:35.8561	val-rmse:51.511	train-MAPE:0.145613	val-MAPE:0.204706
# [51]	train-rmse:35.344	val-rmse:51.132	train-MAPE:0.14221	val-MAPE:0.204148
# [52]	train-rmse:34.8539	val-rmse:50.7892	train-MAPE:0.138979	val-MAPE:0.203843
# [53]	train-rmse:34.4018	val-rmse:50.4761	train-MAPE:0.135906	val-MAPE:0.203547
# [54]	train-rmse:33.969	val-rmse:50.1632	train-MAPE:0.133059	val-MAPE:0.203354
# [55]	train-rmse:33.5628	val-rmse:49.8902	train-MAPE:0.130334	val-MAPE:0.203255
# [56]	train-rmse:33.1909	val-rmse:49.6396	train-MAPE:0.127733	val-MAPE:0.203277
# [57]	train-rmse:32.8372	val-rmse:49.4038	train-MAPE:0.125345	val-MAPE:0.20312
# [58]	train-rmse:32.51	val-rmse:49.1914	train-MAPE:0.123062	val-MAPE:0.203159
# [59]	train-rmse:32.1929	val-rmse:48.9654	train-MAPE:0.12094	val-MAPE:0.203172
# [60]	train-rmse:31.8948	val-rmse:48.7837	train-MAPE:0.118827	val-MAPE:0.203364
# [61]	train-rmse:31.6282	val-rmse:48.6085	train-MAPE:0.116936	val-MAPE:0.203567
# [62]	train-rmse:31.3723	val-rmse:48.4212	train-MAPE:0.115174	val-MAPE:0.203522
# [63]	train-rmse:31.1381	val-rmse:48.2748	train-MAPE:0.113491	val-MAPE:0.203688
# [64]	train-rmse:30.91	val-rmse:48.1225	train-MAPE:0.111918	val-MAPE:0.20385
# [65]	train-rmse:30.6954	val-rmse:47.9844	train-MAPE:0.110374	val-MAPE:0.203987
# [66]	train-rmse:30.5004	val-rmse:47.8564	train-MAPE:0.109087	val-MAPE:0.204126
# [67]	train-rmse:30.3175	val-rmse:47.7625	train-MAPE:0.107807	val-MAPE:0.204364
# [68]	train-rmse:30.1427	val-rmse:47.671	train-MAPE:0.106633	val-MAPE:0.204612
# [69]	train-rmse:29.9876	val-rmse:47.5755	train-MAPE:0.105587	val-MAPE:0.2049
# best best_ntree_limit 70

# %% [markdown]
# #### V10

# %%
# 分割训练集验证集
X_train, X_val, y_train, y_val = train_test_split(V10_train.iloc[:,1:], V10_train.iloc[:,0], test_size=0.2, random_state=5)

# 转化格式
volume_train = xgb.DMatrix(X_train, label=y_train)
volume_val = xgb.DMatrix(X_val, label=y_val)
volume_test = xgb.DMatrix(V10_test)

#参数设置
params = {
    'booster':'gbtree',      #gbtree和gblinear
    'objective':'reg:linear',
    'eta':0.04,             #为了防止过拟合，更新过程中用到的收缩步长。在每次提升计算之后，算法会直接获得新特征的权重。eta通过缩减特征的权重使提升计算过程更加保守。缺省值为0.3,通常最后设置eta为0.01~0.2
    #'gamma':0.3,            #模型在默认情况下，对于一个节点的划分只有在其loss function得到结果大于0的情况下才进行，而gamma 给定了所需的最低loss function的值gamma值使得算法更conservation，且其值依赖于loss function ，
    'max_depth':5,          #树的深度越大，则对数据的拟合程度越高（过拟合程度也越高）。即该参数也是控制过拟合,建议通过交叉验证（xgb.cv ) 进行调参,通常取值：3-10
    #'min_child_weight':2,   #孩子节点中最小的样本权重和。如果一个叶子节点的样本权重和小于min_child_weight则拆分过程结束。在现行回归模型中，这个参数是指建立每个模型所需要的最小样本数。该成熟越大算法越conservative。即调大这个参数能够控制过拟合。
    #'max_delta_step':2,     #如果取值为0，那么意味着无限制。如果取为正数，则其使得xgboost更新过程更加保守。
    'subsample':1,          #用于训练模型的子样本占整个样本集合的比例。如果设置为0.5则意味着XGBoost将随机的从整个样本集合中抽取出50%的子样本建立树模型，这能够防止过拟合。
    'colsample_bytree':1,   #在建立树时对特征随机采样的比例。缺省值为1 
    #'alpha':5,              #L1 正则的惩罚系数,当数据维度极高时可以使用，使得算法运行更快。
    #'lambda':40,           #L2 正则的惩罚系数,用于处理XGBoost的正则化部分。通常不使用，但可以用来降低过拟合
    'seed':2017,
}


plst = list(params.items())
num_rounds = 55
watchlist = [(volume_train, 'train'), (volume_val, 'val')]

V10volume_model = xgb.train(plst, volume_train, num_rounds, watchlist, feval=MAPE)
print("best best_ntree_limit", V10volume_model.best_ntree_limit)

V10volume_predict = V10volume_model.predict(volume_test)
# Out:
# [0]	train-rmse:63.4601	val-rmse:63.4056	train-MAPE:0.923303	val-MAPE:0.919808
# [1]	train-rmse:61.0363	val-rmse:61.0131	train-MAPE:0.881616	val-MAPE:0.876793
# [2]	train-rmse:58.7146	val-rmse:58.7227	train-MAPE:0.842437	val-MAPE:0.836571
# [3]	train-rmse:56.4834	val-rmse:56.511	train-MAPE:0.804996	val-MAPE:0.798366
# [4]	train-rmse:54.3459	val-rmse:54.4036	train-MAPE:0.769222	val-MAPE:0.762534
# [5]	train-rmse:52.2928	val-rmse:52.3622	train-MAPE:0.735898	val-MAPE:0.728927
# [6]	train-rmse:50.3239	val-rmse:50.4137	train-MAPE:0.704571	val-MAPE:0.69753
# [7]	train-rmse:48.4382	val-rmse:48.5589	train-MAPE:0.67465	val-MAPE:0.667798
# [8]	train-rmse:46.6277	val-rmse:46.7578	train-MAPE:0.64634	val-MAPE:0.639752
# [9]	train-rmse:44.8915	val-rmse:45.0642	train-MAPE:0.619363	val-MAPE:0.613504
# [10]	train-rmse:43.2269	val-rmse:43.4251	train-MAPE:0.594756	val-MAPE:0.58961
# [11]	train-rmse:41.6304	val-rmse:41.8594	train-MAPE:0.571272	val-MAPE:0.567523
# [12]	train-rmse:40.0996	val-rmse:40.3747	train-MAPE:0.549411	val-MAPE:0.546236
# [13]	train-rmse:38.6319	val-rmse:38.9236	train-MAPE:0.528701	val-MAPE:0.526192
# [14]	train-rmse:37.2253	val-rmse:37.5643	train-MAPE:0.508853	val-MAPE:0.50736
# [15]	train-rmse:35.8769	val-rmse:36.2263	train-MAPE:0.490403	val-MAPE:0.489946
# [16]	train-rmse:34.5833	val-rmse:34.9768	train-MAPE:0.473435	val-MAPE:0.473346
# [17]	train-rmse:33.3423	val-rmse:33.7787	train-MAPE:0.457238	val-MAPE:0.458771
# [18]	train-rmse:32.1568	val-rmse:32.6418	train-MAPE:0.441909	val-MAPE:0.444473
# [19]	train-rmse:31.0187	val-rmse:31.5406	train-MAPE:0.427318	val-MAPE:0.431077
# [20]	train-rmse:29.9291	val-rmse:30.5018	train-MAPE:0.413699	val-MAPE:0.41874
# [21]	train-rmse:28.8834	val-rmse:29.4881	train-MAPE:0.400835	val-MAPE:0.407665
# [22]	train-rmse:27.8817	val-rmse:28.5341	train-MAPE:0.388716	val-MAPE:0.396891
# [23]	train-rmse:26.9245	val-rmse:27.6	train-MAPE:0.377992	val-MAPE:0.387341
# [24]	train-rmse:26.0059	val-rmse:26.7215	train-MAPE:0.368097	val-MAPE:0.378822
# [25]	train-rmse:25.1259	val-rmse:25.9021	train-MAPE:0.358892	val-MAPE:0.370755
# [26]	train-rmse:24.2786	val-rmse:25.1004	train-MAPE:0.350159	val-MAPE:0.362905
# [27]	train-rmse:23.4721	val-rmse:24.3425	train-MAPE:0.341838	val-MAPE:0.355806
# [28]	train-rmse:22.6913	val-rmse:23.574	train-MAPE:0.333888	val-MAPE:0.349058
# [29]	train-rmse:21.9457	val-rmse:22.8521	train-MAPE:0.326691	val-MAPE:0.34323
# [30]	train-rmse:21.23	val-rmse:22.1675	train-MAPE:0.319897	val-MAPE:0.337489
# [31]	train-rmse:20.5473	val-rmse:21.519	train-MAPE:0.313543	val-MAPE:0.331929
# [32]	train-rmse:19.8916	val-rmse:20.9007	train-MAPE:0.307787	val-MAPE:0.327353
# [33]	train-rmse:19.2696	val-rmse:20.3149	train-MAPE:0.302507	val-MAPE:0.32339
# [34]	train-rmse:18.6711	val-rmse:19.7748	train-MAPE:0.297628	val-MAPE:0.319804
# [35]	train-rmse:18.0975	val-rmse:19.2511	train-MAPE:0.293236	val-MAPE:0.316966
# [36]	train-rmse:17.5511	val-rmse:18.7569	train-MAPE:0.288739	val-MAPE:0.314089
# [37]	train-rmse:17.0303	val-rmse:18.2836	train-MAPE:0.285124	val-MAPE:0.311716
# [38]	train-rmse:16.5354	val-rmse:17.8409	train-MAPE:0.281583	val-MAPE:0.309301
# [39]	train-rmse:16.0593	val-rmse:17.4204	train-MAPE:0.278207	val-MAPE:0.30715
# [40]	train-rmse:15.608	val-rmse:17.026	train-MAPE:0.275124	val-MAPE:0.305411
# [41]	train-rmse:15.1773	val-rmse:16.6598	train-MAPE:0.272321	val-MAPE:0.304254
# [42]	train-rmse:14.7674	val-rmse:16.2871	train-MAPE:0.269623	val-MAPE:0.303559
# [43]	train-rmse:14.3745	val-rmse:15.9278	train-MAPE:0.26734	val-MAPE:0.302394
# [44]	train-rmse:13.9976	val-rmse:15.608	train-MAPE:0.26533	val-MAPE:0.301378
# [45]	train-rmse:13.6408	val-rmse:15.2962	train-MAPE:0.263274	val-MAPE:0.300877
# [46]	train-rmse:13.3017	val-rmse:15.0163	train-MAPE:0.261201	val-MAPE:0.300161
# [47]	train-rmse:12.9775	val-rmse:14.7469	train-MAPE:0.259732	val-MAPE:0.299795
# [48]	train-rmse:12.67	val-rmse:14.4907	train-MAPE:0.258396	val-MAPE:0.299428
# [49]	train-rmse:12.3766	val-rmse:14.2588	train-MAPE:0.256818	val-MAPE:0.299188
# [50]	train-rmse:12.0902	val-rmse:14.014	train-MAPE:0.255444	val-MAPE:0.299173
# [51]	train-rmse:11.8135	val-rmse:13.7754	train-MAPE:0.253769	val-MAPE:0.298641
# [52]	train-rmse:11.5528	val-rmse:13.5746	train-MAPE:0.252635	val-MAPE:0.298451
# [53]	train-rmse:11.3059	val-rmse:13.3877	train-MAPE:0.251529	val-MAPE:0.298154
# [54]	train-rmse:11.0669	val-rmse:13.2073	train-MAPE:0.250138	val-MAPE:0.297964
# best best_ntree_limit 55

# %% [markdown]
# #### V11

# %%
# 分割训练集验证集
X_train, X_val, y_train, y_val = train_test_split(V11_train.iloc[:,1:], V11_train.iloc[:,0], test_size=0.2, random_state=5)

# 转化格式
volume_train = xgb.DMatrix(X_train, label=y_train)
volume_val = xgb.DMatrix(X_val, label=y_val)
volume_test = xgb.DMatrix(V11_test)

#参数设置
params = {
    'booster':'gbtree',      #gbtree和gblinear
    'objective':'reg:linear',
    'eta':0.04,             #为了防止过拟合，更新过程中用到的收缩步长。在每次提升计算之后，算法会直接获得新特征的权重。eta通过缩减特征的权重使提升计算过程更加保守。缺省值为0.3,通常最后设置eta为0.01~0.2
    #'gamma':0.3,            #模型在默认情况下，对于一个节点的划分只有在其loss function得到结果大于0的情况下才进行，而gamma 给定了所需的最低loss function的值gamma值使得算法更conservation，且其值依赖于loss function ，
    'max_depth':5,          #树的深度越大，则对数据的拟合程度越高（过拟合程度也越高）。即该参数也是控制过拟合,建议通过交叉验证（xgb.cv ) 进行调参,通常取值：3-10
    #'min_child_weight':2,   #孩子节点中最小的样本权重和。如果一个叶子节点的样本权重和小于min_child_weight则拆分过程结束。在现行回归模型中，这个参数是指建立每个模型所需要的最小样本数。该成熟越大算法越conservative。即调大这个参数能够控制过拟合。
    #'max_delta_step':2,     #如果取值为0，那么意味着无限制。如果取为正数，则其使得xgboost更新过程更加保守。
    'subsample':1,          #用于训练模型的子样本占整个样本集合的比例。如果设置为0.5则意味着XGBoost将随机的从整个样本集合中抽取出50%的子样本建立树模型，这能够防止过拟合。
    'colsample_bytree':1,   #在建立树时对特征随机采样的比例。缺省值为1 
    #'alpha':5,              #L1 正则的惩罚系数,当数据维度极高时可以使用，使得算法运行更快。
    #'lambda':40,           #L2 正则的惩罚系数,用于处理XGBoost的正则化部分。通常不使用，但可以用来降低过拟合
    'seed':2017,
}


plst = list(params.items())
num_rounds = 1000
watchlist = [(volume_train, 'train'), (volume_val, 'val')]

V11volume_model = xgb.train(plst, volume_train, num_rounds, watchlist, feval=MAPE)
print("best best_ntree_limit", V11volume_model.best_ntree_limit)

V11volume_predict = V11volume_model.predict(volume_test)
# Out:
# [0]	train-rmse:63.2652	val-rmse:62.6941	train-MAPE:0.925639	val-MAPE:0.928784
# [1]	train-rmse:60.8334	val-rmse:60.2734	train-MAPE:0.883026	val-MAPE:0.887018
# [2]	train-rmse:58.4997	val-rmse:57.9719	train-MAPE:0.844733	val-MAPE:0.848824
# [3]	train-rmse:56.2606	val-rmse:55.7636	train-MAPE:0.808067	val-MAPE:0.811673
# [4]	train-rmse:54.1147	val-rmse:53.6354	train-MAPE:0.773174	val-MAPE:0.778129
# [5]	train-rmse:52.0551	val-rmse:51.6166	train-MAPE:0.74028	val-MAPE:0.745071
# [6]	train-rmse:50.0805	val-rmse:49.654	train-MAPE:0.710255	val-MAPE:0.714345
# [7]	train-rmse:48.1845	val-rmse:47.776	train-MAPE:0.682012	val-MAPE:0.685095
# [8]	train-rmse:46.3655	val-rmse:45.9849	train-MAPE:0.654879	val-MAPE:0.657208
# [9]	train-rmse:44.6227	val-rmse:44.2546	train-MAPE:0.629475	val-MAPE:0.630759
# [10]	train-rmse:42.9503	val-rmse:42.6047	train-MAPE:0.605195	val-MAPE:0.60584
# [11]	train-rmse:41.3485	val-rmse:41.0666	train-MAPE:0.583293	val-MAPE:0.583469
# [12]	train-rmse:39.8136	val-rmse:39.5388	train-MAPE:0.561931	val-MAPE:0.561245
# [13]	train-rmse:38.341	val-rmse:38.0897	train-MAPE:0.542341	val-MAPE:0.5409
# [14]	train-rmse:36.93	val-rmse:36.6993	train-MAPE:0.524052	val-MAPE:0.521739
# [15]	train-rmse:35.5763	val-rmse:35.3916	train-MAPE:0.506889	val-MAPE:0.503509
# [16]	train-rmse:34.2801	val-rmse:34.1041	train-MAPE:0.490512	val-MAPE:0.485579
# [17]	train-rmse:33.0395	val-rmse:32.8951	train-MAPE:0.475645	val-MAPE:0.470515
# [18]	train-rmse:31.8491	val-rmse:31.7511	train-MAPE:0.461792	val-MAPE:0.456331
# [19]	train-rmse:30.7086	val-rmse:30.6513	train-MAPE:0.448972	val-MAPE:0.443238
# [20]	train-rmse:29.6166	val-rmse:29.5904	train-MAPE:0.436249	val-MAPE:0.43039
# [21]	train-rmse:28.571	val-rmse:28.5733	train-MAPE:0.424582	val-MAPE:0.41838
# [22]	train-rmse:27.5711	val-rmse:27.603	train-MAPE:0.413055	val-MAPE:0.406649
# [23]	train-rmse:26.6117	val-rmse:26.673	train-MAPE:0.402593	val-MAPE:0.396344
# [24]	train-rmse:25.6968	val-rmse:25.7746	train-MAPE:0.393059	val-MAPE:0.386461
# [25]	train-rmse:24.8194	val-rmse:24.9238	train-MAPE:0.38348	val-MAPE:0.376747
# [26]	train-rmse:23.9809	val-rmse:24.1286	train-MAPE:0.374932	val-MAPE:0.367972
# [27]	train-rmse:23.1814	val-rmse:23.3611	train-MAPE:0.367614	val-MAPE:0.359542
# [28]	train-rmse:22.4132	val-rmse:22.6079	train-MAPE:0.359725	val-MAPE:0.351163
# [29]	train-rmse:21.6797	val-rmse:21.9055	train-MAPE:0.352762	val-MAPE:0.344065
# [30]	train-rmse:20.9784	val-rmse:21.2379	train-MAPE:0.345703	val-MAPE:0.336935
# [31]	train-rmse:20.3119	val-rmse:20.5961	train-MAPE:0.339934	val-MAPE:0.330893
# [32]	train-rmse:19.6682	val-rmse:19.9856	train-MAPE:0.334127	val-MAPE:0.3256
# [33]	train-rmse:19.0573	val-rmse:19.4124	train-MAPE:0.328822	val-MAPE:0.320512
# [34]	train-rmse:18.4743	val-rmse:18.8666	train-MAPE:0.323451	val-MAPE:0.315729
# [35]	train-rmse:17.9194	val-rmse:18.3362	train-MAPE:0.317669	val-MAPE:0.310181
# [36]	train-rmse:17.3859	val-rmse:17.8357	train-MAPE:0.31239	val-MAPE:0.305128
# [37]	train-rmse:16.8813	val-rmse:17.3711	train-MAPE:0.308076	val-MAPE:0.301298
# [38]	train-rmse:16.3983	val-rmse:16.9292	train-MAPE:0.30426	val-MAPE:0.297653
# [39]	train-rmse:15.9359	val-rmse:16.5073	train-MAPE:0.300202	val-MAPE:0.294108
# [40]	train-rmse:15.4963	val-rmse:16.1094	train-MAPE:0.29659	val-MAPE:0.290853
# [41]	train-rmse:15.0782	val-rmse:15.7411	train-MAPE:0.293091	val-MAPE:0.287761
# [42]	train-rmse:14.6825	val-rmse:15.3869	train-MAPE:0.289368	val-MAPE:0.284548
# [43]	train-rmse:14.3034	val-rmse:15.0483	train-MAPE:0.286702	val-MAPE:0.282122
# [44]	train-rmse:13.9438	val-rmse:14.7338	train-MAPE:0.283351	val-MAPE:0.279333
# [45]	train-rmse:13.6049	val-rmse:14.4308	train-MAPE:0.280443	val-MAPE:0.276689
# [46]	train-rmse:13.2802	val-rmse:14.1456	train-MAPE:0.278009	val-MAPE:0.274652
# [47]	train-rmse:12.9767	val-rmse:13.8814	train-MAPE:0.275168	val-MAPE:0.272043
# [48]	train-rmse:12.6857	val-rmse:13.6344	train-MAPE:0.273464	val-MAPE:0.270909
# [49]	train-rmse:12.4097	val-rmse:13.3957	train-MAPE:0.271244	val-MAPE:0.269023
# [50]	train-rmse:12.1501	val-rmse:13.1692	train-MAPE:0.269224	val-MAPE:0.267209
# [51]	train-rmse:11.9001	val-rmse:12.9503	train-MAPE:0.267531	val-MAPE:0.26566
# [52]	train-rmse:11.6676	val-rmse:12.7567	train-MAPE:0.265783	val-MAPE:0.264112
# [53]	train-rmse:11.4466	val-rmse:12.5671	train-MAPE:0.26424	val-MAPE:0.262815
# [54]	train-rmse:11.2337	val-rmse:12.3946	train-MAPE:0.262838	val-MAPE:0.261641
# [55]	train-rmse:11.032	val-rmse:12.2307	train-MAPE:0.26126	val-MAPE:0.259764
# [56]	train-rmse:10.8375	val-rmse:12.0833	train-MAPE:0.260406	val-MAPE:0.25922
# [57]	train-rmse:10.6514	val-rmse:11.9388	train-MAPE:0.259654	val-MAPE:0.258759
# [58]	train-rmse:10.4796	val-rmse:11.8186	train-MAPE:0.258845	val-MAPE:0.258221
# [59]	train-rmse:10.313	val-rmse:11.6832	train-MAPE:0.257212	val-MAPE:0.256998
# [60]	train-rmse:10.1568	val-rmse:11.5677	train-MAPE:0.256192	val-MAPE:0.256384
# [61]	train-rmse:10.0107	val-rmse:11.4703	train-MAPE:0.255613	val-MAPE:0.256212
# [62]	train-rmse:9.87215	val-rmse:11.3768	train-MAPE:0.255294	val-MAPE:0.256242
# [63]	train-rmse:9.74072	val-rmse:11.27	train-MAPE:0.252948	val-MAPE:0.254593
# [64]	train-rmse:9.6167	val-rmse:11.187	train-MAPE:0.252159	val-MAPE:0.254285
# [65]	train-rmse:9.50018	val-rmse:11.0926	train-MAPE:0.250166	val-MAPE:0.253022
# [66]	train-rmse:9.38833	val-rmse:11.0206	train-MAPE:0.249474	val-MAPE:0.252857
# [67]	train-rmse:9.28411	val-rmse:10.94	train-MAPE:0.247194	val-MAPE:0.251636
# [68]	train-rmse:9.18142	val-rmse:10.8772	train-MAPE:0.245744	val-MAPE:0.250733
# [69]	train-rmse:9.07954	val-rmse:10.8168	train-MAPE:0.243827	val-MAPE:0.250015
# [70]	train-rmse:8.98919	val-rmse:10.7538	train-MAPE:0.242548	val-MAPE:0.249604
# [71]	train-rmse:8.90712	val-rmse:10.6967	train-MAPE:0.241202	val-MAPE:0.24912
# [72]	train-rmse:8.82068	val-rmse:10.6482	train-MAPE:0.240368	val-MAPE:0.24881
# [73]	train-rmse:8.73908	val-rmse:10.5952	train-MAPE:0.23867	val-MAPE:0.247548
# [74]	train-rmse:8.66903	val-rmse:10.555	train-MAPE:0.237853	val-MAPE:0.247238
# [75]	train-rmse:8.58956	val-rmse:10.5196	train-MAPE:0.236868	val-MAPE:0.24651
# [76]	train-rmse:8.51673	val-rmse:10.4788	train-MAPE:0.235656	val-MAPE:0.245441
# [77]	train-rmse:8.44764	val-rmse:10.4477	train-MAPE:0.234844	val-MAPE:0.245154
# [78]	train-rmse:8.38664	val-rmse:10.4124	train-MAPE:0.233419	val-MAPE:0.244781
# [79]	train-rmse:8.3242	val-rmse:10.3844	train-MAPE:0.23272	val-MAPE:0.244399
# [80]	train-rmse:8.26388	val-rmse:10.3588	train-MAPE:0.231859	val-MAPE:0.244038
# [81]	train-rmse:8.20841	val-rmse:10.3264	train-MAPE:0.230855	val-MAPE:0.243779
# [82]	train-rmse:8.15767	val-rmse:10.3094	train-MAPE:0.229797	val-MAPE:0.243224
# [83]	train-rmse:8.10703	val-rmse:10.285	train-MAPE:0.228873	val-MAPE:0.242932
# [84]	train-rmse:8.06292	val-rmse:10.2656	train-MAPE:0.227922	val-MAPE:0.242182
# [85]	train-rmse:8.01808	val-rmse:10.2404	train-MAPE:0.226973	val-MAPE:0.241655
# [86]	train-rmse:7.97153	val-rmse:10.2226	train-MAPE:0.22626	val-MAPE:0.241344
# [87]	train-rmse:7.93232	val-rmse:10.1996	train-MAPE:0.225196	val-MAPE:0.240337
# [88]	train-rmse:7.88705	val-rmse:10.1922	train-MAPE:0.224184	val-MAPE:0.240257
# [89]	train-rmse:7.84832	val-rmse:10.178	train-MAPE:0.223584	val-MAPE:0.23997
# [90]	train-rmse:7.80533	val-rmse:10.1644	train-MAPE:0.223079	val-MAPE:0.239755
# [91]	train-rmse:7.76968	val-rmse:10.1483	train-MAPE:0.222012	val-MAPE:0.239229
# [92]	train-rmse:7.73219	val-rmse:10.1434	train-MAPE:0.22146	val-MAPE:0.239101
# [93]	train-rmse:7.70455	val-rmse:10.13	train-MAPE:0.220895	val-MAPE:0.23893
# [94]	train-rmse:7.67796	val-rmse:10.1177	train-MAPE:0.219956	val-MAPE:0.238427
# [95]	train-rmse:7.64258	val-rmse:10.1064	train-MAPE:0.219624	val-MAPE:0.238525
# [96]	train-rmse:7.61291	val-rmse:10.0931	train-MAPE:0.218681	val-MAPE:0.237995
# [97]	train-rmse:7.58098	val-rmse:10.0944	train-MAPE:0.218385	val-MAPE:0.237975
# [98]	train-rmse:7.5464	val-rmse:10.0785	train-MAPE:0.218105	val-MAPE:0.237801
# [99]	train-rmse:7.51129	val-rmse:10.0633	train-MAPE:0.217871	val-MAPE:0.237862
# [100]	train-rmse:7.47676	val-rmse:10.0531	train-MAPE:0.217474	val-MAPE:0.238206
# [101]	train-rmse:7.44836	val-rmse:10.0433	train-MAPE:0.217226	val-MAPE:0.238344
# [102]	train-rmse:7.41395	val-rmse:10.0277	train-MAPE:0.216687	val-MAPE:0.238063
# [103]	train-rmse:7.38395	val-rmse:10.0114	train-MAPE:0.216713	val-MAPE:0.238235
# [104]	train-rmse:7.35462	val-rmse:10.0016	train-MAPE:0.216803	val-MAPE:0.238381
# [105]	train-rmse:7.32395	val-rmse:9.99076	train-MAPE:0.216257	val-MAPE:0.238319
# [106]	train-rmse:7.30286	val-rmse:9.98727	train-MAPE:0.216213	val-MAPE:0.238534
# [107]	train-rmse:7.2842	val-rmse:9.98784	train-MAPE:0.216023	val-MAPE:0.238331
# [108]	train-rmse:7.25673	val-rmse:9.98685	train-MAPE:0.215794	val-MAPE:0.238386
# [109]	train-rmse:7.22055	val-rmse:9.98638	train-MAPE:0.215156	val-MAPE:0.238319
# [110]	train-rmse:7.19829	val-rmse:9.98863	train-MAPE:0.215364	val-MAPE:0.238757
# [111]	train-rmse:7.17024	val-rmse:9.99282	train-MAPE:0.215042	val-MAPE:0.238741
# [112]	train-rmse:7.15503	val-rmse:9.99259	train-MAPE:0.214901	val-MAPE:0.238797
# [113]	train-rmse:7.13803	val-rmse:9.98715	train-MAPE:0.214923	val-MAPE:0.238994
# [114]	train-rmse:7.12767	val-rmse:9.98683	train-MAPE:0.215194	val-MAPE:0.239291
# [115]	train-rmse:7.09559	val-rmse:9.97576	train-MAPE:0.214278	val-MAPE:0.23886
# [116]	train-rmse:7.08289	val-rmse:9.97476	train-MAPE:0.214059	val-MAPE:0.23872
# [117]	train-rmse:7.07381	val-rmse:9.97686	train-MAPE:0.214343	val-MAPE:0.239064
# [118]	train-rmse:7.05814	val-rmse:9.97605	train-MAPE:0.214422	val-MAPE:0.239281
# [119]	train-rmse:7.02877	val-rmse:9.97624	train-MAPE:0.21373	val-MAPE:0.239076
# [120]	train-rmse:7.00938	val-rmse:9.98024	train-MAPE:0.213218	val-MAPE:0.238999
# [121]	train-rmse:6.99448	val-rmse:9.97957	train-MAPE:0.213217	val-MAPE:0.239187
# [122]	train-rmse:6.97818	val-rmse:9.98545	train-MAPE:0.212862	val-MAPE:0.239109
# [123]	train-rmse:6.96057	val-rmse:9.98263	train-MAPE:0.21169	val-MAPE:0.238263
# [124]	train-rmse:6.94988	val-rmse:9.98693	train-MAPE:0.211833	val-MAPE:0.238536
# [125]	train-rmse:6.93372	val-rmse:9.99351	train-MAPE:0.211455	val-MAPE:0.238596
# [126]	train-rmse:6.90894	val-rmse:9.98894	train-MAPE:0.211079	val-MAPE:0.238875
# [127]	train-rmse:6.89306	val-rmse:9.99546	train-MAPE:0.210816	val-MAPE:0.238933
# [128]	train-rmse:6.87967	val-rmse:9.99967	train-MAPE:0.210818	val-MAPE:0.239149
# [129]	train-rmse:6.86351	val-rmse:9.99586	train-MAPE:0.209992	val-MAPE:0.238741
# [130]	train-rmse:6.84778	val-rmse:10.0017	train-MAPE:0.209661	val-MAPE:0.238741
# [131]	train-rmse:6.83221	val-rmse:10.0002	train-MAPE:0.2087	val-MAPE:0.238075
# [132]	train-rmse:6.81375	val-rmse:9.9953	train-MAPE:0.208639	val-MAPE:0.238266
# [133]	train-rmse:6.80321	val-rmse:9.99433	train-MAPE:0.208759	val-MAPE:0.238447
# [134]	train-rmse:6.78832	val-rmse:9.99259	train-MAPE:0.208624	val-MAPE:0.238607
# [135]	train-rmse:6.77749	val-rmse:9.9948	train-MAPE:0.208345	val-MAPE:0.238484
# [136]	train-rmse:6.7643	val-rmse:9.99464	train-MAPE:0.2074	val-MAPE:0.238287
# [137]	train-rmse:6.75433	val-rmse:9.98775	train-MAPE:0.207416	val-MAPE:0.238361
# [138]	train-rmse:6.74584	val-rmse:9.98622	train-MAPE:0.207373	val-MAPE:0.238398
# [139]	train-rmse:6.73644	val-rmse:9.98398	train-MAPE:0.206219	val-MAPE:0.237978
# [140]	train-rmse:6.71543	val-rmse:9.97774	train-MAPE:0.205804	val-MAPE:0.238314
# [141]	train-rmse:6.70235	val-rmse:9.97411	train-MAPE:0.205476	val-MAPE:0.238155
# [142]	train-rmse:6.69118	val-rmse:9.97051	train-MAPE:0.205078	val-MAPE:0.238257
# [143]	train-rmse:6.67886	val-rmse:9.96965	train-MAPE:0.204953	val-MAPE:0.238308
# [144]	train-rmse:6.66701	val-rmse:9.96877	train-MAPE:0.204434	val-MAPE:0.238346
# [145]	train-rmse:6.64685	val-rmse:9.97229	train-MAPE:0.203929	val-MAPE:0.23814
# [146]	train-rmse:6.63966	val-rmse:9.97321	train-MAPE:0.203041	val-MAPE:0.238248
# [147]	train-rmse:6.6285	val-rmse:9.97126	train-MAPE:0.202935	val-MAPE:0.238435
# [148]	train-rmse:6.61419	val-rmse:9.97379	train-MAPE:0.202626	val-MAPE:0.238388
# [149]	train-rmse:6.60075	val-rmse:9.97215	train-MAPE:0.202418	val-MAPE:0.238326
# [150]	train-rmse:6.58472	val-rmse:9.97193	train-MAPE:0.202174	val-MAPE:0.238306
# [151]	train-rmse:6.5791	val-rmse:9.97136	train-MAPE:0.20175	val-MAPE:0.238345
# [152]	train-rmse:6.57078	val-rmse:9.97831	train-MAPE:0.201624	val-MAPE:0.23833
# [153]	train-rmse:6.55987	val-rmse:9.97259	train-MAPE:0.201341	val-MAPE:0.238242
# [154]	train-rmse:6.55199	val-rmse:9.97163	train-MAPE:0.200293	val-MAPE:0.237761
# [155]	train-rmse:6.54156	val-rmse:9.97143	train-MAPE:0.199675	val-MAPE:0.237682
# [156]	train-rmse:6.52773	val-rmse:9.96932	train-MAPE:0.199388	val-MAPE:0.237677
# [157]	train-rmse:6.52084	val-rmse:9.96943	train-MAPE:0.199265	val-MAPE:0.237658
# [158]	train-rmse:6.51125	val-rmse:9.96926	train-MAPE:0.198759	val-MAPE:0.237646
# [159]	train-rmse:6.49676	val-rmse:9.973	train-MAPE:0.198408	val-MAPE:0.23753
# [160]	train-rmse:6.48796	val-rmse:9.97393	train-MAPE:0.198246	val-MAPE:0.237577
# [161]	train-rmse:6.47327	val-rmse:9.97068	train-MAPE:0.197729	val-MAPE:0.237575
# [162]	train-rmse:6.4545	val-rmse:9.96552	train-MAPE:0.197261	val-MAPE:0.237347
# [163]	train-rmse:6.45068	val-rmse:9.96422	train-MAPE:0.19687	val-MAPE:0.237287
# [164]	train-rmse:6.4356	val-rmse:9.97109	train-MAPE:0.19655	val-MAPE:0.237286
# [165]	train-rmse:6.43077	val-rmse:9.9719	train-MAPE:0.19647	val-MAPE:0.237239
# [166]	train-rmse:6.4243	val-rmse:9.97075	train-MAPE:0.196284	val-MAPE:0.237219
# [167]	train-rmse:6.41621	val-rmse:9.9729	train-MAPE:0.196131	val-MAPE:0.237229
# [168]	train-rmse:6.40871	val-rmse:9.97147	train-MAPE:0.195191	val-MAPE:0.236933
# [169]	train-rmse:6.4042	val-rmse:9.97221	train-MAPE:0.195115	val-MAPE:0.236841
# [170]	train-rmse:6.39883	val-rmse:9.97319	train-MAPE:0.194758	val-MAPE:0.236785
# [171]	train-rmse:6.38403	val-rmse:9.97724	train-MAPE:0.194484	val-MAPE:0.236946
# [172]	train-rmse:6.3783	val-rmse:9.97729	train-MAPE:0.193606	val-MAPE:0.236917
# [173]	train-rmse:6.37153	val-rmse:9.97635	train-MAPE:0.193361	val-MAPE:0.23691
# [174]	train-rmse:6.36566	val-rmse:9.97318	train-MAPE:0.193159	val-MAPE:0.236866
# [175]	train-rmse:6.36229	val-rmse:9.97566	train-MAPE:0.19308	val-MAPE:0.23694
# [176]	train-rmse:6.35721	val-rmse:9.97687	train-MAPE:0.192621	val-MAPE:0.236948
# [177]	train-rmse:6.34334	val-rmse:9.98032	train-MAPE:0.192407	val-MAPE:0.236988
# [178]	train-rmse:6.3375	val-rmse:9.98106	train-MAPE:0.192367	val-MAPE:0.237018
# [179]	train-rmse:6.32065	val-rmse:9.97246	train-MAPE:0.191934	val-MAPE:0.236762
# [180]	train-rmse:6.30885	val-rmse:9.97368	train-MAPE:0.191457	val-MAPE:0.236882
# [181]	train-rmse:6.30112	val-rmse:9.9737	train-MAPE:0.191287	val-MAPE:0.237304
# [182]	train-rmse:6.29205	val-rmse:9.97308	train-MAPE:0.190785	val-MAPE:0.237278
# [183]	train-rmse:6.28521	val-rmse:9.97503	train-MAPE:0.190571	val-MAPE:0.237234
# [184]	train-rmse:6.27243	val-rmse:9.97607	train-MAPE:0.18981	val-MAPE:0.23683
# [185]	train-rmse:6.26369	val-rmse:9.9734	train-MAPE:0.189693	val-MAPE:0.236796
# [186]	train-rmse:6.2527	val-rmse:9.97004	train-MAPE:0.189253	val-MAPE:0.236644
# [187]	train-rmse:6.24743	val-rmse:9.96833	train-MAPE:0.188475	val-MAPE:0.236225
# [188]	train-rmse:6.24039	val-rmse:9.97334	train-MAPE:0.188398	val-MAPE:0.236249
# [189]	train-rmse:6.23734	val-rmse:9.97579	train-MAPE:0.188316	val-MAPE:0.236323
# [190]	train-rmse:6.2308	val-rmse:9.97733	train-MAPE:0.18827	val-MAPE:0.236314
# [191]	train-rmse:6.20467	val-rmse:9.98192	train-MAPE:0.187934	val-MAPE:0.236512
# [192]	train-rmse:6.19627	val-rmse:9.98328	train-MAPE:0.187702	val-MAPE:0.23662
# [193]	train-rmse:6.18839	val-rmse:9.97889	train-MAPE:0.187267	val-MAPE:0.236513
# [194]	train-rmse:6.17083	val-rmse:9.9833	train-MAPE:0.186952	val-MAPE:0.236685
# [195]	train-rmse:6.15826	val-rmse:9.98528	train-MAPE:0.186713	val-MAPE:0.236578
# [196]	train-rmse:6.14876	val-rmse:9.98212	train-MAPE:0.186042	val-MAPE:0.236274
# [197]	train-rmse:6.14159	val-rmse:9.98259	train-MAPE:0.185963	val-MAPE:0.236425
# [198]	train-rmse:6.13094	val-rmse:9.98423	train-MAPE:0.185295	val-MAPE:0.236485
# [199]	train-rmse:6.12748	val-rmse:9.98626	train-MAPE:0.185186	val-MAPE:0.236513
# [200]	train-rmse:6.12033	val-rmse:9.98654	train-MAPE:0.185029	val-MAPE:0.236707
# [201]	train-rmse:6.11168	val-rmse:9.98833	train-MAPE:0.184888	val-MAPE:0.236654
# [202]	train-rmse:6.10592	val-rmse:9.98842	train-MAPE:0.184827	val-MAPE:0.236736
# [203]	train-rmse:6.10207	val-rmse:9.98704	train-MAPE:0.184284	val-MAPE:0.236358
# [204]	train-rmse:6.09603	val-rmse:9.98883	train-MAPE:0.184176	val-MAPE:0.236383
# [205]	train-rmse:6.07881	val-rmse:9.99163	train-MAPE:0.183815	val-MAPE:0.236279
# [206]	train-rmse:6.06366	val-rmse:9.98719	train-MAPE:0.18348	val-MAPE:0.236242
# [207]	train-rmse:6.06034	val-rmse:9.98838	train-MAPE:0.183446	val-MAPE:0.236296
# [208]	train-rmse:6.04521	val-rmse:9.98831	train-MAPE:0.183214	val-MAPE:0.236276
# [209]	train-rmse:6.03626	val-rmse:9.98733	train-MAPE:0.18246	val-MAPE:0.236081
# [210]	train-rmse:6.0204	val-rmse:9.98972	train-MAPE:0.181997	val-MAPE:0.235906
# [211]	train-rmse:6.00699	val-rmse:9.98907	train-MAPE:0.181866	val-MAPE:0.235883
# [212]	train-rmse:6.0027	val-rmse:9.99066	train-MAPE:0.181799	val-MAPE:0.235962
# [213]	train-rmse:5.99191	val-rmse:9.99126	train-MAPE:0.18169	val-MAPE:0.23594
# [214]	train-rmse:5.98166	val-rmse:9.99281	train-MAPE:0.181582	val-MAPE:0.235929
# [215]	train-rmse:5.97411	val-rmse:9.99451	train-MAPE:0.181495	val-MAPE:0.235902
# [216]	train-rmse:5.96009	val-rmse:9.99304	train-MAPE:0.181163	val-MAPE:0.235838
# [217]	train-rmse:5.95361	val-rmse:9.9922	train-MAPE:0.180625	val-MAPE:0.235748
# [218]	train-rmse:5.94027	val-rmse:9.99396	train-MAPE:0.180383	val-MAPE:0.235749
# [219]	train-rmse:5.93749	val-rmse:9.99612	train-MAPE:0.180364	val-MAPE:0.23582
# [220]	train-rmse:5.93249	val-rmse:9.99778	train-MAPE:0.18031	val-MAPE:0.235906
# [221]	train-rmse:5.91927	val-rmse:9.99516	train-MAPE:0.179862	val-MAPE:0.235631
# [222]	train-rmse:5.91404	val-rmse:9.99484	train-MAPE:0.179576	val-MAPE:0.235487
# [223]	train-rmse:5.90398	val-rmse:9.99612	train-MAPE:0.179163	val-MAPE:0.235362
# [224]	train-rmse:5.88647	val-rmse:9.99697	train-MAPE:0.17899	val-MAPE:0.235387
# [225]	train-rmse:5.88256	val-rmse:9.99724	train-MAPE:0.178535	val-MAPE:0.235255
# [226]	train-rmse:5.87454	val-rmse:9.99785	train-MAPE:0.178532	val-MAPE:0.235235
# [227]	train-rmse:5.86805	val-rmse:9.99724	train-MAPE:0.178193	val-MAPE:0.235038
# [228]	train-rmse:5.84883	val-rmse:10.0033	train-MAPE:0.177998	val-MAPE:0.23516
# [229]	train-rmse:5.83723	val-rmse:10.004	train-MAPE:0.177762	val-MAPE:0.235111
# [230]	train-rmse:5.83144	val-rmse:10.002	train-MAPE:0.177279	val-MAPE:0.235
# [231]	train-rmse:5.82602	val-rmse:9.99979	train-MAPE:0.177128	val-MAPE:0.235046
# [232]	train-rmse:5.80961	val-rmse:9.99503	train-MAPE:0.176784	val-MAPE:0.235141
# [233]	train-rmse:5.80361	val-rmse:9.99396	train-MAPE:0.176463	val-MAPE:0.234928
# [234]	train-rmse:5.78974	val-rmse:9.99418	train-MAPE:0.176311	val-MAPE:0.234845
# [235]	train-rmse:5.78409	val-rmse:9.9966	train-MAPE:0.176298	val-MAPE:0.234932
# [236]	train-rmse:5.7776	val-rmse:9.99694	train-MAPE:0.176096	val-MAPE:0.235121
# [237]	train-rmse:5.77303	val-rmse:9.99408	train-MAPE:0.175921	val-MAPE:0.235044
# [238]	train-rmse:5.76565	val-rmse:9.99304	train-MAPE:0.17553	val-MAPE:0.234925
# [239]	train-rmse:5.76318	val-rmse:9.99364	train-MAPE:0.175501	val-MAPE:0.234943
# [240]	train-rmse:5.75759	val-rmse:9.99387	train-MAPE:0.175123	val-MAPE:0.235015
# [241]	train-rmse:5.75036	val-rmse:9.99256	train-MAPE:0.174559	val-MAPE:0.23469
# [242]	train-rmse:5.73214	val-rmse:9.99906	train-MAPE:0.174304	val-MAPE:0.234603
# [243]	train-rmse:5.72511	val-rmse:10.0011	train-MAPE:0.174263	val-MAPE:0.234644
# [244]	train-rmse:5.71966	val-rmse:10.0029	train-MAPE:0.173761	val-MAPE:0.2344
# [245]	train-rmse:5.71535	val-rmse:10.0027	train-MAPE:0.173464	val-MAPE:0.23424
# [246]	train-rmse:5.70701	val-rmse:10.0025	train-MAPE:0.17316	val-MAPE:0.234236
# [247]	train-rmse:5.70397	val-rmse:10.0014	train-MAPE:0.172934	val-MAPE:0.234215
# [248]	train-rmse:5.69468	val-rmse:10.002	train-MAPE:0.17269	val-MAPE:0.234369
# [249]	train-rmse:5.68372	val-rmse:10.0044	train-MAPE:0.172464	val-MAPE:0.234371
# [250]	train-rmse:5.67656	val-rmse:10.0046	train-MAPE:0.172367	val-MAPE:0.234378
# [251]	train-rmse:5.67067	val-rmse:10.005	train-MAPE:0.172181	val-MAPE:0.234566
# [252]	train-rmse:5.66477	val-rmse:10.0063	train-MAPE:0.171982	val-MAPE:0.234539
# [253]	train-rmse:5.65616	val-rmse:10.0065	train-MAPE:0.171831	val-MAPE:0.23459
# [254]	train-rmse:5.65053	val-rmse:10.0095	train-MAPE:0.171283	val-MAPE:0.234621
# [255]	train-rmse:5.64523	val-rmse:10.008	train-MAPE:0.170718	val-MAPE:0.234334
# [256]	train-rmse:5.63981	val-rmse:10.0093	train-MAPE:0.170595	val-MAPE:0.234526
# [257]	train-rmse:5.62578	val-rmse:10.0099	train-MAPE:0.170321	val-MAPE:0.234429
# [258]	train-rmse:5.60937	val-rmse:10.0129	train-MAPE:0.170077	val-MAPE:0.234497
# [259]	train-rmse:5.60548	val-rmse:10.0148	train-MAPE:0.170009	val-MAPE:0.23455
# [260]	train-rmse:5.59714	val-rmse:10.0167	train-MAPE:0.169871	val-MAPE:0.234505
# [261]	train-rmse:5.59338	val-rmse:10.0183	train-MAPE:0.16939	val-MAPE:0.234555
# [262]	train-rmse:5.58807	val-rmse:10.0191	train-MAPE:0.169188	val-MAPE:0.23452
# [263]	train-rmse:5.58465	val-rmse:10.0224	train-MAPE:0.169188	val-MAPE:0.234582
# [264]	train-rmse:5.58188	val-rmse:10.022	train-MAPE:0.16899	val-MAPE:0.234391
# [265]	train-rmse:5.57577	val-rmse:10.0222	train-MAPE:0.168875	val-MAPE:0.234331
# [266]	train-rmse:5.57258	val-rmse:10.0251	train-MAPE:0.168874	val-MAPE:0.234389
# [267]	train-rmse:5.56475	val-rmse:10.029	train-MAPE:0.168756	val-MAPE:0.234398
# [268]	train-rmse:5.54813	val-rmse:10.0278	train-MAPE:0.168495	val-MAPE:0.234302
# [269]	train-rmse:5.53702	val-rmse:10.0267	train-MAPE:0.167989	val-MAPE:0.234028
# [270]	train-rmse:5.53065	val-rmse:10.0289	train-MAPE:0.167924	val-MAPE:0.234055
# [271]	train-rmse:5.52799	val-rmse:10.0288	train-MAPE:0.167618	val-MAPE:0.233868
# [272]	train-rmse:5.51302	val-rmse:10.0355	train-MAPE:0.167391	val-MAPE:0.233848
# [273]	train-rmse:5.51022	val-rmse:10.0361	train-MAPE:0.167001	val-MAPE:0.233918
# [274]	train-rmse:5.5012	val-rmse:10.0359	train-MAPE:0.166876	val-MAPE:0.233845
# [275]	train-rmse:5.48385	val-rmse:10.0358	train-MAPE:0.166737	val-MAPE:0.23388
# [276]	train-rmse:5.46615	val-rmse:10.0347	train-MAPE:0.166405	val-MAPE:0.233769
# [277]	train-rmse:5.4562	val-rmse:10.0347	train-MAPE:0.165973	val-MAPE:0.233683
# [278]	train-rmse:5.44889	val-rmse:10.0376	train-MAPE:0.165908	val-MAPE:0.233732
# [279]	train-rmse:5.44178	val-rmse:10.041	train-MAPE:0.165806	val-MAPE:0.233734
# [280]	train-rmse:5.4359	val-rmse:10.0431	train-MAPE:0.165713	val-MAPE:0.233745
# [281]	train-rmse:5.43077	val-rmse:10.0449	train-MAPE:0.165479	val-MAPE:0.233756
# [282]	train-rmse:5.42475	val-rmse:10.0483	train-MAPE:0.165101	val-MAPE:0.233702
# [283]	train-rmse:5.40979	val-rmse:10.0513	train-MAPE:0.164927	val-MAPE:0.233766
# [284]	train-rmse:5.40652	val-rmse:10.051	train-MAPE:0.164476	val-MAPE:0.233577
# [285]	train-rmse:5.39992	val-rmse:10.0552	train-MAPE:0.164328	val-MAPE:0.233507
# [286]	train-rmse:5.39216	val-rmse:10.0599	train-MAPE:0.164082	val-MAPE:0.233635
# [287]	train-rmse:5.37798	val-rmse:10.0618	train-MAPE:0.163877	val-MAPE:0.233565
# [288]	train-rmse:5.37241	val-rmse:10.0628	train-MAPE:0.163819	val-MAPE:0.233546
# [289]	train-rmse:5.36992	val-rmse:10.0629	train-MAPE:0.16378	val-MAPE:0.233579
# [290]	train-rmse:5.3576	val-rmse:10.0636	train-MAPE:0.163288	val-MAPE:0.233988
# [291]	train-rmse:5.35086	val-rmse:10.0662	train-MAPE:0.163238	val-MAPE:0.234041
# [292]	train-rmse:5.3472	val-rmse:10.0671	train-MAPE:0.162962	val-MAPE:0.233895
# [293]	train-rmse:5.34242	val-rmse:10.0664	train-MAPE:0.162683	val-MAPE:0.233917
# [294]	train-rmse:5.33515	val-rmse:10.0638	train-MAPE:0.162559	val-MAPE:0.233938
# [295]	train-rmse:5.33082	val-rmse:10.0626	train-MAPE:0.161933	val-MAPE:0.233516
# [296]	train-rmse:5.32623	val-rmse:10.0619	train-MAPE:0.161457	val-MAPE:0.233575
# [297]	train-rmse:5.32318	val-rmse:10.0632	train-MAPE:0.161319	val-MAPE:0.233533
# [298]	train-rmse:5.31821	val-rmse:10.0644	train-MAPE:0.161325	val-MAPE:0.233685
# [299]	train-rmse:5.31405	val-rmse:10.064	train-MAPE:0.161005	val-MAPE:0.23362
# [300]	train-rmse:5.31177	val-rmse:10.0638	train-MAPE:0.160916	val-MAPE:0.233639
# [301]	train-rmse:5.29964	val-rmse:10.0634	train-MAPE:0.160506	val-MAPE:0.234045
# [302]	train-rmse:5.28278	val-rmse:10.0676	train-MAPE:0.16033	val-MAPE:0.234078
# [303]	train-rmse:5.27619	val-rmse:10.0693	train-MAPE:0.160249	val-MAPE:0.23408
# [304]	train-rmse:5.2597	val-rmse:10.0747	train-MAPE:0.159959	val-MAPE:0.233919
# [305]	train-rmse:5.25533	val-rmse:10.0742	train-MAPE:0.159512	val-MAPE:0.233925
# [306]	train-rmse:5.24297	val-rmse:10.0733	train-MAPE:0.159254	val-MAPE:0.233908
# [307]	train-rmse:5.23912	val-rmse:10.0734	train-MAPE:0.159055	val-MAPE:0.233911
# [308]	train-rmse:5.22891	val-rmse:10.0723	train-MAPE:0.158652	val-MAPE:0.233753
# [309]	train-rmse:5.22238	val-rmse:10.0701	train-MAPE:0.15816	val-MAPE:0.233738
# [310]	train-rmse:5.2099	val-rmse:10.0706	train-MAPE:0.157973	val-MAPE:0.233744
# [311]	train-rmse:5.19641	val-rmse:10.0725	train-MAPE:0.157807	val-MAPE:0.233815
# [312]	train-rmse:5.19324	val-rmse:10.0746	train-MAPE:0.157816	val-MAPE:0.233852
# [313]	train-rmse:5.18998	val-rmse:10.0754	train-MAPE:0.157568	val-MAPE:0.233722
# [314]	train-rmse:5.18461	val-rmse:10.0777	train-MAPE:0.157325	val-MAPE:0.233735
# [315]	train-rmse:5.17355	val-rmse:10.0793	train-MAPE:0.157047	val-MAPE:0.233633
# [316]	train-rmse:5.17138	val-rmse:10.0792	train-MAPE:0.15701	val-MAPE:0.233647
# [317]	train-rmse:5.16833	val-rmse:10.0797	train-MAPE:0.156729	val-MAPE:0.233549
# [318]	train-rmse:5.16375	val-rmse:10.0795	train-MAPE:0.156268	val-MAPE:0.233338
# [319]	train-rmse:5.15723	val-rmse:10.0825	train-MAPE:0.155849	val-MAPE:0.233449
# [320]	train-rmse:5.14951	val-rmse:10.0836	train-MAPE:0.155574	val-MAPE:0.233435
# [321]	train-rmse:5.14789	val-rmse:10.0847	train-MAPE:0.155509	val-MAPE:0.233415
# [322]	train-rmse:5.14094	val-rmse:10.083	train-MAPE:0.154944	val-MAPE:0.233191
# [323]	train-rmse:5.13414	val-rmse:10.0822	train-MAPE:0.154448	val-MAPE:0.233145
# [324]	train-rmse:5.12954	val-rmse:10.0817	train-MAPE:0.154035	val-MAPE:0.232969
# [325]	train-rmse:5.12426	val-rmse:10.0844	train-MAPE:0.153824	val-MAPE:0.232975
# [326]	train-rmse:5.11661	val-rmse:10.0868	train-MAPE:0.153696	val-MAPE:0.232886
# [327]	train-rmse:5.11126	val-rmse:10.0862	train-MAPE:0.153512	val-MAPE:0.232917
# [328]	train-rmse:5.10634	val-rmse:10.0874	train-MAPE:0.153441	val-MAPE:0.232961
# [329]	train-rmse:5.09713	val-rmse:10.0869	train-MAPE:0.153079	val-MAPE:0.232801
# [330]	train-rmse:5.09079	val-rmse:10.0879	train-MAPE:0.152932	val-MAPE:0.232839
# [331]	train-rmse:5.07751	val-rmse:10.093	train-MAPE:0.15272	val-MAPE:0.232848
# [332]	train-rmse:5.06142	val-rmse:10.0928	train-MAPE:0.152545	val-MAPE:0.232832
# [333]	train-rmse:5.05497	val-rmse:10.0924	train-MAPE:0.152117	val-MAPE:0.232621
# [334]	train-rmse:5.04118	val-rmse:10.0943	train-MAPE:0.151871	val-MAPE:0.232464
# [335]	train-rmse:5.03567	val-rmse:10.0935	train-MAPE:0.151477	val-MAPE:0.232379
# [336]	train-rmse:5.02994	val-rmse:10.0963	train-MAPE:0.151308	val-MAPE:0.232339
# [337]	train-rmse:5.02664	val-rmse:10.0954	train-MAPE:0.15102	val-MAPE:0.23226
# [338]	train-rmse:5.0126	val-rmse:10.0998	train-MAPE:0.150798	val-MAPE:0.232279
# [339]	train-rmse:5.00788	val-rmse:10.1019	train-MAPE:0.150753	val-MAPE:0.232357
# [340]	train-rmse:5.00333	val-rmse:10.1028	train-MAPE:0.150671	val-MAPE:0.232375
# [341]	train-rmse:4.99662	val-rmse:10.1004	train-MAPE:0.150415	val-MAPE:0.232329
# [342]	train-rmse:4.99244	val-rmse:10.1032	train-MAPE:0.150377	val-MAPE:0.232392
# [343]	train-rmse:4.9817	val-rmse:10.1009	train-MAPE:0.150142	val-MAPE:0.232607
# [344]	train-rmse:4.9766	val-rmse:10.0995	train-MAPE:0.14965	val-MAPE:0.232455
# [345]	train-rmse:4.97135	val-rmse:10.0983	train-MAPE:0.149571	val-MAPE:0.232503
# [346]	train-rmse:4.96733	val-rmse:10.1005	train-MAPE:0.149474	val-MAPE:0.232374
# [347]	train-rmse:4.9498	val-rmse:10.1039	train-MAPE:0.149333	val-MAPE:0.232461
# [348]	train-rmse:4.94016	val-rmse:10.1025	train-MAPE:0.149126	val-MAPE:0.232299
# [349]	train-rmse:4.93502	val-rmse:10.1039	train-MAPE:0.148992	val-MAPE:0.232306
# [350]	train-rmse:4.92627	val-rmse:10.1054	train-MAPE:0.148799	val-MAPE:0.232384
# [351]	train-rmse:4.91491	val-rmse:10.1099	train-MAPE:0.148482	val-MAPE:0.232241
# [352]	train-rmse:4.90983	val-rmse:10.1119	train-MAPE:0.148413	val-MAPE:0.232264
# [353]	train-rmse:4.90159	val-rmse:10.1135	train-MAPE:0.148164	val-MAPE:0.232252
# [354]	train-rmse:4.89526	val-rmse:10.1148	train-MAPE:0.147769	val-MAPE:0.232331
# [355]	train-rmse:4.8917	val-rmse:10.1182	train-MAPE:0.147746	val-MAPE:0.232381
# [356]	train-rmse:4.88381	val-rmse:10.1184	train-MAPE:0.147478	val-MAPE:0.232262
# [357]	train-rmse:4.88045	val-rmse:10.1176	train-MAPE:0.147223	val-MAPE:0.232323
# [358]	train-rmse:4.86368	val-rmse:10.1189	train-MAPE:0.14707	val-MAPE:0.23229
# [359]	train-rmse:4.84999	val-rmse:10.1217	train-MAPE:0.146751	val-MAPE:0.232274
# [360]	train-rmse:4.8437	val-rmse:10.1197	train-MAPE:0.146328	val-MAPE:0.232189
# [361]	train-rmse:4.8337	val-rmse:10.1232	train-MAPE:0.146089	val-MAPE:0.232212
# [362]	train-rmse:4.82975	val-rmse:10.1237	train-MAPE:0.146012	val-MAPE:0.232227
# [363]	train-rmse:4.81787	val-rmse:10.1262	train-MAPE:0.145922	val-MAPE:0.23216
# [364]	train-rmse:4.80835	val-rmse:10.1294	train-MAPE:0.145741	val-MAPE:0.232076
# [365]	train-rmse:4.80337	val-rmse:10.1319	train-MAPE:0.145612	val-MAPE:0.232075
# [366]	train-rmse:4.79846	val-rmse:10.1306	train-MAPE:0.14523	val-MAPE:0.231978
# [367]	train-rmse:4.78959	val-rmse:10.1346	train-MAPE:0.145044	val-MAPE:0.232013
# [368]	train-rmse:4.78709	val-rmse:10.1371	train-MAPE:0.144993	val-MAPE:0.232035
# [369]	train-rmse:4.77763	val-rmse:10.1354	train-MAPE:0.144808	val-MAPE:0.232286
# [370]	train-rmse:4.76774	val-rmse:10.1349	train-MAPE:0.144625	val-MAPE:0.232325
# [371]	train-rmse:4.75692	val-rmse:10.1361	train-MAPE:0.144556	val-MAPE:0.232215
# [372]	train-rmse:4.75107	val-rmse:10.1346	train-MAPE:0.14412	val-MAPE:0.232109
# [373]	train-rmse:4.74507	val-rmse:10.1377	train-MAPE:0.144057	val-MAPE:0.232063
# [374]	train-rmse:4.74201	val-rmse:10.1374	train-MAPE:0.143982	val-MAPE:0.232019
# [375]	train-rmse:4.73407	val-rmse:10.1413	train-MAPE:0.143791	val-MAPE:0.232212
# [376]	train-rmse:4.73004	val-rmse:10.1424	train-MAPE:0.143719	val-MAPE:0.23224
# [377]	train-rmse:4.71919	val-rmse:10.1422	train-MAPE:0.143518	val-MAPE:0.23215
# [378]	train-rmse:4.70957	val-rmse:10.1398	train-MAPE:0.143122	val-MAPE:0.23198
# [379]	train-rmse:4.70226	val-rmse:10.1405	train-MAPE:0.142788	val-MAPE:0.231844
# [380]	train-rmse:4.68631	val-rmse:10.1437	train-MAPE:0.142525	val-MAPE:0.231832
# [381]	train-rmse:4.67549	val-rmse:10.1431	train-MAPE:0.142388	val-MAPE:0.231821
# [382]	train-rmse:4.67298	val-rmse:10.1432	train-MAPE:0.142087	val-MAPE:0.231605
# [383]	train-rmse:4.66989	val-rmse:10.1428	train-MAPE:0.141929	val-MAPE:0.231466
# [384]	train-rmse:4.66137	val-rmse:10.1413	train-MAPE:0.141788	val-MAPE:0.231676
# [385]	train-rmse:4.65828	val-rmse:10.1428	train-MAPE:0.141638	val-MAPE:0.231697
# [386]	train-rmse:4.64934	val-rmse:10.1441	train-MAPE:0.141416	val-MAPE:0.231652
# [387]	train-rmse:4.64567	val-rmse:10.1457	train-MAPE:0.141352	val-MAPE:0.231698
# [388]	train-rmse:4.62481	val-rmse:10.1435	train-MAPE:0.141147	val-MAPE:0.231803
# [389]	train-rmse:4.6197	val-rmse:10.1414	train-MAPE:0.140847	val-MAPE:0.231783
# [390]	train-rmse:4.61587	val-rmse:10.1425	train-MAPE:0.140612	val-MAPE:0.231883
# [391]	train-rmse:4.61048	val-rmse:10.142	train-MAPE:0.140203	val-MAPE:0.231889
# [392]	train-rmse:4.60834	val-rmse:10.144	train-MAPE:0.140146	val-MAPE:0.231926
# [393]	train-rmse:4.59657	val-rmse:10.1403	train-MAPE:0.139851	val-MAPE:0.231897
# [394]	train-rmse:4.59401	val-rmse:10.1401	train-MAPE:0.139576	val-MAPE:0.231641
# [395]	train-rmse:4.58494	val-rmse:10.1418	train-MAPE:0.139286	val-MAPE:0.231665
# [396]	train-rmse:4.579	val-rmse:10.1446	train-MAPE:0.13916	val-MAPE:0.231555
# [397]	train-rmse:4.57765	val-rmse:10.1449	train-MAPE:0.139131	val-MAPE:0.231601
# [398]	train-rmse:4.57506	val-rmse:10.1443	train-MAPE:0.138862	val-MAPE:0.231536
# [399]	train-rmse:4.5738	val-rmse:10.1446	train-MAPE:0.138829	val-MAPE:0.231564
# [400]	train-rmse:4.56869	val-rmse:10.1426	train-MAPE:0.138729	val-MAPE:0.231565
# [401]	train-rmse:4.56333	val-rmse:10.1451	train-MAPE:0.138514	val-MAPE:0.231643
# [402]	train-rmse:4.55927	val-rmse:10.1438	train-MAPE:0.138293	val-MAPE:0.231578
# [403]	train-rmse:4.55158	val-rmse:10.1434	train-MAPE:0.138116	val-MAPE:0.231451
# [404]	train-rmse:4.55036	val-rmse:10.1438	train-MAPE:0.138091	val-MAPE:0.231494
# [405]	train-rmse:4.54841	val-rmse:10.1444	train-MAPE:0.137799	val-MAPE:0.231423
# [406]	train-rmse:4.53446	val-rmse:10.1439	train-MAPE:0.137479	val-MAPE:0.231167
# [407]	train-rmse:4.53113	val-rmse:10.1443	train-MAPE:0.137343	val-MAPE:0.23126
# [408]	train-rmse:4.5214	val-rmse:10.1439	train-MAPE:0.137121	val-MAPE:0.231184
# [409]	train-rmse:4.51304	val-rmse:10.1469	train-MAPE:0.136898	val-MAPE:0.231351
# [410]	train-rmse:4.50967	val-rmse:10.1475	train-MAPE:0.136832	val-MAPE:0.231366
# [411]	train-rmse:4.50586	val-rmse:10.1461	train-MAPE:0.136736	val-MAPE:0.231197
# [412]	train-rmse:4.50356	val-rmse:10.1463	train-MAPE:0.136461	val-MAPE:0.231078
# [413]	train-rmse:4.49929	val-rmse:10.1488	train-MAPE:0.136274	val-MAPE:0.231018
# [414]	train-rmse:4.48656	val-rmse:10.1497	train-MAPE:0.135968	val-MAPE:0.230971
# [415]	train-rmse:4.47749	val-rmse:10.151	train-MAPE:0.13575	val-MAPE:0.230894
# [416]	train-rmse:4.47221	val-rmse:10.1534	train-MAPE:0.135363	val-MAPE:0.231142
# [417]	train-rmse:4.46894	val-rmse:10.152	train-MAPE:0.135205	val-MAPE:0.231077
# [418]	train-rmse:4.4615	val-rmse:10.1533	train-MAPE:0.134991	val-MAPE:0.231014
# [419]	train-rmse:4.44967	val-rmse:10.1526	train-MAPE:0.134708	val-MAPE:0.230698
# [420]	train-rmse:4.43159	val-rmse:10.153	train-MAPE:0.134599	val-MAPE:0.230683
# [421]	train-rmse:4.42335	val-rmse:10.155	train-MAPE:0.13441	val-MAPE:0.230825
# [422]	train-rmse:4.41383	val-rmse:10.154	train-MAPE:0.134251	val-MAPE:0.230676
# [423]	train-rmse:4.39722	val-rmse:10.1529	train-MAPE:0.134119	val-MAPE:0.230655
# [424]	train-rmse:4.39478	val-rmse:10.1547	train-MAPE:0.133947	val-MAPE:0.230647
# [425]	train-rmse:4.37777	val-rmse:10.1542	train-MAPE:0.133739	val-MAPE:0.230651
# [426]	train-rmse:4.35791	val-rmse:10.1531	train-MAPE:0.1336	val-MAPE:0.230722
# [427]	train-rmse:4.35384	val-rmse:10.1559	train-MAPE:0.13351	val-MAPE:0.230757
# [428]	train-rmse:4.3448	val-rmse:10.1575	train-MAPE:0.133386	val-MAPE:0.230784
# [429]	train-rmse:4.34067	val-rmse:10.1565	train-MAPE:0.133393	val-MAPE:0.230822
# [430]	train-rmse:4.33857	val-rmse:10.1576	train-MAPE:0.133271	val-MAPE:0.230793
# [431]	train-rmse:4.33014	val-rmse:10.1602	train-MAPE:0.133089	val-MAPE:0.230841
# [432]	train-rmse:4.32105	val-rmse:10.1632	train-MAPE:0.13288	val-MAPE:0.230838
# [433]	train-rmse:4.31838	val-rmse:10.1621	train-MAPE:0.132596	val-MAPE:0.230819
# [434]	train-rmse:4.316	val-rmse:10.1648	train-MAPE:0.132569	val-MAPE:0.230903
# [435]	train-rmse:4.30238	val-rmse:10.1695	train-MAPE:0.132353	val-MAPE:0.230901
# [436]	train-rmse:4.28616	val-rmse:10.1689	train-MAPE:0.132092	val-MAPE:0.230994
# [437]	train-rmse:4.27996	val-rmse:10.1699	train-MAPE:0.131914	val-MAPE:0.230857
# [438]	train-rmse:4.2763	val-rmse:10.1727	train-MAPE:0.131831	val-MAPE:0.23089
# [439]	train-rmse:4.26668	val-rmse:10.1757	train-MAPE:0.131672	val-MAPE:0.23085
# [440]	train-rmse:4.2624	val-rmse:10.1771	train-MAPE:0.131402	val-MAPE:0.230909
# [441]	train-rmse:4.25374	val-rmse:10.176	train-MAPE:0.130882	val-MAPE:0.230652
# [442]	train-rmse:4.25154	val-rmse:10.1786	train-MAPE:0.130857	val-MAPE:0.230736
# [443]	train-rmse:4.24836	val-rmse:10.1785	train-MAPE:0.130591	val-MAPE:0.230717
# [444]	train-rmse:4.24495	val-rmse:10.1802	train-MAPE:0.130521	val-MAPE:0.230732
# [445]	train-rmse:4.23286	val-rmse:10.1779	train-MAPE:0.130317	val-MAPE:0.230688
# [446]	train-rmse:4.22891	val-rmse:10.1773	train-MAPE:0.130081	val-MAPE:0.230665
# [447]	train-rmse:4.21993	val-rmse:10.1807	train-MAPE:0.129958	val-MAPE:0.230623
# [448]	train-rmse:4.21839	val-rmse:10.1809	train-MAPE:0.129829	val-MAPE:0.230646
# [449]	train-rmse:4.21389	val-rmse:10.1808	train-MAPE:0.12971	val-MAPE:0.230689
# [450]	train-rmse:4.20195	val-rmse:10.1784	train-MAPE:0.129523	val-MAPE:0.230621
# [451]	train-rmse:4.19791	val-rmse:10.18	train-MAPE:0.129407	val-MAPE:0.230663
# [452]	train-rmse:4.18855	val-rmse:10.1826	train-MAPE:0.128961	val-MAPE:0.230542
# [453]	train-rmse:4.17741	val-rmse:10.1842	train-MAPE:0.128755	val-MAPE:0.230578
# [454]	train-rmse:4.16653	val-rmse:10.1833	train-MAPE:0.128569	val-MAPE:0.230506
# [455]	train-rmse:4.16332	val-rmse:10.1837	train-MAPE:0.128458	val-MAPE:0.230574
# [456]	train-rmse:4.16121	val-rmse:10.184	train-MAPE:0.128278	val-MAPE:0.230483
# [457]	train-rmse:4.15144	val-rmse:10.1843	train-MAPE:0.128127	val-MAPE:0.230537
# [458]	train-rmse:4.13908	val-rmse:10.1833	train-MAPE:0.127999	val-MAPE:0.23041
# [459]	train-rmse:4.13536	val-rmse:10.1844	train-MAPE:0.127883	val-MAPE:0.230426
# [460]	train-rmse:4.1272	val-rmse:10.1836	train-MAPE:0.127382	val-MAPE:0.230254
# [461]	train-rmse:4.11538	val-rmse:10.1883	train-MAPE:0.127194	val-MAPE:0.230209
# [462]	train-rmse:4.10802	val-rmse:10.1885	train-MAPE:0.127022	val-MAPE:0.230204
# [463]	train-rmse:4.10413	val-rmse:10.1889	train-MAPE:0.126935	val-MAPE:0.230205
# [464]	train-rmse:4.09602	val-rmse:10.1933	train-MAPE:0.126849	val-MAPE:0.23023
# [465]	train-rmse:4.09128	val-rmse:10.1945	train-MAPE:0.126769	val-MAPE:0.230238
# [466]	train-rmse:4.0828	val-rmse:10.1947	train-MAPE:0.126625	val-MAPE:0.230225
# [467]	train-rmse:4.07719	val-rmse:10.1937	train-MAPE:0.126263	val-MAPE:0.230449
# [468]	train-rmse:4.07392	val-rmse:10.1935	train-MAPE:0.126187	val-MAPE:0.230485
# [469]	train-rmse:4.06536	val-rmse:10.1899	train-MAPE:0.125873	val-MAPE:0.230284
# [470]	train-rmse:4.06075	val-rmse:10.1874	train-MAPE:0.125483	val-MAPE:0.23021
# [471]	train-rmse:4.0568	val-rmse:10.1861	train-MAPE:0.124836	val-MAPE:0.229992
# [472]	train-rmse:4.04756	val-rmse:10.186	train-MAPE:0.124652	val-MAPE:0.229958
# [473]	train-rmse:4.04287	val-rmse:10.1867	train-MAPE:0.12454	val-MAPE:0.229996
# [474]	train-rmse:4.03199	val-rmse:10.1837	train-MAPE:0.124345	val-MAPE:0.229894
# [475]	train-rmse:4.02836	val-rmse:10.1825	train-MAPE:0.123734	val-MAPE:0.229705
# [476]	train-rmse:4.01898	val-rmse:10.1837	train-MAPE:0.123533	val-MAPE:0.229769
# [477]	train-rmse:4.0144	val-rmse:10.1842	train-MAPE:0.123378	val-MAPE:0.22977
# [478]	train-rmse:4.00796	val-rmse:10.1845	train-MAPE:0.123283	val-MAPE:0.22969
# [479]	train-rmse:4.00461	val-rmse:10.1848	train-MAPE:0.123077	val-MAPE:0.229716
# [480]	train-rmse:3.99643	val-rmse:10.1855	train-MAPE:0.122988	val-MAPE:0.229687
# [481]	train-rmse:3.99351	val-rmse:10.1848	train-MAPE:0.122925	val-MAPE:0.229688
# [482]	train-rmse:3.99064	val-rmse:10.1853	train-MAPE:0.122804	val-MAPE:0.229647
# [483]	train-rmse:3.97197	val-rmse:10.188	train-MAPE:0.12262	val-MAPE:0.22971
# [484]	train-rmse:3.96865	val-rmse:10.1897	train-MAPE:0.12253	val-MAPE:0.229693
# [485]	train-rmse:3.9555	val-rmse:10.1859	train-MAPE:0.122374	val-MAPE:0.229788
# [486]	train-rmse:3.94817	val-rmse:10.1874	train-MAPE:0.122326	val-MAPE:0.229834
# [487]	train-rmse:3.94607	val-rmse:10.1869	train-MAPE:0.122235	val-MAPE:0.229818
# [488]	train-rmse:3.93922	val-rmse:10.188	train-MAPE:0.122186	val-MAPE:0.229839
# [489]	train-rmse:3.92939	val-rmse:10.192	train-MAPE:0.12207	val-MAPE:0.229849
# [490]	train-rmse:3.91859	val-rmse:10.1945	train-MAPE:0.121928	val-MAPE:0.229809
# [491]	train-rmse:3.90674	val-rmse:10.1959	train-MAPE:0.12183	val-MAPE:0.2299
# [492]	train-rmse:3.89357	val-rmse:10.1952	train-MAPE:0.121648	val-MAPE:0.229892
# [493]	train-rmse:3.88413	val-rmse:10.1946	train-MAPE:0.121423	val-MAPE:0.229901
# [494]	train-rmse:3.87981	val-rmse:10.1942	train-MAPE:0.121099	val-MAPE:0.229907
# [495]	train-rmse:3.87051	val-rmse:10.1947	train-MAPE:0.121019	val-MAPE:0.230015
# [496]	train-rmse:3.8687	val-rmse:10.195	train-MAPE:0.120866	val-MAPE:0.230005
# [497]	train-rmse:3.8646	val-rmse:10.1955	train-MAPE:0.120561	val-MAPE:0.230044
# [498]	train-rmse:3.85471	val-rmse:10.1984	train-MAPE:0.120274	val-MAPE:0.229973
# [499]	train-rmse:3.84981	val-rmse:10.1981	train-MAPE:0.119935	val-MAPE:0.229973
# [500]	train-rmse:3.84675	val-rmse:10.1988	train-MAPE:0.119856	val-MAPE:0.229957
# [501]	train-rmse:3.83953	val-rmse:10.2016	train-MAPE:0.119628	val-MAPE:0.229966
# [502]	train-rmse:3.83564	val-rmse:10.2024	train-MAPE:0.119458	val-MAPE:0.229825
# [503]	train-rmse:3.82693	val-rmse:10.2037	train-MAPE:0.119369	val-MAPE:0.229925
# [504]	train-rmse:3.81701	val-rmse:10.2031	train-MAPE:0.119167	val-MAPE:0.229897
# [505]	train-rmse:3.81501	val-rmse:10.203	train-MAPE:0.119111	val-MAPE:0.22989
# [506]	train-rmse:3.80894	val-rmse:10.2018	train-MAPE:0.118962	val-MAPE:0.229847
# [507]	train-rmse:3.80219	val-rmse:10.2052	train-MAPE:0.118721	val-MAPE:0.230026
# [508]	train-rmse:3.79796	val-rmse:10.2059	train-MAPE:0.118396	val-MAPE:0.229922
# [509]	train-rmse:3.79273	val-rmse:10.2077	train-MAPE:0.118165	val-MAPE:0.23001
# [510]	train-rmse:3.78733	val-rmse:10.2086	train-MAPE:0.117989	val-MAPE:0.229943
# [511]	train-rmse:3.78221	val-rmse:10.2104	train-MAPE:0.117883	val-MAPE:0.229966
# [512]	train-rmse:3.77437	val-rmse:10.2135	train-MAPE:0.117738	val-MAPE:0.230049
# [513]	train-rmse:3.76856	val-rmse:10.2134	train-MAPE:0.117286	val-MAPE:0.229937
# [514]	train-rmse:3.75853	val-rmse:10.2123	train-MAPE:0.117172	val-MAPE:0.229907
# [515]	train-rmse:3.75666	val-rmse:10.2121	train-MAPE:0.117017	val-MAPE:0.229815
# [516]	train-rmse:3.7546	val-rmse:10.2131	train-MAPE:0.116953	val-MAPE:0.229801
# [517]	train-rmse:3.74939	val-rmse:10.2131	train-MAPE:0.116525	val-MAPE:0.229627
# [518]	train-rmse:3.74288	val-rmse:10.2156	train-MAPE:0.11644	val-MAPE:0.229646
# [519]	train-rmse:3.7369	val-rmse:10.2183	train-MAPE:0.11637	val-MAPE:0.229709
# [520]	train-rmse:3.72649	val-rmse:10.2196	train-MAPE:0.116217	val-MAPE:0.229775
# [521]	train-rmse:3.72234	val-rmse:10.2207	train-MAPE:0.116049	val-MAPE:0.229764
# [522]	train-rmse:3.71948	val-rmse:10.2205	train-MAPE:0.115511	val-MAPE:0.229726
# [523]	train-rmse:3.71164	val-rmse:10.2232	train-MAPE:0.115365	val-MAPE:0.229704
# [524]	train-rmse:3.7032	val-rmse:10.2256	train-MAPE:0.11509	val-MAPE:0.229688
# [525]	train-rmse:3.7004	val-rmse:10.2261	train-MAPE:0.115055	val-MAPE:0.229676
# [526]	train-rmse:3.69891	val-rmse:10.2267	train-MAPE:0.114999	val-MAPE:0.229659
# [527]	train-rmse:3.69048	val-rmse:10.225	train-MAPE:0.114856	val-MAPE:0.229699
# [528]	train-rmse:3.68363	val-rmse:10.2264	train-MAPE:0.114805	val-MAPE:0.229711
# [529]	train-rmse:3.681	val-rmse:10.2255	train-MAPE:0.114333	val-MAPE:0.229506
# [530]	train-rmse:3.67498	val-rmse:10.2254	train-MAPE:0.114174	val-MAPE:0.229464
# [531]	train-rmse:3.66629	val-rmse:10.2247	train-MAPE:0.114	val-MAPE:0.229435
# [532]	train-rmse:3.65825	val-rmse:10.2264	train-MAPE:0.11374	val-MAPE:0.229408
# [533]	train-rmse:3.65511	val-rmse:10.2276	train-MAPE:0.113632	val-MAPE:0.229369
# [534]	train-rmse:3.63977	val-rmse:10.2289	train-MAPE:0.113487	val-MAPE:0.229413
# [535]	train-rmse:3.63442	val-rmse:10.2288	train-MAPE:0.11348	val-MAPE:0.229505
# [536]	train-rmse:3.62598	val-rmse:10.2289	train-MAPE:0.113314	val-MAPE:0.229499
# [537]	train-rmse:3.61602	val-rmse:10.2302	train-MAPE:0.113178	val-MAPE:0.229553
# [538]	train-rmse:3.6085	val-rmse:10.2291	train-MAPE:0.113023	val-MAPE:0.229575
# [539]	train-rmse:3.60189	val-rmse:10.23	train-MAPE:0.112842	val-MAPE:0.229853
# [540]	train-rmse:3.59767	val-rmse:10.2289	train-MAPE:0.112535	val-MAPE:0.22976
# [541]	train-rmse:3.59154	val-rmse:10.2325	train-MAPE:0.112352	val-MAPE:0.229813
# [542]	train-rmse:3.58999	val-rmse:10.2341	train-MAPE:0.112275	val-MAPE:0.229811
# [543]	train-rmse:3.58341	val-rmse:10.2335	train-MAPE:0.112035	val-MAPE:0.229939
# [544]	train-rmse:3.57943	val-rmse:10.2335	train-MAPE:0.111697	val-MAPE:0.229801
# [545]	train-rmse:3.577	val-rmse:10.2342	train-MAPE:0.111573	val-MAPE:0.22984
# [546]	train-rmse:3.57494	val-rmse:10.2348	train-MAPE:0.111526	val-MAPE:0.229745
# [547]	train-rmse:3.57228	val-rmse:10.2368	train-MAPE:0.111447	val-MAPE:0.229762
# [548]	train-rmse:3.56676	val-rmse:10.2368	train-MAPE:0.111299	val-MAPE:0.229725
# [549]	train-rmse:3.5599	val-rmse:10.236	train-MAPE:0.11108	val-MAPE:0.229768
# [550]	train-rmse:3.55512	val-rmse:10.2361	train-MAPE:0.111082	val-MAPE:0.229869
# [551]	train-rmse:3.55393	val-rmse:10.2361	train-MAPE:0.11089	val-MAPE:0.22986
# [552]	train-rmse:3.54716	val-rmse:10.2397	train-MAPE:0.110805	val-MAPE:0.229794
# [553]	train-rmse:3.53868	val-rmse:10.2401	train-MAPE:0.110678	val-MAPE:0.229774
# [554]	train-rmse:3.53538	val-rmse:10.241	train-MAPE:0.110601	val-MAPE:0.229794
# [555]	train-rmse:3.53118	val-rmse:10.2401	train-MAPE:0.110491	val-MAPE:0.229875
# [556]	train-rmse:3.52661	val-rmse:10.2399	train-MAPE:0.110159	val-MAPE:0.22972
# [557]	train-rmse:3.52345	val-rmse:10.2401	train-MAPE:0.109746	val-MAPE:0.229642
# [558]	train-rmse:3.5153	val-rmse:10.2424	train-MAPE:0.109614	val-MAPE:0.229831
# [559]	train-rmse:3.51032	val-rmse:10.2428	train-MAPE:0.109535	val-MAPE:0.229762
# [560]	train-rmse:3.50223	val-rmse:10.2418	train-MAPE:0.109417	val-MAPE:0.229759
# [561]	train-rmse:3.49673	val-rmse:10.2433	train-MAPE:0.109238	val-MAPE:0.229738
# [562]	train-rmse:3.49424	val-rmse:10.244	train-MAPE:0.109028	val-MAPE:0.229769
# [563]	train-rmse:3.49374	val-rmse:10.2439	train-MAPE:0.108952	val-MAPE:0.229771
# [564]	train-rmse:3.4918	val-rmse:10.2445	train-MAPE:0.108912	val-MAPE:0.229685
# [565]	train-rmse:3.48857	val-rmse:10.2445	train-MAPE:0.108865	val-MAPE:0.229688
# [566]	train-rmse:3.48485	val-rmse:10.245	train-MAPE:0.108812	val-MAPE:0.229761
# [567]	train-rmse:3.48012	val-rmse:10.2459	train-MAPE:0.108739	val-MAPE:0.229745
# [568]	train-rmse:3.47215	val-rmse:10.2465	train-MAPE:0.108577	val-MAPE:0.229875
# [569]	train-rmse:3.46388	val-rmse:10.2449	train-MAPE:0.108444	val-MAPE:0.229811
# [570]	train-rmse:3.45771	val-rmse:10.2463	train-MAPE:0.108375	val-MAPE:0.229803
# [571]	train-rmse:3.45533	val-rmse:10.2463	train-MAPE:0.1079	val-MAPE:0.229741
# [572]	train-rmse:3.45351	val-rmse:10.2466	train-MAPE:0.107755	val-MAPE:0.229741
# [573]	train-rmse:3.44699	val-rmse:10.2455	train-MAPE:0.107589	val-MAPE:0.22974
# [574]	train-rmse:3.44521	val-rmse:10.2462	train-MAPE:0.107453	val-MAPE:0.229722
# [575]	train-rmse:3.43583	val-rmse:10.2457	train-MAPE:0.107359	val-MAPE:0.229719
# [576]	train-rmse:3.43334	val-rmse:10.2449	train-MAPE:0.106921	val-MAPE:0.229566
# [577]	train-rmse:3.42585	val-rmse:10.2423	train-MAPE:0.106809	val-MAPE:0.229458
# [578]	train-rmse:3.42073	val-rmse:10.2412	train-MAPE:0.10675	val-MAPE:0.229449
# [579]	train-rmse:3.41737	val-rmse:10.2406	train-MAPE:0.106367	val-MAPE:0.229448
# [580]	train-rmse:3.41095	val-rmse:10.2396	train-MAPE:0.106307	val-MAPE:0.229511
# [581]	train-rmse:3.40463	val-rmse:10.2405	train-MAPE:0.106144	val-MAPE:0.2297
# [582]	train-rmse:3.40367	val-rmse:10.2407	train-MAPE:0.106007	val-MAPE:0.229709
# [583]	train-rmse:3.39989	val-rmse:10.2391	train-MAPE:0.105785	val-MAPE:0.22972
# [584]	train-rmse:3.39805	val-rmse:10.2413	train-MAPE:0.10572	val-MAPE:0.229599
# [585]	train-rmse:3.39358	val-rmse:10.2437	train-MAPE:0.105621	val-MAPE:0.229662
# [586]	train-rmse:3.38948	val-rmse:10.2449	train-MAPE:0.105479	val-MAPE:0.229608
# [587]	train-rmse:3.38533	val-rmse:10.2474	train-MAPE:0.105405	val-MAPE:0.229687
# [588]	train-rmse:3.38267	val-rmse:10.2474	train-MAPE:0.104806	val-MAPE:0.229668
# [589]	train-rmse:3.37678	val-rmse:10.2486	train-MAPE:0.104703	val-MAPE:0.229606
# [590]	train-rmse:3.3699	val-rmse:10.2471	train-MAPE:0.104599	val-MAPE:0.229557
# [591]	train-rmse:3.36671	val-rmse:10.2467	train-MAPE:0.104237	val-MAPE:0.229599
# [592]	train-rmse:3.35543	val-rmse:10.2475	train-MAPE:0.10411	val-MAPE:0.229608
# [593]	train-rmse:3.35234	val-rmse:10.2496	train-MAPE:0.104034	val-MAPE:0.229656
# [594]	train-rmse:3.34982	val-rmse:10.2501	train-MAPE:0.103733	val-MAPE:0.229607
# [595]	train-rmse:3.34353	val-rmse:10.2509	train-MAPE:0.103578	val-MAPE:0.229844
# [596]	train-rmse:3.34182	val-rmse:10.2513	train-MAPE:0.10341	val-MAPE:0.229877
# [597]	train-rmse:3.33795	val-rmse:10.2536	train-MAPE:0.103324	val-MAPE:0.229941
# [598]	train-rmse:3.33593	val-rmse:10.2547	train-MAPE:0.103258	val-MAPE:0.229967
# [599]	train-rmse:3.33245	val-rmse:10.2536	train-MAPE:0.103054	val-MAPE:0.229764
# [600]	train-rmse:3.32986	val-rmse:10.2522	train-MAPE:0.102957	val-MAPE:0.229761
# [601]	train-rmse:3.32431	val-rmse:10.2525	train-MAPE:0.102834	val-MAPE:0.229686
# [602]	train-rmse:3.32297	val-rmse:10.2528	train-MAPE:0.102745	val-MAPE:0.229644
# [603]	train-rmse:3.31981	val-rmse:10.2526	train-MAPE:0.102617	val-MAPE:0.229613
# ...
# [800]	train-rmse:2.52408	val-rmse:10.3149	train-MAPE:0.079709	val-MAPE:0.22937
# [801]	train-rmse:2.52241	val-rmse:10.3159	train-MAPE:0.079638	val-MAPE:0.229385
# [802]	train-rmse:2.51837	val-rmse:10.3174	train-MAPE:0.079577	val-MAPE:0.229399
# [803]	train-rmse:2.51507	val-rmse:10.315	train-MAPE:0.079306	val-MAPE:0.229346
# [804]	train-rmse:2.51011	val-rmse:10.3153	train-MAPE:0.079154	val-MAPE:0.229359
# [805]	train-rmse:2.50902	val-rmse:10.3164	train-MAPE:0.079094	val-MAPE:0.229362
# [806]	train-rmse:2.50805	val-rmse:10.3162	train-MAPE:0.079007	val-MAPE:0.229365
# [807]	train-rmse:2.5044	val-rmse:10.3158	train-MAPE:0.079011	val-MAPE:0.229349
# [808]	train-rmse:2.50382	val-rmse:10.3162	train-MAPE:0.079005	val-MAPE:0.229368
# [809]	train-rmse:2.50093	val-rmse:10.3163	train-MAPE:0.078931	val-MAPE:0.229348
# [810]	train-rmse:2.4941	val-rmse:10.3198	train-MAPE:0.078671	val-MAPE:0.229455
# [811]	train-rmse:2.49122	val-rmse:10.3197	train-MAPE:0.078581	val-MAPE:0.229468
# [812]	train-rmse:2.48773	val-rmse:10.3214	train-MAPE:0.078559	val-MAPE:0.229478
# [813]	train-rmse:2.48548	val-rmse:10.3215	train-MAPE:0.078291	val-MAPE:0.229487
# [814]	train-rmse:2.48299	val-rmse:10.321	train-MAPE:0.078095	val-MAPE:0.229428
# [815]	train-rmse:2.48004	val-rmse:10.3214	train-MAPE:0.077941	val-MAPE:0.229433
# [816]	train-rmse:2.47842	val-rmse:10.322	train-MAPE:0.077903	val-MAPE:0.229468
# [817]	train-rmse:2.47618	val-rmse:10.3225	train-MAPE:0.077773	val-MAPE:0.229506
# [818]	train-rmse:2.47438	val-rmse:10.3216	train-MAPE:0.077657	val-MAPE:0.229461
# [819]	train-rmse:2.47111	val-rmse:10.3239	train-MAPE:0.077637	val-MAPE:0.229478
# [820]	train-rmse:2.46857	val-rmse:10.3243	train-MAPE:0.077565	val-MAPE:0.229493
# [821]	train-rmse:2.46456	val-rmse:10.3244	train-MAPE:0.077459	val-MAPE:0.229467
# [822]	train-rmse:2.4621	val-rmse:10.3239	train-MAPE:0.077204	val-MAPE:0.229437
# [823]	train-rmse:2.45357	val-rmse:10.3263	train-MAPE:0.077164	val-MAPE:0.22945
# [824]	train-rmse:2.45062	val-rmse:10.3258	train-MAPE:0.077092	val-MAPE:0.229504
# [825]	train-rmse:2.44941	val-rmse:10.3254	train-MAPE:0.076974	val-MAPE:0.229469
# [826]	train-rmse:2.44571	val-rmse:10.3266	train-MAPE:0.076868	val-MAPE:0.229466
# [827]	train-rmse:2.44402	val-rmse:10.3263	train-MAPE:0.076728	val-MAPE:0.229479
# [828]	train-rmse:2.44321	val-rmse:10.3272	train-MAPE:0.07666	val-MAPE:0.229468
# [829]	train-rmse:2.44247	val-rmse:10.326	train-MAPE:0.076637	val-MAPE:0.229394
# [830]	train-rmse:2.43875	val-rmse:10.3265	train-MAPE:0.076537	val-MAPE:0.229394
# [831]	train-rmse:2.43649	val-rmse:10.3271	train-MAPE:0.076466	val-MAPE:0.229423
# [832]	train-rmse:2.43409	val-rmse:10.3264	train-MAPE:0.076308	val-MAPE:0.229459
# [833]	train-rmse:2.43015	val-rmse:10.3265	train-MAPE:0.076278	val-MAPE:0.229474
# [834]	train-rmse:2.42328	val-rmse:10.3285	train-MAPE:0.076215	val-MAPE:0.229489
# [835]	train-rmse:2.42054	val-rmse:10.3291	train-MAPE:0.076149	val-MAPE:0.229528
# [836]	train-rmse:2.41861	val-rmse:10.3294	train-MAPE:0.076087	val-MAPE:0.229527
# [837]	train-rmse:2.4155	val-rmse:10.3292	train-MAPE:0.076012	val-MAPE:0.229552
# [838]	train-rmse:2.41508	val-rmse:10.3288	train-MAPE:0.076002	val-MAPE:0.229553
# [839]	train-rmse:2.41235	val-rmse:10.3283	train-MAPE:0.075949	val-MAPE:0.229505
# [840]	train-rmse:2.41035	val-rmse:10.3279	train-MAPE:0.075925	val-MAPE:0.229508
# [841]	train-rmse:2.40926	val-rmse:10.328	train-MAPE:0.07591	val-MAPE:0.229522
# [842]	train-rmse:2.40819	val-rmse:10.3283	train-MAPE:0.075835	val-MAPE:0.229483
# [843]	train-rmse:2.40343	val-rmse:10.3301	train-MAPE:0.07582	val-MAPE:0.229562
# [844]	train-rmse:2.39973	val-rmse:10.3313	train-MAPE:0.0757	val-MAPE:0.229596
# [845]	train-rmse:2.39628	val-rmse:10.3318	train-MAPE:0.07566	val-MAPE:0.229599
# [846]	train-rmse:2.3936	val-rmse:10.3321	train-MAPE:0.075566	val-MAPE:0.229668
# [847]	train-rmse:2.38983	val-rmse:10.3341	train-MAPE:0.075441	val-MAPE:0.229645
# [848]	train-rmse:2.38728	val-rmse:10.333	train-MAPE:0.075194	val-MAPE:0.229586
# [849]	train-rmse:2.38461	val-rmse:10.3326	train-MAPE:0.07509	val-MAPE:0.229627
# [850]	train-rmse:2.38393	val-rmse:10.3332	train-MAPE:0.075036	val-MAPE:0.229611
# [851]	train-rmse:2.38246	val-rmse:10.334	train-MAPE:0.074995	val-MAPE:0.229587
# [852]	train-rmse:2.3797	val-rmse:10.3339	train-MAPE:0.07479	val-MAPE:0.229701
# [853]	train-rmse:2.37428	val-rmse:10.3326	train-MAPE:0.074745	val-MAPE:0.229617
# [854]	train-rmse:2.37052	val-rmse:10.3321	train-MAPE:0.074706	val-MAPE:0.229622
# [855]	train-rmse:2.3688	val-rmse:10.3325	train-MAPE:0.074686	val-MAPE:0.229642
# [856]	train-rmse:2.36426	val-rmse:10.3328	train-MAPE:0.074622	val-MAPE:0.229644
# [857]	train-rmse:2.36091	val-rmse:10.3333	train-MAPE:0.074576	val-MAPE:0.229646
# [858]	train-rmse:2.3605	val-rmse:10.3332	train-MAPE:0.07456	val-MAPE:0.229647
# [859]	train-rmse:2.35539	val-rmse:10.3335	train-MAPE:0.074469	val-MAPE:0.229602
# [860]	train-rmse:2.3484	val-rmse:10.3345	train-MAPE:0.074366	val-MAPE:0.229669
# [861]	train-rmse:2.34671	val-rmse:10.3346	train-MAPE:0.074329	val-MAPE:0.229668
# [862]	train-rmse:2.34025	val-rmse:10.3358	train-MAPE:0.074205	val-MAPE:0.229736
# [863]	train-rmse:2.33498	val-rmse:10.3343	train-MAPE:0.074134	val-MAPE:0.229669
# [864]	train-rmse:2.32886	val-rmse:10.3349	train-MAPE:0.073971	val-MAPE:0.22973
# [865]	train-rmse:2.32423	val-rmse:10.3346	train-MAPE:0.073816	val-MAPE:0.229609
# [866]	train-rmse:2.31825	val-rmse:10.3368	train-MAPE:0.073698	val-MAPE:0.229619
# [867]	train-rmse:2.31345	val-rmse:10.3369	train-MAPE:0.073658	val-MAPE:0.229671
# [868]	train-rmse:2.30895	val-rmse:10.3365	train-MAPE:0.073554	val-MAPE:0.229672
# [869]	train-rmse:2.30293	val-rmse:10.3372	train-MAPE:0.073485	val-MAPE:0.22959
# [870]	train-rmse:2.29877	val-rmse:10.3355	train-MAPE:0.073412	val-MAPE:0.22946
# [871]	train-rmse:2.29457	val-rmse:10.3356	train-MAPE:0.073296	val-MAPE:0.229463
# [872]	train-rmse:2.28937	val-rmse:10.3342	train-MAPE:0.073162	val-MAPE:0.229441
# [873]	train-rmse:2.28861	val-rmse:10.3343	train-MAPE:0.07311	val-MAPE:0.229385
# [874]	train-rmse:2.28818	val-rmse:10.3345	train-MAPE:0.073103	val-MAPE:0.229397
# [875]	train-rmse:2.28779	val-rmse:10.3346	train-MAPE:0.073111	val-MAPE:0.229423
# [876]	train-rmse:2.28386	val-rmse:10.3342	train-MAPE:0.073021	val-MAPE:0.229437
# [877]	train-rmse:2.28353	val-rmse:10.3343	train-MAPE:0.072986	val-MAPE:0.229426
# [878]	train-rmse:2.28322	val-rmse:10.3343	train-MAPE:0.072958	val-MAPE:0.229413
# [879]	train-rmse:2.27795	val-rmse:10.3349	train-MAPE:0.072843	val-MAPE:0.229429
# [880]	train-rmse:2.27586	val-rmse:10.3336	train-MAPE:0.07266	val-MAPE:0.229431
# [881]	train-rmse:2.27434	val-rmse:10.3331	train-MAPE:0.072637	val-MAPE:0.229429
# [882]	train-rmse:2.27294	val-rmse:10.3328	train-MAPE:0.072487	val-MAPE:0.229209
# [883]	train-rmse:2.26974	val-rmse:10.3337	train-MAPE:0.072406	val-MAPE:0.229201
# [884]	train-rmse:2.26514	val-rmse:10.3322	train-MAPE:0.072366	val-MAPE:0.229144
# [885]	train-rmse:2.25999	val-rmse:10.334	train-MAPE:0.072314	val-MAPE:0.229199
# [886]	train-rmse:2.25805	val-rmse:10.3345	train-MAPE:0.072277	val-MAPE:0.22924
# [887]	train-rmse:2.25745	val-rmse:10.3352	train-MAPE:0.072245	val-MAPE:0.229278
# [888]	train-rmse:2.25348	val-rmse:10.3363	train-MAPE:0.072084	val-MAPE:0.229399
# [889]	train-rmse:2.24893	val-rmse:10.3356	train-MAPE:0.072022	val-MAPE:0.229285
# [890]	train-rmse:2.24862	val-rmse:10.3356	train-MAPE:0.071989	val-MAPE:0.229274
# [891]	train-rmse:2.24473	val-rmse:10.3345	train-MAPE:0.071917	val-MAPE:0.229369
# [892]	train-rmse:2.24272	val-rmse:10.3335	train-MAPE:0.071758	val-MAPE:0.229343
# [893]	train-rmse:2.24113	val-rmse:10.3333	train-MAPE:0.071723	val-MAPE:0.229343
# [894]	train-rmse:2.2397	val-rmse:10.3333	train-MAPE:0.071685	val-MAPE:0.229324
# [895]	train-rmse:2.23931	val-rmse:10.3328	train-MAPE:0.071665	val-MAPE:0.229322
# [896]	train-rmse:2.23861	val-rmse:10.3331	train-MAPE:0.071628	val-MAPE:0.229269
# [897]	train-rmse:2.23757	val-rmse:10.3332	train-MAPE:0.071554	val-MAPE:0.229268
# [898]	train-rmse:2.23717	val-rmse:10.3333	train-MAPE:0.071548	val-MAPE:0.22928
# [899]	train-rmse:2.23436	val-rmse:10.334	train-MAPE:0.071332	val-MAPE:0.2293
# [900]	train-rmse:2.23258	val-rmse:10.3334	train-MAPE:0.071188	val-MAPE:0.229073
# [901]	train-rmse:2.22747	val-rmse:10.3344	train-MAPE:0.070996	val-MAPE:0.229126
# [902]	train-rmse:2.22701	val-rmse:10.3339	train-MAPE:0.070994	val-MAPE:0.229125
# [903]	train-rmse:2.22545	val-rmse:10.3337	train-MAPE:0.070753	val-MAPE:0.22917
# [904]	train-rmse:2.2251	val-rmse:10.333	train-MAPE:0.070737	val-MAPE:0.229167
# [905]	train-rmse:2.22352	val-rmse:10.3341	train-MAPE:0.070719	val-MAPE:0.229154
# [906]	train-rmse:2.21943	val-rmse:10.3341	train-MAPE:0.070661	val-MAPE:0.229158
# [907]	train-rmse:2.21889	val-rmse:10.3335	train-MAPE:0.070643	val-MAPE:0.229156
# [908]	train-rmse:2.21461	val-rmse:10.3338	train-MAPE:0.070626	val-MAPE:0.229211
# [909]	train-rmse:2.2125	val-rmse:10.3353	train-MAPE:0.07052	val-MAPE:0.229339
# [910]	train-rmse:2.20946	val-rmse:10.3353	train-MAPE:0.07037	val-MAPE:0.22951
# [911]	train-rmse:2.20602	val-rmse:10.335	train-MAPE:0.070327	val-MAPE:0.229526
# [912]	train-rmse:2.20489	val-rmse:10.3348	train-MAPE:0.07021	val-MAPE:0.229534
# [913]	train-rmse:2.20065	val-rmse:10.3355	train-MAPE:0.070126	val-MAPE:0.229547
# [914]	train-rmse:2.19767	val-rmse:10.3356	train-MAPE:0.070054	val-MAPE:0.229512
# [915]	train-rmse:2.19306	val-rmse:10.3368	train-MAPE:0.069888	val-MAPE:0.229501
# [916]	train-rmse:2.19277	val-rmse:10.3368	train-MAPE:0.069854	val-MAPE:0.2295
# [917]	train-rmse:2.18848	val-rmse:10.3359	train-MAPE:0.069747	val-MAPE:0.229508
# [918]	train-rmse:2.18738	val-rmse:10.3353	train-MAPE:0.069608	val-MAPE:0.229309
# [919]	train-rmse:2.18399	val-rmse:10.3342	train-MAPE:0.069557	val-MAPE:0.229353
# [920]	train-rmse:2.18056	val-rmse:10.3337	train-MAPE:0.069489	val-MAPE:0.229371
# [921]	train-rmse:2.17689	val-rmse:10.3348	train-MAPE:0.069387	val-MAPE:0.229418
# [922]	train-rmse:2.17226	val-rmse:10.3363	train-MAPE:0.069338	val-MAPE:0.229454
# [923]	train-rmse:2.17198	val-rmse:10.3364	train-MAPE:0.069308	val-MAPE:0.229444
# [924]	train-rmse:2.16676	val-rmse:10.3345	train-MAPE:0.069229	val-MAPE:0.229397
# [925]	train-rmse:2.1633	val-rmse:10.3355	train-MAPE:0.069122	val-MAPE:0.229428
# [926]	train-rmse:2.15907	val-rmse:10.3358	train-MAPE:0.068949	val-MAPE:0.229514
# [927]	train-rmse:2.15203	val-rmse:10.3361	train-MAPE:0.068833	val-MAPE:0.229557
# [928]	train-rmse:2.15177	val-rmse:10.3362	train-MAPE:0.06881	val-MAPE:0.22954
# [929]	train-rmse:2.14987	val-rmse:10.3367	train-MAPE:0.068607	val-MAPE:0.229573
# [930]	train-rmse:2.14789	val-rmse:10.3364	train-MAPE:0.068525	val-MAPE:0.229515
# [931]	train-rmse:2.14372	val-rmse:10.3383	train-MAPE:0.06848	val-MAPE:0.229537
# [932]	train-rmse:2.13952	val-rmse:10.3382	train-MAPE:0.068389	val-MAPE:0.229572
# [933]	train-rmse:2.13751	val-rmse:10.3376	train-MAPE:0.068184	val-MAPE:0.229522
# [934]	train-rmse:2.13366	val-rmse:10.3387	train-MAPE:0.068044	val-MAPE:0.229492
# [935]	train-rmse:2.13169	val-rmse:10.3393	train-MAPE:0.067976	val-MAPE:0.229528
# [936]	train-rmse:2.12718	val-rmse:10.3373	train-MAPE:0.067949	val-MAPE:0.229516
# [937]	train-rmse:2.12426	val-rmse:10.3377	train-MAPE:0.067863	val-MAPE:0.229448
# [938]	train-rmse:2.12242	val-rmse:10.3376	train-MAPE:0.067677	val-MAPE:0.229456
# [939]	train-rmse:2.11622	val-rmse:10.3375	train-MAPE:0.067598	val-MAPE:0.229444
# [940]	train-rmse:2.11388	val-rmse:10.3375	train-MAPE:0.067535	val-MAPE:0.229453
# [941]	train-rmse:2.10848	val-rmse:10.338	train-MAPE:0.067447	val-MAPE:0.229465
# [942]	train-rmse:2.10663	val-rmse:10.3386	train-MAPE:0.067388	val-MAPE:0.229503
# [943]	train-rmse:2.10235	val-rmse:10.34	train-MAPE:0.067229	val-MAPE:0.229525
# [944]	train-rmse:2.1006	val-rmse:10.3396	train-MAPE:0.06708	val-MAPE:0.229576
# [945]	train-rmse:2.09893	val-rmse:10.3401	train-MAPE:0.067005	val-MAPE:0.229596
# [946]	train-rmse:2.09843	val-rmse:10.3394	train-MAPE:0.066993	val-MAPE:0.229603
# [947]	train-rmse:2.09477	val-rmse:10.3392	train-MAPE:0.066964	val-MAPE:0.229603
# [948]	train-rmse:2.09265	val-rmse:10.3388	train-MAPE:0.066869	val-MAPE:0.229556
# [949]	train-rmse:2.09046	val-rmse:10.3392	train-MAPE:0.066841	val-MAPE:0.229586
# [950]	train-rmse:2.08712	val-rmse:10.3396	train-MAPE:0.066748	val-MAPE:0.229594
# [951]	train-rmse:2.08449	val-rmse:10.3393	train-MAPE:0.066656	val-MAPE:0.229577
# [952]	train-rmse:2.08079	val-rmse:10.3402	train-MAPE:0.066587	val-MAPE:0.229577
# [953]	train-rmse:2.07864	val-rmse:10.3403	train-MAPE:0.066549	val-MAPE:0.229603
# [954]	train-rmse:2.07585	val-rmse:10.3413	train-MAPE:0.066535	val-MAPE:0.229612
# [955]	train-rmse:2.07431	val-rmse:10.3419	train-MAPE:0.066485	val-MAPE:0.229626
# [956]	train-rmse:2.06948	val-rmse:10.3413	train-MAPE:0.066372	val-MAPE:0.229749
# [957]	train-rmse:2.06735	val-rmse:10.3427	train-MAPE:0.066338	val-MAPE:0.229761
# [958]	train-rmse:2.06374	val-rmse:10.3419	train-MAPE:0.066079	val-MAPE:0.229586
# [959]	train-rmse:2.06038	val-rmse:10.3418	train-MAPE:0.065967	val-MAPE:0.229606
# [960]	train-rmse:2.05796	val-rmse:10.3425	train-MAPE:0.065794	val-MAPE:0.229655
# [961]	train-rmse:2.0557	val-rmse:10.3428	train-MAPE:0.065586	val-MAPE:0.229698
# [962]	train-rmse:2.05199	val-rmse:10.3433	train-MAPE:0.065558	val-MAPE:0.22973
# [963]	train-rmse:2.0506	val-rmse:10.3437	train-MAPE:0.06547	val-MAPE:0.229716
# [964]	train-rmse:2.04836	val-rmse:10.3443	train-MAPE:0.065294	val-MAPE:0.229563
# [965]	train-rmse:2.04559	val-rmse:10.3432	train-MAPE:0.065142	val-MAPE:0.229558
# [966]	train-rmse:2.04356	val-rmse:10.344	train-MAPE:0.065108	val-MAPE:0.229556
# [967]	train-rmse:2.04142	val-rmse:10.3446	train-MAPE:0.065055	val-MAPE:0.229549
# [968]	train-rmse:2.03922	val-rmse:10.3441	train-MAPE:0.064997	val-MAPE:0.229542
# [969]	train-rmse:2.03508	val-rmse:10.3458	train-MAPE:0.064898	val-MAPE:0.229569
# [970]	train-rmse:2.03363	val-rmse:10.3465	train-MAPE:0.064865	val-MAPE:0.229584
# [971]	train-rmse:2.0334	val-rmse:10.3466	train-MAPE:0.064845	val-MAPE:0.229578
# [972]	train-rmse:2.0314	val-rmse:10.3461	train-MAPE:0.064664	val-MAPE:0.229617
# [973]	train-rmse:2.02959	val-rmse:10.3471	train-MAPE:0.064604	val-MAPE:0.22962
# [974]	train-rmse:2.02492	val-rmse:10.3479	train-MAPE:0.064587	val-MAPE:0.229651
# [975]	train-rmse:2.02421	val-rmse:10.348	train-MAPE:0.064545	val-MAPE:0.229663
# [976]	train-rmse:2.02074	val-rmse:10.3491	train-MAPE:0.06451	val-MAPE:0.229653
# [977]	train-rmse:2.01871	val-rmse:10.3483	train-MAPE:0.064414	val-MAPE:0.229601
# [978]	train-rmse:2.01667	val-rmse:10.3482	train-MAPE:0.06433	val-MAPE:0.229552
# [979]	train-rmse:2.01485	val-rmse:10.3484	train-MAPE:0.064268	val-MAPE:0.229545
# [980]	train-rmse:2.01351	val-rmse:10.3481	train-MAPE:0.064254	val-MAPE:0.229556
# [981]	train-rmse:2.00905	val-rmse:10.3503	train-MAPE:0.064216	val-MAPE:0.229584
# [982]	train-rmse:2.0077	val-rmse:10.3507	train-MAPE:0.064189	val-MAPE:0.229607
# [983]	train-rmse:2.00748	val-rmse:10.3507	train-MAPE:0.064171	val-MAPE:0.229585
# [984]	train-rmse:2.00647	val-rmse:10.3505	train-MAPE:0.063993	val-MAPE:0.229452
# [985]	train-rmse:2.00482	val-rmse:10.3512	train-MAPE:0.06393	val-MAPE:0.22949
# [986]	train-rmse:2.00276	val-rmse:10.3507	train-MAPE:0.063867	val-MAPE:0.229491
# [987]	train-rmse:2.00087	val-rmse:10.3502	train-MAPE:0.063784	val-MAPE:0.229429
# [988]	train-rmse:1.99981	val-rmse:10.35	train-MAPE:0.063738	val-MAPE:0.229427
# [989]	train-rmse:1.9963	val-rmse:10.3498	train-MAPE:0.063636	val-MAPE:0.229404
# [990]	train-rmse:1.99185	val-rmse:10.3513	train-MAPE:0.063613	val-MAPE:0.229418
# [991]	train-rmse:1.99052	val-rmse:10.3522	train-MAPE:0.063593	val-MAPE:0.229435
# [992]	train-rmse:1.98928	val-rmse:10.3523	train-MAPE:0.063566	val-MAPE:0.229456
# [993]	train-rmse:1.98568	val-rmse:10.3526	train-MAPE:0.063345	val-MAPE:0.229356
# [994]	train-rmse:1.98395	val-rmse:10.3526	train-MAPE:0.063148	val-MAPE:0.229302
# [995]	train-rmse:1.98256	val-rmse:10.3523	train-MAPE:0.063016	val-MAPE:0.229133
# [996]	train-rmse:1.98161	val-rmse:10.3521	train-MAPE:0.06289	val-MAPE:0.229139
# [997]	train-rmse:1.97831	val-rmse:10.3534	train-MAPE:0.062828	val-MAPE:0.229201
# [998]	train-rmse:1.9734	val-rmse:10.3551	train-MAPE:0.062785	val-MAPE:0.229312
# [999]	train-rmse:1.9706	val-rmse:10.3557	train-MAPE:0.062759	val-MAPE:0.229345
# best best_ntree_limit 1000

# %% [markdown]
# #### V20

# %%
# 分割训练集验证集
X_train, X_val, y_train, y_val = train_test_split(V20_train.iloc[:,1:], V20_train.iloc[:,0], test_size=0.2, random_state=5)

# 转化格式
volume_train = xgb.DMatrix(X_train, label=y_train)
volume_val = xgb.DMatrix(X_val, label=y_val)
volume_test = xgb.DMatrix(V20_test)

#参数设置
params = {
    'booster':'gbtree',      #gbtree和gblinear
    'objective':'reg:linear',
    'eta':0.04,             #为了防止过拟合，更新过程中用到的收缩步长。在每次提升计算之后，算法会直接获得新特征的权重。eta通过缩减特征的权重使提升计算过程更加保守。缺省值为0.3,通常最后设置eta为0.01~0.2
    #'gamma':0.3,            #模型在默认情况下，对于一个节点的划分只有在其loss function得到结果大于0的情况下才进行，而gamma 给定了所需的最低loss function的值gamma值使得算法更conservation，且其值依赖于loss function ，
    'max_depth':5,          #树的深度越大，则对数据的拟合程度越高（过拟合程度也越高）。即该参数也是控制过拟合,建议通过交叉验证（xgb.cv ) 进行调参,通常取值：3-10
    #'min_child_weight':2,   #孩子节点中最小的样本权重和。如果一个叶子节点的样本权重和小于min_child_weight则拆分过程结束。在现行回归模型中，这个参数是指建立每个模型所需要的最小样本数。该成熟越大算法越conservative。即调大这个参数能够控制过拟合。
    #'max_delta_step':2,     #如果取值为0，那么意味着无限制。如果取为正数，则其使得xgboost更新过程更加保守。
    'subsample':1,          #用于训练模型的子样本占整个样本集合的比例。如果设置为0.5则意味着XGBoost将随机的从整个样本集合中抽取出50%的子样本建立树模型，这能够防止过拟合。
    'colsample_bytree':1,   #在建立树时对特征随机采样的比例。缺省值为1 
    #'alpha':5,              #L1 正则的惩罚系数,当数据维度极高时可以使用，使得算法运行更快。
    #'lambda':40,           #L2 正则的惩罚系数,用于处理XGBoost的正则化部分。通常不使用，但可以用来降低过拟合
    'seed':2017,
}


plst = list(params.items())
num_rounds = 60
watchlist = [(volume_train, 'train'), (volume_val, 'val')]

V20volume_model = xgb.train(plst, volume_train, num_rounds, watchlist, feval=MAPE)
print("best best_ntree_limit", V20volume_model.best_ntree_limit)

V20volume_predict = V20volume_model.predict(volume_test)
# Out:
# [0]	train-rmse:48.1394	val-rmse:47.5372	train-MAPE:0.855496	val-MAPE:0.85166
# [1]	train-rmse:46.3015	val-rmse:45.719	train-MAPE:0.816632	val-MAPE:0.811286
# [2]	train-rmse:44.5375	val-rmse:44.005	train-MAPE:0.780418	val-MAPE:0.773629
# [3]	train-rmse:42.8429	val-rmse:42.3541	train-MAPE:0.746686	val-MAPE:0.73822
# [4]	train-rmse:41.2186	val-rmse:40.7769	train-MAPE:0.716459	val-MAPE:0.706608
# [5]	train-rmse:39.6621	val-rmse:39.2522	train-MAPE:0.687205	val-MAPE:0.676049
# [6]	train-rmse:38.1655	val-rmse:37.8002	train-MAPE:0.659602	val-MAPE:0.647632
# [7]	train-rmse:36.7324	val-rmse:36.4314	train-MAPE:0.634239	val-MAPE:0.620968
# [8]	train-rmse:35.3563	val-rmse:35.0929	train-MAPE:0.610757	val-MAPE:0.595841
# [9]	train-rmse:34.0364	val-rmse:33.8171	train-MAPE:0.588562	val-MAPE:0.572457
# [10]	train-rmse:32.7721	val-rmse:32.589	train-MAPE:0.567436	val-MAPE:0.549763
# [11]	train-rmse:31.5595	val-rmse:31.4147	train-MAPE:0.548144	val-MAPE:0.529091
# [12]	train-rmse:30.3981	val-rmse:30.2715	train-MAPE:0.529104	val-MAPE:0.50782
# [13]	train-rmse:29.282	val-rmse:29.2108	train-MAPE:0.510516	val-MAPE:0.488963
# [14]	train-rmse:28.2129	val-rmse:28.1774	train-MAPE:0.493594	val-MAPE:0.470496
# [15]	train-rmse:27.1913	val-rmse:27.1819	train-MAPE:0.477507	val-MAPE:0.453264
# [16]	train-rmse:26.2094	val-rmse:26.2286	train-MAPE:0.463681	val-MAPE:0.439029
# [17]	train-rmse:25.27	val-rmse:25.3238	train-MAPE:0.450528	val-MAPE:0.42509
# [18]	train-rmse:24.3682	val-rmse:24.459	train-MAPE:0.438196	val-MAPE:0.413188
# [19]	train-rmse:23.5084	val-rmse:23.6264	train-MAPE:0.425137	val-MAPE:0.400302
# [20]	train-rmse:22.6824	val-rmse:22.836	train-MAPE:0.414339	val-MAPE:0.389633
# [21]	train-rmse:21.8935	val-rmse:22.0818	train-MAPE:0.404036	val-MAPE:0.380042
# [22]	train-rmse:21.14	val-rmse:21.3551	train-MAPE:0.393016	val-MAPE:0.36959
# [23]	train-rmse:20.4159	val-rmse:20.6716	train-MAPE:0.384031	val-MAPE:0.360955
# [24]	train-rmse:19.7254	val-rmse:20.0176	train-MAPE:0.374506	val-MAPE:0.352078
# [25]	train-rmse:19.0623	val-rmse:19.391	train-MAPE:0.366495	val-MAPE:0.3449
# [26]	train-rmse:18.4283	val-rmse:18.7928	train-MAPE:0.358275	val-MAPE:0.33768
# [27]	train-rmse:17.8219	val-rmse:18.2364	train-MAPE:0.350194	val-MAPE:0.33128
# [28]	train-rmse:17.2433	val-rmse:17.6896	train-MAPE:0.343941	val-MAPE:0.325949
# [29]	train-rmse:16.69	val-rmse:17.1836	train-MAPE:0.337495	val-MAPE:0.32067
# [30]	train-rmse:16.16	val-rmse:16.6882	train-MAPE:0.330941	val-MAPE:0.315248
# [31]	train-rmse:15.6572	val-rmse:16.2217	train-MAPE:0.325763	val-MAPE:0.31117
# [32]	train-rmse:15.1743	val-rmse:15.792	train-MAPE:0.320232	val-MAPE:0.306721
# [33]	train-rmse:14.7145	val-rmse:15.3761	train-MAPE:0.315308	val-MAPE:0.302514
# [34]	train-rmse:14.2706	val-rmse:14.9692	train-MAPE:0.311445	val-MAPE:0.298705
# [35]	train-rmse:13.8536	val-rmse:14.5813	train-MAPE:0.30654	val-MAPE:0.294446
# [36]	train-rmse:13.4501	val-rmse:14.2109	train-MAPE:0.303303	val-MAPE:0.291337
# [37]	train-rmse:13.0735	val-rmse:13.8602	train-MAPE:0.299474	val-MAPE:0.288194
# [38]	train-rmse:12.7095	val-rmse:13.532	train-MAPE:0.297034	val-MAPE:0.286474
# [39]	train-rmse:12.3608	val-rmse:13.2212	train-MAPE:0.294185	val-MAPE:0.284171
# [40]	train-rmse:12.0297	val-rmse:12.9297	train-MAPE:0.289841	val-MAPE:0.281185
# [41]	train-rmse:11.7094	val-rmse:12.6583	train-MAPE:0.287301	val-MAPE:0.279345
# [42]	train-rmse:11.4043	val-rmse:12.4019	train-MAPE:0.285149	val-MAPE:0.27814
# [43]	train-rmse:11.1186	val-rmse:12.1588	train-MAPE:0.281533	val-MAPE:0.275743
# [44]	train-rmse:10.8462	val-rmse:11.9282	train-MAPE:0.278503	val-MAPE:0.273161
# [45]	train-rmse:10.5902	val-rmse:11.712	train-MAPE:0.275514	val-MAPE:0.271167
# [46]	train-rmse:10.3428	val-rmse:11.5031	train-MAPE:0.272861	val-MAPE:0.268829
# [47]	train-rmse:10.1038	val-rmse:11.3141	train-MAPE:0.269965	val-MAPE:0.26653
# [48]	train-rmse:9.88372	val-rmse:11.134	train-MAPE:0.268197	val-MAPE:0.265781
# [49]	train-rmse:9.67104	val-rmse:10.964	train-MAPE:0.266031	val-MAPE:0.263979
# [50]	train-rmse:9.46579	val-rmse:10.8037	train-MAPE:0.263468	val-MAPE:0.262223
# [51]	train-rmse:9.27942	val-rmse:10.6576	train-MAPE:0.261916	val-MAPE:0.261943
# [52]	train-rmse:9.09871	val-rmse:10.5115	train-MAPE:0.259611	val-MAPE:0.260131
# [53]	train-rmse:8.92899	val-rmse:10.3779	train-MAPE:0.258627	val-MAPE:0.260669
# [54]	train-rmse:8.76451	val-rmse:10.2474	train-MAPE:0.256996	val-MAPE:0.259201
# [55]	train-rmse:8.60921	val-rmse:10.1363	train-MAPE:0.255074	val-MAPE:0.257841
# [56]	train-rmse:8.46545	val-rmse:10.0243	train-MAPE:0.254882	val-MAPE:0.258256
# [57]	train-rmse:8.32591	val-rmse:9.92529	train-MAPE:0.254824	val-MAPE:0.258673
# [58]	train-rmse:8.19493	val-rmse:9.82831	train-MAPE:0.253923	val-MAPE:0.258088
# [59]	train-rmse:8.07361	val-rmse:9.74142	train-MAPE:0.253959	val-MAPE:0.258868
# best best_ntree_limit 60

# %% [markdown]
# #### V30

# %%
# 分割训练集验证集
X_train, X_val, y_train, y_val = train_test_split(V30_train.iloc[:,1:], V30_train.iloc[:,0], test_size=0.2, random_state=5)

# 转化格式
volume_train = xgb.DMatrix(X_train, label=y_train)
volume_val = xgb.DMatrix(X_val, label=y_val)
volume_test = xgb.DMatrix(V30_test)

#参数设置
params = {
    'booster':'gbtree',      #gbtree和gblinear
    'objective':'reg:linear',
    'eta':0.04,             #为了防止过拟合，更新过程中用到的收缩步长。在每次提升计算之后，算法会直接获得新特征的权重。eta通过缩减特征的权重使提升计算过程更加保守。缺省值为0.3,通常最后设置eta为0.01~0.2
    #'gamma':0.3,            #模型在默认情况下，对于一个节点的划分只有在其loss function得到结果大于0的情况下才进行，而gamma 给定了所需的最低loss function的值gamma值使得算法更conservation，且其值依赖于loss function ，
    'max_depth':5,          #树的深度越大，则对数据的拟合程度越高（过拟合程度也越高）。即该参数也是控制过拟合,建议通过交叉验证（xgb.cv ) 进行调参,通常取值：3-10
    #'min_child_weight':2,   #孩子节点中最小的样本权重和。如果一个叶子节点的样本权重和小于min_child_weight则拆分过程结束。在现行回归模型中，这个参数是指建立每个模型所需要的最小样本数。该成熟越大算法越conservative。即调大这个参数能够控制过拟合。
    #'max_delta_step':2,     #如果取值为0，那么意味着无限制。如果取为正数，则其使得xgboost更新过程更加保守。
    'subsample':1,          #用于训练模型的子样本占整个样本集合的比例。如果设置为0.5则意味着XGBoost将随机的从整个样本集合中抽取出50%的子样本建立树模型，这能够防止过拟合。
    'colsample_bytree':1,   #在建立树时对特征随机采样的比例。缺省值为1 
    #'alpha':5,              #L1 正则的惩罚系数,当数据维度极高时可以使用，使得算法运行更快。
    #'lambda':40,           #L2 正则的惩罚系数,用于处理XGBoost的正则化部分。通常不使用，但可以用来降低过拟合
    'seed':2017,
}


plst = list(params.items())
num_rounds = 85
watchlist = [(volume_train, 'train'), (volume_val, 'val')]

V30volume_model = xgb.train(plst, volume_train, num_rounds, watchlist, feval=MAPE)
print("best best_ntree_limit", V30volume_model.best_ntree_limit)

V30volume_predict = V30volume_model.predict(volume_test)
# Out:
# [0]	train-rmse:82.7557	val-rmse:82.2831	train-MAPE:0.942352	val-MAPE:0.943621
# [1]	train-rmse:79.5492	val-rmse:79.1176	train-MAPE:0.90257	val-MAPE:0.904419
# [2]	train-rmse:76.4738	val-rmse:76.0847	train-MAPE:0.864692	val-MAPE:0.866966
# [3]	train-rmse:73.5237	val-rmse:73.1846	train-MAPE:0.828531	val-MAPE:0.830862
# [4]	train-rmse:70.694	val-rmse:70.3988	train-MAPE:0.794054	val-MAPE:0.796158
# [5]	train-rmse:67.9796	val-rmse:67.7339	train-MAPE:0.761063	val-MAPE:0.762864
# [6]	train-rmse:65.3754	val-rmse:65.1655	train-MAPE:0.729546	val-MAPE:0.730927
# [7]	train-rmse:62.8789	val-rmse:62.7186	train-MAPE:0.699341	val-MAPE:0.700178
# [8]	train-rmse:60.4848	val-rmse:60.3565	train-MAPE:0.670423	val-MAPE:0.671027
# [9]	train-rmse:58.1889	val-rmse:58.1441	train-MAPE:0.64273	val-MAPE:0.643272
# [10]	train-rmse:55.9844	val-rmse:55.9818	train-MAPE:0.616294	val-MAPE:0.616585
# [11]	train-rmse:53.8743	val-rmse:53.904	train-MAPE:0.591017	val-MAPE:0.590908
# [12]	train-rmse:51.8479	val-rmse:51.8965	train-MAPE:0.566689	val-MAPE:0.5658
# [13]	train-rmse:49.9055	val-rmse:49.9775	train-MAPE:0.543588	val-MAPE:0.542001
# [14]	train-rmse:48.0435	val-rmse:48.1704	train-MAPE:0.521491	val-MAPE:0.519391
# [15]	train-rmse:46.2599	val-rmse:46.4154	train-MAPE:0.500329	val-MAPE:0.497264
# [16]	train-rmse:44.5503	val-rmse:44.7347	train-MAPE:0.480469	val-MAPE:0.47635
# [17]	train-rmse:42.9122	val-rmse:43.1295	train-MAPE:0.461477	val-MAPE:0.456503
# [18]	train-rmse:41.3423	val-rmse:41.5705	train-MAPE:0.443287	val-MAPE:0.437649
# [19]	train-rmse:39.836	val-rmse:40.0863	train-MAPE:0.426044	val-MAPE:0.419953
# [20]	train-rmse:38.3963	val-rmse:38.6715	train-MAPE:0.409689	val-MAPE:0.403063
# [21]	train-rmse:37.0179	val-rmse:37.3452	train-MAPE:0.394156	val-MAPE:0.387115
# [22]	train-rmse:35.698	val-rmse:36.0528	train-MAPE:0.379411	val-MAPE:0.372186
# [23]	train-rmse:34.4339	val-rmse:34.8255	train-MAPE:0.365291	val-MAPE:0.357851
# [24]	train-rmse:33.2253	val-rmse:33.6476	train-MAPE:0.351821	val-MAPE:0.34428
# [25]	train-rmse:32.0663	val-rmse:32.5273	train-MAPE:0.339176	val-MAPE:0.331367
# [26]	train-rmse:30.9599	val-rmse:31.4565	train-MAPE:0.327251	val-MAPE:0.319149
# [27]	train-rmse:29.8971	val-rmse:30.4089	train-MAPE:0.315902	val-MAPE:0.307786
# [28]	train-rmse:28.8858	val-rmse:29.4222	train-MAPE:0.305241	val-MAPE:0.296904
# [29]	train-rmse:27.9176	val-rmse:28.4885	train-MAPE:0.295204	val-MAPE:0.286732
# [30]	train-rmse:26.9909	val-rmse:27.6013	train-MAPE:0.285521	val-MAPE:0.276926
# [31]	train-rmse:26.104	val-rmse:26.7435	train-MAPE:0.276463	val-MAPE:0.267594
# [32]	train-rmse:25.2572	val-rmse:25.9293	train-MAPE:0.267931	val-MAPE:0.259076
# [33]	train-rmse:24.4523	val-rmse:25.1637	train-MAPE:0.259835	val-MAPE:0.251115
# [34]	train-rmse:23.6804	val-rmse:24.4174	train-MAPE:0.252452	val-MAPE:0.243976
# [35]	train-rmse:22.9455	val-rmse:23.7181	train-MAPE:0.245319	val-MAPE:0.237226
# [36]	train-rmse:22.2438	val-rmse:23.0522	train-MAPE:0.2386	val-MAPE:0.230944
# [37]	train-rmse:21.5723	val-rmse:22.4337	train-MAPE:0.232269	val-MAPE:0.225172
# [38]	train-rmse:20.9328	val-rmse:21.8392	train-MAPE:0.2263	val-MAPE:0.219668
# [39]	train-rmse:20.3206	val-rmse:21.2539	train-MAPE:0.220708	val-MAPE:0.214434
# [40]	train-rmse:19.74	val-rmse:20.7246	train-MAPE:0.215497	val-MAPE:0.209561
# [41]	train-rmse:19.1803	val-rmse:20.2099	train-MAPE:0.210753	val-MAPE:0.205042
# [42]	train-rmse:18.653	val-rmse:19.7382	train-MAPE:0.206238	val-MAPE:0.201136
# [43]	train-rmse:18.1522	val-rmse:19.2882	train-MAPE:0.202114	val-MAPE:0.197671
# [44]	train-rmse:17.6635	val-rmse:18.865	train-MAPE:0.198167	val-MAPE:0.194333
# [45]	train-rmse:17.2004	val-rmse:18.4564	train-MAPE:0.194507	val-MAPE:0.191144
# [46]	train-rmse:16.7634	val-rmse:18.0597	train-MAPE:0.191063	val-MAPE:0.188188
# [47]	train-rmse:16.3433	val-rmse:17.6943	train-MAPE:0.18783	val-MAPE:0.1857
# [48]	train-rmse:15.9462	val-rmse:17.3379	train-MAPE:0.184785	val-MAPE:0.183204
# [49]	train-rmse:15.579	val-rmse:17.0083	train-MAPE:0.182125	val-MAPE:0.1811
# [50]	train-rmse:15.2197	val-rmse:16.6993	train-MAPE:0.179571	val-MAPE:0.179037
# [51]	train-rmse:14.8783	val-rmse:16.4086	train-MAPE:0.177136	val-MAPE:0.17734
# [52]	train-rmse:14.5533	val-rmse:16.1174	train-MAPE:0.174939	val-MAPE:0.175624
# [53]	train-rmse:14.2449	val-rmse:15.8413	train-MAPE:0.172862	val-MAPE:0.174123
# [54]	train-rmse:13.9561	val-rmse:15.5921	train-MAPE:0.171005	val-MAPE:0.172759
# [55]	train-rmse:13.6858	val-rmse:15.3632	train-MAPE:0.169286	val-MAPE:0.171446
# [56]	train-rmse:13.4223	val-rmse:15.1439	train-MAPE:0.167531	val-MAPE:0.170286
# [57]	train-rmse:13.1767	val-rmse:14.945	train-MAPE:0.166081	val-MAPE:0.169251
# [58]	train-rmse:12.9457	val-rmse:14.7572	train-MAPE:0.164797	val-MAPE:0.168377
# [59]	train-rmse:12.728	val-rmse:14.5748	train-MAPE:0.163425	val-MAPE:0.167565
# [60]	train-rmse:12.5156	val-rmse:14.3991	train-MAPE:0.162295	val-MAPE:0.166649
# [61]	train-rmse:12.3122	val-rmse:14.2426	train-MAPE:0.161312	val-MAPE:0.1661
# [62]	train-rmse:12.1277	val-rmse:14.0909	train-MAPE:0.160166	val-MAPE:0.165417
# [63]	train-rmse:11.9513	val-rmse:13.9372	train-MAPE:0.159163	val-MAPE:0.164712
# [64]	train-rmse:11.7848	val-rmse:13.8065	train-MAPE:0.15846	val-MAPE:0.16423
# [65]	train-rmse:11.6186	val-rmse:13.6922	train-MAPE:0.157548	val-MAPE:0.16377
# [66]	train-rmse:11.4669	val-rmse:13.5737	train-MAPE:0.156849	val-MAPE:0.163439
# [67]	train-rmse:11.3192	val-rmse:13.4676	train-MAPE:0.156157	val-MAPE:0.163219
# [68]	train-rmse:11.1847	val-rmse:13.3636	train-MAPE:0.155581	val-MAPE:0.162957
# [69]	train-rmse:11.0599	val-rmse:13.2644	train-MAPE:0.155035	val-MAPE:0.162708
# [70]	train-rmse:10.9375	val-rmse:13.1753	train-MAPE:0.154506	val-MAPE:0.162527
# [71]	train-rmse:10.822	val-rmse:13.0904	train-MAPE:0.153916	val-MAPE:0.162416
# [72]	train-rmse:10.7141	val-rmse:13.0076	train-MAPE:0.153458	val-MAPE:0.162286
# [73]	train-rmse:10.615	val-rmse:12.9325	train-MAPE:0.153033	val-MAPE:0.16198
# [74]	train-rmse:10.517	val-rmse:12.8595	train-MAPE:0.152526	val-MAPE:0.161814
# [75]	train-rmse:10.4328	val-rmse:12.8026	train-MAPE:0.15202	val-MAPE:0.161688
# [76]	train-rmse:10.3483	val-rmse:12.7335	train-MAPE:0.151629	val-MAPE:0.161496
# [77]	train-rmse:10.261	val-rmse:12.6705	train-MAPE:0.151138	val-MAPE:0.161434
# [78]	train-rmse:10.1792	val-rmse:12.6078	train-MAPE:0.15085	val-MAPE:0.161283
# [79]	train-rmse:10.1005	val-rmse:12.5434	train-MAPE:0.150611	val-MAPE:0.161174
# [80]	train-rmse:10.0291	val-rmse:12.4887	train-MAPE:0.150399	val-MAPE:0.161046
# [81]	train-rmse:9.95867	val-rmse:12.4304	train-MAPE:0.150224	val-MAPE:0.160987
# [82]	train-rmse:9.89401	val-rmse:12.3854	train-MAPE:0.150042	val-MAPE:0.16091
# [83]	train-rmse:9.82939	val-rmse:12.3406	train-MAPE:0.149727	val-MAPE:0.160933
# [84]	train-rmse:9.76957	val-rmse:12.3066	train-MAPE:0.149388	val-MAPE:0.160882
# best best_ntree_limit 85

# %%
# 分割训练集验证集
X_train, X_val, y_train, y_val = train_test_split(V31_train.iloc[:,1:], V31_train.iloc[:,0], test_size=0.2, random_state=5)

# 转化格式
volume_train = xgb.DMatrix(X_train, label=y_train)
volume_val = xgb.DMatrix(X_val, label=y_val)
volume_test = xgb.DMatrix(V31_test)

#参数设置
params = {
    'booster':'gbtree',      #gbtree和gblinear
    'objective':'reg:linear',
    'eta':0.04,             #为了防止过拟合，更新过程中用到的收缩步长。在每次提升计算之后，算法会直接获得新特征的权重。eta通过缩减特征的权重使提升计算过程更加保守。缺省值为0.3,通常最后设置eta为0.01~0.2
    #'gamma':0.3,            #模型在默认情况下，对于一个节点的划分只有在其loss function得到结果大于0的情况下才进行，而gamma 给定了所需的最低loss function的值gamma值使得算法更conservation，且其值依赖于loss function ，
    'max_depth':5,          #树的深度越大，则对数据的拟合程度越高（过拟合程度也越高）。即该参数也是控制过拟合,建议通过交叉验证（xgb.cv ) 进行调参,通常取值：3-10
    #'min_child_weight':2,   #孩子节点中最小的样本权重和。如果一个叶子节点的样本权重和小于min_child_weight则拆分过程结束。在现行回归模型中，这个参数是指建立每个模型所需要的最小样本数。该成熟越大算法越conservative。即调大这个参数能够控制过拟合。
    #'max_delta_step':2,     #如果取值为0，那么意味着无限制。如果取为正数，则其使得xgboost更新过程更加保守。
    'subsample':1,          #用于训练模型的子样本占整个样本集合的比例。如果设置为0.5则意味着XGBoost将随机的从整个样本集合中抽取出50%的子样本建立树模型，这能够防止过拟合。
    'colsample_bytree':1,   #在建立树时对特征随机采样的比例。缺省值为1 
    #'alpha':5,              #L1 正则的惩罚系数,当数据维度极高时可以使用，使得算法运行更快。
    #'lambda':40,           #L2 正则的惩罚系数,用于处理XGBoost的正则化部分。通常不使用，但可以用来降低过拟合
    'seed':2017,
}


plst = list(params.items())
num_rounds = 55
watchlist = [(volume_train, 'train'), (volume_val, 'val')]

V31volume_model = xgb.train(plst, volume_train, num_rounds, watchlist, feval=MAPE)
print("best best_ntree_limit", V31volume_model.best_ntree_limit)

V31volume_predict = V31volume_model.predict(volume_test)
# Out:
# [0]	train-rmse:62.9828	val-rmse:62.3467	train-MAPE:0.916402	val-MAPE:0.917024
# [1]	train-rmse:60.5736	val-rmse:59.9648	train-MAPE:0.873143	val-MAPE:0.873712
# [2]	train-rmse:58.2628	val-rmse:57.6899	train-MAPE:0.833588	val-MAPE:0.833455
# [3]	train-rmse:56.0465	val-rmse:55.4839	train-MAPE:0.797932	val-MAPE:0.797231
# [4]	train-rmse:53.921	val-rmse:53.3831	train-MAPE:0.764435	val-MAPE:0.763666
# [5]	train-rmse:51.8829	val-rmse:51.3528	train-MAPE:0.732416	val-MAPE:0.731795
# [6]	train-rmse:49.9275	val-rmse:49.4102	train-MAPE:0.703061	val-MAPE:0.701592
# [7]	train-rmse:48.0528	val-rmse:47.5433	train-MAPE:0.674593	val-MAPE:0.673626
# [8]	train-rmse:46.2547	val-rmse:45.7466	train-MAPE:0.647312	val-MAPE:0.646651
# [9]	train-rmse:44.5262	val-rmse:44.0516	train-MAPE:0.622757	val-MAPE:0.622431
# [10]	train-rmse:42.8706	val-rmse:42.401	train-MAPE:0.600276	val-MAPE:0.599938
# [11]	train-rmse:41.2844	val-rmse:40.8338	train-MAPE:0.578024	val-MAPE:0.577903
# [12]	train-rmse:39.7617	val-rmse:39.3208	train-MAPE:0.558169	val-MAPE:0.557009
# [13]	train-rmse:38.3021	val-rmse:37.8729	train-MAPE:0.539302	val-MAPE:0.536878
# [14]	train-rmse:36.9056	val-rmse:36.5047	train-MAPE:0.521194	val-MAPE:0.517126
# [15]	train-rmse:35.5636	val-rmse:35.177	train-MAPE:0.505311	val-MAPE:0.498829
# [16]	train-rmse:34.2795	val-rmse:33.913	train-MAPE:0.490481	val-MAPE:0.481996
# [17]	train-rmse:33.0426	val-rmse:32.6967	train-MAPE:0.476138	val-MAPE:0.46568
# [18]	train-rmse:31.8624	val-rmse:31.5264	train-MAPE:0.463544	val-MAPE:0.451332
# [19]	train-rmse:30.7274	val-rmse:30.4076	train-MAPE:0.45051	val-MAPE:0.437165
# [20]	train-rmse:29.6408	val-rmse:29.3376	train-MAPE:0.438631	val-MAPE:0.424124
# [21]	train-rmse:28.6018	val-rmse:28.3138	train-MAPE:0.42762	val-MAPE:0.411743
# [22]	train-rmse:27.6074	val-rmse:27.3384	train-MAPE:0.415905	val-MAPE:0.399759
# [23]	train-rmse:26.6524	val-rmse:26.3883	train-MAPE:0.405196	val-MAPE:0.389188
# [24]	train-rmse:25.7426	val-rmse:25.5172	train-MAPE:0.39496	val-MAPE:0.379659
# [25]	train-rmse:24.867	val-rmse:24.6719	train-MAPE:0.385944	val-MAPE:0.370671
# [26]	train-rmse:24.0287	val-rmse:23.8499	train-MAPE:0.376712	val-MAPE:0.36186
# [27]	train-rmse:23.2312	val-rmse:23.0812	train-MAPE:0.368268	val-MAPE:0.353294
# [28]	train-rmse:22.4705	val-rmse:22.3496	train-MAPE:0.360352	val-MAPE:0.345533
# [29]	train-rmse:21.739	val-rmse:21.6599	train-MAPE:0.35329	val-MAPE:0.339499
# [30]	train-rmse:21.0436	val-rmse:20.9923	train-MAPE:0.346324	val-MAPE:0.333341
# [31]	train-rmse:20.382	val-rmse:20.3578	train-MAPE:0.339974	val-MAPE:0.328101
# [32]	train-rmse:19.7506	val-rmse:19.7596	train-MAPE:0.333862	val-MAPE:0.32309
# [33]	train-rmse:19.149	val-rmse:19.2044	train-MAPE:0.328399	val-MAPE:0.318604
# [34]	train-rmse:18.5693	val-rmse:18.6787	train-MAPE:0.322994	val-MAPE:0.31452
# [35]	train-rmse:18.0141	val-rmse:18.1707	train-MAPE:0.317607	val-MAPE:0.310884
# [36]	train-rmse:17.4896	val-rmse:17.686	train-MAPE:0.313038	val-MAPE:0.307307
# [37]	train-rmse:16.9829	val-rmse:17.2166	train-MAPE:0.308507	val-MAPE:0.303782
# [38]	train-rmse:16.5081	val-rmse:16.7925	train-MAPE:0.303733	val-MAPE:0.300678
# [39]	train-rmse:16.0506	val-rmse:16.3773	train-MAPE:0.299875	val-MAPE:0.298079
# [40]	train-rmse:15.6222	val-rmse:15.9977	train-MAPE:0.295918	val-MAPE:0.295832
# [41]	train-rmse:15.2141	val-rmse:15.6453	train-MAPE:0.292917	val-MAPE:0.293756
# [42]	train-rmse:14.8187	val-rmse:15.294	train-MAPE:0.290115	val-MAPE:0.291751
# [43]	train-rmse:14.4514	val-rmse:14.994	train-MAPE:0.287347	val-MAPE:0.290564
# [44]	train-rmse:14.0909	val-rmse:14.678	train-MAPE:0.284538	val-MAPE:0.288863
# [45]	train-rmse:13.7506	val-rmse:14.3804	train-MAPE:0.282161	val-MAPE:0.287431
# [46]	train-rmse:13.4263	val-rmse:14.1049	train-MAPE:0.279835	val-MAPE:0.286207
# [47]	train-rmse:13.1203	val-rmse:13.8488	train-MAPE:0.278108	val-MAPE:0.285668
# [48]	train-rmse:12.8311	val-rmse:13.6061	train-MAPE:0.27621	val-MAPE:0.284775
# [49]	train-rmse:12.557	val-rmse:13.3789	train-MAPE:0.274524	val-MAPE:0.284263
# [50]	train-rmse:12.2937	val-rmse:13.1751	train-MAPE:0.272504	val-MAPE:0.283626
# [51]	train-rmse:12.0487	val-rmse:12.9839	train-MAPE:0.271165	val-MAPE:0.283569
# [52]	train-rmse:11.8138	val-rmse:12.7972	train-MAPE:0.269975	val-MAPE:0.283306
# [53]	train-rmse:11.5866	val-rmse:12.6374	train-MAPE:0.268775	val-MAPE:0.283405
# [54]	train-rmse:11.3719	val-rmse:12.4857	train-MAPE:0.267547	val-MAPE:0.283421
# best best_ntree_limit 55

# %% [markdown]
# ### 整合及输出

# %%
submission_travel_time = test_travel_time[['intersection_id','tollgate_id','time_window']]
predict_result = np.concatenate([A2time_predict,A3time_predict,B1time_predict,B3time_predict,C1time_predict,C3time_predict], axis=0)
submission_travel_time['avg_travel_time'] = predict_result
# Out:
# /home/godcedric/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
submission_travel_time.to_csv('/home/godcedric/GitLocal/KDDCUP2017/submission_result/phase2.5/xgboost_original/travel_time_submission.csv', index=False)
