# %% [markdown]
# # xgboost

# %% [markdown]
# 2017-05-21

# %%
import xgboost as xgb
import numpy as np
import pandas as pd
from datetime import datetime,timedelta,date,time

# %% [markdown]
# ### 录入数据

# %%
travel_time_train_data = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/加工过的数据集/5.0/travel_time/包含1个月的训练集和测试集/travel_time_train_data.csv')
volume_train_data = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/加工过的数据集/5.0/volume/volume_train_data.csv')
travel_time_test_data = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/加工过的数据集/5.0/travel_time/包含1个月的训练集和测试集/test_travel_time_data.csv')
volume_test_data = pd.read_csv('/home/godcedric/GitLocal/KDDCUP2017/加工过的数据集/5.0/volume/test_volume_data.csv')

# %% [markdown]
# ### 准备数据

# %%
# 分割训练集和验证集
test_date = ['2016-10-11', '2016-10-12', '2016-10-13', '2016-10-14', '2016-10-15', '2016-10-16', '2016-10-17']
def isin(x):
    if x in test_date:
        return 1
    else:
        return 0
# 平均时间
travel_time_train_data['is_test'] = travel_time_train_data['date'].map(isin)
travel_time_train = travel_time_train_data[travel_time_train_data['is_test'] == 0]
travel_time_val = travel_time_train_data[travel_time_train_data['is_test'] == 1]
# 流量
volume_train_data['is_test'] = volume_train_data['date'].map(isin)
volume_train = volume_train_data[volume_train_data['is_test'] == 0]
volume_val = volume_train_data[volume_train_data['is_test'] == 1]

# %%
# 分离标签和特征
Y_time = travel_time_train['avg_travel_time']
X_time = travel_time_train.drop(['avg_travel_time'], axis=1)
val_Y_time = travel_time_val.avg_travel_time
val_X_time = travel_time_val.drop(['avg_travel_time'], axis=1)


Y_volume = volume_train['volume']
X_volume = volume_train.drop(['volume'], axis=1)
val_Y_volume = volume_val.volume
val_X_volume = volume_val.drop(['volume'], axis=1)

# %%
# 选择特征
travel_time_features = ['route', 'weekday', 'timemap',\
                        'pressure', 'wind_direction', 'wind_speed', 'temperature', 'rel_humidity', 'precipitation',\
                        #'last_20min',\
                        'SSD',\
                        'is_workday'  
                       ]

volume_features = ['pair', 'weekday', 'timemap',\
                   'pressure', 'wind_direction', 'wind_speed', 'temperature', 'rel_humidity', 'precipitation',\
                   #'last_20min',\
                   'SSD',\
                   'is_workday'  
                  ]

# %%
# 选择特征
travel_time_features = ['A-2', 'A-3', 'B-1', 'B-3', 'C-1', 'C-3',
                        'weekday__0', 'weekday__1', 'weekday__2', 'weekday__3', 'weekday__4', 'weekday__5', 'weekday__6', 
                        'workday__1', 'workday__2', 'workday__3',
                        'hour__0', 'hour__1', 'hour__2','hour__3', 'hour__4', 'hour__5', 'hour__6', 'hour__7', 'hour__8',
                        'hour__9', 'hour__10', 'hour__11', 'hour__12', 'hour__13', 'hour__14', 'hour__15', 'hour__16', 
                        'hour__17', 'hour__18', 'hour__19', 'hour__20',
                        'hour__21', 'hour__22', 'hour__23', 'minute__0', 'minute__20', 'minute__40',
                        'pressure', 'wind_direction', 'wind_speed', 'temperature', 'rel_humidity', 'precipitation',\
                        #'last_20min',\
                        'SSD'
                       ]

volume_features = ['1-0', '1-1', '2-0', '3-0', '3-1',
                   'weekday__1', 'weekday__2', 'weekday__3', 'weekday__4', 'weekday__5', 'weekday__6', 'workday__1', 'workday__2',
                   'hour__0', 'hour__1', 'hour__2','hour__3', 'hour__4', 'hour__5', 'hour__6', 'hour__7', 'hour__8',
                   'hour__9', 'hour__10', 'hour__11', 'hour__12', 'hour__13', 'hour__14', 'hour__15', 'hour__16', 
                   'hour__17', 'hour__18', 'hour__19', 'hour__20',
                   'hour__21', 'hour__22', 'hour__23', 'minute__0', 'minute__20', 'minute__40',
                   'pressure', 'wind_direction', 'wind_speed', 'temperature', 'rel_humidity', 'precipitation',\
                   #'last_20min',\
                   'SSD'
                  ]

# %%
X_time = X_time[travel_time_features]
val_X_time = val_X_time[travel_time_features]
travel_time_submission = travel_time_test_data[['intersection_id', 'tollgate_id', 'time_window']]
travel_time_test_data = travel_time_test_data[travel_time_features]

X_volume = X_volume[volume_features]
val_X_volume = val_X_volume[volume_features]
volume_submission = volume_test_data[['tollgate_id', 'time_window', 'direction']]
volume_test_data = volume_test_data[volume_features]

# %%
# 字符串特征转换数值
X_time['route'] = pd.factorize(X_time['route'])[0]
val_X_time['route'] = pd.factorize(val_X_time['route'])[0]
travel_time_test_data['route'] = pd.factorize(travel_time_test_data['route'])[0]
X_volume['pair'] = pd.factorize(X_volume['pair'])[0]
val_X_volume['pair'] = pd.factorize(val_X_volume['pair'])[0]
volume_test_data['pair'] = pd.factorize(volume_test_data['pair'])[0]

# %%
# 转化格式
time_train = xgb.DMatrix(X_time, label=Y_time)
time_val = xgb.DMatrix(val_X_time, label=val_Y_time)
time_test = xgb.DMatrix(travel_time_test_data)

volume_train = xgb.DMatrix(X_volume, label=Y_volume)
volume_val = xgb.DMatrix(val_X_volume, label=val_Y_volume)
volume_test = xgb.DMatrix(volume_test_data)

# %% [markdown]
# ### 参数设置

# %%
params = {
    'booster':'gbtree',      #gbtree和gblinear
    'objective':'reg:linear',
    'eta':0.08,             #为了防止过拟合，更新过程中用到的收缩步长。在每次提升计算之后，算法会直接获得新特征的权重。eta通过缩减特征的权重使提升计算过程更加保守。缺省值为0.3,通常最后设置eta为0.01~0.2
    #'gamma':0.3,            #模型在默认情况下，对于一个节点的划分只有在其loss function得到结果大于0的情况下才进行，而gamma 给定了所需的最低loss function的值gamma值使得算法更conservation，且其值依赖于loss function ，
    'max_depth':5,          #树的深度越大，则对数据的拟合程度越高（过拟合程度也越高）。即该参数也是控制过拟合,建议通过交叉验证（xgb.cv ) 进行调参,通常取值：3-10
    #'min_child_weight':2,   #孩子节点中最小的样本权重和。如果一个叶子节点的样本权重和小于min_child_weight则拆分过程结束。在现行回归模型中，这个参数是指建立每个模型所需要的最小样本数。该成熟越大算法越conservative。即调大这个参数能够控制过拟合。
    #'max_delta_step':2,     #如果取值为0，那么意味着无限制。如果取为正数，则其使得xgboost更新过程更加保守。
    'subsample':1,          #用于训练模型的子样本占整个样本集合的比例。如果设置为0.5则意味着XGBoost将随机的从整个样本集合中抽取出50%的子样本建立树模型，这能够防止过拟合。
    'colsample_bytree':0.8,   #在建立树时对特征随机采样的比例。缺省值为1 
    #'alpha':5,              #L1 正则的惩罚系数,当数据维度极高时可以使用，使得算法运行更快。
    #'lambda':40,           #L2 正则的惩罚系数,用于处理XGBoost的正则化部分。通常不使用，但可以用来降低过拟合
    'seed':2017,
}

# %% [markdown]
# ### 平均时间训练

# %%
# 自定义评价函数
def MAPE(preds, dtrain):
    labels = dtrain.get_label()
    return 'MAPE', float(sum(np.fabs((labels - preds) / labels))) / len(labels)
plst = list(params.items())
num_rounds = 130
watchlist = [(time_train, 'train'), (time_val, 'val')]

time_model = xgb.train(plst, time_train, num_rounds, watchlist, feval=MAPE)
print("best best_ntree_limit", time_model.best_ntree_limit)
# Out:
# [0]	train-rmse:113.968	val-rmse:116.269	train-MAPE:0.908798	val-MAPE:0.910145
# [1]	train-rmse:105.532	val-rmse:107.8	train-MAPE:0.830673	val-MAPE:0.833955
# [2]	train-rmse:97.7033	val-rmse:100.055	train-MAPE:0.758543	val-MAPE:0.762931
# [3]	train-rmse:90.5911	val-rmse:92.9532	train-MAPE:0.693655	val-MAPE:0.699257
# [4]	train-rmse:83.9676	val-rmse:86.3336	train-MAPE:0.635114	val-MAPE:0.642009
# [5]	train-rmse:77.9186	val-rmse:80.4321	train-MAPE:0.581526	val-MAPE:0.590427
# [6]	train-rmse:72.5254	val-rmse:74.9616	train-MAPE:0.531919	val-MAPE:0.540809
# [7]	train-rmse:67.4811	val-rmse:69.9458	train-MAPE:0.48733	val-MAPE:0.497375
# [8]	train-rmse:62.8894	val-rmse:65.4583	train-MAPE:0.446573	val-MAPE:0.45809
# [9]	train-rmse:58.8701	val-rmse:61.502	train-MAPE:0.408775	val-MAPE:0.421762
# [10]	train-rmse:55.2097	val-rmse:58.0505	train-MAPE:0.374908	val-MAPE:0.390716
# [11]	train-rmse:51.7964	val-rmse:54.7267	train-MAPE:0.344158	val-MAPE:0.360819
# [12]	train-rmse:48.6733	val-rmse:51.5804	train-MAPE:0.317996	val-MAPE:0.335736
# [13]	train-rmse:45.9699	val-rmse:49.1488	train-MAPE:0.294203	val-MAPE:0.315038
# [14]	train-rmse:43.4291	val-rmse:46.5907	train-MAPE:0.274216	val-MAPE:0.29539
# [15]	train-rmse:41.1431	val-rmse:44.3057	train-MAPE:0.25682	val-MAPE:0.278159
# [16]	train-rmse:39.1047	val-rmse:42.2495	train-MAPE:0.241932	val-MAPE:0.263072
# [17]	train-rmse:37.2835	val-rmse:40.4491	train-MAPE:0.228952	val-MAPE:0.250731
# [18]	train-rmse:35.6646	val-rmse:38.8987	train-MAPE:0.217904	val-MAPE:0.240249
# [19]	train-rmse:34.2101	val-rmse:37.4703	train-MAPE:0.208617	val-MAPE:0.23072
# [20]	train-rmse:32.9862	val-rmse:36.2128	train-MAPE:0.200778	val-MAPE:0.222363
# [21]	train-rmse:31.8491	val-rmse:35.0606	train-MAPE:0.194379	val-MAPE:0.215724
# [22]	train-rmse:30.8595	val-rmse:34.0632	train-MAPE:0.189139	val-MAPE:0.210133
# [23]	train-rmse:29.9732	val-rmse:33.1672	train-MAPE:0.184988	val-MAPE:0.205751
# [24]	train-rmse:29.2071	val-rmse:32.3613	train-MAPE:0.181595	val-MAPE:0.201973
# [25]	train-rmse:28.5381	val-rmse:31.6631	train-MAPE:0.178734	val-MAPE:0.198803
# [26]	train-rmse:27.9563	val-rmse:31.0572	train-MAPE:0.176377	val-MAPE:0.196306
# [27]	train-rmse:27.4424	val-rmse:30.521	train-MAPE:0.174395	val-MAPE:0.194608
# [28]	train-rmse:27.0057	val-rmse:30.05	train-MAPE:0.172787	val-MAPE:0.192941
# [29]	train-rmse:26.619	val-rmse:29.6568	train-MAPE:0.171628	val-MAPE:0.191536
# [30]	train-rmse:26.2742	val-rmse:29.2913	train-MAPE:0.170684	val-MAPE:0.190503
# [31]	train-rmse:25.981	val-rmse:28.9336	train-MAPE:0.169988	val-MAPE:0.189412
# [32]	train-rmse:25.712	val-rmse:28.7061	train-MAPE:0.169236	val-MAPE:0.1886
# [33]	train-rmse:25.4478	val-rmse:28.465	train-MAPE:0.168782	val-MAPE:0.187813
# [34]	train-rmse:25.2504	val-rmse:28.2435	train-MAPE:0.168421	val-MAPE:0.187522
# [35]	train-rmse:25.047	val-rmse:28.0828	train-MAPE:0.168201	val-MAPE:0.187199
# [36]	train-rmse:24.8832	val-rmse:27.9113	train-MAPE:0.167947	val-MAPE:0.186866
# [37]	train-rmse:24.7374	val-rmse:27.7791	train-MAPE:0.167834	val-MAPE:0.186786
# [38]	train-rmse:24.5804	val-rmse:27.6833	train-MAPE:0.167713	val-MAPE:0.186911
# [39]	train-rmse:24.4424	val-rmse:27.5525	train-MAPE:0.167662	val-MAPE:0.186607
# [40]	train-rmse:24.3255	val-rmse:27.4573	train-MAPE:0.167558	val-MAPE:0.186461
# [41]	train-rmse:24.2142	val-rmse:27.3768	train-MAPE:0.167554	val-MAPE:0.186406
# [42]	train-rmse:24.1201	val-rmse:27.321	train-MAPE:0.167536	val-MAPE:0.186204
# [43]	train-rmse:24.0449	val-rmse:27.2377	train-MAPE:0.167456	val-MAPE:0.186187
# [44]	train-rmse:23.9774	val-rmse:27.1675	train-MAPE:0.167385	val-MAPE:0.186156
# [45]	train-rmse:23.9029	val-rmse:27.0958	train-MAPE:0.167399	val-MAPE:0.186149
# [46]	train-rmse:23.8415	val-rmse:27.0295	train-MAPE:0.167384	val-MAPE:0.186061
# [47]	train-rmse:23.782	val-rmse:26.9788	train-MAPE:0.16732	val-MAPE:0.185926
# [48]	train-rmse:23.72	val-rmse:26.911	train-MAPE:0.167269	val-MAPE:0.185801
# [49]	train-rmse:23.6685	val-rmse:26.8659	train-MAPE:0.16708	val-MAPE:0.185758
# [50]	train-rmse:23.625	val-rmse:26.8241	train-MAPE:0.167018	val-MAPE:0.185651
# [51]	train-rmse:23.5661	val-rmse:26.7943	train-MAPE:0.166866	val-MAPE:0.185323
# [52]	train-rmse:23.5125	val-rmse:26.7781	train-MAPE:0.166786	val-MAPE:0.185379
# [53]	train-rmse:23.4611	val-rmse:26.7284	train-MAPE:0.166661	val-MAPE:0.185329
# [54]	train-rmse:23.4115	val-rmse:26.6994	train-MAPE:0.166516	val-MAPE:0.185045
# [55]	train-rmse:23.3452	val-rmse:26.6809	train-MAPE:0.166175	val-MAPE:0.185138
# [56]	train-rmse:23.3001	val-rmse:26.6598	train-MAPE:0.166067	val-MAPE:0.185138
# [57]	train-rmse:23.2633	val-rmse:26.637	train-MAPE:0.165903	val-MAPE:0.184909
# [58]	train-rmse:23.2311	val-rmse:26.6148	train-MAPE:0.165774	val-MAPE:0.184843
# [59]	train-rmse:23.1896	val-rmse:26.5842	train-MAPE:0.165658	val-MAPE:0.184773
# [60]	train-rmse:23.1486	val-rmse:26.5701	train-MAPE:0.165513	val-MAPE:0.184683
# [61]	train-rmse:23.1143	val-rmse:26.5443	train-MAPE:0.165411	val-MAPE:0.184589
# [62]	train-rmse:23.0898	val-rmse:26.5228	train-MAPE:0.165238	val-MAPE:0.184554
# [63]	train-rmse:23.0257	val-rmse:26.527	train-MAPE:0.164797	val-MAPE:0.184507
# [64]	train-rmse:22.979	val-rmse:26.5223	train-MAPE:0.164557	val-MAPE:0.184582
# [65]	train-rmse:22.9387	val-rmse:26.5008	train-MAPE:0.164411	val-MAPE:0.184479
# [66]	train-rmse:22.9078	val-rmse:26.4871	train-MAPE:0.164215	val-MAPE:0.184381
# [67]	train-rmse:22.8654	val-rmse:26.4691	train-MAPE:0.163942	val-MAPE:0.184379
# [68]	train-rmse:22.8215	val-rmse:26.4592	train-MAPE:0.163719	val-MAPE:0.184249
# [69]	train-rmse:22.7846	val-rmse:26.4732	train-MAPE:0.163524	val-MAPE:0.18429
# [70]	train-rmse:22.7647	val-rmse:26.4568	train-MAPE:0.16332	val-MAPE:0.184172
# [71]	train-rmse:22.7371	val-rmse:26.4563	train-MAPE:0.163166	val-MAPE:0.184235
# [72]	train-rmse:22.704	val-rmse:26.4476	train-MAPE:0.162942	val-MAPE:0.184223
# [73]	train-rmse:22.6743	val-rmse:26.4403	train-MAPE:0.162702	val-MAPE:0.184229
# [74]	train-rmse:22.6512	val-rmse:26.4269	train-MAPE:0.162515	val-MAPE:0.184116
# [75]	train-rmse:22.5965	val-rmse:26.4499	train-MAPE:0.162176	val-MAPE:0.184101
# [76]	train-rmse:22.5681	val-rmse:26.4518	train-MAPE:0.16201	val-MAPE:0.184115
# [77]	train-rmse:22.5451	val-rmse:26.4491	train-MAPE:0.161848	val-MAPE:0.184099
# [78]	train-rmse:22.5043	val-rmse:26.4541	train-MAPE:0.16147	val-MAPE:0.184014
# [79]	train-rmse:22.4727	val-rmse:26.4577	train-MAPE:0.161285	val-MAPE:0.183835
# [80]	train-rmse:22.452	val-rmse:26.4586	train-MAPE:0.161154	val-MAPE:0.183709
# [81]	train-rmse:22.4371	val-rmse:26.4598	train-MAPE:0.161054	val-MAPE:0.183683
# [82]	train-rmse:22.4079	val-rmse:26.486	train-MAPE:0.160865	val-MAPE:0.183508
# [83]	train-rmse:22.375	val-rmse:26.5036	train-MAPE:0.160596	val-MAPE:0.183477
# [84]	train-rmse:22.3509	val-rmse:26.5036	train-MAPE:0.160314	val-MAPE:0.183441
# [85]	train-rmse:22.333	val-rmse:26.5021	train-MAPE:0.160178	val-MAPE:0.183431
# [86]	train-rmse:22.3144	val-rmse:26.5052	train-MAPE:0.160032	val-MAPE:0.183376
# [87]	train-rmse:22.2914	val-rmse:26.5134	train-MAPE:0.159919	val-MAPE:0.183427
# [88]	train-rmse:22.2707	val-rmse:26.5167	train-MAPE:0.159782	val-MAPE:0.183434
# [89]	train-rmse:22.2521	val-rmse:26.5181	train-MAPE:0.159606	val-MAPE:0.183476
# [90]	train-rmse:22.2151	val-rmse:26.507	train-MAPE:0.159369	val-MAPE:0.183432
# [91]	train-rmse:22.197	val-rmse:26.5116	train-MAPE:0.159248	val-MAPE:0.183387
# [92]	train-rmse:22.1722	val-rmse:26.5107	train-MAPE:0.159041	val-MAPE:0.183325
# [93]	train-rmse:22.1492	val-rmse:26.5121	train-MAPE:0.158889	val-MAPE:0.183301
# [94]	train-rmse:22.1337	val-rmse:26.5112	train-MAPE:0.158761	val-MAPE:0.183244
# [95]	train-rmse:22.1111	val-rmse:26.5296	train-MAPE:0.158596	val-MAPE:0.183245
# [96]	train-rmse:22.0906	val-rmse:26.5203	train-MAPE:0.15845	val-MAPE:0.183175
# [97]	train-rmse:22.0702	val-rmse:26.5344	train-MAPE:0.158306	val-MAPE:0.183102
# [98]	train-rmse:22.039	val-rmse:26.5531	train-MAPE:0.158035	val-MAPE:0.18309
# [99]	train-rmse:22.0113	val-rmse:26.552	train-MAPE:0.157834	val-MAPE:0.183099
# [100]	train-rmse:21.9843	val-rmse:26.5899	train-MAPE:0.157602	val-MAPE:0.18327
# [101]	train-rmse:21.9666	val-rmse:26.5814	train-MAPE:0.157485	val-MAPE:0.183296
# [102]	train-rmse:21.9521	val-rmse:26.5697	train-MAPE:0.157327	val-MAPE:0.18327
# [103]	train-rmse:21.9364	val-rmse:26.5566	train-MAPE:0.157176	val-MAPE:0.183225
# [104]	train-rmse:21.9103	val-rmse:26.5493	train-MAPE:0.157008	val-MAPE:0.183163
# [105]	train-rmse:21.8951	val-rmse:26.552	train-MAPE:0.156852	val-MAPE:0.183166
# [106]	train-rmse:21.8802	val-rmse:26.5554	train-MAPE:0.156672	val-MAPE:0.183255
# [107]	train-rmse:21.8582	val-rmse:26.5857	train-MAPE:0.156473	val-MAPE:0.183329
# [108]	train-rmse:21.841	val-rmse:26.5789	train-MAPE:0.156317	val-MAPE:0.183324
# [109]	train-rmse:21.822	val-rmse:26.5781	train-MAPE:0.15621	val-MAPE:0.183285
# [110]	train-rmse:21.8021	val-rmse:26.5709	train-MAPE:0.156083	val-MAPE:0.183258
# [111]	train-rmse:21.7786	val-rmse:26.5466	train-MAPE:0.15591	val-MAPE:0.183263
# [112]	train-rmse:21.765	val-rmse:26.5505	train-MAPE:0.155816	val-MAPE:0.183248
# [113]	train-rmse:21.7535	val-rmse:26.5425	train-MAPE:0.155696	val-MAPE:0.183235
# [114]	train-rmse:21.7322	val-rmse:26.546	train-MAPE:0.155582	val-MAPE:0.183222
# [115]	train-rmse:21.7094	val-rmse:26.5628	train-MAPE:0.155402	val-MAPE:0.183257
# [116]	train-rmse:21.6954	val-rmse:26.5641	train-MAPE:0.15529	val-MAPE:0.183269
# [117]	train-rmse:21.6772	val-rmse:26.5518	train-MAPE:0.15515	val-MAPE:0.183193
# [118]	train-rmse:21.6627	val-rmse:26.5621	train-MAPE:0.155028	val-MAPE:0.183277
# [119]	train-rmse:21.6449	val-rmse:26.5665	train-MAPE:0.154924	val-MAPE:0.183319
# [120]	train-rmse:21.6289	val-rmse:26.5586	train-MAPE:0.15482	val-MAPE:0.183257
# [121]	train-rmse:21.6112	val-rmse:26.5585	train-MAPE:0.15469	val-MAPE:0.183319
# [122]	train-rmse:21.5972	val-rmse:26.5656	train-MAPE:0.15456	val-MAPE:0.183264
# [123]	train-rmse:21.5792	val-rmse:26.5665	train-MAPE:0.154447	val-MAPE:0.183212
# [124]	train-rmse:21.5621	val-rmse:26.5714	train-MAPE:0.154288	val-MAPE:0.183296
# [125]	train-rmse:21.5377	val-rmse:26.5766	train-MAPE:0.15409	val-MAPE:0.183375
# [126]	train-rmse:21.5119	val-rmse:26.5901	train-MAPE:0.153981	val-MAPE:0.183429
# [127]	train-rmse:21.5027	val-rmse:26.5954	train-MAPE:0.153868	val-MAPE:0.183033
# [128]	train-rmse:21.4847	val-rmse:26.6217	train-MAPE:0.153721	val-MAPE:0.183194
# [129]	train-rmse:21.4746	val-rmse:26.6192	train-MAPE:0.153623	val-MAPE:0.183156
# best best_ntree_limit 130

# %%
time_model.get_fscore()
# Out:
# {'A-2': 174,
#  'A-3': 112,
#  'B-1': 101,
#  'B-3': 112,
#  'C-1': 136,
#  'C-3': 155,
#  'SSD': 182,
#  'hour__0': 30,
#  'hour__1': 34,
#  'hour__10': 28,
#  'hour__11': 7,
#  'hour__12': 20,
#  'hour__13': 10,
#  'hour__14': 33,
#  'hour__15': 29,
#  'hour__16': 35,
#  'hour__17': 30,
#  'hour__18': 38,
#  'hour__19': 26,
#  'hour__2': 27,
#  'hour__20': 25,
#  'hour__21': 21,
#  'hour__22': 31,
#  'hour__23': 40,
#  'hour__3': 33,
#  'hour__4': 27,
#  'hour__5': 35,
#  'hour__6': 45,
#  'hour__7': 23,
#  'hour__8': 37,
#  'hour__9': 38,
#  'minute__0': 186,
#  'minute__20': 120,
#  'minute__40': 130,
#  'precipitation': 46,
#  'pressure': 272,
#  'rel_humidity': 161,
#  'temperature': 212,
#  'weekday__0': 53,
#  'weekday__1': 36,
#  'weekday__2': 29,
#  'weekday__3': 38,
#  'weekday__4': 46,
#  'weekday__5': 37,
#  'weekday__6': 31,
#  'wind_direction': 265,
#  'wind_speed': 230,
#  'workday__1': 38,
#  'workday__2': 47,
#  'workday__3': 75}

# %% [markdown]
# ### 预测输出

# %%
time_predict = time_model.predict(time_test, ntree_limit=time_model.best_ntree_limit)

# %%
travel_time_submission['avg_travel_time'] = time_predict
travel_time_submission.to_csv('/home/godcedric/GitLocal/KDDCUP2017/submission_result/phase1.5/xgboost/独热结果/travel_time_submission.csv', index=False)

# %% [markdown]
# ### 流量训练

# %%
params = {
    'booster':'gbtree',      #gbtree和gblinear
    'objective':'reg:linear',
    'eta':0.05,             #为了防止过拟合，更新过程中用到的收缩步长。在每次提升计算之后，算法会直接获得新特征的权重。eta通过缩减特征的权重使提升计算过程更加保守。缺省值为0.3,通常最后设置eta为0.01~0.2
    #'gamma':0.3,            #模型在默认情况下，对于一个节点的划分只有在其loss function得到结果大于0的情况下才进行，而gamma给定了所需的最低loss function的值gamma值使得算法更conservation，且其值依赖于loss function ，
    'max_depth':3,          #树的深度越大，则对数据的拟合程度越高（过拟合程度也越高）。即该参数也是控制过拟合,建议通过交叉验证（xgb.cv ) 进行调参,通常取值：3-10
    #'min_child_weight':0,   #孩子节点中最小的样本权重和。如果一个叶子节点的样本权重和小于min_child_weight则拆分过程结束。在现行回归模型中，这个参数是指建立每个模型所需要的最小样本数。该成熟越大算法越conservative。即调大这个参数能够控制过拟合。
    #'max_delta_step':0,     #如果取值为0，那么意味着无限制。如果取为正数，则其使得xgboost更新过程更加保守。
    'subsample':0.8,          #用于训练模型的子样本占整个样本集合的比例。如果设置为0.5则意味着XGBoost将随机的从整个样本集合中抽取出50%的子样本建立树模型，这能够防止过拟合。
    'colsample_bytree':1,   #在建立树时对特征随机采样的比例。缺省值为1 
    #'alpha':0,              #L1 正则的惩罚系数,当数据维度极高时可以使用，使得算法运行更快。
    #'lambda':120,           #L2 正则的惩罚系数,用于处理XGBoost的正则化部分。通常不使用，但可以用来降低过拟合
    'seed':2016,
}

# %%
plst = list(params.items())
num_rounds = 4000
watchlist = [(volume_train, 'train'), (volume_val, 'val')]

volume_model = xgb.train(plst, volume_train, num_rounds, watchlist, feval=MAPE)
print("best best_ntree_limit", volume_model.best_ntree_limit )
# Out:
# [0]	train-rmse:61.4448	val-rmse:67.584	train-MAPE:0.901745	val-MAPE:0.909125
# [1]	train-rmse:58.8964	val-rmse:66.211	train-MAPE:0.860208	val-MAPE:0.875109
# [2]	train-rmse:56.4499	val-rmse:64.9236	train-MAPE:0.825226	val-MAPE:0.855233
# [3]	train-rmse:54.1903	val-rmse:63.8669	train-MAPE:0.785996	val-MAPE:0.852071
# [4]	train-rmse:52.0492	val-rmse:62.6457	train-MAPE:0.766878	val-MAPE:0.856206
# [5]	train-rmse:50.0243	val-rmse:61.6102	train-MAPE:0.738272	val-MAPE:0.868183
# [6]	train-rmse:48.1094	val-rmse:60.893	train-MAPE:0.728464	val-MAPE:0.879579
# [7]	train-rmse:46.3062	val-rmse:59.8086	train-MAPE:0.720513	val-MAPE:0.899118
# [8]	train-rmse:44.6123	val-rmse:59.0483	train-MAPE:0.717478	val-MAPE:0.915438
# [9]	train-rmse:43.0227	val-rmse:58.4452	train-MAPE:0.702018	val-MAPE:0.932893
# [10]	train-rmse:41.5415	val-rmse:57.7207	train-MAPE:0.689372	val-MAPE:0.952352
# [11]	train-rmse:40.147	val-rmse:57.1297	train-MAPE:0.69802	val-MAPE:0.970168
# [12]	train-rmse:38.8439	val-rmse:56.5963	train-MAPE:0.704658	val-MAPE:0.987917
# [13]	train-rmse:37.6506	val-rmse:55.6099	train-MAPE:0.710036	val-MAPE:1.00745
# [14]	train-rmse:36.4633	val-rmse:55.0293	train-MAPE:0.709555	val-MAPE:1.03029
# [15]	train-rmse:35.324	val-rmse:54.5896	train-MAPE:0.717921	val-MAPE:1.04897
# [16]	train-rmse:34.3346	val-rmse:53.9208	train-MAPE:0.741378	val-MAPE:1.0662
# [17]	train-rmse:33.3937	val-rmse:53.3612	train-MAPE:0.746576	val-MAPE:1.08913
# [18]	train-rmse:32.5095	val-rmse:52.6743	train-MAPE:0.764359	val-MAPE:1.10477
# [19]	train-rmse:31.6734	val-rmse:51.9632	train-MAPE:0.773388	val-MAPE:1.1266
# [20]	train-rmse:30.8877	val-rmse:51.1955	train-MAPE:0.797131	val-MAPE:1.14647
# [21]	train-rmse:30.1697	val-rmse:50.7197	train-MAPE:0.822456	val-MAPE:1.1615
# [22]	train-rmse:29.4958	val-rmse:50.2667	train-MAPE:0.846412	val-MAPE:1.17582
# [23]	train-rmse:28.7809	val-rmse:50.0352	train-MAPE:0.865599	val-MAPE:1.18939
# [24]	train-rmse:28.1114	val-rmse:49.5428	train-MAPE:0.879533	val-MAPE:1.20512
# [25]	train-rmse:27.5393	val-rmse:49.0887	train-MAPE:0.897051	val-MAPE:1.21736
# [26]	train-rmse:26.9956	val-rmse:48.7482	train-MAPE:0.915389	val-MAPE:1.22948
# [27]	train-rmse:26.4291	val-rmse:48.3257	train-MAPE:0.928905	val-MAPE:1.24421
# [28]	train-rmse:25.9532	val-rmse:47.8135	train-MAPE:0.948313	val-MAPE:1.25929
# [29]	train-rmse:25.4814	val-rmse:47.4505	train-MAPE:0.961257	val-MAPE:1.27298
# [30]	train-rmse:25.0415	val-rmse:47.1411	train-MAPE:0.964585	val-MAPE:1.28108
# [31]	train-rmse:24.6599	val-rmse:46.7182	train-MAPE:0.980716	val-MAPE:1.29342
# [32]	train-rmse:24.3055	val-rmse:46.4317	train-MAPE:0.99247	val-MAPE:1.30071
# [33]	train-rmse:23.8843	val-rmse:46.5938	train-MAPE:0.983602	val-MAPE:1.30071
# [34]	train-rmse:23.5325	val-rmse:46.3952	train-MAPE:0.99585	val-MAPE:1.30618
# [35]	train-rmse:23.1452	val-rmse:46.217	train-MAPE:1.00144	val-MAPE:1.31706
# [36]	train-rmse:22.8574	val-rmse:45.8932	train-MAPE:1.01099	val-MAPE:1.32295
# [37]	train-rmse:22.5411	val-rmse:45.6726	train-MAPE:1.01713	val-MAPE:1.33042
# [38]	train-rmse:22.1944	val-rmse:45.8052	train-MAPE:1.01091	val-MAPE:1.32546
# [39]	train-rmse:21.9539	val-rmse:45.645	train-MAPE:1.02223	val-MAPE:1.32782
# [40]	train-rmse:21.6213	val-rmse:45.491	train-MAPE:1.02348	val-MAPE:1.33183
# [41]	train-rmse:21.3017	val-rmse:45.4797	train-MAPE:1.02165	val-MAPE:1.3275
# [42]	train-rmse:21.0594	val-rmse:45.2358	train-MAPE:1.02581	val-MAPE:1.33205
# [43]	train-rmse:20.8483	val-rmse:45.2352	train-MAPE:1.02241	val-MAPE:1.32888
# [44]	train-rmse:20.6325	val-rmse:45.0562	train-MAPE:1.02707	val-MAPE:1.333
# [45]	train-rmse:20.4209	val-rmse:44.8058	train-MAPE:1.02734	val-MAPE:1.33215
# [46]	train-rmse:20.2336	val-rmse:44.8539	train-MAPE:1.02697	val-MAPE:1.32689
# [47]	train-rmse:20.0258	val-rmse:44.6872	train-MAPE:1.03118	val-MAPE:1.33373
# [48]	train-rmse:19.8527	val-rmse:44.4934	train-MAPE:1.03557	val-MAPE:1.34048
# [49]	train-rmse:19.6769	val-rmse:44.2919	train-MAPE:1.03275	val-MAPE:1.33745
# [50]	train-rmse:19.5137	val-rmse:44.1721	train-MAPE:1.03458	val-MAPE:1.34221
# [51]	train-rmse:19.3419	val-rmse:43.9992	train-MAPE:1.03727	val-MAPE:1.34632
# [52]	train-rmse:19.1992	val-rmse:43.8227	train-MAPE:1.03448	val-MAPE:1.34336
# [53]	train-rmse:19.0707	val-rmse:43.6473	train-MAPE:1.0298	val-MAPE:1.34016
# [54]	train-rmse:18.9411	val-rmse:43.4965	train-MAPE:1.03242	val-MAPE:1.34617
# [55]	train-rmse:18.8235	val-rmse:43.3371	train-MAPE:1.0327	val-MAPE:1.35032
# [56]	train-rmse:18.6138	val-rmse:43.61	train-MAPE:1.01597	val-MAPE:1.33814
# [57]	train-rmse:18.5047	val-rmse:43.4664	train-MAPE:1.01914	val-MAPE:1.33994
# [58]	train-rmse:18.3889	val-rmse:43.3235	train-MAPE:1.01531	val-MAPE:1.33604
# [59]	train-rmse:18.2868	val-rmse:43.2227	train-MAPE:1.01475	val-MAPE:1.33832
# [60]	train-rmse:18.195	val-rmse:43.0823	train-MAPE:1.00496	val-MAPE:1.32839
# [61]	train-rmse:18.1025	val-rmse:42.943	train-MAPE:0.999472	val-MAPE:1.32199
# [62]	train-rmse:18.0028	val-rmse:42.8759	train-MAPE:0.996833	val-MAPE:1.31979
# [63]	train-rmse:17.9188	val-rmse:42.8119	train-MAPE:0.996702	val-MAPE:1.32109
# [64]	train-rmse:17.8321	val-rmse:42.6844	train-MAPE:0.988648	val-MAPE:1.31478
# [65]	train-rmse:17.7389	val-rmse:42.6145	train-MAPE:0.991846	val-MAPE:1.31842
# [66]	train-rmse:17.6386	val-rmse:42.5614	train-MAPE:0.989675	val-MAPE:1.31999
# [67]	train-rmse:17.5574	val-rmse:42.4542	train-MAPE:0.987507	val-MAPE:1.32212
# [68]	train-rmse:17.4287	val-rmse:42.5906	train-MAPE:0.980333	val-MAPE:1.31253
# [69]	train-rmse:17.3507	val-rmse:42.477	train-MAPE:0.973775	val-MAPE:1.30939
# [70]	train-rmse:17.272	val-rmse:42.3739	train-MAPE:0.966512	val-MAPE:1.30083
# [71]	train-rmse:17.1591	val-rmse:42.2506	train-MAPE:0.957823	val-MAPE:1.29142
# [72]	train-rmse:17.0131	val-rmse:42.3881	train-MAPE:0.947967	val-MAPE:1.27963
# [73]	train-rmse:16.9369	val-rmse:42.3019	train-MAPE:0.944801	val-MAPE:1.27478
# [74]	train-rmse:16.8709	val-rmse:42.1985	train-MAPE:0.938608	val-MAPE:1.26901
# [75]	train-rmse:16.7868	val-rmse:42.3031	train-MAPE:0.932361	val-MAPE:1.26355
# [76]	train-rmse:16.7227	val-rmse:42.2381	train-MAPE:0.930256	val-MAPE:1.26377
# [77]	train-rmse:16.6545	val-rmse:42.3343	train-MAPE:0.922759	val-MAPE:1.25898
# [78]	train-rmse:16.5861	val-rmse:42.2328	train-MAPE:0.916254	val-MAPE:1.25603
# [79]	train-rmse:16.5226	val-rmse:42.2297	train-MAPE:0.908949	val-MAPE:1.24433
# [80]	train-rmse:16.464	val-rmse:42.2646	train-MAPE:0.904142	val-MAPE:1.23341
# [81]	train-rmse:16.3678	val-rmse:42.1688	train-MAPE:0.891886	val-MAPE:1.23306
# [82]	train-rmse:16.2035	val-rmse:42.2591	train-MAPE:0.875187	val-MAPE:1.22864
# [83]	train-rmse:16.1388	val-rmse:42.2611	train-MAPE:0.869096	val-MAPE:1.21906
# [84]	train-rmse:16.0659	val-rmse:42.2634	train-MAPE:0.861093	val-MAPE:1.21732
# [85]	train-rmse:15.9685	val-rmse:42.3077	train-MAPE:0.855699	val-MAPE:1.21495
# [86]	train-rmse:15.9201	val-rmse:42.2542	train-MAPE:0.853174	val-MAPE:1.2138
# [87]	train-rmse:15.8559	val-rmse:42.1832	train-MAPE:0.844732	val-MAPE:1.20394
# [88]	train-rmse:15.7384	val-rmse:42.2392	train-MAPE:0.83328	val-MAPE:1.19493
# [89]	train-rmse:15.6882	val-rmse:42.1721	train-MAPE:0.825973	val-MAPE:1.19123
# [90]	train-rmse:15.6192	val-rmse:42.3046	train-MAPE:0.819871	val-MAPE:1.18548
# [91]	train-rmse:15.5732	val-rmse:42.237	train-MAPE:0.809833	val-MAPE:1.17703
# [92]	train-rmse:15.5161	val-rmse:42.2501	train-MAPE:0.803164	val-MAPE:1.17212
# [93]	train-rmse:15.4708	val-rmse:42.3337	train-MAPE:0.796748	val-MAPE:1.16612
# [94]	train-rmse:15.4058	val-rmse:42.5015	train-MAPE:0.793745	val-MAPE:1.15994
# [95]	train-rmse:15.3594	val-rmse:42.4249	train-MAPE:0.792273	val-MAPE:1.15834
# [96]	train-rmse:15.2986	val-rmse:42.3887	train-MAPE:0.789277	val-MAPE:1.15601
# [97]	train-rmse:15.2309	val-rmse:42.3757	train-MAPE:0.785186	val-MAPE:1.15331
# [98]	train-rmse:15.183	val-rmse:42.462	train-MAPE:0.781877	val-MAPE:1.14992
# [99]	train-rmse:15.1327	val-rmse:42.5071	train-MAPE:0.778823	val-MAPE:1.14613
# [100]	train-rmse:15.0897	val-rmse:42.4604	train-MAPE:0.771085	val-MAPE:1.13929
# [101]	train-rmse:15.0042	val-rmse:42.4226	train-MAPE:0.761666	val-MAPE:1.13384
# [102]	train-rmse:14.9091	val-rmse:42.4524	train-MAPE:0.750537	val-MAPE:1.12745
# [103]	train-rmse:14.8662	val-rmse:42.3741	train-MAPE:0.746808	val-MAPE:1.12798
# [104]	train-rmse:14.7736	val-rmse:42.6297	train-MAPE:0.739502	val-MAPE:1.12376
# [105]	train-rmse:14.7316	val-rmse:42.6027	train-MAPE:0.736455	val-MAPE:1.12341
# [106]	train-rmse:14.6903	val-rmse:42.561	train-MAPE:0.73445	val-MAPE:1.12321
# [107]	train-rmse:14.6439	val-rmse:42.5876	train-MAPE:0.727489	val-MAPE:1.11469
# [108]	train-rmse:14.6079	val-rmse:42.5301	train-MAPE:0.723014	val-MAPE:1.11234
# [109]	train-rmse:14.5585	val-rmse:42.74	train-MAPE:0.718621	val-MAPE:1.10553
# [110]	train-rmse:14.4916	val-rmse:42.7158	train-MAPE:0.71053	val-MAPE:1.09988
# [111]	train-rmse:14.4444	val-rmse:42.6865	train-MAPE:0.707738	val-MAPE:1.09726
# [112]	train-rmse:14.2966	val-rmse:42.6168	train-MAPE:0.699025	val-MAPE:1.09013
# [113]	train-rmse:14.2421	val-rmse:42.6622	train-MAPE:0.695763	val-MAPE:1.09161
# [114]	train-rmse:14.2121	val-rmse:42.6426	train-MAPE:0.688448	val-MAPE:1.08621
# [115]	train-rmse:14.1689	val-rmse:42.6101	train-MAPE:0.685939	val-MAPE:1.08445
# [116]	train-rmse:14.131	val-rmse:42.5921	train-MAPE:0.682755	val-MAPE:1.08391
# [117]	train-rmse:14.0886	val-rmse:42.6081	train-MAPE:0.680884	val-MAPE:1.08589
# [118]	train-rmse:14.0559	val-rmse:42.5907	train-MAPE:0.677287	val-MAPE:1.0849
# [119]	train-rmse:14.027	val-rmse:42.687	train-MAPE:0.671805	val-MAPE:1.07981
# [120]	train-rmse:13.9839	val-rmse:42.7311	train-MAPE:0.665226	val-MAPE:1.08181
# [121]	train-rmse:13.9352	val-rmse:42.7696	train-MAPE:0.656656	val-MAPE:1.07888
# [122]	train-rmse:13.8006	val-rmse:42.7251	train-MAPE:0.650792	val-MAPE:1.07397
# [123]	train-rmse:13.7729	val-rmse:42.6746	train-MAPE:0.646501	val-MAPE:1.07052
# [124]	train-rmse:13.7404	val-rmse:42.6834	train-MAPE:0.645418	val-MAPE:1.07151
# [125]	train-rmse:13.6958	val-rmse:42.6489	train-MAPE:0.641444	val-MAPE:1.06931
# [126]	train-rmse:13.6669	val-rmse:42.6282	train-MAPE:0.637668	val-MAPE:1.0669
# [127]	train-rmse:13.5499	val-rmse:42.5737	train-MAPE:0.632628	val-MAPE:1.06188
# [128]	train-rmse:13.4249	val-rmse:42.5208	train-MAPE:0.624816	val-MAPE:1.0552
# [129]	train-rmse:13.3903	val-rmse:42.4853	train-MAPE:0.620908	val-MAPE:1.05149
# [130]	train-rmse:13.3644	val-rmse:42.4369	train-MAPE:0.616183	val-MAPE:1.04839
# [131]	train-rmse:13.3317	val-rmse:42.4891	train-MAPE:0.615611	val-MAPE:1.04896
# [132]	train-rmse:13.3005	val-rmse:42.4756	train-MAPE:0.611114	val-MAPE:1.04685
# [133]	train-rmse:13.2734	val-rmse:42.4615	train-MAPE:0.606353	val-MAPE:1.04317
# [134]	train-rmse:13.2427	val-rmse:42.4417	train-MAPE:0.604301	val-MAPE:1.04281
# [135]	train-rmse:13.2175	val-rmse:42.4114	train-MAPE:0.601696	val-MAPE:1.04111
# [136]	train-rmse:13.1567	val-rmse:42.5581	train-MAPE:0.594207	val-MAPE:1.03852
# [137]	train-rmse:13.1167	val-rmse:42.5407	train-MAPE:0.595198	val-MAPE:1.04154
# [138]	train-rmse:13.0914	val-rmse:42.5266	train-MAPE:0.592767	val-MAPE:1.04068
# [139]	train-rmse:13.0625	val-rmse:42.4525	train-MAPE:0.589245	val-MAPE:1.03979
# [140]	train-rmse:13.0388	val-rmse:42.4246	train-MAPE:0.583882	val-MAPE:1.03609
# [141]	train-rmse:12.9825	val-rmse:42.4696	train-MAPE:0.577535	val-MAPE:1.03151
# [142]	train-rmse:12.9439	val-rmse:42.4181	train-MAPE:0.575001	val-MAPE:1.03128
# [143]	train-rmse:12.9118	val-rmse:42.4222	train-MAPE:0.573729	val-MAPE:1.03203
# [144]	train-rmse:12.8364	val-rmse:42.3711	train-MAPE:0.571381	val-MAPE:1.02998
# [145]	train-rmse:12.8101	val-rmse:42.3403	train-MAPE:0.568407	val-MAPE:1.02985
# [146]	train-rmse:12.7859	val-rmse:42.3121	train-MAPE:0.566591	val-MAPE:1.02866
# [147]	train-rmse:12.7593	val-rmse:42.2803	train-MAPE:0.566094	val-MAPE:1.02783
# [148]	train-rmse:12.6548	val-rmse:42.2543	train-MAPE:0.560833	val-MAPE:1.02353
# [149]	train-rmse:12.5943	val-rmse:42.2767	train-MAPE:0.556803	val-MAPE:1.02539
# [150]	train-rmse:12.4998	val-rmse:42.3774	train-MAPE:0.552304	val-MAPE:1.01927
# [151]	train-rmse:12.476	val-rmse:42.3636	train-MAPE:0.550954	val-MAPE:1.01896
# [152]	train-rmse:12.4463	val-rmse:42.3906	train-MAPE:0.549789	val-MAPE:1.02006
# [153]	train-rmse:12.361	val-rmse:42.3579	train-MAPE:0.544759	val-MAPE:1.0157
# [154]	train-rmse:12.327	val-rmse:42.3845	train-MAPE:0.542686	val-MAPE:1.01686
# [155]	train-rmse:12.3042	val-rmse:42.4296	train-MAPE:0.541167	val-MAPE:1.01622
# [156]	train-rmse:12.2181	val-rmse:42.3783	train-MAPE:0.537812	val-MAPE:1.01336
# [157]	train-rmse:12.189	val-rmse:42.4287	train-MAPE:0.536029	val-MAPE:1.01147
# [158]	train-rmse:12.1105	val-rmse:42.4339	train-MAPE:0.532384	val-MAPE:1.00936
# [159]	train-rmse:12.075	val-rmse:42.3566	train-MAPE:0.530299	val-MAPE:1.00935
# [160]	train-rmse:12.0556	val-rmse:42.3382	train-MAPE:0.527639	val-MAPE:1.00685
# [161]	train-rmse:12.0357	val-rmse:42.3323	train-MAPE:0.524863	val-MAPE:1.00721
# [162]	train-rmse:11.9775	val-rmse:42.3103	train-MAPE:0.525027	val-MAPE:1.00868
# [163]	train-rmse:11.9589	val-rmse:42.2814	train-MAPE:0.522946	val-MAPE:1.00919
# [164]	train-rmse:11.9118	val-rmse:42.2819	train-MAPE:0.515152	val-MAPE:1.00882
# [165]	train-rmse:11.8964	val-rmse:42.3221	train-MAPE:0.510652	val-MAPE:1.0049
# [166]	train-rmse:11.876	val-rmse:42.3084	train-MAPE:0.508988	val-MAPE:1.00391
# [167]	train-rmse:11.8039	val-rmse:42.3066	train-MAPE:0.505621	val-MAPE:1.00179
# [168]	train-rmse:11.7524	val-rmse:42.2309	train-MAPE:0.501025	val-MAPE:1.00169
# [169]	train-rmse:11.6837	val-rmse:42.245	train-MAPE:0.498273	val-MAPE:0.999333
# [170]	train-rmse:11.6678	val-rmse:42.227	train-MAPE:0.496789	val-MAPE:0.998372
# [171]	train-rmse:11.6387	val-rmse:42.3079	train-MAPE:0.495786	val-MAPE:0.997527
# [172]	train-rmse:11.6097	val-rmse:42.3346	train-MAPE:0.493484	val-MAPE:0.997825
# [173]	train-rmse:11.5772	val-rmse:42.3147	train-MAPE:0.49243	val-MAPE:0.997129
# [174]	train-rmse:11.5306	val-rmse:42.299	train-MAPE:0.490105	val-MAPE:0.995641
# [175]	train-rmse:11.5036	val-rmse:42.2836	train-MAPE:0.487681	val-MAPE:0.994172
# [176]	train-rmse:11.4791	val-rmse:42.2035	train-MAPE:0.484886	val-MAPE:0.996329
# [177]	train-rmse:11.4602	val-rmse:42.187	train-MAPE:0.483764	val-MAPE:0.995487
# [178]	train-rmse:11.4337	val-rmse:42.1677	train-MAPE:0.482282	val-MAPE:0.995022
# [179]	train-rmse:11.4181	val-rmse:42.157	train-MAPE:0.480451	val-MAPE:0.993948
# [180]	train-rmse:11.401	val-rmse:42.1216	train-MAPE:0.479664	val-MAPE:0.993321
# [181]	train-rmse:11.3812	val-rmse:42.1002	train-MAPE:0.47754	val-MAPE:0.99231
# [182]	train-rmse:11.3582	val-rmse:42.081	train-MAPE:0.476043	val-MAPE:0.991408
# [183]	train-rmse:11.3292	val-rmse:42.0817	train-MAPE:0.472923	val-MAPE:0.992324
# [184]	train-rmse:11.3086	val-rmse:42.0745	train-MAPE:0.471922	val-MAPE:0.992549
# [185]	train-rmse:11.2833	val-rmse:42.0941	train-MAPE:0.469875	val-MAPE:0.99313
# [186]	train-rmse:11.2626	val-rmse:42.2075	train-MAPE:0.46781	val-MAPE:0.991228
# [187]	train-rmse:11.2498	val-rmse:42.2633	train-MAPE:0.465603	val-MAPE:0.989549
# [188]	train-rmse:11.2353	val-rmse:42.2118	train-MAPE:0.463936	val-MAPE:0.989604
# [189]	train-rmse:11.2233	val-rmse:42.1787	train-MAPE:0.462909	val-MAPE:0.989811
# [190]	train-rmse:11.2012	val-rmse:42.2052	train-MAPE:0.461204	val-MAPE:0.990697
# [191]	train-rmse:11.1653	val-rmse:42.1777	train-MAPE:0.462587	val-MAPE:0.991693
# [192]	train-rmse:11.1485	val-rmse:42.1836	train-MAPE:0.461388	val-MAPE:0.991884
# [193]	train-rmse:11.1359	val-rmse:42.2304	train-MAPE:0.45947	val-MAPE:0.990731
# [194]	train-rmse:11.0694	val-rmse:42.2197	train-MAPE:0.455834	val-MAPE:0.987876
# [195]	train-rmse:11.0468	val-rmse:42.211	train-MAPE:0.455062	val-MAPE:0.98744
# [196]	train-rmse:11.035	val-rmse:42.2028	train-MAPE:0.45469	val-MAPE:0.987883
# [197]	train-rmse:11.023	val-rmse:42.1798	train-MAPE:0.453221	val-MAPE:0.98735
# [198]	train-rmse:11.0117	val-rmse:42.1727	train-MAPE:0.451211	val-MAPE:0.986925
# [199]	train-rmse:10.9506	val-rmse:42.1567	train-MAPE:0.449307	val-MAPE:0.985057
# [200]	train-rmse:10.9286	val-rmse:42.1394	train-MAPE:0.448856	val-MAPE:0.984773
# [201]	train-rmse:10.914	val-rmse:42.2391	train-MAPE:0.445677	val-MAPE:0.982923
# [202]	train-rmse:10.8931	val-rmse:42.3025	train-MAPE:0.44297	val-MAPE:0.982548
# [203]	train-rmse:10.8503	val-rmse:42.286	train-MAPE:0.440537	val-MAPE:0.980287
# [204]	train-rmse:10.8137	val-rmse:42.273	train-MAPE:0.44004	val-MAPE:0.979925
# [205]	train-rmse:10.8014	val-rmse:42.2628	train-MAPE:0.438856	val-MAPE:0.979068
# [206]	train-rmse:10.7832	val-rmse:42.2446	train-MAPE:0.437751	val-MAPE:0.978329
# [207]	train-rmse:10.7693	val-rmse:42.2257	train-MAPE:0.437085	val-MAPE:0.977756
# [208]	train-rmse:10.7209	val-rmse:42.2066	train-MAPE:0.434696	val-MAPE:0.975749
# [209]	train-rmse:10.6894	val-rmse:42.2111	train-MAPE:0.431906	val-MAPE:0.976131
# [210]	train-rmse:10.6578	val-rmse:42.2042	train-MAPE:0.431228	val-MAPE:0.975666
# [211]	train-rmse:10.6293	val-rmse:42.2712	train-MAPE:0.429044	val-MAPE:0.974124
# [212]	train-rmse:10.6202	val-rmse:42.2615	train-MAPE:0.428335	val-MAPE:0.97344
# [213]	train-rmse:10.5793	val-rmse:42.3341	train-MAPE:0.426664	val-MAPE:0.971048
# [214]	train-rmse:10.5655	val-rmse:42.323	train-MAPE:0.42683	val-MAPE:0.971583
# [215]	train-rmse:10.5467	val-rmse:42.3144	train-MAPE:0.425449	val-MAPE:0.970717
# [216]	train-rmse:10.5357	val-rmse:42.3137	train-MAPE:0.42407	val-MAPE:0.97112
# [217]	train-rmse:10.511	val-rmse:42.2936	train-MAPE:0.423167	val-MAPE:0.970527
# [218]	train-rmse:10.5006	val-rmse:42.356	train-MAPE:0.421532	val-MAPE:0.969919
# [219]	train-rmse:10.48	val-rmse:42.3998	train-MAPE:0.418605	val-MAPE:0.968505
# [220]	train-rmse:10.4701	val-rmse:42.391	train-MAPE:0.417883	val-MAPE:0.967775
# [221]	train-rmse:10.4497	val-rmse:42.3842	train-MAPE:0.416557	val-MAPE:0.967627
# [222]	train-rmse:10.4411	val-rmse:42.3801	train-MAPE:0.41461	val-MAPE:0.966684
# [223]	train-rmse:10.4261	val-rmse:42.3988	train-MAPE:0.412514	val-MAPE:0.964374
# [224]	train-rmse:10.4149	val-rmse:42.3848	train-MAPE:0.411884	val-MAPE:0.964247
# [225]	train-rmse:10.398	val-rmse:42.3741	train-MAPE:0.411063	val-MAPE:0.964005
# [226]	train-rmse:10.3875	val-rmse:42.3636	train-MAPE:0.40935	val-MAPE:0.962516
# [227]	train-rmse:10.3781	val-rmse:42.3492	train-MAPE:0.409467	val-MAPE:0.961853
# [228]	train-rmse:10.3628	val-rmse:42.347	train-MAPE:0.408594	val-MAPE:0.961957
# [229]	train-rmse:10.3223	val-rmse:42.3399	train-MAPE:0.407534	val-MAPE:0.96057
# [230]	train-rmse:10.3113	val-rmse:42.3361	train-MAPE:0.40659	val-MAPE:0.960115
# [231]	train-rmse:10.2824	val-rmse:42.3318	train-MAPE:0.407346	val-MAPE:0.96034
# [232]	train-rmse:10.2668	val-rmse:42.3121	train-MAPE:0.406703	val-MAPE:0.960932
# [233]	train-rmse:10.2557	val-rmse:42.3001	train-MAPE:0.405679	val-MAPE:0.96079
# [234]	train-rmse:10.2452	val-rmse:42.289	train-MAPE:0.405212	val-MAPE:0.960303
# [235]	train-rmse:10.2336	val-rmse:42.2726	train-MAPE:0.404275	val-MAPE:0.959494
# [236]	train-rmse:10.2223	val-rmse:42.3453	train-MAPE:0.402474	val-MAPE:0.959438
# [237]	train-rmse:10.2147	val-rmse:42.3605	train-MAPE:0.401918	val-MAPE:0.958892
# [238]	train-rmse:10.2052	val-rmse:42.3474	train-MAPE:0.401512	val-MAPE:0.958392
# [239]	train-rmse:10.1881	val-rmse:42.3393	train-MAPE:0.40074	val-MAPE:0.958484
# [240]	train-rmse:10.1782	val-rmse:42.3284	train-MAPE:0.398996	val-MAPE:0.958006
# [241]	train-rmse:10.1385	val-rmse:42.3022	train-MAPE:0.397971	val-MAPE:0.956617
# [242]	train-rmse:10.1261	val-rmse:42.345	train-MAPE:0.397565	val-MAPE:0.956285
# [243]	train-rmse:10.1129	val-rmse:42.3525	train-MAPE:0.39692	val-MAPE:0.956882
# [244]	train-rmse:10.0954	val-rmse:42.3437	train-MAPE:0.396266	val-MAPE:0.956699
# [245]	train-rmse:10.0818	val-rmse:42.3423	train-MAPE:0.395213	val-MAPE:0.957068
# [246]	train-rmse:10.0439	val-rmse:42.3261	train-MAPE:0.394758	val-MAPE:0.956943
# [247]	train-rmse:10.0024	val-rmse:42.3044	train-MAPE:0.394157	val-MAPE:0.957437
# [248]	train-rmse:9.98482	val-rmse:42.287	train-MAPE:0.393499	val-MAPE:0.957303
# [249]	train-rmse:9.96293	val-rmse:42.2707	train-MAPE:0.391118	val-MAPE:0.958079
# [250]	train-rmse:9.95258	val-rmse:42.2586	train-MAPE:0.391038	val-MAPE:0.958853
# [251]	train-rmse:9.94187	val-rmse:42.2616	train-MAPE:0.390282	val-MAPE:0.958694
# [252]	train-rmse:9.92913	val-rmse:42.2574	train-MAPE:0.389805	val-MAPE:0.95856
# [253]	train-rmse:9.91755	val-rmse:42.2351	train-MAPE:0.390006	val-MAPE:0.958504
# [254]	train-rmse:9.91142	val-rmse:42.232	train-MAPE:0.389131	val-MAPE:0.958375
# [255]	train-rmse:9.90615	val-rmse:42.2544	train-MAPE:0.388632	val-MAPE:0.957482
# [256]	train-rmse:9.8959	val-rmse:42.2507	train-MAPE:0.388422	val-MAPE:0.95791
# [257]	train-rmse:9.88457	val-rmse:42.2166	train-MAPE:0.388044	val-MAPE:0.957365
# [258]	train-rmse:9.86902	val-rmse:42.2333	train-MAPE:0.38742	val-MAPE:0.956948
# [259]	train-rmse:9.83929	val-rmse:42.2444	train-MAPE:0.386833	val-MAPE:0.957172
# [260]	train-rmse:9.82899	val-rmse:42.2179	train-MAPE:0.386207	val-MAPE:0.956859
# [261]	train-rmse:9.82149	val-rmse:42.2212	train-MAPE:0.385058	val-MAPE:0.956067
# [262]	train-rmse:9.81417	val-rmse:42.2096	train-MAPE:0.385031	val-MAPE:0.956013
# [263]	train-rmse:9.80843	val-rmse:42.1914	train-MAPE:0.385021	val-MAPE:0.956345
# [264]	train-rmse:9.8012	val-rmse:42.188	train-MAPE:0.384449	val-MAPE:0.955934
# [265]	train-rmse:9.78948	val-rmse:42.2042	train-MAPE:0.383679	val-MAPE:0.955689
# [266]	train-rmse:9.78167	val-rmse:42.2405	train-MAPE:0.382722	val-MAPE:0.955414
# [267]	train-rmse:9.76741	val-rmse:42.2421	train-MAPE:0.380758	val-MAPE:0.955273
# [268]	train-rmse:9.75136	val-rmse:42.2667	train-MAPE:0.380543	val-MAPE:0.954873
# [269]	train-rmse:9.73757	val-rmse:42.251	train-MAPE:0.379941	val-MAPE:0.955087
# [270]	train-rmse:9.72662	val-rmse:42.2624	train-MAPE:0.378903	val-MAPE:0.95494
# [271]	train-rmse:9.71925	val-rmse:42.2742	train-MAPE:0.378593	val-MAPE:0.955409
# [272]	train-rmse:9.69424	val-rmse:42.2635	train-MAPE:0.378209	val-MAPE:0.955432
# [273]	train-rmse:9.67531	val-rmse:42.2757	train-MAPE:0.374777	val-MAPE:0.954776
# [274]	train-rmse:9.66807	val-rmse:42.2503	train-MAPE:0.374125	val-MAPE:0.954709
# [275]	train-rmse:9.65925	val-rmse:42.2682	train-MAPE:0.373645	val-MAPE:0.955294
# [276]	train-rmse:9.65191	val-rmse:42.291	train-MAPE:0.373094	val-MAPE:0.954917
# [277]	train-rmse:9.62457	val-rmse:42.2833	train-MAPE:0.371097	val-MAPE:0.953034
# [278]	train-rmse:9.61774	val-rmse:42.2798	train-MAPE:0.370414	val-MAPE:0.952877
# [279]	train-rmse:9.6084	val-rmse:42.2784	train-MAPE:0.369951	val-MAPE:0.952445
# [280]	train-rmse:9.60377	val-rmse:42.2928	train-MAPE:0.36925	val-MAPE:0.95214
# [281]	train-rmse:9.58964	val-rmse:42.3015	train-MAPE:0.3679	val-MAPE:0.952048
# [282]	train-rmse:9.58474	val-rmse:42.3072	train-MAPE:0.36672	val-MAPE:0.950728
# [283]	train-rmse:9.56211	val-rmse:42.2975	train-MAPE:0.364865	val-MAPE:0.949778
# [284]	train-rmse:9.53601	val-rmse:42.302	train-MAPE:0.363956	val-MAPE:0.949537
# [285]	train-rmse:9.52796	val-rmse:42.2897	train-MAPE:0.364201	val-MAPE:0.949431
# [286]	train-rmse:9.52	val-rmse:42.2981	train-MAPE:0.364006	val-MAPE:0.949787
# [287]	train-rmse:9.51655	val-rmse:42.2672	train-MAPE:0.363714	val-MAPE:0.949495
# [288]	train-rmse:9.50966	val-rmse:42.2701	train-MAPE:0.363515	val-MAPE:0.949231
# [289]	train-rmse:9.50506	val-rmse:42.2841	train-MAPE:0.361521	val-MAPE:0.947776
# [290]	train-rmse:9.50019	val-rmse:42.2724	train-MAPE:0.360615	val-MAPE:0.946614
# [291]	train-rmse:9.49379	val-rmse:42.2846	train-MAPE:0.360004	val-MAPE:0.946679
# [292]	train-rmse:9.48539	val-rmse:42.2885	train-MAPE:0.359063	val-MAPE:0.946414
# [293]	train-rmse:9.46661	val-rmse:42.3045	train-MAPE:0.359658	val-MAPE:0.946301
# [294]	train-rmse:9.46292	val-rmse:42.3026	train-MAPE:0.359355	val-MAPE:0.94614
# [295]	train-rmse:9.45477	val-rmse:42.3131	train-MAPE:0.359988	val-MAPE:0.945945
# [296]	train-rmse:9.44713	val-rmse:42.3	train-MAPE:0.359786	val-MAPE:0.945829
# [297]	train-rmse:9.43998	val-rmse:42.3029	train-MAPE:0.359648	val-MAPE:0.945891
# [298]	train-rmse:9.43502	val-rmse:42.3257	train-MAPE:0.35879	val-MAPE:0.945825
# [299]	train-rmse:9.42372	val-rmse:42.3325	train-MAPE:0.358082	val-MAPE:0.945629
# [300]	train-rmse:9.41393	val-rmse:42.3457	train-MAPE:0.356824	val-MAPE:0.945638
# [301]	train-rmse:9.4009	val-rmse:42.3494	train-MAPE:0.357409	val-MAPE:0.946113
# [302]	train-rmse:9.39363	val-rmse:42.3152	train-MAPE:0.357535	val-MAPE:0.94629
# [303]	train-rmse:9.38162	val-rmse:42.2982	train-MAPE:0.357172	val-MAPE:0.945999
# [304]	train-rmse:9.36516	val-rmse:42.3334	train-MAPE:0.356038	val-MAPE:0.945291
# [305]	train-rmse:9.33455	val-rmse:42.3266	train-MAPE:0.357685	val-MAPE:0.946672
# [306]	train-rmse:9.32157	val-rmse:42.3407	train-MAPE:0.357308	val-MAPE:0.946371
# [307]	train-rmse:9.31239	val-rmse:42.3391	train-MAPE:0.356479	val-MAPE:0.946278
# [308]	train-rmse:9.30111	val-rmse:42.3566	train-MAPE:0.355242	val-MAPE:0.946505
# [309]	train-rmse:9.29516	val-rmse:42.3544	train-MAPE:0.354667	val-MAPE:0.946163
# [310]	train-rmse:9.28015	val-rmse:42.3293	train-MAPE:0.353707	val-MAPE:0.945774
# [311]	train-rmse:9.27162	val-rmse:42.3236	train-MAPE:0.352958	val-MAPE:0.945469
# [312]	train-rmse:9.26771	val-rmse:42.3135	train-MAPE:0.352706	val-MAPE:0.945414
# [313]	train-rmse:9.2615	val-rmse:42.3043	train-MAPE:0.352327	val-MAPE:0.945266
# [314]	train-rmse:9.24572	val-rmse:42.329	train-MAPE:0.352184	val-MAPE:0.945199
# [315]	train-rmse:9.23891	val-rmse:42.3338	train-MAPE:0.351979	val-MAPE:0.945271
# [316]	train-rmse:9.22879	val-rmse:42.3309	train-MAPE:0.351361	val-MAPE:0.945437
# [317]	train-rmse:9.22383	val-rmse:42.3287	train-MAPE:0.350846	val-MAPE:0.944241
# [318]	train-rmse:9.21714	val-rmse:42.3237	train-MAPE:0.350572	val-MAPE:0.944162
# [319]	train-rmse:9.20719	val-rmse:42.3177	train-MAPE:0.350336	val-MAPE:0.944324
# [320]	train-rmse:9.19641	val-rmse:42.2961	train-MAPE:0.350069	val-MAPE:0.944178
# [321]	train-rmse:9.17376	val-rmse:42.2931	train-MAPE:0.348528	val-MAPE:0.943126
# [322]	train-rmse:9.16707	val-rmse:42.3028	train-MAPE:0.34835	val-MAPE:0.943225
# [323]	train-rmse:9.16155	val-rmse:42.2948	train-MAPE:0.348321	val-MAPE:0.943473
# [324]	train-rmse:9.15074	val-rmse:42.2817	train-MAPE:0.347671	val-MAPE:0.94338
# [325]	train-rmse:9.14795	val-rmse:42.2803	train-MAPE:0.346373	val-MAPE:0.943008
# [326]	train-rmse:9.14347	val-rmse:42.2967	train-MAPE:0.345702	val-MAPE:0.942917
# [327]	train-rmse:9.13068	val-rmse:42.2929	train-MAPE:0.345669	val-MAPE:0.942805
# [328]	train-rmse:9.12443	val-rmse:42.2827	train-MAPE:0.34579	val-MAPE:0.943107
# [329]	train-rmse:9.11721	val-rmse:42.2743	train-MAPE:0.345577	val-MAPE:0.942974
# [330]	train-rmse:9.11425	val-rmse:42.2667	train-MAPE:0.345477	val-MAPE:0.942875
# [331]	train-rmse:9.11372	val-rmse:42.2763	train-MAPE:0.345002	val-MAPE:0.942645
# [332]	train-rmse:9.10676	val-rmse:42.2625	train-MAPE:0.346102	val-MAPE:0.943255
# [333]	train-rmse:9.10202	val-rmse:42.2612	train-MAPE:0.345604	val-MAPE:0.943538
# [334]	train-rmse:9.09916	val-rmse:42.2593	train-MAPE:0.345269	val-MAPE:0.944026
# [335]	train-rmse:9.09245	val-rmse:42.244	train-MAPE:0.344989	val-MAPE:0.944092
# [336]	train-rmse:9.09014	val-rmse:42.2492	train-MAPE:0.343752	val-MAPE:0.943544
# [337]	train-rmse:9.06996	val-rmse:42.267	train-MAPE:0.342384	val-MAPE:0.942969
# [338]	train-rmse:9.0606	val-rmse:42.3019	train-MAPE:0.341313	val-MAPE:0.942573
# [339]	train-rmse:9.0553	val-rmse:42.2703	train-MAPE:0.341272	val-MAPE:0.94239
# [340]	train-rmse:9.05003	val-rmse:42.2782	train-MAPE:0.340431	val-MAPE:0.942295
# [341]	train-rmse:9.03925	val-rmse:42.2735	train-MAPE:0.339257	val-MAPE:0.942143
# [342]	train-rmse:9.02816	val-rmse:42.2778	train-MAPE:0.338927	val-MAPE:0.942168
# [343]	train-rmse:9.02423	val-rmse:42.2913	train-MAPE:0.338003	val-MAPE:0.941638
# [344]	train-rmse:9.01815	val-rmse:42.3192	train-MAPE:0.338015	val-MAPE:0.941554
# [345]	train-rmse:8.99521	val-rmse:42.304	train-MAPE:0.338128	val-MAPE:0.941518
# [346]	train-rmse:8.98757	val-rmse:42.3102	train-MAPE:0.337708	val-MAPE:0.94178
# [347]	train-rmse:8.96894	val-rmse:42.2861	train-MAPE:0.337944	val-MAPE:0.941995
# [348]	train-rmse:8.94344	val-rmse:42.2853	train-MAPE:0.338044	val-MAPE:0.941965
# [349]	train-rmse:8.9391	val-rmse:42.2793	train-MAPE:0.338463	val-MAPE:0.942261
# [350]	train-rmse:8.92749	val-rmse:42.2776	train-MAPE:0.338041	val-MAPE:0.942111
# [351]	train-rmse:8.91747	val-rmse:42.277	train-MAPE:0.338095	val-MAPE:0.942231
# [352]	train-rmse:8.9119	val-rmse:42.2658	train-MAPE:0.338066	val-MAPE:0.942368
# [353]	train-rmse:8.89974	val-rmse:42.2796	train-MAPE:0.337784	val-MAPE:0.942326
# [354]	train-rmse:8.8925	val-rmse:42.2698	train-MAPE:0.337646	val-MAPE:0.942273
# [355]	train-rmse:8.88382	val-rmse:42.2545	train-MAPE:0.336879	val-MAPE:0.941746
# [356]	train-rmse:8.87776	val-rmse:42.2672	train-MAPE:0.336307	val-MAPE:0.9413
# [357]	train-rmse:8.8665	val-rmse:42.2433	train-MAPE:0.336291	val-MAPE:0.941792
# [358]	train-rmse:8.85462	val-rmse:42.2443	train-MAPE:0.336991	val-MAPE:0.942314
# [359]	train-rmse:8.84908	val-rmse:42.2461	train-MAPE:0.336966	val-MAPE:0.942601
# [360]	train-rmse:8.84482	val-rmse:42.2264	train-MAPE:0.336467	val-MAPE:0.942522
# [361]	train-rmse:8.83604	val-rmse:42.2237	train-MAPE:0.335496	val-MAPE:0.942376
# [362]	train-rmse:8.82638	val-rmse:42.224	train-MAPE:0.335489	val-MAPE:0.94257
# [363]	train-rmse:8.82225	val-rmse:42.1982	train-MAPE:0.335456	val-MAPE:0.942606
# [364]	train-rmse:8.81745	val-rmse:42.1996	train-MAPE:0.334999	val-MAPE:0.942432
# [365]	train-rmse:8.81387	val-rmse:42.2141	train-MAPE:0.334266	val-MAPE:0.941998
# [366]	train-rmse:8.80455	val-rmse:42.2094	train-MAPE:0.334379	val-MAPE:0.941741
# [367]	train-rmse:8.78096	val-rmse:42.1928	train-MAPE:0.335731	val-MAPE:0.942526
# [368]	train-rmse:8.77792	val-rmse:42.2036	train-MAPE:0.33526	val-MAPE:0.942238
# [369]	train-rmse:8.77272	val-rmse:42.1903	train-MAPE:0.335115	val-MAPE:0.942018
# [370]	train-rmse:8.76874	val-rmse:42.1856	train-MAPE:0.335126	val-MAPE:0.942375
# [371]	train-rmse:8.76371	val-rmse:42.1929	train-MAPE:0.334275	val-MAPE:0.942286
# [372]	train-rmse:8.75786	val-rmse:42.1758	train-MAPE:0.333897	val-MAPE:0.942363
# [373]	train-rmse:8.75454	val-rmse:42.1937	train-MAPE:0.333041	val-MAPE:0.942024
# [374]	train-rmse:8.74023	val-rmse:42.2029	train-MAPE:0.333571	val-MAPE:0.94232
# [375]	train-rmse:8.73247	val-rmse:42.1936	train-MAPE:0.333599	val-MAPE:0.942452
# [376]	train-rmse:8.72813	val-rmse:42.1856	train-MAPE:0.333115	val-MAPE:0.942885
# [377]	train-rmse:8.72593	val-rmse:42.181	train-MAPE:0.333074	val-MAPE:0.942928
# [378]	train-rmse:8.72005	val-rmse:42.1856	train-MAPE:0.332908	val-MAPE:0.942671
# [379]	train-rmse:8.71247	val-rmse:42.1822	train-MAPE:0.332316	val-MAPE:0.942568
# [380]	train-rmse:8.70852	val-rmse:42.1855	train-MAPE:0.332344	val-MAPE:0.942362
# [381]	train-rmse:8.70435	val-rmse:42.1838	train-MAPE:0.332064	val-MAPE:0.942328
# [382]	train-rmse:8.70044	val-rmse:42.1702	train-MAPE:0.330926	val-MAPE:0.941512
# [383]	train-rmse:8.69665	val-rmse:42.1887	train-MAPE:0.330319	val-MAPE:0.941442
# [384]	train-rmse:8.68818	val-rmse:42.1983	train-MAPE:0.330086	val-MAPE:0.941339
# [385]	train-rmse:8.68416	val-rmse:42.1873	train-MAPE:0.32996	val-MAPE:0.941175
# [386]	train-rmse:8.66761	val-rmse:42.1815	train-MAPE:0.328775	val-MAPE:0.940108
# [387]	train-rmse:8.66283	val-rmse:42.175	train-MAPE:0.328113	val-MAPE:0.940317
# [388]	train-rmse:8.65453	val-rmse:42.1714	train-MAPE:0.327928	val-MAPE:0.940126
# [389]	train-rmse:8.64572	val-rmse:42.1576	train-MAPE:0.327277	val-MAPE:0.940472
# [390]	train-rmse:8.64181	val-rmse:42.1535	train-MAPE:0.327194	val-MAPE:0.940427
# [391]	train-rmse:8.62983	val-rmse:42.1532	train-MAPE:0.325577	val-MAPE:0.939164
# [392]	train-rmse:8.62456	val-rmse:42.1463	train-MAPE:0.325681	val-MAPE:0.939242
# [393]	train-rmse:8.61957	val-rmse:42.1203	train-MAPE:0.325564	val-MAPE:0.939139
# [394]	train-rmse:8.61402	val-rmse:42.1092	train-MAPE:0.325727	val-MAPE:0.939153
# [395]	train-rmse:8.607	val-rmse:42.1089	train-MAPE:0.325664	val-MAPE:0.939472
# [396]	train-rmse:8.6018	val-rmse:42.0872	train-MAPE:0.325333	val-MAPE:0.939311
# [397]	train-rmse:8.59814	val-rmse:42.0791	train-MAPE:0.325389	val-MAPE:0.939296
# [398]	train-rmse:8.5886	val-rmse:42.0708	train-MAPE:0.325142	val-MAPE:0.939763
# [399]	train-rmse:8.58487	val-rmse:42.0695	train-MAPE:0.324926	val-MAPE:0.939748
# [400]	train-rmse:8.58147	val-rmse:42.0574	train-MAPE:0.325094	val-MAPE:0.939896
# [401]	train-rmse:8.57876	val-rmse:42.0664	train-MAPE:0.324905	val-MAPE:0.939838
# [402]	train-rmse:8.57259	val-rmse:42.054	train-MAPE:0.325306	val-MAPE:0.940167
# [403]	train-rmse:8.55672	val-rmse:42.0517	train-MAPE:0.323259	val-MAPE:0.938931
# [404]	train-rmse:8.551	val-rmse:42.0181	train-MAPE:0.322816	val-MAPE:0.939881
# [405]	train-rmse:8.54614	val-rmse:42.0121	train-MAPE:0.322758	val-MAPE:0.939997
# [406]	train-rmse:8.53973	val-rmse:42.0207	train-MAPE:0.321711	val-MAPE:0.939886
# [407]	train-rmse:8.53401	val-rmse:42.0243	train-MAPE:0.32174	val-MAPE:0.94047
# [408]	train-rmse:8.52853	val-rmse:42.0253	train-MAPE:0.321803	val-MAPE:0.940667
# [409]	train-rmse:8.52257	val-rmse:42.0463	train-MAPE:0.321432	val-MAPE:0.940132
# [410]	train-rmse:8.51907	val-rmse:42.0566	train-MAPE:0.321233	val-MAPE:0.940035
# [411]	train-rmse:8.51526	val-rmse:42.0782	train-MAPE:0.321366	val-MAPE:0.939634
# [412]	train-rmse:8.50909	val-rmse:42.0844	train-MAPE:0.321311	val-MAPE:0.939846
# [413]	train-rmse:8.50257	val-rmse:42.091	train-MAPE:0.320858	val-MAPE:0.939717
# [414]	train-rmse:8.49663	val-rmse:42.079	train-MAPE:0.320552	val-MAPE:0.939618
# [415]	train-rmse:8.48725	val-rmse:42.0755	train-MAPE:0.32041	val-MAPE:0.939564
# [416]	train-rmse:8.48336	val-rmse:42.0807	train-MAPE:0.320144	val-MAPE:0.939539
# [417]	train-rmse:8.47884	val-rmse:42.086	train-MAPE:0.319722	val-MAPE:0.939654
# [418]	train-rmse:8.47691	val-rmse:42.0755	train-MAPE:0.319808	val-MAPE:0.93961
# [419]	train-rmse:8.46387	val-rmse:42.0777	train-MAPE:0.318471	val-MAPE:0.938684
# [420]	train-rmse:8.46235	val-rmse:42.0751	train-MAPE:0.318074	val-MAPE:0.938507
# [421]	train-rmse:8.45935	val-rmse:42.0834	train-MAPE:0.318108	val-MAPE:0.938562
# [422]	train-rmse:8.45183	val-rmse:42.087	train-MAPE:0.318035	val-MAPE:0.938523
# [423]	train-rmse:8.452	val-rmse:42.1018	train-MAPE:0.317736	val-MAPE:0.938422
# [424]	train-rmse:8.44672	val-rmse:42.0911	train-MAPE:0.317759	val-MAPE:0.93858
# [425]	train-rmse:8.44401	val-rmse:42.0906	train-MAPE:0.317538	val-MAPE:0.93872
# [426]	train-rmse:8.43931	val-rmse:42.0865	train-MAPE:0.317298	val-MAPE:0.938549
# [427]	train-rmse:8.43259	val-rmse:42.0839	train-MAPE:0.317197	val-MAPE:0.938689
# [428]	train-rmse:8.42552	val-rmse:42.0715	train-MAPE:0.317142	val-MAPE:0.938745
# [429]	train-rmse:8.41888	val-rmse:42.088	train-MAPE:0.31637	val-MAPE:0.938894
# [430]	train-rmse:8.41776	val-rmse:42.084	train-MAPE:0.316088	val-MAPE:0.938857
# [431]	train-rmse:8.39625	val-rmse:42.082	train-MAPE:0.317194	val-MAPE:0.939878
# [432]	train-rmse:8.39341	val-rmse:42.0943	train-MAPE:0.31722	val-MAPE:0.939972
# [433]	train-rmse:8.38656	val-rmse:42.0986	train-MAPE:0.317012	val-MAPE:0.939962
# [434]	train-rmse:8.38404	val-rmse:42.1069	train-MAPE:0.316784	val-MAPE:0.939692
# [435]	train-rmse:8.37229	val-rmse:42.1089	train-MAPE:0.31562	val-MAPE:0.938804
# [436]	train-rmse:8.3639	val-rmse:42.1425	train-MAPE:0.315325	val-MAPE:0.938783
# [437]	train-rmse:8.35808	val-rmse:42.1289	train-MAPE:0.315171	val-MAPE:0.93873
# [438]	train-rmse:8.35434	val-rmse:42.1148	train-MAPE:0.315025	val-MAPE:0.938251
# [439]	train-rmse:8.34956	val-rmse:42.1067	train-MAPE:0.315035	val-MAPE:0.938235
# [440]	train-rmse:8.34197	val-rmse:42.0985	train-MAPE:0.315281	val-MAPE:0.938106
# [441]	train-rmse:8.33956	val-rmse:42.0985	train-MAPE:0.315268	val-MAPE:0.938233
# [442]	train-rmse:8.33128	val-rmse:42.0934	train-MAPE:0.315424	val-MAPE:0.938326
# [443]	train-rmse:8.31687	val-rmse:42.0902	train-MAPE:0.314513	val-MAPE:0.938262
# [444]	train-rmse:8.31134	val-rmse:42.0884	train-MAPE:0.314399	val-MAPE:0.938486
# [445]	train-rmse:8.30795	val-rmse:42.1127	train-MAPE:0.314298	val-MAPE:0.938317
# [446]	train-rmse:8.30227	val-rmse:42.1203	train-MAPE:0.314136	val-MAPE:0.938294
# [447]	train-rmse:8.29948	val-rmse:42.1124	train-MAPE:0.314129	val-MAPE:0.938351
# [448]	train-rmse:8.29295	val-rmse:42.1165	train-MAPE:0.314635	val-MAPE:0.938549
# [449]	train-rmse:8.28828	val-rmse:42.1217	train-MAPE:0.314404	val-MAPE:0.938447
# [450]	train-rmse:8.28557	val-rmse:42.1256	train-MAPE:0.314231	val-MAPE:0.938448
# [451]	train-rmse:8.28126	val-rmse:42.1121	train-MAPE:0.314075	val-MAPE:0.938356
# [452]	train-rmse:8.27641	val-rmse:42.1172	train-MAPE:0.313833	val-MAPE:0.938317
# [453]	train-rmse:8.26639	val-rmse:42.1244	train-MAPE:0.315247	val-MAPE:0.939583
# [454]	train-rmse:8.25481	val-rmse:42.117	train-MAPE:0.3158	val-MAPE:0.939967
# [455]	train-rmse:8.24833	val-rmse:42.1307	train-MAPE:0.315602	val-MAPE:0.939989
# [456]	train-rmse:8.2404	val-rmse:42.1308	train-MAPE:0.3157	val-MAPE:0.939965
# [457]	train-rmse:8.23414	val-rmse:42.1375	train-MAPE:0.314537	val-MAPE:0.93927
# [458]	train-rmse:8.22912	val-rmse:42.1263	train-MAPE:0.31407	val-MAPE:0.938847
# [459]	train-rmse:8.21917	val-rmse:42.124	train-MAPE:0.314858	val-MAPE:0.939622
# [460]	train-rmse:8.2162	val-rmse:42.1421	train-MAPE:0.314491	val-MAPE:0.939331
# [461]	train-rmse:8.21231	val-rmse:42.1267	train-MAPE:0.314149	val-MAPE:0.939074
# [462]	train-rmse:8.20871	val-rmse:42.1214	train-MAPE:0.313809	val-MAPE:0.938807
# [463]	train-rmse:8.20603	val-rmse:42.1138	train-MAPE:0.31384	val-MAPE:0.938998
# [464]	train-rmse:8.20235	val-rmse:42.1187	train-MAPE:0.313728	val-MAPE:0.939043
# [465]	train-rmse:8.19896	val-rmse:42.1211	train-MAPE:0.312736	val-MAPE:0.938512
# [466]	train-rmse:8.19933	val-rmse:42.1273	train-MAPE:0.31241	val-MAPE:0.938712
# [467]	train-rmse:8.19357	val-rmse:42.1342	train-MAPE:0.312211	val-MAPE:0.93878
# [468]	train-rmse:8.18755	val-rmse:42.1364	train-MAPE:0.312958	val-MAPE:0.939525
# [469]	train-rmse:8.18567	val-rmse:42.1345	train-MAPE:0.312717	val-MAPE:0.939359
# [470]	train-rmse:8.18308	val-rmse:42.1152	train-MAPE:0.312931	val-MAPE:0.939353
# [471]	train-rmse:8.18108	val-rmse:42.1175	train-MAPE:0.31291	val-MAPE:0.939282
# [472]	train-rmse:8.17739	val-rmse:42.1087	train-MAPE:0.312089	val-MAPE:0.939045
# [473]	train-rmse:8.17347	val-rmse:42.1323	train-MAPE:0.311652	val-MAPE:0.938817
# [474]	train-rmse:8.16593	val-rmse:42.1294	train-MAPE:0.310638	val-MAPE:0.938417
# [475]	train-rmse:8.16445	val-rmse:42.1262	train-MAPE:0.309981	val-MAPE:0.937818
# [476]	train-rmse:8.15387	val-rmse:42.1142	train-MAPE:0.308489	val-MAPE:0.937503
# [477]	train-rmse:8.15008	val-rmse:42.1079	train-MAPE:0.308222	val-MAPE:0.937376
# [478]	train-rmse:8.14754	val-rmse:42.1141	train-MAPE:0.307153	val-MAPE:0.937175
# [479]	train-rmse:8.14089	val-rmse:42.1056	train-MAPE:0.307099	val-MAPE:0.937069
# [480]	train-rmse:8.13105	val-rmse:42.1028	train-MAPE:0.306187	val-MAPE:0.936872
# [481]	train-rmse:8.12804	val-rmse:42.1027	train-MAPE:0.306047	val-MAPE:0.936966
# [482]	train-rmse:8.12265	val-rmse:42.0993	train-MAPE:0.30589	val-MAPE:0.937035
# [483]	train-rmse:8.1191	val-rmse:42.0984	train-MAPE:0.305638	val-MAPE:0.937213
# [484]	train-rmse:8.11222	val-rmse:42.1072	train-MAPE:0.305256	val-MAPE:0.937237
# [485]	train-rmse:8.1078	val-rmse:42.1103	train-MAPE:0.304837	val-MAPE:0.93726
# [486]	train-rmse:8.10638	val-rmse:42.1089	train-MAPE:0.30501	val-MAPE:0.937281
# [487]	train-rmse:8.103	val-rmse:42.1203	train-MAPE:0.304373	val-MAPE:0.937203
# [488]	train-rmse:8.09831	val-rmse:42.1171	train-MAPE:0.303884	val-MAPE:0.936945
# [489]	train-rmse:8.09352	val-rmse:42.1324	train-MAPE:0.303277	val-MAPE:0.936764
# [490]	train-rmse:8.092	val-rmse:42.1188	train-MAPE:0.302859	val-MAPE:0.93651
# [491]	train-rmse:8.08485	val-rmse:42.1124	train-MAPE:0.302471	val-MAPE:0.936259
# [492]	train-rmse:8.0811	val-rmse:42.1147	train-MAPE:0.301831	val-MAPE:0.936162
# [493]	train-rmse:8.07647	val-rmse:42.1029	train-MAPE:0.301505	val-MAPE:0.935879
# [494]	train-rmse:8.07038	val-rmse:42.0909	train-MAPE:0.30196	val-MAPE:0.935932
# [495]	train-rmse:8.05734	val-rmse:42.1033	train-MAPE:0.303093	val-MAPE:0.937507
# [496]	train-rmse:8.05279	val-rmse:42.0989	train-MAPE:0.302984	val-MAPE:0.93773
# [497]	train-rmse:8.04548	val-rmse:42.1122	train-MAPE:0.302709	val-MAPE:0.937772
# [498]	train-rmse:8.04001	val-rmse:42.1165	train-MAPE:0.302739	val-MAPE:0.937808
# [499]	train-rmse:8.03482	val-rmse:42.1156	train-MAPE:0.302816	val-MAPE:0.937894
# [500]	train-rmse:8.03287	val-rmse:42.1237	train-MAPE:0.302474	val-MAPE:0.937639
# [501]	train-rmse:8.02926	val-rmse:42.1135	train-MAPE:0.302616	val-MAPE:0.937602
# [502]	train-rmse:8.02341	val-rmse:42.1227	train-MAPE:0.302306	val-MAPE:0.937632
# [503]	train-rmse:8.01642	val-rmse:42.127	train-MAPE:0.302468	val-MAPE:0.937779
# [504]	train-rmse:8.01344	val-rmse:42.1292	train-MAPE:0.302441	val-MAPE:0.937901
# [505]	train-rmse:8.00524	val-rmse:42.124	train-MAPE:0.302093	val-MAPE:0.938177
# [506]	train-rmse:7.99869	val-rmse:42.1288	train-MAPE:0.30273	val-MAPE:0.939091
# [507]	train-rmse:7.97968	val-rmse:42.1215	train-MAPE:0.301617	val-MAPE:0.938699
# [508]	train-rmse:7.97894	val-rmse:42.1268	train-MAPE:0.300597	val-MAPE:0.938015
# [509]	train-rmse:7.97412	val-rmse:42.1225	train-MAPE:0.300523	val-MAPE:0.937925
# [510]	train-rmse:7.97063	val-rmse:42.1209	train-MAPE:0.300327	val-MAPE:0.937884
# [511]	train-rmse:7.96727	val-rmse:42.1207	train-MAPE:0.300068	val-MAPE:0.937721
# [512]	train-rmse:7.96124	val-rmse:42.1041	train-MAPE:0.299827	val-MAPE:0.937602
# [513]	train-rmse:7.9582	val-rmse:42.0995	train-MAPE:0.299597	val-MAPE:0.93756
# [514]	train-rmse:7.95233	val-rmse:42.1204	train-MAPE:0.299047	val-MAPE:0.93724
# [515]	train-rmse:7.94888	val-rmse:42.1356	train-MAPE:0.298382	val-MAPE:0.937209
# [516]	train-rmse:7.94101	val-rmse:42.155	train-MAPE:0.298333	val-MAPE:0.937358
# [517]	train-rmse:7.93867	val-rmse:42.1624	train-MAPE:0.298212	val-MAPE:0.937101
# [518]	train-rmse:7.93435	val-rmse:42.1422	train-MAPE:0.297645	val-MAPE:0.937835
# [519]	train-rmse:7.93148	val-rmse:42.1454	train-MAPE:0.297498	val-MAPE:0.937816
# [520]	train-rmse:7.92778	val-rmse:42.1506	train-MAPE:0.29731	val-MAPE:0.937704
# [521]	train-rmse:7.92404	val-rmse:42.1368	train-MAPE:0.297351	val-MAPE:0.937581
# [522]	train-rmse:7.91625	val-rmse:42.1355	train-MAPE:0.296829	val-MAPE:0.937401
# [523]	train-rmse:7.91134	val-rmse:42.1438	train-MAPE:0.296778	val-MAPE:0.937353
# [524]	train-rmse:7.9068	val-rmse:42.1434	train-MAPE:0.296333	val-MAPE:0.937019
# [525]	train-rmse:7.90522	val-rmse:42.1402	train-MAPE:0.296341	val-MAPE:0.936984
# [526]	train-rmse:7.90121	val-rmse:42.1491	train-MAPE:0.295457	val-MAPE:0.936572
# [527]	train-rmse:7.90016	val-rmse:42.1684	train-MAPE:0.295246	val-MAPE:0.936568
# [528]	train-rmse:7.89503	val-rmse:42.171	train-MAPE:0.295207	val-MAPE:0.936726
# [529]	train-rmse:7.89122	val-rmse:42.1726	train-MAPE:0.294889	val-MAPE:0.936657
# [530]	train-rmse:7.89016	val-rmse:42.1833	train-MAPE:0.294662	val-MAPE:0.936649
# [531]	train-rmse:7.88587	val-rmse:42.1896	train-MAPE:0.294559	val-MAPE:0.936774
# [532]	train-rmse:7.88144	val-rmse:42.1935	train-MAPE:0.293922	val-MAPE:0.93673
# [533]	train-rmse:7.87965	val-rmse:42.1998	train-MAPE:0.294026	val-MAPE:0.936672
# [534]	train-rmse:7.87652	val-rmse:42.1927	train-MAPE:0.294053	val-MAPE:0.936378
# [535]	train-rmse:7.86815	val-rmse:42.2316	train-MAPE:0.293285	val-MAPE:0.936273
# [536]	train-rmse:7.86379	val-rmse:42.2453	train-MAPE:0.293411	val-MAPE:0.936747
# [537]	train-rmse:7.85925	val-rmse:42.2748	train-MAPE:0.293326	val-MAPE:0.937059
# [538]	train-rmse:7.85616	val-rmse:42.2699	train-MAPE:0.29304	val-MAPE:0.936924
# [539]	train-rmse:7.85429	val-rmse:42.2705	train-MAPE:0.292642	val-MAPE:0.93692
# [540]	train-rmse:7.85032	val-rmse:42.2615	train-MAPE:0.292346	val-MAPE:0.9368
# [541]	train-rmse:7.84477	val-rmse:42.267	train-MAPE:0.29147	val-MAPE:0.93685
# [542]	train-rmse:7.8423	val-rmse:42.2428	train-MAPE:0.291602	val-MAPE:0.937004
# [543]	train-rmse:7.83898	val-rmse:42.2427	train-MAPE:0.291576	val-MAPE:0.937133
# [544]	train-rmse:7.8354	val-rmse:42.239	train-MAPE:0.291263	val-MAPE:0.936769
# [545]	train-rmse:7.83056	val-rmse:42.2248	train-MAPE:0.291386	val-MAPE:0.936684
# [546]	train-rmse:7.82452	val-rmse:42.2284	train-MAPE:0.291561	val-MAPE:0.936764
# [547]	train-rmse:7.82065	val-rmse:42.2299	train-MAPE:0.291163	val-MAPE:0.936758
# [548]	train-rmse:7.81442	val-rmse:42.2429	train-MAPE:0.290964	val-MAPE:0.93643
# [549]	train-rmse:7.79953	val-rmse:42.2429	train-MAPE:0.290744	val-MAPE:0.936076
# [550]	train-rmse:7.79436	val-rmse:42.2372	train-MAPE:0.290671	val-MAPE:0.935918
# [551]	train-rmse:7.79089	val-rmse:42.2338	train-MAPE:0.290766	val-MAPE:0.935906
# [552]	train-rmse:7.78511	val-rmse:42.2208	train-MAPE:0.289795	val-MAPE:0.935887
# [553]	train-rmse:7.78203	val-rmse:42.221	train-MAPE:0.28976	val-MAPE:0.935866
# [554]	train-rmse:7.77931	val-rmse:42.2269	train-MAPE:0.289254	val-MAPE:0.935879
# [555]	train-rmse:7.77417	val-rmse:42.2257	train-MAPE:0.288717	val-MAPE:0.935861
# [556]	train-rmse:7.76995	val-rmse:42.2305	train-MAPE:0.288017	val-MAPE:0.935664
# [557]	train-rmse:7.76834	val-rmse:42.2359	train-MAPE:0.287935	val-MAPE:0.935735
# [558]	train-rmse:7.76431	val-rmse:42.248	train-MAPE:0.287438	val-MAPE:0.935782
# [559]	train-rmse:7.75624	val-rmse:42.2432	train-MAPE:0.287443	val-MAPE:0.935697
# [560]	train-rmse:7.75391	val-rmse:42.2519	train-MAPE:0.287567	val-MAPE:0.935843
# [561]	train-rmse:7.75016	val-rmse:42.252	train-MAPE:0.2875	val-MAPE:0.935739
# [562]	train-rmse:7.74843	val-rmse:42.2436	train-MAPE:0.287426	val-MAPE:0.935803
# [563]	train-rmse:7.74837	val-rmse:42.2466	train-MAPE:0.287208	val-MAPE:0.93584
# [564]	train-rmse:7.74531	val-rmse:42.2465	train-MAPE:0.286955	val-MAPE:0.935822
# [565]	train-rmse:7.73983	val-rmse:42.2482	train-MAPE:0.286697	val-MAPE:0.935945
# [566]	train-rmse:7.73784	val-rmse:42.2411	train-MAPE:0.286608	val-MAPE:0.93587
# [567]	train-rmse:7.73361	val-rmse:42.2361	train-MAPE:0.285867	val-MAPE:0.935541
# [568]	train-rmse:7.72968	val-rmse:42.2511	train-MAPE:0.285614	val-MAPE:0.935897
# [569]	train-rmse:7.72755	val-rmse:42.2413	train-MAPE:0.285537	val-MAPE:0.935998
# [570]	train-rmse:7.72472	val-rmse:42.2399	train-MAPE:0.285356	val-MAPE:0.935924
# [571]	train-rmse:7.72372	val-rmse:42.2312	train-MAPE:0.285339	val-MAPE:0.935807
# [572]	train-rmse:7.71872	val-rmse:42.2327	train-MAPE:0.285384	val-MAPE:0.935858
# [573]	train-rmse:7.71422	val-rmse:42.2256	train-MAPE:0.285075	val-MAPE:0.936137
# [574]	train-rmse:7.70814	val-rmse:42.2241	train-MAPE:0.283925	val-MAPE:0.936208
# [575]	train-rmse:7.70625	val-rmse:42.23	train-MAPE:0.283822	val-MAPE:0.936372
# [576]	train-rmse:7.70197	val-rmse:42.2181	train-MAPE:0.283439	val-MAPE:0.936522
# [577]	train-rmse:7.69923	val-rmse:42.2147	train-MAPE:0.283558	val-MAPE:0.936384
# [578]	train-rmse:7.69701	val-rmse:42.2105	train-MAPE:0.283602	val-MAPE:0.936374
# [579]	train-rmse:7.69104	val-rmse:42.2093	train-MAPE:0.282955	val-MAPE:0.935886
# [580]	train-rmse:7.68522	val-rmse:42.2168	train-MAPE:0.282713	val-MAPE:0.935581
# [581]	train-rmse:7.6826	val-rmse:42.2181	train-MAPE:0.282745	val-MAPE:0.935662
# [582]	train-rmse:7.68018	val-rmse:42.2056	train-MAPE:0.282748	val-MAPE:0.935562
# [583]	train-rmse:7.67969	val-rmse:42.2	train-MAPE:0.282926	val-MAPE:0.935737
# [584]	train-rmse:7.67808	val-rmse:42.2081	train-MAPE:0.282809	val-MAPE:0.935783
# [585]	train-rmse:7.67431	val-rmse:42.2146	train-MAPE:0.282782	val-MAPE:0.935822
# [586]	train-rmse:7.67085	val-rmse:42.2392	train-MAPE:0.283422	val-MAPE:0.936006
# [587]	train-rmse:7.66572	val-rmse:42.2509	train-MAPE:0.282979	val-MAPE:0.935925
# [588]	train-rmse:7.65026	val-rmse:42.2416	train-MAPE:0.28251	val-MAPE:0.935732
# [589]	train-rmse:7.64834	val-rmse:42.236	train-MAPE:0.282399	val-MAPE:0.935447
# [590]	train-rmse:7.64659	val-rmse:42.2282	train-MAPE:0.282356	val-MAPE:0.93533
# [591]	train-rmse:7.64027	val-rmse:42.2275	train-MAPE:0.281962	val-MAPE:0.935643
# [592]	train-rmse:7.63701	val-rmse:42.2374	train-MAPE:0.28195	val-MAPE:0.935711
# [593]	train-rmse:7.63225	val-rmse:42.2296	train-MAPE:0.282042	val-MAPE:0.935607
# [594]	train-rmse:7.62615	val-rmse:42.2195	train-MAPE:0.28211	val-MAPE:0.935539
# [595]	train-rmse:7.62381	val-rmse:42.2225	train-MAPE:0.281724	val-MAPE:0.935849
# [596]	train-rmse:7.62294	val-rmse:42.238	train-MAPE:0.28172	val-MAPE:0.935638
# [597]	train-rmse:7.62202	val-rmse:42.2321	train-MAPE:0.281419	val-MAPE:0.935527
# [598]	train-rmse:7.61965	val-rmse:42.2407	train-MAPE:0.281283	val-MAPE:0.935614
# [599]	train-rmse:7.61485	val-rmse:42.225	train-MAPE:0.281189	val-MAPE:0.935695
# [600]	train-rmse:7.6106	val-rmse:42.2214	train-MAPE:0.279975	val-MAPE:0.93465
# [601]	train-rmse:7.60861	val-rmse:42.2237	train-MAPE:0.279888	val-MAPE:0.934873
# [602]	train-rmse:7.60742	val-rmse:42.2237	train-MAPE:0.279699	val-MAPE:0.934747
# [603]	train-rmse:7.60589	val-rmse:42.2172	train-MAPE:0.279665	val-MAPE:0.934654
# [604]	train-rmse:7.60218	val-rmse:42.1997	train-MAPE:0.279191	val-MAPE:0.934488
# [605]	train-rmse:7.59889	val-rmse:42.1728	train-MAPE:0.279339	val-MAPE:0.934568
# ...
# [3802]	train-rmse:5.35116	val-rmse:42.721	train-MAPE:0.174418	val-MAPE:0.93231
# [3803]	train-rmse:5.35104	val-rmse:42.7207	train-MAPE:0.174312	val-MAPE:0.932394
# [3804]	train-rmse:5.35074	val-rmse:42.7389	train-MAPE:0.174348	val-MAPE:0.932334
# [3805]	train-rmse:5.35032	val-rmse:42.7378	train-MAPE:0.174411	val-MAPE:0.931897
# [3806]	train-rmse:5.35028	val-rmse:42.7415	train-MAPE:0.174503	val-MAPE:0.931935
# [3807]	train-rmse:5.34993	val-rmse:42.7455	train-MAPE:0.17434	val-MAPE:0.932058
# [3808]	train-rmse:5.34977	val-rmse:42.7499	train-MAPE:0.174446	val-MAPE:0.932156
# [3809]	train-rmse:5.34958	val-rmse:42.7443	train-MAPE:0.174399	val-MAPE:0.932126
# [3810]	train-rmse:5.34835	val-rmse:42.742	train-MAPE:0.174297	val-MAPE:0.932114
# [3811]	train-rmse:5.34829	val-rmse:42.7311	train-MAPE:0.174527	val-MAPE:0.931917
# [3812]	train-rmse:5.34799	val-rmse:42.7332	train-MAPE:0.174536	val-MAPE:0.931989
# [3813]	train-rmse:5.34807	val-rmse:42.7355	train-MAPE:0.174601	val-MAPE:0.931985
# [3814]	train-rmse:5.34805	val-rmse:42.7425	train-MAPE:0.174654	val-MAPE:0.931994
# [3815]	train-rmse:5.34803	val-rmse:42.7376	train-MAPE:0.174563	val-MAPE:0.931972
# [3816]	train-rmse:5.34768	val-rmse:42.739	train-MAPE:0.174661	val-MAPE:0.932053
# [3817]	train-rmse:5.34779	val-rmse:42.7395	train-MAPE:0.174545	val-MAPE:0.932075
# [3818]	train-rmse:5.34718	val-rmse:42.7365	train-MAPE:0.174485	val-MAPE:0.932036
# [3819]	train-rmse:5.34699	val-rmse:42.7526	train-MAPE:0.174396	val-MAPE:0.932168
# [3820]	train-rmse:5.34708	val-rmse:42.7414	train-MAPE:0.174321	val-MAPE:0.932094
# [3821]	train-rmse:5.34702	val-rmse:42.741	train-MAPE:0.174329	val-MAPE:0.932037
# [3822]	train-rmse:5.34736	val-rmse:42.7418	train-MAPE:0.17438	val-MAPE:0.93206
# [3823]	train-rmse:5.34727	val-rmse:42.7467	train-MAPE:0.174329	val-MAPE:0.932202
# [3824]	train-rmse:5.34725	val-rmse:42.7452	train-MAPE:0.17441	val-MAPE:0.932186
# [3825]	train-rmse:5.34734	val-rmse:42.755	train-MAPE:0.174347	val-MAPE:0.932221
# [3826]	train-rmse:5.34711	val-rmse:42.7572	train-MAPE:0.174539	val-MAPE:0.932174
# [3827]	train-rmse:5.34671	val-rmse:42.7553	train-MAPE:0.174516	val-MAPE:0.932145
# [3828]	train-rmse:5.34653	val-rmse:42.7551	train-MAPE:0.174328	val-MAPE:0.932156
# [3829]	train-rmse:5.34649	val-rmse:42.7637	train-MAPE:0.174236	val-MAPE:0.932189
# [3830]	train-rmse:5.34614	val-rmse:42.7644	train-MAPE:0.174181	val-MAPE:0.93214
# [3831]	train-rmse:5.34605	val-rmse:42.7662	train-MAPE:0.174103	val-MAPE:0.932136
# [3832]	train-rmse:5.34532	val-rmse:42.7641	train-MAPE:0.174214	val-MAPE:0.932115
# [3833]	train-rmse:5.34516	val-rmse:42.7595	train-MAPE:0.174428	val-MAPE:0.932059
# [3834]	train-rmse:5.34481	val-rmse:42.7469	train-MAPE:0.174325	val-MAPE:0.931918
# [3835]	train-rmse:5.34464	val-rmse:42.7547	train-MAPE:0.174213	val-MAPE:0.931986
# [3836]	train-rmse:5.34456	val-rmse:42.7471	train-MAPE:0.17424	val-MAPE:0.931891
# [3837]	train-rmse:5.3446	val-rmse:42.7466	train-MAPE:0.174275	val-MAPE:0.931885
# [3838]	train-rmse:5.34416	val-rmse:42.7402	train-MAPE:0.174442	val-MAPE:0.93186
# [3839]	train-rmse:5.34417	val-rmse:42.7429	train-MAPE:0.174543	val-MAPE:0.931797
# [3840]	train-rmse:5.34379	val-rmse:42.7514	train-MAPE:0.174294	val-MAPE:0.931814
# [3841]	train-rmse:5.34349	val-rmse:42.7538	train-MAPE:0.174329	val-MAPE:0.931839
# [3842]	train-rmse:5.34366	val-rmse:42.7626	train-MAPE:0.174285	val-MAPE:0.931961
# [3843]	train-rmse:5.34283	val-rmse:42.7625	train-MAPE:0.174529	val-MAPE:0.931842
# [3844]	train-rmse:5.34288	val-rmse:42.7667	train-MAPE:0.174652	val-MAPE:0.931904
# [3845]	train-rmse:5.34256	val-rmse:42.7653	train-MAPE:0.174797	val-MAPE:0.931983
# [3846]	train-rmse:5.34277	val-rmse:42.7646	train-MAPE:0.174688	val-MAPE:0.932223
# [3847]	train-rmse:5.34247	val-rmse:42.7601	train-MAPE:0.174588	val-MAPE:0.932173
# [3848]	train-rmse:5.34204	val-rmse:42.7612	train-MAPE:0.17456	val-MAPE:0.932281
# [3849]	train-rmse:5.34188	val-rmse:42.7631	train-MAPE:0.174522	val-MAPE:0.932374
# [3850]	train-rmse:5.3419	val-rmse:42.7761	train-MAPE:0.174524	val-MAPE:0.932465
# [3851]	train-rmse:5.34172	val-rmse:42.7716	train-MAPE:0.174531	val-MAPE:0.932331
# [3852]	train-rmse:5.34143	val-rmse:42.7747	train-MAPE:0.174477	val-MAPE:0.932284
# [3853]	train-rmse:5.34119	val-rmse:42.7751	train-MAPE:0.174503	val-MAPE:0.932295
# [3854]	train-rmse:5.34045	val-rmse:42.7729	train-MAPE:0.174354	val-MAPE:0.932181
# [3855]	train-rmse:5.34035	val-rmse:42.7764	train-MAPE:0.17445	val-MAPE:0.932013
# [3856]	train-rmse:5.34045	val-rmse:42.7782	train-MAPE:0.174309	val-MAPE:0.932114
# [3857]	train-rmse:5.3403	val-rmse:42.7765	train-MAPE:0.17434	val-MAPE:0.932109
# [3858]	train-rmse:5.33978	val-rmse:42.7854	train-MAPE:0.174265	val-MAPE:0.93233
# [3859]	train-rmse:5.33976	val-rmse:42.783	train-MAPE:0.174388	val-MAPE:0.932215
# [3860]	train-rmse:5.33924	val-rmse:42.7793	train-MAPE:0.174281	val-MAPE:0.932119
# [3861]	train-rmse:5.33926	val-rmse:42.779	train-MAPE:0.174218	val-MAPE:0.932088
# [3862]	train-rmse:5.33939	val-rmse:42.7724	train-MAPE:0.174284	val-MAPE:0.932074
# [3863]	train-rmse:5.33802	val-rmse:42.7678	train-MAPE:0.174132	val-MAPE:0.932296
# [3864]	train-rmse:5.33806	val-rmse:42.7711	train-MAPE:0.174198	val-MAPE:0.932382
# [3865]	train-rmse:5.33827	val-rmse:42.7744	train-MAPE:0.173908	val-MAPE:0.932454
# [3866]	train-rmse:5.33833	val-rmse:42.7746	train-MAPE:0.174007	val-MAPE:0.932417
# [3867]	train-rmse:5.33817	val-rmse:42.7733	train-MAPE:0.174027	val-MAPE:0.932365
# [3868]	train-rmse:5.33802	val-rmse:42.7776	train-MAPE:0.174064	val-MAPE:0.932405
# [3869]	train-rmse:5.33784	val-rmse:42.776	train-MAPE:0.174016	val-MAPE:0.932358
# [3870]	train-rmse:5.3377	val-rmse:42.7702	train-MAPE:0.174021	val-MAPE:0.932308
# [3871]	train-rmse:5.33764	val-rmse:42.7711	train-MAPE:0.17402	val-MAPE:0.93214
# [3872]	train-rmse:5.33716	val-rmse:42.7757	train-MAPE:0.173898	val-MAPE:0.932079
# [3873]	train-rmse:5.33718	val-rmse:42.7857	train-MAPE:0.173877	val-MAPE:0.932174
# [3874]	train-rmse:5.33679	val-rmse:42.7898	train-MAPE:0.173771	val-MAPE:0.932226
# [3875]	train-rmse:5.33644	val-rmse:42.7858	train-MAPE:0.17386	val-MAPE:0.932199
# [3876]	train-rmse:5.33628	val-rmse:42.7795	train-MAPE:0.173763	val-MAPE:0.932128
# [3877]	train-rmse:5.3356	val-rmse:42.7694	train-MAPE:0.173639	val-MAPE:0.932069
# [3878]	train-rmse:5.33555	val-rmse:42.7752	train-MAPE:0.173593	val-MAPE:0.932053
# [3879]	train-rmse:5.33544	val-rmse:42.7708	train-MAPE:0.173597	val-MAPE:0.932049
# [3880]	train-rmse:5.33545	val-rmse:42.7706	train-MAPE:0.173602	val-MAPE:0.932046
# [3881]	train-rmse:5.33521	val-rmse:42.7718	train-MAPE:0.173763	val-MAPE:0.932135
# [3882]	train-rmse:5.335	val-rmse:42.7731	train-MAPE:0.173753	val-MAPE:0.932164
# [3883]	train-rmse:5.33492	val-rmse:42.7803	train-MAPE:0.173769	val-MAPE:0.932309
# [3884]	train-rmse:5.33514	val-rmse:42.7774	train-MAPE:0.173681	val-MAPE:0.932287
# [3885]	train-rmse:5.33483	val-rmse:42.7922	train-MAPE:0.173632	val-MAPE:0.932361
# [3886]	train-rmse:5.3351	val-rmse:42.781	train-MAPE:0.173639	val-MAPE:0.932437
# [3887]	train-rmse:5.3346	val-rmse:42.7843	train-MAPE:0.173636	val-MAPE:0.932453
# [3888]	train-rmse:5.33352	val-rmse:42.7772	train-MAPE:0.17371	val-MAPE:0.932421
# [3889]	train-rmse:5.33241	val-rmse:42.779	train-MAPE:0.173728	val-MAPE:0.932499
# [3890]	train-rmse:5.33212	val-rmse:42.8038	train-MAPE:0.173778	val-MAPE:0.932477
# [3891]	train-rmse:5.33195	val-rmse:42.7988	train-MAPE:0.173911	val-MAPE:0.932373
# [3892]	train-rmse:5.33033	val-rmse:42.8013	train-MAPE:0.173795	val-MAPE:0.932302
# [3893]	train-rmse:5.32987	val-rmse:42.8081	train-MAPE:0.17376	val-MAPE:0.932479
# [3894]	train-rmse:5.32984	val-rmse:42.8105	train-MAPE:0.17363	val-MAPE:0.932607
# [3895]	train-rmse:5.32995	val-rmse:42.8146	train-MAPE:0.173554	val-MAPE:0.932612
# [3896]	train-rmse:5.32976	val-rmse:42.8185	train-MAPE:0.173693	val-MAPE:0.932587
# [3897]	train-rmse:5.32949	val-rmse:42.8298	train-MAPE:0.173438	val-MAPE:0.932768
# [3898]	train-rmse:5.32729	val-rmse:42.8273	train-MAPE:0.173519	val-MAPE:0.932604
# [3899]	train-rmse:5.32694	val-rmse:42.8281	train-MAPE:0.173497	val-MAPE:0.93242
# [3900]	train-rmse:5.32676	val-rmse:42.8227	train-MAPE:0.173568	val-MAPE:0.932449
# [3901]	train-rmse:5.3265	val-rmse:42.8466	train-MAPE:0.173454	val-MAPE:0.932563
# [3902]	train-rmse:5.32652	val-rmse:42.8531	train-MAPE:0.173303	val-MAPE:0.932596
# [3903]	train-rmse:5.3263	val-rmse:42.8596	train-MAPE:0.17325	val-MAPE:0.932612
# [3904]	train-rmse:5.32662	val-rmse:42.8728	train-MAPE:0.173368	val-MAPE:0.932754
# [3905]	train-rmse:5.32621	val-rmse:42.8662	train-MAPE:0.173251	val-MAPE:0.932643
# [3906]	train-rmse:5.32599	val-rmse:42.8639	train-MAPE:0.173306	val-MAPE:0.932616
# [3907]	train-rmse:5.32593	val-rmse:42.8594	train-MAPE:0.173256	val-MAPE:0.932622
# [3908]	train-rmse:5.32582	val-rmse:42.8584	train-MAPE:0.172945	val-MAPE:0.932478
# [3909]	train-rmse:5.3255	val-rmse:42.8709	train-MAPE:0.172923	val-MAPE:0.932524
# [3910]	train-rmse:5.32566	val-rmse:42.8763	train-MAPE:0.172953	val-MAPE:0.932486
# [3911]	train-rmse:5.32558	val-rmse:42.8725	train-MAPE:0.172932	val-MAPE:0.932483
# [3912]	train-rmse:5.32553	val-rmse:42.8554	train-MAPE:0.172986	val-MAPE:0.932389
# [3913]	train-rmse:5.3252	val-rmse:42.8597	train-MAPE:0.172979	val-MAPE:0.932507
# [3914]	train-rmse:5.32508	val-rmse:42.8589	train-MAPE:0.172992	val-MAPE:0.932486
# [3915]	train-rmse:5.325	val-rmse:42.8643	train-MAPE:0.172975	val-MAPE:0.93244
# [3916]	train-rmse:5.3248	val-rmse:42.8688	train-MAPE:0.172747	val-MAPE:0.93243
# [3917]	train-rmse:5.32472	val-rmse:42.8667	train-MAPE:0.172833	val-MAPE:0.932455
# [3918]	train-rmse:5.32404	val-rmse:42.8654	train-MAPE:0.172573	val-MAPE:0.932291
# [3919]	train-rmse:5.32361	val-rmse:42.8662	train-MAPE:0.172606	val-MAPE:0.932392
# [3920]	train-rmse:5.32364	val-rmse:42.8768	train-MAPE:0.172636	val-MAPE:0.932414
# [3921]	train-rmse:5.32383	val-rmse:42.8705	train-MAPE:0.172676	val-MAPE:0.932287
# [3922]	train-rmse:5.32384	val-rmse:42.8741	train-MAPE:0.172502	val-MAPE:0.932217
# [3923]	train-rmse:5.32366	val-rmse:42.8769	train-MAPE:0.172576	val-MAPE:0.932233
# [3924]	train-rmse:5.3232	val-rmse:42.8815	train-MAPE:0.172575	val-MAPE:0.932423
# [3925]	train-rmse:5.32295	val-rmse:42.8768	train-MAPE:0.172861	val-MAPE:0.932362
# [3926]	train-rmse:5.32257	val-rmse:42.8652	train-MAPE:0.172878	val-MAPE:0.932455
# [3927]	train-rmse:5.3226	val-rmse:42.8517	train-MAPE:0.172625	val-MAPE:0.932491
# [3928]	train-rmse:5.32217	val-rmse:42.8591	train-MAPE:0.172568	val-MAPE:0.932622
# [3929]	train-rmse:5.32227	val-rmse:42.8591	train-MAPE:0.172561	val-MAPE:0.932611
# [3930]	train-rmse:5.32193	val-rmse:42.8549	train-MAPE:0.172964	val-MAPE:0.932712
# [3931]	train-rmse:5.32201	val-rmse:42.8527	train-MAPE:0.172989	val-MAPE:0.932689
# [3932]	train-rmse:5.32074	val-rmse:42.847	train-MAPE:0.173141	val-MAPE:0.93268
# [3933]	train-rmse:5.32022	val-rmse:42.8528	train-MAPE:0.172895	val-MAPE:0.932638
# [3934]	train-rmse:5.31991	val-rmse:42.8454	train-MAPE:0.172658	val-MAPE:0.932443
# [3935]	train-rmse:5.31999	val-rmse:42.8484	train-MAPE:0.172779	val-MAPE:0.932463
# [3936]	train-rmse:5.31899	val-rmse:42.8497	train-MAPE:0.172721	val-MAPE:0.932504
# [3937]	train-rmse:5.319	val-rmse:42.8494	train-MAPE:0.17283	val-MAPE:0.932563
# [3938]	train-rmse:5.31801	val-rmse:42.8328	train-MAPE:0.172843	val-MAPE:0.932425
# [3939]	train-rmse:5.31801	val-rmse:42.8299	train-MAPE:0.172637	val-MAPE:0.932307
# [3940]	train-rmse:5.3179	val-rmse:42.8197	train-MAPE:0.172705	val-MAPE:0.932067
# [3941]	train-rmse:5.31751	val-rmse:42.821	train-MAPE:0.172653	val-MAPE:0.932071
# [3942]	train-rmse:5.31741	val-rmse:42.8117	train-MAPE:0.172679	val-MAPE:0.931954
# [3943]	train-rmse:5.3172	val-rmse:42.8164	train-MAPE:0.172484	val-MAPE:0.932098
# [3944]	train-rmse:5.31691	val-rmse:42.824	train-MAPE:0.172449	val-MAPE:0.932187
# [3945]	train-rmse:5.31684	val-rmse:42.8236	train-MAPE:0.172522	val-MAPE:0.932195
# [3946]	train-rmse:5.31663	val-rmse:42.8254	train-MAPE:0.172697	val-MAPE:0.932282
# [3947]	train-rmse:5.31686	val-rmse:42.8215	train-MAPE:0.172644	val-MAPE:0.932385
# [3948]	train-rmse:5.31685	val-rmse:42.8234	train-MAPE:0.172684	val-MAPE:0.932418
# [3949]	train-rmse:5.316	val-rmse:42.83	train-MAPE:0.172585	val-MAPE:0.932342
# [3950]	train-rmse:5.31552	val-rmse:42.8281	train-MAPE:0.172606	val-MAPE:0.932346
# [3951]	train-rmse:5.31524	val-rmse:42.8374	train-MAPE:0.172598	val-MAPE:0.932395
# [3952]	train-rmse:5.31531	val-rmse:42.8415	train-MAPE:0.172694	val-MAPE:0.932366
# [3953]	train-rmse:5.31487	val-rmse:42.8343	train-MAPE:0.172808	val-MAPE:0.93237
# [3954]	train-rmse:5.31477	val-rmse:42.8331	train-MAPE:0.172691	val-MAPE:0.932367
# [3955]	train-rmse:5.31452	val-rmse:42.8355	train-MAPE:0.172534	val-MAPE:0.932459
# [3956]	train-rmse:5.31459	val-rmse:42.837	train-MAPE:0.172556	val-MAPE:0.932572
# [3957]	train-rmse:5.31422	val-rmse:42.8213	train-MAPE:0.172529	val-MAPE:0.932517
# [3958]	train-rmse:5.31406	val-rmse:42.8192	train-MAPE:0.172471	val-MAPE:0.932666
# [3959]	train-rmse:5.31316	val-rmse:42.8207	train-MAPE:0.172273	val-MAPE:0.932688
# [3960]	train-rmse:5.31234	val-rmse:42.8025	train-MAPE:0.172245	val-MAPE:0.93239
# [3961]	train-rmse:5.3113	val-rmse:42.8073	train-MAPE:0.172306	val-MAPE:0.932409
# [3962]	train-rmse:5.31109	val-rmse:42.8015	train-MAPE:0.172473	val-MAPE:0.932441
# [3963]	train-rmse:5.31116	val-rmse:42.7995	train-MAPE:0.172754	val-MAPE:0.932348
# [3964]	train-rmse:5.31075	val-rmse:42.8057	train-MAPE:0.172712	val-MAPE:0.932388
# [3965]	train-rmse:5.31064	val-rmse:42.8055	train-MAPE:0.172668	val-MAPE:0.932423
# [3966]	train-rmse:5.31053	val-rmse:42.7925	train-MAPE:0.172806	val-MAPE:0.932263
# [3967]	train-rmse:5.31019	val-rmse:42.799	train-MAPE:0.1727	val-MAPE:0.932372
# [3968]	train-rmse:5.30991	val-rmse:42.7982	train-MAPE:0.172471	val-MAPE:0.932446
# [3969]	train-rmse:5.30981	val-rmse:42.798	train-MAPE:0.1724	val-MAPE:0.932383
# [3970]	train-rmse:5.30949	val-rmse:42.7841	train-MAPE:0.172446	val-MAPE:0.931976
# [3971]	train-rmse:5.3093	val-rmse:42.7806	train-MAPE:0.172013	val-MAPE:0.932004
# [3972]	train-rmse:5.30918	val-rmse:42.7865	train-MAPE:0.172008	val-MAPE:0.932091
# [3973]	train-rmse:5.3091	val-rmse:42.7913	train-MAPE:0.172274	val-MAPE:0.932164
# [3974]	train-rmse:5.30918	val-rmse:42.7968	train-MAPE:0.172258	val-MAPE:0.932213
# [3975]	train-rmse:5.30874	val-rmse:42.809	train-MAPE:0.172	val-MAPE:0.932326
# [3976]	train-rmse:5.30715	val-rmse:42.8133	train-MAPE:0.171784	val-MAPE:0.932352
# [3977]	train-rmse:5.30714	val-rmse:42.8087	train-MAPE:0.172063	val-MAPE:0.932232
# [3978]	train-rmse:5.30694	val-rmse:42.8013	train-MAPE:0.172141	val-MAPE:0.932198
# [3979]	train-rmse:5.30636	val-rmse:42.8014	train-MAPE:0.172213	val-MAPE:0.932247
# [3980]	train-rmse:5.30629	val-rmse:42.7994	train-MAPE:0.172226	val-MAPE:0.932205
# [3981]	train-rmse:5.30645	val-rmse:42.7995	train-MAPE:0.172342	val-MAPE:0.932117
# [3982]	train-rmse:5.3064	val-rmse:42.7941	train-MAPE:0.172506	val-MAPE:0.93174
# [3983]	train-rmse:5.30572	val-rmse:42.7904	train-MAPE:0.172535	val-MAPE:0.931791
# [3984]	train-rmse:5.30519	val-rmse:42.7892	train-MAPE:0.172529	val-MAPE:0.93183
# [3985]	train-rmse:5.30523	val-rmse:42.7884	train-MAPE:0.172372	val-MAPE:0.93193
# [3986]	train-rmse:5.30516	val-rmse:42.7814	train-MAPE:0.172292	val-MAPE:0.931829
# [3987]	train-rmse:5.30514	val-rmse:42.7648	train-MAPE:0.172324	val-MAPE:0.931851
# [3988]	train-rmse:5.30517	val-rmse:42.779	train-MAPE:0.172358	val-MAPE:0.93198
# [3989]	train-rmse:5.30479	val-rmse:42.7729	train-MAPE:0.172336	val-MAPE:0.93194
# [3990]	train-rmse:5.30461	val-rmse:42.7731	train-MAPE:0.172309	val-MAPE:0.931936
# [3991]	train-rmse:5.30465	val-rmse:42.769	train-MAPE:0.172513	val-MAPE:0.931967
# [3992]	train-rmse:5.30478	val-rmse:42.7678	train-MAPE:0.172431	val-MAPE:0.932229
# [3993]	train-rmse:5.30466	val-rmse:42.7677	train-MAPE:0.172615	val-MAPE:0.932249
# [3994]	train-rmse:5.30447	val-rmse:42.7732	train-MAPE:0.172847	val-MAPE:0.932253
# [3995]	train-rmse:5.30479	val-rmse:42.7603	train-MAPE:0.173067	val-MAPE:0.932151
# [3996]	train-rmse:5.30396	val-rmse:42.7596	train-MAPE:0.172926	val-MAPE:0.932382
# [3997]	train-rmse:5.3025	val-rmse:42.7561	train-MAPE:0.17301	val-MAPE:0.932384
# [3998]	train-rmse:5.30248	val-rmse:42.7647	train-MAPE:0.173222	val-MAPE:0.932503
# [3999]	train-rmse:5.30248	val-rmse:42.7584	train-MAPE:0.173223	val-MAPE:0.932566
# best best_ntree_limit 4000

# %%
volume_model.get_fscore()
# Out:
# {'1-0': 1324,
#  '1-1': 1972,
#  '2-0': 1164,
#  '3-0': 1521,
#  '3-1': 1561,
#  'SSD': 771,
#  'hour__0': 730,
#  'hour__1': 59,
#  'hour__10': 369,
#  'hour__11': 789,
#  'hour__12': 292,
#  'hour__13': 613,
#  'hour__14': 586,
#  'hour__15': 329,
#  'hour__16': 477,
#  'hour__17': 575,
#  'hour__18': 397,
#  'hour__19': 237,
#  'hour__2': 49,
#  'hour__20': 199,
#  'hour__21': 142,
#  'hour__22': 78,
#  'hour__23': 102,
#  'hour__3': 50,
#  'hour__4': 57,
#  'hour__5': 160,
#  'hour__6': 318,
#  'hour__7': 521,
#  'hour__8': 471,
#  'hour__9': 720,
#  'minute__0': 1580,
#  'minute__20': 1060,
#  'minute__40': 1509,
#  'pressure': 1059,
#  'rel_humidity': 729,
#  'temperature': 893,
#  'weekday__5': 577,
#  'weekday__6': 595,
#  'wind_direction': 1248,
#  'wind_speed': 1203,
#  'workday__1': 827}

# %% [markdown]
# ### 预测输出

# %%
volume_predict = volume_model.predict(volume_test, ntree_limit=volume_model.best_ntree_limit)

# %%
volume_submission['volume'] = volume_predict
volume_submission.to_csv('/home/godcedric/GitLocal/KDDCUP2017/submission_result/phase1.5/xgboost/独热结果/volume_submission.csv', index=False)
